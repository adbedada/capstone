# %% [markdown]
# ## Spatial Features Vs Urban Footprint Vs Population Size

# %%
import sklearn
import pandas as pd
import numpy as np
import csv
import scipy.stats as stats
from statistics import pstdev
from statistics import mean
from sklearn import preprocessing
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import ElasticNet, Lasso
from sklearn.datasets import make_regression
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from itertools import product
import copy

# %% [markdown]
# ### Read the Features data

# %%
spfeas = pd.read_excel('blz_spfeas_v3.xlsx', sheet_name=0)
spfeas['OBJECTID'] = spfeas['OBJECTID'].astype(int)
spfeas = spfeas.set_index('OBJECTID')
spfeas.head()
# Out:
#           FID            Administra Administ_1               Area Urban_Rura  \
# OBJECTID
# 1           0       Toledo District     BLZ006       Toledo Rural      Rural
# 2           1  Stann Creek District     BLZ005  Stann Creek Rural      Rural
# 3           2                   NaN        NaN                NaN        NaN
# 4           3                   NaN        NaN                NaN        NaN
# 5           4                   NaN        NaN                NaN        NaN
#
#          CTV_2018  ED_2018  Cluster_Nu  fourier_sc31_variance_mean  \
# OBJECTID
# 1           Cayes      217         665                    1.871010
# 2           Cayes      201         602                    2.608672
# 3           Cayes      126           0                    6.380702
# 4           Cayes      122           0                    2.894536
# 5           Cayes      123           0                    4.566548
#
#           fourier_sc31_variance_std  ...  sfs_sc51_std_sum  \
# OBJECTID                             ...
# 1                          4.929879  ...        42799652.0
# 2                          6.141846  ...        92699568.0
# 3                          8.840365  ...        10851945.0
# 4                          6.357571  ...        65703932.0
# 5                          7.459406  ...        44759044.0
#
#           sfs_sc71_max_ratio_of_orthgonal_angles_mean  \
# OBJECTID
# 1                                          140.709890
# 2                                          140.376936
# 3                                          139.219940
# 4                                          139.365071
# 5                                          140.065461
#
#           sfs_sc71_max_ratio_of_orthgonal_angles_std  \
# OBJECTID
# 1                                           1.065200
# 2                                           4.624142
# 3                                           8.347895
# 4                                          12.484677
# 5                                           2.836504
#
#           sfs_sc71_max_ratio_of_orthgonal_angles_sum  sfs_sc31_std_mean  \
# OBJECTID
# 1                                         4286729472           1.193974
# 2                                         7790784512           1.375928
# 3                                          461388384           2.413110
# 4                                         5233991680           1.457598
# 5                                         2403786496           1.953999
#
#           sfs_sc31_std_std  sfs_sc31_std_sum  sfs_sc71_min_line_length_mean  \
# OBJECTID
# 1                 1.408849        36374452.0                  874775.350589
# 2                 1.689124        76362680.0                  824859.818661
# 3                 2.699090         7997279.0                  614737.965726
# 4                 1.841355        54741532.0                  814288.179976
# 5                 2.401075        33534290.0                  692178.805971
#
#           sfs_sc71_min_line_length_std  sfs_sc71_min_line_length_sum
# OBJECTID
# 1                        330970.948840                26650047676400
# 2                        380083.243379                45778923946000
# 3                        486655.097810                 2037301248000
# 4                        388871.179731                30581389787100
# 5                        461589.477238                11879088914400
#
# [5 rows x 440 columns]

# %% [markdown]
# ### Load GHS

# %%
guf = pd.read_csv('blz_ghs.csv')
guf['OBJECTID'] = guf['OBJECTID'].astype(int)
guf = guf.set_index('OBJECTID')
guf.head()
# Out:
#                     Administra Administ_1               Area Urban_Rura  \
# OBJECTID
# 1              Toledo District     BLZ006       Toledo Rural      Rural
# 2         Stann Creek District     BLZ005  Stann Creek Rural      Rural
# 3                          NaN        NaN                NaN        NaN
# 4                          NaN        NaN                NaN        NaN
# 5                          NaN        NaN                NaN        NaN
#
#          CTV_2018  ED_2018  Cluster_Nu     Shape_Leng    Shape_Area  \
# OBJECTID
# 1           Cayes      217         665  294022.358507  2.934572e+09
# 2           Cayes      201         602  431082.304407  5.345558e+09
# 3           Cayes      126           0   69417.179782  3.192064e+08
# 4           Cayes      122           0  247650.430790  3.617347e+09
# 5           Cayes      123           0  240469.134053  1.652992e+09
#
#           ghs_count    ghs_sum  ghs_mean
# OBJECTID
# 1         2191097.0  2191297.0  1.000091
# 2         4016469.0  4019169.0  1.000672
# 3          241847.0   241847.0  1.000000
# 4         2735984.0  2735984.0  1.000000
# 5         1249474.0  1250674.0  1.000960

# %% [markdown]
# ### Merge the two

# %%
spfeas_guf = spfeas.merge(guf, left_on='OBJECTID', right_on="OBJECTID", how='outer')
spfeas_guf = spfeas_guf.round(3)
spfeas_guf.head()
# Out:
#           FID          Administra_x Administ_1_x             Area_x  \
# OBJECTID
# 1           0       Toledo District       BLZ006       Toledo Rural
# 2           1  Stann Creek District       BLZ005  Stann Creek Rural
# 3           2                   NaN          NaN                NaN
# 4           3                   NaN          NaN                NaN
# 5           4                   NaN          NaN                NaN
#
#          Urban_Rura_x CTV_2018_x  ED_2018_x  Cluster_Nu_x  \
# OBJECTID
# 1               Rural      Cayes        217           665
# 2               Rural      Cayes        201           602
# 3                 NaN      Cayes        126             0
# 4                 NaN      Cayes        122             0
# 5                 NaN      Cayes        123             0
#
#           fourier_sc31_variance_mean  fourier_sc31_variance_std  ...  \
# OBJECTID                                                         ...
# 1                              1.871                      4.930  ...
# 2                              2.609                      6.142  ...
# 3                              6.381                      8.840  ...
# 4                              2.895                      6.358  ...
# 5                              4.567                      7.459  ...
#
#                      Area_y  Urban_Rura_y  CTV_2018_y  ED_2018_y  \
# OBJECTID
# 1              Toledo Rural         Rural       Cayes        217
# 2         Stann Creek Rural         Rural       Cayes        201
# 3                       NaN           NaN       Cayes        126
# 4                       NaN           NaN       Cayes        122
# 5                       NaN           NaN       Cayes        123
#
#           Cluster_Nu_y  Shape_Leng    Shape_Area  ghs_count    ghs_sum  \
# OBJECTID
# 1                  665  294022.359  2.934572e+09  2191097.0  2191297.0
# 2                  602  431082.304  5.345558e+09  4016469.0  4019169.0
# 3                    0   69417.180  3.192064e+08   241847.0   241847.0
# 4                    0  247650.431  3.617347e+09  2735984.0  2735984.0
# 5                    0  240469.134  1.652992e+09  1249474.0  1250674.0
#
#           ghs_mean
# OBJECTID
# 1            1.000
# 2            1.001
# 3            1.000
# 4            1.000
# 5            1.001
#
# [5 rows x 452 columns]

# %% [markdown]
# ### Filter Dataset by Builtup Surface.
#
# Select Rows where  builtup is greater than or equal to 10 percent

# %%
spfeas_guf.shape
# Out:
# (723, 452)

# %% [markdown]
# ### Analysis

# %% [markdown]
# Get the list of dependent variables from the DataFrame to store in list y_vars

# %%
y_var = list(spfeas_guf.axes[1])[451]
y_var
# Out:
# 'ghs_mean'

# %% [markdown]
# Get a list of all independent variables from the DataFrame in list all_x

# %%
all_x = list(spfeas_guf.axes[1])[8:440]

#Check
all_x
# Out:
# ['fourier_sc31_variance_mean',
#  'fourier_sc31_variance_std',
#  'fourier_sc31_variance_sum',
#  'fourier_sc71_mean_mean',
#  'fourier_sc71_mean_std',
#  'fourier_sc71_mean_sum',
#  'fourier_sc51_mean_mean',
#  'fourier_sc51_mean_std',
#  'fourier_sc51_mean_sum',
#  'fourier_sc31_mean_mean',
#  'fourier_sc31_mean_std',
#  'fourier_sc31_mean_sum',
#  'fourier_sc51_variance_mean',
#  'fourier_sc51_variance_std',
#  'fourier_sc51_variance_sum',
#  'fourier_sc71_variance_mean',
#  'fourier_sc71_variance_std',
#  'fourier_sc71_variance_sum',
#  'gabor_sc3_filter_5_mean',
#  'gabor_sc3_filter_5_std',
#  'gabor_sc3_filter_5_sum',
#  'gabor_sc3_filter_4_mean',
#  'gabor_sc3_filter_4_std',
#  'gabor_sc3_filter_4_sum',
#  'gabor_sc3_filter_7_mean',
#  'gabor_sc3_filter_7_std',
#  'gabor_sc3_filter_7_sum',
#  'gabor_sc3_filter_6_mean',
#  'gabor_sc3_filter_6_std',
#  'gabor_sc3_filter_6_sum',
#  'gabor_sc3_filter_1_mean',
#  'gabor_sc3_filter_1_std',
#  'gabor_sc3_filter_1_sum',
#  'gabor_sc3_mean_mean',
#  'gabor_sc3_mean_std',
#  'gabor_sc3_mean_sum',
#  'gabor_sc3_filter_3_mean',
#  'gabor_sc3_filter_3_std',
#  'gabor_sc3_filter_3_sum',
#  'gabor_sc3_filter_2_mean',
#  'gabor_sc3_filter_2_std',
#  'gabor_sc3_filter_2_sum',
#  'gabor_sc3_filter_9_mean',
#  'gabor_sc3_filter_9_std',
#  'gabor_sc3_filter_9_sum',
#  'gabor_sc3_filter_13_mean',
#  'gabor_sc3_filter_13_std',
#  'gabor_sc3_filter_13_sum',
#  'gabor_sc3_filter_8_mean',
#  'gabor_sc3_filter_8_std',
#  'gabor_sc3_filter_8_sum',
#  'gabor_sc3_filter_10_mean',
#  'gabor_sc3_filter_10_std',
#  'gabor_sc3_filter_10_sum',
#  'gabor_sc3_variance_mean',
#  'gabor_sc3_variance_std',
#  'gabor_sc3_variance_sum',
#  'gabor_sc3_filter_11_mean',
#  'gabor_sc3_filter_11_std',
#  'gabor_sc3_filter_11_sum',
#  'gabor_sc3_filter_12_mean',
#  'gabor_sc3_filter_12_std',
#  'gabor_sc3_filter_12_sum',
#  'gabor_sc3_filter_14_mean',
#  'gabor_sc3_filter_14_std',
#  'gabor_sc3_filter_14_sum',
#  'gabor_sc5_filter_4_mean',
#  'gabor_sc5_filter_4_std',
#  'gabor_sc5_filter_4_sum',
#  'gabor_sc5_variance_mean',
#  'gabor_sc5_variance_std',
#  'gabor_sc5_variance_sum',
#  'gabor_sc5_mean_mean',
#  'gabor_sc5_mean_std',
#  'gabor_sc5_mean_sum',
#  'gabor_sc5_filter_6_mean',
#  'gabor_sc5_filter_6_std',
#  'gabor_sc5_filter_6_sum',
#  'gabor_sc5_filter_3_mean',
#  'gabor_sc5_filter_3_std',
#  'gabor_sc5_filter_3_sum',
#  'gabor_sc5_filter_9_mean',
#  'gabor_sc5_filter_9_std',
#  'gabor_sc5_filter_9_sum',
#  'gabor_sc5_filter_8_mean',
#  'gabor_sc5_filter_8_std',
#  'gabor_sc5_filter_8_sum',
#  'gabor_sc5_filter_2_mean',
#  'gabor_sc5_filter_2_std',
#  'gabor_sc5_filter_2_sum',
#  'gabor_sc5_filter_13_mean',
#  'gabor_sc5_filter_13_std',
#  'gabor_sc5_filter_13_sum',
#  'gabor_sc5_filter_12_mean',
#  'gabor_sc5_filter_12_std',
#  'gabor_sc5_filter_12_sum',
#  'gabor_sc5_filter_11_mean',
#  'gabor_sc5_filter_11_std',
#  'gabor_sc5_filter_11_sum',
#  'gabor_sc5_filter_10_mean',
#  'gabor_sc5_filter_10_std',
#  'gabor_sc5_filter_10_sum',
#  'gabor_sc5_filter_7_mean',
#  'gabor_sc5_filter_7_std',
#  'gabor_sc5_filter_7_sum',
#  'gabor_sc5_filter_1_mean',
#  'gabor_sc5_filter_1_std',
#  'gabor_sc5_filter_1_sum',
#  'gabor_sc5_filter_5_mean',
#  'gabor_sc5_filter_5_std',
#  'gabor_sc5_filter_5_sum',
#  'gabor_sc5_filter_14_mean',
#  'gabor_sc5_filter_14_std',
#  'gabor_sc5_filter_14_sum',
#  'gabor_sc7_filter_9_mean',
#  'gabor_sc7_filter_9_std',
#  'gabor_sc7_filter_9_sum',
#  'gabor_sc7_mean_mean',
#  'gabor_sc7_mean_std',
#  'gabor_sc7_mean_sum',
#  'gabor_sc7_variance_mean',
#  'gabor_sc7_variance_std',
#  'gabor_sc7_variance_sum',
#  'gabor_sc7_filter_1_mean',
#  'gabor_sc7_filter_1_std',
#  'gabor_sc7_filter_1_sum',
#  'gabor_sc7_filter_5_mean',
#  'gabor_sc7_filter_5_std',
#  'gabor_sc7_filter_5_sum',
#  'gabor_sc7_filter_3_mean',
#  'gabor_sc7_filter_3_std',
#  'gabor_sc7_filter_3_sum',
#  'gabor_sc7_filter_2_mean',
#  'gabor_sc7_filter_2_std',
#  'gabor_sc7_filter_2_sum',
#  'gabor_sc7_filter_11_mean',
#  'gabor_sc7_filter_11_std',
#  'gabor_sc7_filter_11_sum',
#  'gabor_sc7_filter_10_mean',
#  'gabor_sc7_filter_10_std',
#  'gabor_sc7_filter_10_sum',
#  'gabor_sc7_filter_7_mean',
#  'gabor_sc7_filter_7_std',
#  'gabor_sc7_filter_7_sum',
#  'gabor_sc7_filter_4_mean',
#  'gabor_sc7_filter_4_std',
#  'gabor_sc7_filter_4_sum',
#  'gabor_sc7_filter_12_mean',
#  'gabor_sc7_filter_12_std',
#  'gabor_sc7_filter_12_sum',
#  'gabor_sc7_filter_13_mean',
#  'gabor_sc7_filter_13_std',
#  'gabor_sc7_filter_13_sum',
#  'gabor_sc7_filter_14_mean',
#  'gabor_sc7_filter_14_std',
#  'gabor_sc7_filter_14_sum',
#  'gabor_sc7_filter_6_mean',
#  'gabor_sc7_filter_6_std',
#  'gabor_sc7_filter_6_sum',
#  'gabor_sc7_filter_8_mean',
#  'gabor_sc7_filter_8_std',
#  'gabor_sc7_filter_8_sum',
#  'hog_sc7_mean_mean',
#  'hog_sc7_mean_std',
#  'hog_sc7_mean_sum',
#  'hog_sc5_kurtosis_mean',
#  'hog_sc5_kurtosis_std',
#  'hog_sc5_kurtosis_sum',
#  'hog_sc5_skew_mean',
#  'hog_sc5_skew_std',
#  'hog_sc5_skew_sum',
#  'hog_sc7_variance_mean',
#  'hog_sc7_variance_std',
#  'hog_sc7_variance_sum',
#  'hog_sc7_skew_mean',
#  'hog_sc7_skew_std',
#  'hog_sc7_skew_sum',
#  'hog_sc5_mean_mean',
#  'hog_sc5_mean_std',
#  'hog_sc5_mean_sum',
#  'hog_sc3_skew_mean',
#  'hog_sc3_skew_std',
#  'hog_sc3_skew_sum',
#  'hog_sc5_max_mean',
#  'hog_sc5_max_std',
#  'hog_sc5_max_sum',
#  'hog_sc5_variance_mean',
#  'hog_sc5_variance_std',
#  'hog_sc5_variance_sum',
#  'hog_sc7_kurtosis_mean',
#  'hog_sc7_kurtosis_std',
#  'hog_sc7_kurtosis_sum',
#  'hog_sc3_max_mean',
#  'hog_sc3_max_std',
#  'hog_sc3_max_sum',
#  'hog_sc3_variance_mean',
#  'hog_sc3_variance_std',
#  'hog_sc3_variance_sum',
#  'hog_sc3_kurtosis_mean',
#  'hog_sc3_kurtosis_std',
#  'hog_sc3_kurtosis_sum',
#  'hog_sc7_max_mean',
#  'hog_sc7_max_std',
#  'hog_sc7_max_sum',
#  'hog_sc3_mean_mean',
#  'hog_sc3_mean_std',
#  'hog_sc3_mean_sum',
#  'lac_sc3_lac_mean',
#  'lac_sc3_lac_std',
#  'lac_sc3_lac_sum',
#  'lac_sc5_lac_mean',
#  'lac_sc5_lac_std',
#  'lac_sc5_lac_sum',
#  'lac_sc7_lac_mean',
#  'lac_sc7_lac_std',
#  'lac_sc7_lac_sum',
#  'lbpm_sc7_mean_mean',
#  'lbpm_sc7_mean_std',
#  'lbpm_sc7_mean_sum',
#  'lbpm_sc5_variance_mean',
#  'lbpm_sc5_variance_std',
#  'lbpm_sc5_variance_sum',
#  'lbpm_sc3_max_mean',
#  'lbpm_sc3_max_std',
#  'lbpm_sc3_max_sum',
#  'lbpm_sc5_skew_mean',
#  'lbpm_sc5_skew_std',
#  'lbpm_sc5_skew_sum',
#  'lbpm_sc5_mean_mean',
#  'lbpm_sc5_mean_std',
#  'lbpm_sc5_mean_sum',
#  'lbpm_sc3_mean_mean',
#  'lbpm_sc3_mean_std',
#  'lbpm_sc3_mean_sum',
#  'lbpm_sc7_skew_mean',
#  'lbpm_sc7_skew_std',
#  'lbpm_sc7_skew_sum',
#  'lbpm_sc7_kurtosis_mean',
#  'lbpm_sc7_kurtosis_std',
#  'lbpm_sc7_kurtosis_sum',
#  'lbpm_sc7_max_mean',
#  'lbpm_sc7_max_std',
#  'lbpm_sc7_max_sum',
#  'lbpm_sc3_skew_mean',
#  'lbpm_sc3_skew_std',
#  'lbpm_sc3_skew_sum',
#  'lbpm_sc3_kurtosis_mean',
#  'lbpm_sc3_kurtosis_std',
#  'lbpm_sc3_kurtosis_sum',
#  'lbpm_sc5_max_mean',
#  'lbpm_sc5_max_std',
#  'lbpm_sc5_max_sum',
#  'lbpm_sc7_variance_mean',
#  'lbpm_sc7_variance_std',
#  'lbpm_sc7_variance_sum',
#  'lbpm_sc5_kurtosis_mean',
#  'lbpm_sc5_kurtosis_std',
#  'lbpm_sc5_kurtosis_sum',
#  'lbpm_sc3_variance_mean',
#  'lbpm_sc3_variance_std',
#  'lbpm_sc3_variance_sum',
#  'lsr_sc71_line_contrast_mean',
#  'lsr_sc71_line_contrast_std',
#  'lsr_sc71_line_contrast_sum',
#  'lsr_sc71_line_length_mean',
#  'lsr_sc71_line_length_std',
#  'lsr_sc71_line_length_sum',
#  'lsr_sc31_line_mean_mean',
#  'lsr_sc31_line_mean_std',
#  'lsr_sc31_line_mean_sum',
#  'lsr_sc51_line_length_mean',
#  'lsr_sc51_line_length_std',
#  'lsr_sc51_line_length_sum',
#  'lsr_sc71_line_mean_mean',
#  'lsr_sc71_line_mean_std',
#  'lsr_sc71_line_mean_sum',
#  'lsr_sc31_line_contrast_mean',
#  'lsr_sc31_line_contrast_std',
#  'lsr_sc31_line_contrast_sum',
#  'lsr_sc31_line_length_mean',
#  'lsr_sc31_line_length_std',
#  'lsr_sc31_line_length_sum',
#  'lsr_sc51_line_contrast_mean',
#  'lsr_sc51_line_contrast_std',
#  'lsr_sc51_line_contrast_sum',
#  'lsr_sc51_line_mean_mean',
#  'lsr_sc51_line_mean_std',
#  'lsr_sc51_line_mean_sum',
#  'mean_sc3_mean_mean',
#  'mean_sc3_mean_std',
#  'mean_sc3_mean_sum',
#  'mean_sc7_variance_mean',
#  'mean_sc7_variance_std',
#  'mean_sc7_variance_sum',
#  'mean_sc3_variance_mean',
#  'mean_sc3_variance_std',
#  'mean_sc3_variance_sum',
#  'mean_sc7_mean_mean',
#  'mean_sc7_mean_std',
#  'mean_sc7_mean_sum',
#  'mean_sc5_variance_mean',
#  'mean_sc5_variance_std',
#  'mean_sc5_variance_sum',
#  'mean_sc5_mean_mean',
#  'mean_sc5_mean_std',
#  'mean_sc5_mean_sum',
#  'ndvi_sc3_variance_mean',
#  'ndvi_sc3_variance_std',
#  'ndvi_sc3_variance_sum',
#  'ndvi_sc3_mean_mean',
#  'ndvi_sc3_mean_std',
#  'ndvi_sc3_mean_sum',
#  'ndvi_sc7_mean_mean',
#  'ndvi_sc7_mean_std',
#  'ndvi_sc7_mean_sum',
#  'ndvi_sc7_variance_mean',
#  'ndvi_sc7_variance_std',
#  'ndvi_sc7_variance_sum',
#  'ndvi_sc5_variance_mean',
#  'ndvi_sc5_variance_std',
#  'ndvi_sc5_variance_sum',
#  'ndvi_sc5_mean_mean',
#  'ndvi_sc5_mean_std',
#  'ndvi_sc5_mean_sum',
#  'orb_sc71_skew_mean',
#  'orb_sc71_skew_std',
#  'orb_sc71_skew_sum',
#  'orb_sc71_mean_mean',
#  'orb_sc71_mean_std',
#  'orb_sc71_mean_sum',
#  'orb_sc31_max_mean',
#  'orb_sc31_max_std',
#  'orb_sc31_max_sum',
#  'orb_sc71_variance_mean',
#  'orb_sc71_variance_std',
#  'orb_sc71_variance_sum',
#  'orb_sc51_skew_mean',
#  'orb_sc51_skew_std',
#  'orb_sc51_skew_sum',
#  'orb_sc31_variance_mean',
#  'orb_sc31_variance_std',
#  'orb_sc31_variance_sum',
#  'orb_sc31_mean_mean',
#  'orb_sc31_mean_std',
#  'orb_sc31_mean_sum',
#  'orb_sc31_kurtosis_mean',
#  'orb_sc31_kurtosis_std',
#  'orb_sc31_kurtosis_sum',
#  'orb_sc31_skew_mean',
#  'orb_sc31_skew_std',
#  'orb_sc31_skew_sum',
#  'orb_sc51_max_mean',
#  'orb_sc51_max_std',
#  'orb_sc51_max_sum',
#  'orb_sc51_mean_mean',
#  'orb_sc51_mean_std',
#  'orb_sc51_mean_sum',
#  'orb_sc51_kurtosis_mean',
#  'orb_sc51_kurtosis_std',
#  'orb_sc51_kurtosis_sum',
#  'orb_sc51_variance_mean',
#  'orb_sc51_variance_std',
#  'orb_sc51_variance_sum',
#  'orb_sc71_kurtosis_mean',
#  'orb_sc71_kurtosis_std',
#  'orb_sc71_kurtosis_sum',
#  'orb_sc71_max_mean',
#  'orb_sc71_max_std',
#  'orb_sc71_max_sum',
#  'pantex_sc5_min_mean',
#  'pantex_sc5_min_std',
#  'pantex_sc5_min_sum',
#  'pantex_sc7_min_mean',
#  'pantex_sc7_min_std',
#  'pantex_sc7_min_sum',
#  'pantex_sc3_min_mean',
#  'pantex_sc3_min_std',
#  'pantex_sc3_min_sum',
#  'sfs_sc31_max_ratio_of_orthgonal_angles_mean',
#  'sfs_sc31_max_ratio_of_orthgonal_angles_std',
#  'sfs_sc31_max_ratio_of_orthgonal_angles_sum',
#  'sfs_sc71_std_mean',
#  'sfs_sc71_std_std',
#  'sfs_sc71_std_sum',
#  'sfs_sc51_min_line_length_mean',
#  'sfs_sc51_min_line_length_std',
#  'sfs_sc51_min_line_length_sum',
#  'sfs_sc51_max_line_length_mean',
#  'sfs_sc51_max_line_length_std',
#  'sfs_sc51_max_line_length_sum',
#  'sfs_sc31_mean_mean',
#  'sfs_sc31_mean_std',
#  'sfs_sc31_mean_sum',
#  'sfs_sc71_max_line_length_mean',
#  'sfs_sc71_max_line_length_std',
#  'sfs_sc71_max_line_length_sum',
#  'sfs_sc71_mean_mean',
#  'sfs_sc71_mean_std',
#  'sfs_sc71_mean_sum',
#  'sfs_sc31_min_line_length_mean',
#  'sfs_sc31_min_line_length_std',
#  'sfs_sc31_min_line_length_sum',
#  'sfs_sc71_w_mean_mean',
#  'sfs_sc71_w_mean_std',
#  'sfs_sc71_w_mean_sum',
#  'sfs_sc51_mean_mean',
#  'sfs_sc51_mean_std',
#  'sfs_sc51_mean_sum',
#  'sfs_sc31_w_mean_mean',
#  'sfs_sc31_w_mean_std',
#  'sfs_sc31_w_mean_sum',
#  'sfs_sc51_max_ratio_of_orthgonal_angles_mean',
#  'sfs_sc51_max_ratio_of_orthgonal_angles_std',
#  'sfs_sc51_max_ratio_of_orthgonal_angles_sum',
#  'sfs_sc31_max_line_length_mean',
#  'sfs_sc31_max_line_length_std',
#  'sfs_sc31_max_line_length_sum',
#  'sfs_sc51_w_mean_mean',
#  'sfs_sc51_w_mean_std',
#  'sfs_sc51_w_mean_sum',
#  'sfs_sc51_std_mean',
#  'sfs_sc51_std_std',
#  'sfs_sc51_std_sum',
#  'sfs_sc71_max_ratio_of_orthgonal_angles_mean',
#  'sfs_sc71_max_ratio_of_orthgonal_angles_std',
#  'sfs_sc71_max_ratio_of_orthgonal_angles_sum',
#  'sfs_sc31_std_mean',
#  'sfs_sc31_std_std',
#  'sfs_sc31_std_sum',
#  'sfs_sc71_min_line_length_mean',
#  'sfs_sc71_min_line_length_std',
#  'sfs_sc71_min_line_length_sum']

# %% [markdown]
# ### Compute Coorelation of features with population density

# %% [markdown]
# Store all features with the least correlation (stat. significance (p < 0.05))

# %% [markdown]
# The Pearson correlation coefficient **measures the linear relationship
# between two datasets.** Strictly speaking, Pearson's correlation requires
# that each dataset be **normally distributed, and not necessarily zero-mean.**
#
# Like other correlation coefficients, this one varies between -1 and +1
# with 0 implying no correlation. Correlations of -1 or +1 imply an exact
# linear relationship. Positive correlations imply that as x increases, so
# does y. Negative correlations imply that as x increases, y decreases.
#
# The p-value roughly indicates **the probability of an uncorrelated system**
# producing datasets that have a Pearson correlation at least as extreme
# as the one computed from these datasets.
#
# ***The p-values are not entirely
# reliable but are probably reasonable for datasets larger than 500 or so.***

# %%
spfeas_guf[y_var] = spfeas_guf[y_var].fillna(0)
spfeas_guf[y_var].isnull().values.any()
# Out:
# False

# %%
y_dict = {}
x = []

for x_var in all_x:
    
    #Calculate the Pearson statistics, 
    # returns the Pearson value and p value
    
    p = stats.skew(spfeas_guf[x_var])
    
    #print(y_var, x_var, p)
    # print back for mike
    #print (y_var + " , " + x_var + " , " +  p)

# %%
y_dict = {}
x = []

for x_var in all_x:
    
    #Calculate the Pearson statistics, 
    # returns the Pearson value and p value
    
    p = stats.pearsonr(spfeas_guf[x_var],spfeas_guf[y_var])
    
    # print back for mike
    #print (y_var + " , " + x_var + " , " +  str(p[0]) + " , " + str(p[1]))
    
    #If p < 0.05 append to list x
    if p[1] < 0.05:
        x.append([x_var,abs(p[0])])

#List x is made into a DataFrame 
# which is sorted by the absolute values of the Pearson values
x_df = pd.DataFrame(x,columns=["x_var","abs_r2"]).sort_values("abs_r2",ascending=False)


#The dependent variable dictionary is given an entry 
# where the key is the name of the dependent variable
# and the value is a list of top 200 most significant values

y_dict[y_var] = list(x_df["x_var"][0:294])
#y_dict[y_var]
#Print out each dependent variable and 
#the number of x values that remain to check completion

# %%
x_df.head(15)
# Out:
#                         x_var    abs_r2
# 135  gabor_sc7_filter_11_mean  0.746377
# 114   gabor_sc7_filter_9_mean  0.745728
# 81    gabor_sc5_filter_9_mean  0.744895
# 150  gabor_sc7_filter_13_mean  0.744810
# 96   gabor_sc5_filter_11_mean  0.744652
# 102   gabor_sc5_filter_7_mean  0.744583
# 141   gabor_sc7_filter_7_mean  0.744513
# 126   gabor_sc7_filter_5_mean  0.744480
# 108   gabor_sc5_filter_5_mean  0.744463
# 296        mean_sc7_mean_mean  0.744133
# 78    gabor_sc5_filter_3_mean  0.744124
# 129   gabor_sc7_filter_3_mean  0.744122
# 90   gabor_sc5_filter_13_mean  0.744071
# 105   gabor_sc5_filter_1_mean  0.743564
# 72        gabor_sc5_mean_mean  0.743086

# %%
#check 

for key in y_dict.keys():
    print(key,len(y_dict[key]))
# Out:
# ghs_mean 294

# %% [markdown]
# ### Correlation Significance

# %% [markdown]
# For each dependent variable y in the list of all dependent values, calibrate the model.
# Add new key to the output dictionary where y is the dependent variable curently being processed and the values are empty for now

# %%
#Initialize the output dictionary, Y_D, 
# with each key being a dependent variable and the values being the results of the analyses

Y_D = {}

Y_D[y_var]={}

#Dictionary Models is used to store each result object for later use if needed

Models ={}

#Get independent variables from the variable dictionary and store in list x_vars
x_vars = y_dict[y_var]


vars_df = pd.DataFrame()

vars_df[y_var] = spfeas_guf[y_var]


for x in x_vars:
    vars_df[x] = spfeas_guf[x]

# %%
stats.describe(vars_df['ghs_mean'])
# Out:
# DescribeResult(nobs=723, minmax=(1.0, 101.0), mean=16.570911479944677, variance=638.4296127262253, skewness=1.630291157307923, kurtosis=1.452901986170958)

# %% [markdown]
# ### Scale/Normalize Data

# %%
#minmax_scaler = preprocessing.MinMaxScaler()
standard_scaler = preprocessing.StandardScaler()

names = vars_df.columns
scaled_df = standard_scaler.fit_transform(vars_df)
scaled_df = pd.DataFrame(scaled_df, columns=names)
scaled_df.head()
# Out:
#    ghs_mean  gabor_sc7_filter_11_mean  gabor_sc7_filter_9_mean  \
# 0 -0.616677                 -3.287058                -3.272931
# 1 -0.616638                 -3.174185                -3.159913
# 2 -0.616677                 -2.307744                -2.298957
# 3 -0.616677                 -3.135207                -3.120357
# 4 -0.616638                 -2.695897                -2.685640
#
#    gabor_sc5_filter_9_mean  gabor_sc7_filter_13_mean  \
# 0                -3.272570                 -3.292668
# 1                -3.160689                 -3.179829
# 2                -2.302038                 -2.310518
# 3                -3.121008                 -3.141944
# 4                -2.686909                 -2.698327
#
#    gabor_sc5_filter_11_mean  gabor_sc5_filter_7_mean  gabor_sc7_filter_7_mean  \
# 0                 -3.277816                -3.268348                -3.261398
# 1                 -3.166262                -3.156661                -3.148873
# 2                 -2.305233                -2.299794                -2.292073
# 3                 -3.126785                -3.116751                -3.109489
# 4                 -2.690737                -2.683999                -2.677472
#
#    gabor_sc7_filter_5_mean  gabor_sc5_filter_5_mean  ...  \
# 0                -3.262020                -3.266306  ...
# 1                -3.149904                -3.155004  ...
# 2                -2.294768                -2.299711  ...
# 3                -3.109719                -3.114829  ...
# 4                -2.678936                -2.683016  ...
#
#    gabor_sc5_filter_1_sum  gabor_sc5_mean_sum  gabor_sc7_filter_3_sum  \
# 0                3.562737            3.564356                3.558191
# 1                8.387257            8.388597                8.390193
# 2                0.999228            0.998974                1.000399
# 3                5.996942            5.997545                6.000800
# 4                4.588081            4.588890                4.587880
#
#    gabor_sc5_filter_3_sum  gabor_sc7_filter_1_sum  gabor_sc7_mean_sum  \
# 0                3.561772                3.559917            3.561598
# 1                8.388098                8.391321            8.395969
# 2                0.999845                0.999760            0.999945
# 3                5.995676                6.004782            6.007480
# 4                4.587908                4.590860            4.593834
#
#    gabor_sc5_filter_5_sum  gabor_sc5_filter_7_sum  gabor_sc7_filter_5_sum  \
# 0                3.561764                3.562599                3.557865
# 1                8.391788                8.396010                8.398936
# 2                1.000728                1.001567                1.002172
# 3                5.994968                5.994357                5.999986
# 4                4.589421                4.592238                4.590781
#
#    gabor_sc5_filter_9_sum
# 0                3.565032
# 1                8.399253
# 2                1.002091
# 3                5.993266
# 4                4.595131
#
# [5 rows x 295 columns]

# %%
# #Create a new dataframe for scaled and centered values
# scaled_df = pd.DataFrame()

# #Scale and center the values
# scaled_df[y_var] = scale(pop_count, with_mean=True, with_std=True)


# for x in x_vars:
#     scaled_df[x] = scale(spfeas_world_pop_merged[x], with_mean=True, with_std=True)

# scaled_df = scaled_df.round(3)

# %%
# Y = preprocessing.minmax_scale(vars_df[y_var])
# name='pop_sum'
# Y = pd.DataFrame(Y)
# #X = pd.DataFrame()

# X = scaler.fit_transform(vars_df[x_vars])
# X = pd.DataFrame(X, columns=x_vars)
# Y.head()

# %%
#X.head()

# %% [markdown]
# ### Scale the variables

# %% [markdown]
# ### Set Elastic net's parameters

# %%
enet_result = ElasticNetCV(max_iter=1e8,
                    alphas = [0.0005, 0.001, 0.01, 0.03, 0.05, 0.1],
                    l1_ratio =[.1, .5, .7, .9, .95, .99, 1],
                    verbose= False,
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)

# %%
scaled_df.shape
# Out:
# (723, 295)

# %%
# Fit the mode

# %%
#Fit the model with the scaled data
enet_result.fit(scaled_df[x_vars],scaled_df[y_var])
#Append the model to the Models dictionary
Models[y_var] = enet_result

# %%
enet_result
# Out:
# ElasticNetCV(alphas=[0.0005, 0.001, 0.01, 0.03, 0.05, 0.1], copy_X=True, cv=5,
#        eps=0.001, fit_intercept=False,
#        l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=100000000.0,
#        n_alphas=100, n_jobs=-1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='random',
#        tol=0.0001, verbose=False)

# %%
opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_

#Print update to ensure that the script is progressing properly
print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[x_vars],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.71 Alpha: 0.1 l1_ratio: 0.1

# %% [markdown]
# Record the overall R squared score and optimal alpha
# and l1 ratio values and store them in the output dictionary

# %%
Y_D[y_var]['Total R2'] = enet_result.score(scaled_df[x_vars],scaled_df[y_var])
Y_D[y_var]['Alpha'] = opt_alpha
Y_D[y_var]['l1_ratio'] = opt_l1_ratio

# %% [markdown]
# ### Ten Fold Cross validated regression

# %%
#Create a list R2s to store out of sample R squared values

R2s = []

#Specify the number of trials to run

trials = 10

#Run the number of trials specified in trials, 
#for each trial 66% of the observations are randomly selected to train the model
#Testing is done on the remaining 33% of observations and the R squared values are recorded

for i in range(trials):    
    X_train, X_test, y_train, y_test = train_test_split(scaled_df[x_vars],scaled_df[y_var], test_size=0.34)
    enet_regr = ElasticNetCV(max_iter=1e8,
                    alphas = [opt_alpha],
                    l1_ratio =[opt_l1_ratio],
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)
    enet_regr.fit(X_train,y_train)
    R2s.append(enet_regr.score(X_test,y_test))

#print("Mean R2: {:.2f} StDev: {:.4f}".format(mean(R2s),pstdev(R2s)))
#Record the out of sample R squared values
Y_D[y_var]['Sampling']={'trials':trials,'R2':mean(R2s),'StDev':pstdev(R2s),'R2s':R2s}
coefs = [i for i in zip(list(scaled_df[x_vars].axes[1]),enet_result.coef_)]
remaining = [i for i in coefs if abs(i[1])>0.0]
Y_D[y_var]["Coefficients"]=remaining

# %%
Y_D[y_var]
# Out:
# {'Total R2': 0.710778664093275,
#  'Alpha': 0.1,
#  'l1_ratio': 0.1,
#  'Sampling': {'trials': 10,
#   'R2': 0.662377185247622,
#   'StDev': 0.04678496706453735,
#   'R2s': [0.6239392133515399,
#    0.6228967160355452,
#    0.5539006172362566,
#    0.6855371271698796,
#    0.7074091291921388,
#    0.7222884141687271,
#    0.6846621949379728,
#    0.6743464320931255,
#    0.6755312824449607,
#    0.6732607258460741]},
#  'Coefficients': [('gabor_sc7_filter_11_mean', 0.03440379183303893),
#   ('gabor_sc7_filter_9_mean', 0.033308932123672655),
#   ('gabor_sc5_filter_9_mean', 0.02031859975750532),
#   ('gabor_sc7_filter_13_mean', 0.02508249248240065),
#   ('gabor_sc5_filter_11_mean', 0.01769798573790377),
#   ('gabor_sc5_filter_7_mean', 0.0192078449530281),
#   ('gabor_sc7_filter_7_mean', 0.027352143721408175),
#   ('gabor_sc7_filter_5_mean', 0.025680621409100043),
#   ('gabor_sc5_filter_5_mean', 0.01948136887063428),
#   ('mean_sc7_mean_mean', 0.01676765621732389),
#   ('gabor_sc5_filter_3_mean', 0.019859439229951946),
#   ('gabor_sc7_filter_3_mean', 0.026049236684411493),
#   ('gabor_sc5_filter_13_mean', 0.013734107151667839),
#   ('gabor_sc5_filter_1_mean', 0.020473753919437673),
#   ('gabor_sc5_mean_mean', 0.022003452967779117),
#   ('gabor_sc3_filter_5_mean', 0.007226758792690572),
#   ('gabor_sc3_filter_7_mean', 0.006218389532626691),
#   ('gabor_sc3_filter_9_mean', 0.005472136404622661),
#   ('mean_sc5_mean_mean', 0.007611313529737451),
#   ('gabor_sc3_filter_11_mean', 0.004048961396598685),
#   ('gabor_sc3_filter_3_mean', 0.006806016218517988),
#   ('gabor_sc7_filter_1_mean', 0.028449853875501887),
#   ('gabor_sc3_filter_1_mean', 0.00680396721165731),
#   ('gabor_sc3_filter_13_mean', 0.0017236602490548918),
#   ('gabor_sc3_mean_mean', 0.0064441549552006205),
#   ('gabor_sc7_mean_mean', 0.030657760431163934),
#   ('gabor_sc7_filter_12_mean', 0.04242875880035755),
#   ('gabor_sc7_filter_14_mean', 0.031201234811622437),
#   ('gabor_sc7_filter_10_mean', 0.013812123884699766),
#   ('gabor_sc5_filter_12_mean', 0.0011973115522206181),
#   ('sfs_sc51_max_line_length_std', -0.06544891983713694),
#   ('sfs_sc71_max_line_length_std', -0.039104662326907444),
#   ('ndvi_sc3_mean_mean', -0.08888423216794779),
#   ('ndvi_sc5_mean_mean', -0.08116717633811275),
#   ('ndvi_sc7_mean_mean', -0.07123799508796709),
#   ('pantex_sc3_min_mean', -0.04541920435298383),
#   ('hog_sc7_variance_std', -0.04725529728032444),
#   ('sfs_sc31_max_ratio_of_orthgonal_angles_mean', -0.05588299629273295),
#   ('hog_sc7_skew_mean', 0.004904912537740626),
#   ('hog_sc7_max_std', -0.051544568086801655),
#   ('hog_sc7_variance_mean', -0.014637856554321248),
#   ('mean_sc3_variance_mean', -0.030607085686443995),
#   ('hog_sc5_skew_std', 0.0646892153302165),
#   ('hog_sc7_max_mean', -0.028141947917312487),
#   ('fourier_sc71_mean_mean', 0.03297794964013349),
#   ('sfs_sc31_std_std', 0.01400736741068119),
#   ('orb_sc71_max_mean', 0.0032934877038512203),
#   ('gabor_sc3_filter_2_mean', -0.003972713575697503),
#   ('gabor_sc3_filter_4_mean', -0.005210036314549833),
#   ('lsr_sc71_line_mean_std', -0.026587814413337497),
#   ('orb_sc71_mean_mean', 0.011413095063964217),
#   ('hog_sc7_skew_std', 0.015552272899164384),
#   ('lbpm_sc5_kurtosis_mean', -0.03010811600238805),
#   ('sfs_sc31_mean_mean', 0.04811121463731926),
#   ('lbpm_sc5_skew_mean', -0.020366574620543837),
#   ('orb_sc71_variance_mean', 0.01412887999026956),
#   ('lbpm_sc7_kurtosis_mean', -0.08059523586318984),
#   ('orb_sc31_mean_mean', -0.033515092203476746),
#   ('lbpm_sc7_skew_mean', -0.06478491509116845),
#   ('sfs_sc51_max_line_length_mean', -0.002909686207553115),
#   ('lac_sc7_lac_mean', -0.09697611324536055),
#   ('mean_sc3_variance_std', 0.019146087828376557),
#   ('lsr_sc51_line_contrast_std', -0.020782279212094103),
#   ('gabor_sc3_variance_std', 0.004541635062847838),
#   ('gabor_sc3_filter_10_std', 0.0167084817179918),
#   ('gabor_sc3_filter_8_std', 0.007883221996549204),
#   ('gabor_sc3_filter_12_std', 0.0037133987071537792),
#   ('lsr_sc51_line_length_std', -0.019963431096703493),
#   ('sfs_sc71_max_ratio_of_orthgonal_angles_std', 0.021430180156063978),
#   ('sfs_sc31_mean_std', 0.02562831282330075),
#   ('orb_sc51_variance_std', 0.017623349071818662),
#   ('hog_sc7_kurtosis_std', -0.017156959796529654),
#   ('orb_sc71_skew_mean', -0.0007497900886426912),
#   ('sfs_sc31_max_ratio_of_orthgonal_angles_std', -0.06674873521845791),
#   ('orb_sc71_max_std', 0.009847341816527421),
#   ('orb_sc51_mean_std', 0.012762409456577669),
#   ('orb_sc51_max_std', 0.014377845077592263),
#   ('sfs_sc51_max_ratio_of_orthgonal_angles_std', 0.03358441123132298),
#   ('lbpm_sc3_max_std', 0.017510059973164772),
#   ('lbpm_sc3_max_mean', 0.07101777339131927),
#   ('ndvi_sc7_mean_std', -0.02261498669661326),
#   ('gabor_sc7_mean_std', -0.032424573974508125),
#   ('lsr_sc71_line_contrast_mean', 0.004885506237768364),
#   ('sfs_sc51_std_mean', -0.018205467650541225),
#   ('orb_sc31_kurtosis_mean', 0.017372776210290392),
#   ('gabor_sc7_filter_1_std', -0.0608778412739603),
#   ('gabor_sc7_filter_5_std', -0.005512423158892836),
#   ('lbpm_sc7_kurtosis_std', -0.05641062910290959),
#   ('sfs_sc71_mean_sum', 0.0029486215027293783),
#   ('sfs_sc31_w_mean_sum', 0.0012420652187418938),
#   ('gabor_sc7_filter_3_std', -0.05003657364390703),
#   ('sfs_sc71_max_line_length_sum', 0.0006063408274782812),
#   ('lsr_sc31_line_contrast_mean', -0.02787843988617231)]}

# %%
y_df = coefs = [i for i in zip(list(scaled_df[x_vars].axes[1]),enet_result.coef_)]
y_df
# Out:
# [('gabor_sc7_filter_11_mean', 0.03440379183303893),
#  ('gabor_sc7_filter_9_mean', 0.033308932123672655),
#  ('gabor_sc5_filter_9_mean', 0.02031859975750532),
#  ('gabor_sc7_filter_13_mean', 0.02508249248240065),
#  ('gabor_sc5_filter_11_mean', 0.01769798573790377),
#  ('gabor_sc5_filter_7_mean', 0.0192078449530281),
#  ('gabor_sc7_filter_7_mean', 0.027352143721408175),
#  ('gabor_sc7_filter_5_mean', 0.025680621409100043),
#  ('gabor_sc5_filter_5_mean', 0.01948136887063428),
#  ('mean_sc7_mean_mean', 0.01676765621732389),
#  ('gabor_sc5_filter_3_mean', 0.019859439229951946),
#  ('gabor_sc7_filter_3_mean', 0.026049236684411493),
#  ('gabor_sc5_filter_13_mean', 0.013734107151667839),
#  ('gabor_sc5_filter_1_mean', 0.020473753919437673),
#  ('gabor_sc5_mean_mean', 0.022003452967779117),
#  ('gabor_sc3_filter_5_mean', 0.007226758792690572),
#  ('gabor_sc3_filter_7_mean', 0.006218389532626691),
#  ('gabor_sc3_filter_9_mean', 0.005472136404622661),
#  ('mean_sc5_mean_mean', 0.007611313529737451),
#  ('gabor_sc3_filter_11_mean', 0.004048961396598685),
#  ('gabor_sc3_filter_3_mean', 0.006806016218517988),
#  ('gabor_sc7_filter_1_mean', 0.028449853875501887),
#  ('gabor_sc3_filter_1_mean', 0.00680396721165731),
#  ('gabor_sc3_filter_13_mean', 0.0017236602490548918),
#  ('gabor_sc3_mean_mean', 0.0064441549552006205),
#  ('mean_sc3_mean_mean', 0.0),
#  ('gabor_sc7_mean_mean', 0.030657760431163934),
#  ('gabor_sc7_filter_12_mean', 0.04242875880035755),
#  ('gabor_sc7_filter_14_mean', 0.031201234811622437),
#  ('mean_sc7_variance_mean', 0.0),
#  ('gabor_sc7_filter_10_mean', 0.013812123884699766),
#  ('gabor_sc5_filter_12_mean', 0.0011973115522206181),
#  ('gabor_sc5_filter_14_mean', 0.0),
#  ('gabor_sc5_filter_10_mean', 0.0),
#  ('gabor_sc5_filter_8_mean', 0.0),
#  ('gabor_sc7_filter_4_mean', 0.0),
#  ('gabor_sc5_filter_6_mean', 0.0),
#  ('gabor_sc7_filter_8_mean', 0.0),
#  ('gabor_sc7_filter_6_mean', 0.0),
#  ('gabor_sc5_filter_4_mean', 0.0),
#  ('gabor_sc5_variance_mean', 0.0),
#  ('gabor_sc5_filter_2_mean', 0.0),
#  ('mean_sc5_variance_mean', 0.0),
#  ('gabor_sc7_filter_2_mean', 0.0),
#  ('gabor_sc7_variance_mean', 0.0),
#  ('hog_sc5_kurtosis_mean', 0.0),
#  ('hog_sc7_kurtosis_mean', 0.0),
#  ('ndvi_sc7_variance_mean', -0.0),
#  ('sfs_sc51_max_line_length_std', -0.06544891983713694),
#  ('ndvi_sc5_variance_mean', -0.0),
#  ('sfs_sc51_std_std', -0.0),
#  ('sfs_sc71_max_line_length_std', -0.039104662326907444),
#  ('ndvi_sc3_mean_mean', -0.08888423216794779),
#  ('sfs_sc71_mean_std', -0.0),
#  ('ndvi_sc5_mean_mean', -0.08116717633811275),
#  ('ndvi_sc7_mean_mean', -0.07123799508796709),
#  ('sfs_sc51_mean_std', -0.0),
#  ('pantex_sc5_min_mean', -0.0),
#  ('pantex_sc7_min_mean', -0.0),
#  ('hog_sc3_variance_std', -0.0),
#  ('hog_sc3_mean_std', -0.0),
#  ('hog_sc3_skew_std', -0.0),
#  ('pantex_sc3_min_mean', -0.04541920435298383),
#  ('hog_sc5_skew_mean', -0.0),
#  ('hog_sc5_variance_std', -0.0),
#  ('hog_sc3_kurtosis_mean', 0.0),
#  ('hog_sc7_variance_std', -0.04725529728032444),
#  ('sfs_sc31_max_ratio_of_orthgonal_angles_mean', -0.05588299629273295),
#  ('hog_sc3_max_std', -0.0),
#  ('hog_sc7_skew_mean', 0.004904912537740626),
#  ('lac_sc3_lac_mean', -0.0),
#  ('hog_sc7_max_std', -0.051544568086801655),
#  ('hog_sc5_variance_mean', -0.0),
#  ('sfs_sc31_w_mean_std', -0.0),
#  ('hog_sc5_max_std', -0.0),
#  ('hog_sc7_variance_mean', -0.014637856554321248),
#  ('hog_sc3_skew_mean', 0.0),
#  ('mean_sc3_variance_mean', -0.030607085686443995),
#  ('fourier_sc31_mean_mean', 0.0),
#  ('fourier_sc51_mean_mean', 0.0),
#  ('hog_sc5_skew_std', 0.0646892153302165),
#  ('hog_sc7_max_mean', -0.028141947917312487),
#  ('fourier_sc71_mean_mean', 0.03297794964013349),
#  ('lac_sc3_lac_std', -0.0),
#  ('sfs_sc31_std_std', 0.01400736741068119),
#  ('sfs_sc51_w_mean_std', -0.0),
#  ('gabor_sc3_filter_10_mean', -0.0),
#  ('gabor_sc3_filter_12_mean', -0.0),
#  ('gabor_sc3_filter_8_mean', -0.0),
#  ('gabor_sc3_filter_14_mean', -0.0),
#  ('sfs_sc71_max_line_length_mean', -0.0),
#  ('gabor_sc3_filter_6_mean', -0.0),
#  ('orb_sc71_max_mean', 0.0032934877038512203),
#  ('gabor_sc3_variance_mean', -0.0),
#  ('gabor_sc3_filter_2_mean', -0.003972713575697503),
#  ('gabor_sc3_filter_4_mean', -0.005210036314549833),
#  ('lsr_sc71_line_mean_std', -0.026587814413337497),
#  ('lbpm_sc3_variance_std', 0.0),
#  ('orb_sc71_mean_mean', 0.011413095063964217),
#  ('sfs_sc71_w_mean_std', -0.0),
#  ('sfs_sc51_w_mean_mean', -0.0),
#  ('pantex_sc3_min_std', 0.0),
#  ('sfs_sc31_max_line_length_std', 0.0),
#  ('hog_sc5_max_mean', -0.0),
#  ('fourier_sc31_mean_std', -0.0),
#  ('sfs_sc71_w_mean_mean', -0.0),
#  ('lbpm_sc7_max_std', -0.0),
#  ('lbpm_sc3_kurtosis_mean', -0.0),
#  ('lbpm_sc5_variance_std', 0.0),
#  ('orb_sc51_max_mean', 0.0),
#  ('hog_sc5_mean_std', -0.0),
#  ('lsr_sc51_line_mean_std', -0.0),
#  ('lac_sc5_lac_mean', -0.0),
#  ('lbpm_sc7_variance_std', 0.0),
#  ('orb_sc51_mean_mean', -0.0),
#  ('lbpm_sc3_skew_mean', -0.0),
#  ('fourier_sc51_mean_std', -0.0),
#  ('hog_sc7_skew_std', 0.015552272899164384),
#  ('ndvi_sc7_variance_std', -0.0),
#  ('lbpm_sc3_skew_std', 0.0),
#  ('lbpm_sc5_kurtosis_mean', -0.03010811600238805),
#  ('lac_sc5_lac_std', -0.0),
#  ('lbpm_sc5_max_std', 0.0),
#  ('fourier_sc31_variance_std', 0.0),
#  ('sfs_sc31_w_mean_mean', -0.0),
#  ('orb_sc71_skew_std', -0.0),
#  ('sfs_sc71_max_ratio_of_orthgonal_angles_mean', -0.0),
#  ('orb_sc31_max_mean', -0.0),
#  ('orb_sc71_kurtosis_std', 0.0),
#  ('sfs_sc31_mean_mean', 0.04811121463731926),
#  ('ndvi_sc3_variance_mean', -0.0),
#  ('hog_sc3_mean_mean', 0.0),
#  ('sfs_sc51_max_ratio_of_orthgonal_angles_mean', -0.0),
#  ('lbpm_sc5_skew_mean', -0.020366574620543837),
#  ('orb_sc71_variance_mean', 0.01412887999026956),
#  ('fourier_sc71_mean_std', -0.0),
#  ('lbpm_sc7_mean_std', 0.0),
#  ('fourier_sc51_variance_std', 0.0),
#  ('lbpm_sc7_kurtosis_mean', -0.08059523586318984),
#  ('orb_sc31_mean_mean', -0.033515092203476746),
#  ('sfs_sc71_mean_mean', -0.0),
#  ('lac_sc7_lac_std', 0.0),
#  ('hog_sc7_mean_std', -0.0),
#  ('lbpm_sc7_skew_mean', -0.06478491509116845),
#  ('lbpm_sc3_variance_mean', 0.0),
#  ('fourier_sc71_variance_std', 0.0),
#  ('lbpm_sc5_mean_std', 0.0),
#  ('lbpm_sc5_mean_mean', -0.0),
#  ('orb_sc51_variance_mean', 0.0),
#  ('lbpm_sc5_skew_std', -0.0),
#  ('sfs_sc51_max_line_length_mean', -0.002909686207553115),
#  ('lsr_sc31_line_mean_std', 0.0),
#  ('lac_sc7_lac_mean', -0.09697611324536055),
#  ('mean_sc3_variance_std', 0.019146087828376557),
#  ('lbpm_sc7_skew_std', -0.0),
#  ('pantex_sc5_min_std', -0.0),
#  ('fourier_sc71_variance_mean', -0.0),
#  ('lbpm_sc5_variance_mean', 0.0),
#  ('sfs_sc71_min_line_length_std', 0.0),
#  ('fourier_sc51_variance_mean', -0.0),
#  ('orb_sc51_kurtosis_std', -0.0),
#  ('fourier_sc31_variance_mean', -0.0),
#  ('orb_sc51_skew_std', -0.0),
#  ('orb_sc31_variance_mean', -0.0),
#  ('lsr_sc31_line_contrast_std', -0.0),
#  ('lsr_sc51_line_contrast_std', -0.020782279212094103),
#  ('lbpm_sc7_variance_mean', 0.0),
#  ('gabor_sc3_variance_std', 0.004541635062847838),
#  ('gabor_sc3_filter_2_std', 0.0),
#  ('hog_sc5_kurtosis_std', 0.0),
#  ('gabor_sc3_filter_10_std', 0.0167084817179918),
#  ('gabor_sc3_filter_8_std', 0.007883221996549204),
#  ('gabor_sc3_filter_6_std', 0.0),
#  ('gabor_sc3_filter_14_std', 0.0),
#  ('gabor_sc3_filter_12_std', 0.0037133987071537792),
#  ('gabor_sc3_filter_4_std', 0.0),
#  ('lsr_sc31_line_length_std', -0.0),
#  ('lsr_sc51_line_length_std', -0.019963431096703493),
#  ('hog_sc3_variance_mean', 0.0),
#  ('pantex_sc7_min_std', -0.0),
#  ('lsr_sc71_line_contrast_std', -0.0),
#  ('orb_sc71_variance_std', 0.0),
#  ('sfs_sc71_max_ratio_of_orthgonal_angles_std', 0.021430180156063978),
#  ('mean_sc5_variance_std', 0.0),
#  ('lsr_sc71_line_length_std', -0.0),
#  ('mean_sc3_mean_std', 0.0),
#  ('orb_sc31_mean_std', 0.0),
#  ('sfs_sc31_mean_std', 0.02562831282330075),
#  ('orb_sc51_variance_std', 0.017623349071818662),
#  ('gabor_sc5_variance_std', 0.0),
#  ('sfs_sc31_max_line_length_mean', 0.0),
#  ('gabor_sc5_filter_2_std', 0.0),
#  ('gabor_sc5_filter_14_std', -0.0),
#  ('orb_sc71_kurtosis_mean', -0.0),
#  ('orb_sc31_max_std', -0.0),
#  ('gabor_sc5_filter_10_std', 0.0),
#  ('gabor_sc5_filter_8_std', -0.0),
#  ('gabor_sc5_filter_12_std', -0.0),
#  ('gabor_sc5_filter_4_std', -0.0),
#  ('hog_sc7_kurtosis_std', -0.017156959796529654),
#  ('gabor_sc5_filter_6_std', -0.0),
#  ('orb_sc71_skew_mean', -0.0007497900886426912),
#  ('lbpm_sc7_mean_mean', 0.0),
#  ('gabor_sc3_filter_9_std', 0.0),
#  ('gabor_sc3_filter_7_std', 0.0),
#  ('gabor_sc3_mean_std', 0.0),
#  ('hog_sc3_kurtosis_std', -0.0),
#  ('gabor_sc3_filter_11_std', 0.0),
#  ('sfs_sc31_max_ratio_of_orthgonal_angles_std', -0.06674873521845791),
#  ('gabor_sc3_filter_5_std', 0.0),
#  ('gabor_sc3_filter_1_std', 0.0),
#  ('gabor_sc3_filter_13_std', 0.0),
#  ('gabor_sc7_variance_std', 0.0),
#  ('ndvi_sc5_variance_std', -0.0),
#  ('gabor_sc3_filter_3_std', 0.0),
#  ('orb_sc71_max_std', 0.009847341816527421),
#  ('orb_sc31_variance_std', 0.0),
#  ('mean_sc7_variance_std', 0.0),
#  ('orb_sc51_mean_std', 0.012762409456577669),
#  ('gabor_sc7_filter_14_std', -0.0),
#  ('orb_sc51_max_std', 0.014377845077592263),
#  ('gabor_sc7_filter_2_std', 0.0),
#  ('gabor_sc7_filter_10_std', -0.0),
#  ('gabor_sc7_filter_12_std', -0.0),
#  ('gabor_sc7_filter_8_std', -0.0),
#  ('lbpm_sc3_mean_mean', -0.0),
#  ('sfs_sc51_max_ratio_of_orthgonal_angles_std', 0.03358441123132298),
#  ('sfs_sc71_min_line_length_mean', -0.0),
#  ('gabor_sc7_filter_6_std', -0.0),
#  ('lbpm_sc3_max_std', 0.017510059973164772),
#  ('lbpm_sc3_max_mean', 0.07101777339131927),
#  ('gabor_sc7_filter_4_std', -0.0),
#  ('hog_sc5_mean_mean', 0.0),
#  ('mean_sc5_mean_std', -0.0),
#  ('orb_sc31_skew_mean', 0.0),
#  ('gabor_sc5_filter_7_std', -0.0),
#  ('gabor_sc7_filter_7_std', -0.0),
#  ('gabor_sc5_mean_std', -0.0),
#  ('gabor_sc5_filter_9_std', 0.0),
#  ('ndvi_sc7_mean_std', -0.02261498669661326),
#  ('gabor_sc7_mean_std', -0.032424573974508125),
#  ('gabor_sc5_filter_13_std', -0.0),
#  ('gabor_sc5_filter_11_std', 0.0),
#  ('gabor_sc7_filter_9_std', 0.0),
#  ('orb_sc71_mean_std', 0.0),
#  ('gabor_sc5_filter_5_std', -0.0),
#  ('lsr_sc71_line_contrast_mean', 0.004885506237768364),
#  ('gabor_sc5_filter_1_std', -0.0),
#  ('sfs_sc51_std_mean', -0.018205467650541225),
#  ('orb_sc31_kurtosis_mean', 0.017372776210290392),
#  ('gabor_sc7_filter_13_std', -0.0),
#  ('lsr_sc51_line_contrast_mean', 0.0),
#  ('gabor_sc5_filter_3_std', -0.0),
#  ('sfs_sc31_min_line_length_std', 0.0),
#  ('gabor_sc7_filter_11_std', 0.0),
#  ('gabor_sc7_filter_1_std', -0.0608778412739603),
#  ('gabor_sc7_filter_5_std', -0.005512423158892836),
#  ('lsr_sc71_line_length_mean', 0.0),
#  ('lbpm_sc7_kurtosis_std', -0.05641062910290959),
#  ('ndvi_sc5_mean_std', -0.0),
#  ('lsr_sc51_line_length_mean', 0.0),
#  ('sfs_sc71_mean_sum', 0.0029486215027293783),
#  ('sfs_sc51_w_mean_sum', 0.0),
#  ('sfs_sc31_w_mean_sum', 0.0012420652187418938),
#  ('sfs_sc71_w_mean_sum', 0.0),
#  ('ndvi_sc3_variance_sum', 0.0),
#  ('sfs_sc51_max_line_length_sum', 0.0),
#  ('gabor_sc7_filter_3_std', -0.05003657364390703),
#  ('sfs_sc71_max_line_length_sum', 0.0006063408274782812),
#  ('pantex_sc3_min_sum', 0.0),
#  ('sfs_sc31_min_line_length_mean', 0.0),
#  ('lsr_sc31_line_contrast_mean', -0.02787843988617231),
#  ('sfs_sc51_min_line_length_std', 0.0),
#  ('pantex_sc5_min_sum', 0.0),
#  ('mean_sc7_mean_std', -0.0),
#  ('pantex_sc7_min_sum', 0.0),
#  ('ndvi_sc3_variance_std', -0.0),
#  ('hog_sc7_kurtosis_sum', 0.0),
#  ('fourier_sc31_variance_sum', 0.0),
#  ('fourier_sc51_variance_sum', 0.0),
#  ('fourier_sc71_variance_sum', 0.0),
#  ('hog_sc5_kurtosis_sum', 0.0),
#  ('sfs_sc51_std_sum', 0.0),
#  ('lbpm_sc7_kurtosis_sum', 0.0),
#  ('gabor_sc5_filter_1_sum', 0.0),
#  ('gabor_sc5_mean_sum', 0.0),
#  ('gabor_sc7_filter_3_sum', 0.0),
#  ('gabor_sc5_filter_3_sum', 0.0),
#  ('gabor_sc7_filter_1_sum', 0.0),
#  ('gabor_sc7_mean_sum', 0.0),
#  ('gabor_sc5_filter_5_sum', 0.0),
#  ('gabor_sc5_filter_7_sum', 0.0),
#  ('gabor_sc7_filter_5_sum', 0.0),
#  ('gabor_sc5_filter_9_sum', 0.0)]
