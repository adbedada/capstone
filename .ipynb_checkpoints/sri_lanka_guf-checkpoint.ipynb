# %%
import sklearn
import pandas as pd
import numpy as np
import csv
import scipy.stats as stats
from statistics import pstdev
from statistics import mean
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from itertools import product
import copy

# %%
df = pd.read_excel('../v2/spfeas_final_all_stats_v2.xlsx', sheet_name=0)

# %%
#Ensure that the GN_Code field is of type int and make it the index
df['gid'] = df['gid'].astype(int)
df = df.set_index('gid')

# %%
df.head()
# Out:
#       fid              gnd_n    gnd_c  fourier_v2_sc31_mean_mean  \
# gid
# 43      0  Karagaskada South  2148065                  69.388822
# 564     1            Panvila  2115070                  59.471181
# 7917    2          Ganepalla  9227135                  50.736799
# 2263    3    Akkaraipattu 11  5236065                  73.662439
# 8       4       Delgasthenna  2109125                  66.871213
#
#       fourier_v2_sc31_mean_std  fourier_v2_sc31_mean_sum  \
# gid
# 43                    3.203212              2.375179e+05
# 564                   7.831063              1.399654e+06
# 7917                  5.697583              3.626159e+06
# 2263                  1.809957              9.745541e+04
# 8                     2.745255              2.654118e+05
#
#       fourier_v2_sc31_variance_mean  fourier_v2_sc31_variance_std  \
# gid
# 43                        18.623078                      0.985125
# 564                       17.069666                      2.198242
# 7917                      14.453749                      2.114334
# 2263                      18.855526                      1.246785
# 8                         18.704186                      1.010429
#
#       fourier_v2_sc31_variance_sum  fourier_v2_sc51_mean_mean  \
# gid
# 43                    6.374680e+04                  78.463793
# 564                   4.017346e+05                  69.620847
# 7917                  1.033009e+06                  60.716923
# 2263                  2.494586e+04                  82.547466
# 8                     7.423691e+04                  75.940020
#
#              ...           sfs_sc71_min_ll_sum  sfs_sc71_roa_mean  \
# gid          ...
# 43           ...                          3933         136.394391
# 564          ...                      40076188         137.910516
# 7917         ...                    7900571136         139.556597
# 2263         ...                          1331         136.077853
# 8            ...                          4809         136.681028
#
#       sfs_sc71_roa_std  sfs_sc71_roa_sum  sfs_sc71_std_mean  sfs_sc71_std_std  \
# gid
# 43            0.938602            466878          16.233955          3.648450
# 564           2.093903           3245724          14.498129          5.118067
# 7917          2.014015           9974110           9.856942          7.202832
# 2263          0.267941            180031          10.558998          4.329045
# 8             1.377590            542487          15.218429          4.465160
#
#       sfs_sc71_std_sum  sfs_sc71_w_mean_mean  sfs_sc71_w_mean_std  \
# gid
# 43        55568.828125              1.228705             0.707158
# 564      341213.468750              2.838843             3.471181
# 7917     704475.625000              3.388618             5.864246
# 2263      13969.554688              0.514668             0.239074
# 8         60401.945312              1.180995             0.868924
#
#       sfs_sc71_w_mean_sum
# gid
# 43            4205.858398
# 564          66812.164062
# 7917        242184.515625
# 2263           680.906372
# 8             4687.369141
#
# [5 rows x 426 columns]

# %%
depvar = pd.read_csv("../srilanka/guf.csv")
pc_blt = depvar['PCNT_built']
pc_blt.shape
# Out:
# (14021,)

# %%
depvar = pd.read_csv("../srilanka/guf.csv")

# %%
depvar.head()
# Out:
#      gid             name     code gnnum      GN_area  PCNT_built  GUF_built  \
# 0   8317      Amuhenkanda  9103141  146A    2827990.0    0.000000        NaN
# 1   8343       Pathberiya  9103143   127    7990630.0    0.003116        NaN
# 2   8034  Karandana South  9109051  143A    6962440.0    0.009336        NaN
# 3   2530     Ninthavur 21  5230105   37F     136328.0    0.950648        NaN
# 4  11485      Hambegamuwa  8230020   149  169392000.0    0.000407        NaN
#
#    stats_min  stats_max  stats_sum  stats_coun  stats_mean  stats_std  \
# 0        NaN        NaN        NaN         0.0         NaN        NaN
# 1      255.0      255.0    63240.0       248.0       255.0        0.0
# 2      255.0      255.0   165750.0       650.0       255.0        0.0
# 3      255.0      255.0   327675.0      1285.0       255.0        0.0
# 4      255.0      255.0   176205.0       691.0       255.0        0.0
#
#    stats_uniq  stats_rang  stats_var  stats_medi  stats_mode
# 0         0.0         NaN        NaN         NaN         0.0
# 1         1.0         0.0        0.0       255.0       255.0
# 2         1.0         0.0        0.0       255.0       255.0
# 3         1.0         0.0        0.0       255.0       255.0
# 4         1.0         0.0        0.0       255.0       255.0

# %%
pop_data = pd.read_csv("../srilanka/LKA_ppp_v2b_2015_UNadj.csv")

# %%
pop_data.head()

# %%
df_p = pop_data['stats_sum']
df_p.shape
# Out:
# (14021,)

# %%
pop_data
# Out:
#          gid                        gnd_n    gnd_c  prov_c  dis_c  dsd_c  \
# 0         43            Karagaskada South  2148065       2     21   2148
# 1        564                      Panvila  2115070       2     21   2115
# 2       7917                    Ganepalla  9227135       9     92   9227
# 3       2263              Akkaraipattu 11  5236065       5     52   5236
# 4          8                 Delgasthenna  2109125       2     21   2109
# 5         61                  Udadelthota  2148020       2     21   2148
# 6       2900                   Santhiveli  5110065       5     51   5110
# 7        631               Nawayalathenna  2112235       2     21   2112
# 8         67                       Galoya  2142005       2     21   2142
# 9         89                Panvilathenna  2142125       2     21   2142
# 10      7919              Garagoda pahala  9227020       9     92   9227
# 11      2298                   Kolavil 01  5239090       5     52   5239
# 12        73                       Haloya  2142010       2     21   2142
# 13      2341                    Kalugolla  5242060       5     52   5242
# 14      2825  Kattankudy division 1 South  5124010       5     51   5124
# 15        74                     Hunugala  2142150       2     21   2142
# 16      2625              Sammanthurai 05  5218045       5     52   5218
# 17      8093                    Julangete  9148195       9     91   9148
# 18      2826        Kattankudy Division 2  5124015       5     51   5124
# 19        91                    Pupuressa  2142160       2     21   2142
# 20      2901                   Thevapuram  5110075       5     51   5110
# 21      2420                Kalmunai  01B  5221075       5     52   5221
# 22        98                     Alugolla  2154090       2     21   2154
# 23       102                      Galpaya  2154015       2     21   2154
# 24      2282             Town Division 04  5236140       5     52   5236
# 25      2958             Araipattai North  5127125       5     51   5127
# 26       112                  Miyanagolla  2154155       2     21   2154
# 27       206                    Wathuwala  2133200       2     21   2133
# 28       121                      Udagama  2154115       2     21   2154
# 29       136                  Banwelgolla  2133380       2     21   2133
# ...      ...                          ...      ...     ...    ...    ...
# 13991  13049                       Elhena  1212310       1     12   1212
# 13992  13298               Atulugama East  1306250       1     13   1306
# 13993  13068               Hapugahagedara  1212040       1     12   1212
# 8      2274.372200    8.008353    2.798243
# 9      1125.583167    2.849578    1.291164
# 10     2643.005122   17.979627    6.120455
# 11     1584.133856   29.335812   16.832899
# 12     1439.768222    2.292625    1.207188
# 13      822.351639    1.581445    1.297456
# 14     1873.977489  124.931833   25.368736
# 15     1466.947452    2.347116    0.919148
# 16      845.941910   84.594191   12.960926
# 17     2363.398944    2.813570    1.615364
# 18     2115.832336  302.261762   24.301644
# 19     5049.192916    2.224314    1.484054
# 20     2008.801172    6.543326    6.125935
# 21      599.232992   19.974433    5.097390
# 22     1678.624347    2.840312    1.411021
# 23     2542.493476    4.682308    2.418503
# 24     1319.293068   47.117610    7.232633
# 25      653.994917   32.699746   10.146486
# 26     1833.777216    2.575530    1.310065
# 27     1059.488774   20.374784    7.228716
# 28     2151.376858    5.325190    3.360474
# 29      888.062483   13.875976    5.029764
# ...            ...         ...         ...
# 13991  1717.148450   15.899523    4.350503
# 13992  2287.199005  120.378895   19.996946
# 13993   937.780541    4.361770    1.838486
# 13994  5781.504477   38.036214    7.893114
# 13995  3117.175674  239.782744   38.342473
# 13996   412.504425    1.108883    0.336016
# 13997  4278.390156   33.688111    7.708366
# 13998   859.128559    1.142458    0.583584
# 13999   853.179309    5.540125    1.276815
# 14000   774.322568    3.366620    2.243591
# 14001   998.069116   11.605455    6.942728
# 14002  1371.241542    1.330011    1.297553
# 14003  1667.604728   23.487391    8.275666
# 14004   757.888405   13.067041    5.605815
# 14005  3199.322083  799.830521   80.855512
# 14006  1203.697710   10.466937    4.976267
# 14007  2020.669472   96.222356   24.476567
# 14008  1252.863002    2.717707    2.119916
# 14009  1593.021608    6.080235    3.996524
# 14010  1718.180347   15.205136    6.798505
# 14011  2274.878728    4.434461    2.400862
# 14012  1016.260330   35.043460    9.200838
# 14013   719.292065    8.363861    2.614734
# 14014  2913.969654   32.741232    4.609056
# 14015  1241.634163   37.625278    5.608569
# 14016  1101.466107    3.708640    2.265922
# 14017   635.678753    2.311559    1.413012
# 14018  1851.577012   10.520324    7.238886
# 14019  3119.607159   53.786330    9.764463
# 14020  1740.248753   26.773058    9.540825
#
# [14021 rows x 15 columns]

# %%
pop_density = pop_data['stats_sum']/depvar['GN_area']
# Out:
# /Users/adbe/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py:3140: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   return this.join(other, how=how, return_indexers=return_indexers)

# %%
depvar['GN_area'].shape
# Out:
# (14021,)

# %%
# import matplotlib.pyplot as plt
# plt.subplots(figsize=(15,15))
# x = pc_blt
# y = pop_density
# plt.scatter(x, y)

# z = np.polyfit(x, y, 1)
# p = np.poly1d(z)
# plt.plot(x,p(x),"r--")
# plt.show()

# %%
d = stats.pearsonr(pc_blt,df_p)
d
# Out:
# (0.10943495138291805, 1.2871302063859758e-38)

# %%
depvar.head()
# Out:
#                   name     code gnnum      GN_area  PCNT_built  GUF_built  \
# gid
# 8317       Amuhenkanda  9103141  146A    2827990.0    0.000000        NaN
# 8343        Pathberiya  9103143   127    7990630.0    0.003116        NaN
# 8034   Karandana South  9109051  143A    6962440.0    0.009336        NaN
# 2530      Ninthavur 21  5230105   37F     136328.0    0.950648        NaN
# 11485      Hambegamuwa  8230020   149  169392000.0    0.000407        NaN
#
#        stats_min  stats_max  stats_sum  stats_coun  stats_mean  stats_std  \
# gid
# 8317         NaN        NaN        NaN         0.0         NaN        NaN
# 8343       255.0      255.0    63240.0       248.0       255.0        0.0
# 8034       255.0      255.0   165750.0       650.0       255.0        0.0
# 2530       255.0      255.0   327675.0      1285.0       255.0        0.0
# 11485      255.0      255.0   176205.0       691.0       255.0        0.0
#
#        stats_uniq  stats_rang  stats_var  stats_medi  stats_mode
# gid
# 8317          0.0         NaN        NaN         NaN         0.0
# 8343          1.0         0.0        0.0       255.0       255.0
# 8034          1.0         0.0        0.0       255.0       255.0
# 2530          1.0         0.0        0.0       255.0       255.0
# 11485         1.0         0.0        0.0       255.0       255.0

# %%
depvar['gid'] = depvar['gid'].astype(int)
depvar = depvar.set_index('gid')

# %%
depvar.head()
# Out:
#                   name     code gnnum      GN_area  PCNT_built  GUF_built  \
# gid
# 8317       Amuhenkanda  9103141  146A    2827990.0    0.000000        NaN
# 8343        Pathberiya  9103143   127    7990630.0    0.003116        NaN
# 8034   Karandana South  9109051  143A    6962440.0    0.009336        NaN
# 2530      Ninthavur 21  5230105   37F     136328.0    0.950648        NaN
# 11485      Hambegamuwa  8230020   149  169392000.0    0.000407        NaN
#
#        stats_min  stats_max  stats_sum  stats_coun  stats_mean  stats_std  \
# gid
# 8317         NaN        NaN        NaN         0.0         NaN        NaN
# 8343       255.0      255.0    63240.0       248.0       255.0        0.0
# 8034       255.0      255.0   165750.0       650.0       255.0        0.0
# 2530       255.0      255.0   327675.0      1285.0       255.0        0.0
# 11485      255.0      255.0   176205.0       691.0       255.0        0.0
#
#        stats_uniq  stats_rang  stats_var  stats_medi  stats_mode
# gid
# 8317          0.0         NaN        NaN         NaN         0.0
# 8343          1.0         0.0        0.0       255.0       255.0
# 8034          1.0         0.0        0.0       255.0       255.0
# 2530          1.0         0.0        0.0       255.0       255.0
# 11485         1.0         0.0        0.0       255.0       255.0

# %%
merged = df.merge(depvar, left_on='gnd_c', right_on='code', how='outer')

# %%
df3 = merged.merge(pop_data, left_on='code', right_on='gnd_c', how='outer')

# %%
pop_density = df3['stats_sum_y']/df3['GN_area']

# %%
df3['PCNT_built'].shape
# Out:
# (14047,)

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,15))
y = pop_density
x = df3['PCNT_built']
plt.scatter(x, y)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-199-347cefefa113> in <module>()
#       5 plt.scatter(x, y)
#       6
# ----> 7 z = np.polyfit(x, y, 1)
#       8 p = np.poly1d(z)
#       9 plt.plot(x,p(x),"r--")
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     583     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     584     lhs /= scale
# --> 585     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     586     c = (c.T/scale).T  # broadcast scale coefficients
#     587
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2039         work = zeros((lwork,), t)
#    2040         results = lapack_routine(m, n, n_rhs, a, m, bstar, ldb, s, rcond,
# -> 2041                                  0, work, lwork, iwork, 0)
#    2042     if results['info'] > 0:
#    2043         raise LinAlgError('SVD did not converge in Linear Least Squares')
#
# ValueError: On entry to DGELSD parameter number 4 had an illegal value

# %%
df2 = merged[merged['PCNT_built']>=0.1]

# %%
df4 = df3[df3['PCNT_built']>=0.1]

# %%
pop_density = df4['stats_sum_y']/df4['GN_area']

# %%
df4.shape, pop_density.shape
# Out:
# ((3747, 458), (3747,))

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,15))
y = pop_density
x = df4['PCNT_built']
plt.scatter(x, y)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,15))
x = df2['fourier_v2_sc31_mean_mean']
y = df2['PCNT_built']
plt.scatter(x, y)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-06a395792235> in <module>()
#       4 x = df2['fourier_v2_sc31_mean_mean']
#       5 y = merged['PCNT_built']
# ----> 6 plt.scatter(x, y)
#       7
#       8 z = np.polyfit(x, y, 1)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3376                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3377                          linewidths=linewidths, verts=verts,
# -> 3378                          edgecolors=edgecolors, data=data, **kwargs)
#    3379     finally:
#    3380         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3953         y = np.ma.ravel(y)
#    3954         if x.size != y.size:
# -> 3955             raise ValueError("x and y must be the same size")
#    3956
#    3957         if s is None:
#
# ValueError: x and y must be the same size

# %%
df2.columns
# Out:
# Index(['fid', 'gnd_n', 'gnd_c', 'fourier_v2_sc31_mean_mean',
#        'fourier_v2_sc31_mean_std', 'fourier_v2_sc31_mean_sum',
#        'fourier_v2_sc31_variance_mean', 'fourier_v2_sc31_variance_std',
#        'fourier_v2_sc31_variance_sum', 'fourier_v2_sc51_mean_mean',
#        ...
#        'stats_max', 'stats_sum', 'stats_coun', 'stats_mean', 'stats_std',
#        'stats_uniq', 'stats_rang', 'stats_var', 'stats_medi', 'stats_mode'],
#       dtype='object', length=443)

# %%
#Get the list of dependent variables from the DataFrame to store in list y_vars
y_var = list(df4.axes[1])[430]
#Initialize a dictionary to store independent variables for each dependent variable 
y_dict = {}
#Get a list of all independent variables from the DataFrame in list all_x
all_x = list(df4.axes[1])[3:426]
y_var
# Out:
# 'PCNT_built'

# %%
# Out:
# ['fourier_v2_sc31_mean_mean',
#  'fourier_v2_sc31_mean_std',
#  'fourier_v2_sc31_mean_sum',
#  'fourier_v2_sc31_variance_mean',
#  'fourier_v2_sc31_variance_std',
#  'fourier_v2_sc31_variance_sum',
#  'fourier_v2_sc51_mean_mean',
#  'fourier_v2_sc51_mean_std',
#  'fourier_v2_sc51_mean_sum',
#  'fourier_v2_sc51_variance_mean',
#  'fourier_v2_sc51_variance_std',
#  'fourier_v2_sc51_variance_sum',
#  'fourier_v2_sc71_mean_mean',
#  'fourier_v2_sc71_mean_std',
#  'fourier_v2_sc71_mean_sum',
#  'fourier_v2_sc71_variance_mean',
#  'fourier_v2_sc71_variance_std',
#  'fourier_v2_sc71_variance_sum',
#  'gabor_sc3_filter_1_mean',
#  'gabor_sc3_filter_1_std',
#  'gabor_sc3_filter_1_sum',
#  'gabor_sc3_filter_10_mean',
#  'gabor_sc3_filter_10_std',
#  'gabor_sc3_filter_10_sum',
#  'gabor_sc3_filter_11_mean',
#  'gabor_sc3_filter_11_std',
#  'gabor_sc3_filter_11_sum',
#  'gabor_sc3_filter_12_mean',
#  'gabor_sc3_filter_12_std',
#  'gabor_sc3_filter_12_sum',
#  'gabor_sc3_filter_13_mean',
#  'gabor_sc3_filter_13_std',
#  'gabor_sc3_filter_13_sum',
#  'gabor_sc3_filter_14_mean',
#  'gabor_sc3_filter_14_std',
#  'gabor_sc3_filter_14_sum',
#  'gabor_sc3_filter_2_mean',
#  'gabor_sc3_filter_2_std',
#  'gabor_sc3_filter_2_sum',
#  'gabor_sc3_filter_3_mean',
#  'gabor_sc3_filter_3_std',
#  'gabor_sc3_filter_3_sum',
#  'gabor_sc3_filter_4_mean',
#  'gabor_sc3_filter_4_std',
#  'gabor_sc3_filter_4_sum',
#  'gabor_sc3_filter_5_mean',
#  'gabor_sc3_filter_5_std',
#  'gabor_sc3_filter_5_sum',
#  'gabor_sc3_filter_6_mean',
#  'gabor_sc3_filter_6_std',
#  'gabor_sc3_filter_6_sum',
#  'gabor_sc3_filter_7_mean',
#  'gabor_sc3_filter_7_std',
#  'gabor_sc3_filter_7_sum',
#  'gabor_sc3_filter_8_mean',
#  'gabor_sc3_filter_8_std',
#  'gabor_sc3_filter_8_sum',
#  'gabor_sc3_filter_9_mean',
#  'gabor_sc3_filter_9_std',
#  'gabor_sc3_filter_9_sum',
#  'gabor_sc3_mean_mean',
#  'gabor_sc3_mean_std',
#  'gabor_sc3_mean_sum',
#  'gabor_sc3_variance_mean',
#  'gabor_sc3_variance_std',
#  'gabor_sc3_variance_sum',
#  'gabor_sc5_filter_1_mean',
#  'gabor_sc5_filter_1_std',
#  'gabor_sc5_filter_1_sum',
#  'gabor_sc5_filter_10_mean',
#  'gabor_sc5_filter_10_std',
#  'gabor_sc5_filter_10_sum',
#  'gabor_sc5_filter_11_mean',
#  'gabor_sc5_filter_11_std',
#  'gabor_sc5_filter_11_sum',
#  'gabor_sc5_filter_12_mean',
#  'gabor_sc5_filter_12_std',
#  'gabor_sc5_filter_12_sum',
#  'gabor_sc5_filter_13_mean',
#  'gabor_sc5_filter_13_std',
#  'gabor_sc5_filter_13_sum',
#  'gabor_sc5_filter_14_mean',
#  'gabor_sc5_filter_14_std',
#  'gabor_sc5_filter_14_sum',
#  'gabor_sc5_filter_2_mean',
#  'gabor_sc5_filter_2_std',
#  'gabor_sc5_filter_2_sum',
#  'gabor_sc5_filter_3_mean',
#  'gabor_sc5_filter_3_std',
#  'gabor_sc5_filter_3_sum',
#  'gabor_sc5_filter_4_mean',
#  'gabor_sc5_filter_4_std',
#  'gabor_sc5_filter_4_sum',
#  'gabor_sc5_filter_5_mean',
#  'gabor_sc5_filter_5_std',
#  'gabor_sc5_filter_5_sum',
#  'gabor_sc5_filter_6_mean',
#  'gabor_sc5_filter_6_std',
#  'gabor_sc5_filter_6_sum',
#  'gabor_sc5_filter_7_mean',
#  'gabor_sc5_filter_7_std',
#  'gabor_sc5_filter_7_sum',
#  'gabor_sc5_filter_8_mean',
#  'gabor_sc5_filter_8_std',
#  'gabor_sc5_filter_8_sum',
#  'gabor_sc5_filter_9_mean',
#  'gabor_sc5_filter_9_std',
#  'gabor_sc5_filter_9_sum',
#  'gabor_sc5_mean_mean',
#  'gabor_sc5_mean_std',
#  'gabor_sc5_mean_sum',
#  'gabor_sc5_variance_mean',
#  'gabor_sc5_variance_std',
#  'gabor_sc5_variance_sum',
#  'gabor_sc7_filter_1_mean',
#  'gabor_sc7_filter_1_std',
#  'gabor_sc7_filter_1_sum',
#  'gabor_sc7_filter_10_mean',
#  'gabor_sc7_filter_10_std',
#  'gabor_sc7_filter_10_sum',
#  'gabor_sc7_filter_11_mean',
#  'gabor_sc7_filter_11_std',
#  'gabor_sc7_filter_11_sum',
#  'gabor_sc7_filter_12_mean',
#  'gabor_sc7_filter_12_std',
#  'gabor_sc7_filter_12_sum',
#  'gabor_sc7_filter_13_mean',
#  'gabor_sc7_filter_13_std',
#  'gabor_sc7_filter_13_sum',
#  'gabor_sc7_filter_14_mean',
#  'gabor_sc7_filter_14_std',
#  'gabor_sc7_filter_14_sum',
#  'gabor_sc7_filter_2_mean',
#  'gabor_sc7_filter_2_std',
#  'gabor_sc7_filter_2_sum',
#  'gabor_sc7_filter_3_mean',
#  'gabor_sc7_filter_3_std',
#  'gabor_sc7_filter_3_sum',
#  'gabor_sc7_filter_4_mean',
#  'gabor_sc7_filter_4_std',
#  'gabor_sc7_filter_4_sum',
#  'gabor_sc7_filter_5_mean',
#  'gabor_sc7_filter_5_std',
#  'gabor_sc7_filter_5_sum',
#  'gabor_sc7_filter_6_mean',
#  'gabor_sc7_filter_6_std',
#  'gabor_sc7_filter_6_sum',
#  'gabor_sc7_filter_7_mean',
#  'gabor_sc7_filter_7_std',
#  'gabor_sc7_filter_7_sum',
#  'gabor_sc7_filter_8_mean',
#  'gabor_sc7_filter_8_std',
#  'gabor_sc7_filter_8_sum',
#  'gabor_sc7_filter_9_mean',
#  'gabor_sc7_filter_9_std',
#  'gabor_sc7_filter_9_sum',
#  'gabor_sc7_mean_mean',
#  'gabor_sc7_mean_std',
#  'gabor_sc7_mean_sum',
#  'gabor_sc7_variance_mean',
#  'gabor_sc7_variance_std',
#  'gabor_sc7_variance_sum',
#  'hog_sc3_kurtosis_mean',
#  'hog_sc3_kurtosis_std',
#  'hog_sc3_kurtosis_sum',
#  'hog_sc3_mean_mean',
#  'hog_sc3_mean_std',
#  'hog_sc3_mean_sum',
#  'hog_sc3_skew_mean',
#  'hog_sc3_skew_std',
#  'hog_sc3_skew_sum',
#  'hog_sc3_variance_mean',
#  'hog_sc3_variance_std',
#  'hog_sc3_variance_sum',
#  'hog_sc5_kurtosis_mean',
#  'hog_sc5_kurtosis_std',
#  'hog_sc5_kurtosis_sum',
#  'hog_sc5_mean_mean',
#  'hog_sc5_mean_std',
#  'hog_sc5_mean_sum',
#  'hog_sc5_skew_mean',
#  'hog_sc5_skew_std',
#  'hog_sc5_skew_sum',
#  'hog_sc5_variance_mean',
#  'hog_sc5_variance_std',
#  'hog_sc5_variance_sum',
#  'hog_sc7_kurtosis_mean',
#  'hog_sc7_kurtosis_std',
#  'hog_sc7_kurtosis_sum',
#  'hog_sc7_mean_mean',
#  'hog_sc7_mean_std',
#  'hog_sc7_mean_sum',
#  'hog_sc7_skew_mean',
#  'hog_sc7_skew_std',
#  'hog_sc7_skew_sum',
#  'hog_sc7_variance_mean',
#  'hog_sc7_variance_std',
#  'hog_sc7_variance_sum',
#  'lac_sc3_lac_mean',
#  'lac_sc3_lac_std',
#  'lac_sc3_lac_sum',
#  'lac_sc5_lac_mean',
#  'lac_sc5_lac_std',
#  'lac_sc5_lac_sum',
#  'lac_sc7_lac_mean',
#  'lac_sc7_lac_std',
#  'lac_sc7_lac_sum',
#  'lbpm_sc3_kurtosis_mean',
#  'lbpm_sc3_kurtosis_std',
#  'lbpm_sc3_kurtosis_sum',
#  'lbpm_sc3_max_mean',
#  'lbpm_sc3_max_std',
#  'lbpm_sc3_max_sum',
#  'lbpm_sc3_mean_mean',
#  'lbpm_sc3_mean_std',
#  'lbpm_sc3_mean_sum',
#  'lbpm_sc3_skew_mean',
#  'lbpm_sc3_skew_std',
#  'lbpm_sc3_skew_sum',
#  'lbpm_sc3_variance_mean',
#  'lbpm_sc3_variance_std',
#  'lbpm_sc3_variance_sum',
#  'lbpm_sc5_kurtosis_mean',
#  'lbpm_sc5_kurtosis_std',
#  'lbpm_sc5_kurtosis_sum',
#  'lbpm_sc5_max_mean',
#  'lbpm_sc5_max_std',
#  'lbpm_sc5_max_sum',
#  'lbpm_sc5_mean_mean',
#  'lbpm_sc5_mean_std',
#  'lbpm_sc5_mean_sum',
#  'lbpm_sc5_skew_mean',
#  'lbpm_sc5_skew_std',
#  'lbpm_sc5_skew_sum',
#  'lbpm_sc5_variance_mean',
#  'lbpm_sc5_variance_std',
#  'lbpm_sc5_variance_sum',
#  'lbpm_sc7_kurtosis_mean',
#  'lbpm_sc7_kurtosis_std',
#  'lbpm_sc7_kurtosis_sum',
#  'lbpm_sc7_max_mean',
#  'lbpm_sc7_max_std',
#  'lbpm_sc7_max_sum',
#  'lbpm_sc7_mean_mean',
#  'lbpm_sc7_mean_std',
#  'lbpm_sc7_mean_sum',
#  'lbpm_sc7_skew_mean',
#  'lbpm_sc7_skew_std',
#  'lbpm_sc7_skew_sum',
#  'lbpm_sc7_variance_mean',
#  'lbpm_sc7_variance_std',
#  'lbpm_sc7_variance_sum',
#  'lsr_sc3_line_contrast_mean',
#  'lsr_sc3_line_contrast_std',
#  'lsr_sc3_line_contrast_sum',
#  'lsr_sc3_line_length_mean',
#  'lsr_sc3_line_length_std',
#  'lsr_sc3_line_length_sum',
#  'lsr_sc3_line_mean_mean',
#  'lsr_sc3_line_mean_std',
#  'lsr_sc3_line_mean_sum',
#  'lsr_sc5_line_contrast_mean',
#  'lsr_sc5_line_contrast_std',
#  'lsr_sc5_line_contrast_sum',
#  'lsr_sc5_line_length_mean',
#  'lsr_sc5_line_length_std',
#  'lsr_sc5_line_length_sum',
#  'lsr_sc5_line_mean_mean',
#  'lsr_sc5_line_mean_std',
#  'lsr_sc5_line_mean_sum',
#  'lsr_sc7_line_contrast_mean',
#  'lsr_sc7_line_contrast_std',
#  'lsr_sc7_line_contrast_sum',
#  'lsr_sc7_line_length_mean',
#  'lsr_sc7_line_length_std',
#  'lsr_sc7_line_length_sum',
#  'lsr_sc7_line_mean_mean',
#  'lsr_sc7_line_mean_std',
#  'lsr_sc7_line_mean_sum',
#  'mean_sc3_mean_mean',
#  'mean_sc3_mean_std',
#  'mean_sc3_mean_sum',
#  'mean_sc3_variance_mean',
#  'mean_sc3_variance_std',
#  'mean_sc3_variance_sum',
#  'mean_sc5_mean_mean',
#  'mean_sc5_mean_std',
#  'mean_sc5_mean_sum',
#  'mean_sc5_variance_mean',
#  'mean_sc5_variance_std',
#  'mean_sc5_variance_sum',
#  'mean_sc7_mean_mean',
#  'mean_sc7_mean_std',
#  'mean_sc7_mean_sum',
#  'mean_sc7_variance_mean',
#  'mean_sc7_variance_std',
#  'mean_sc7_variance_sum',
#  'ndvi_sc3_mean_mean',
#  'ndvi_sc3_mean_std',
#  'ndvi_sc3_mean_sum',
#  'ndvi_sc3_variance_mean',
#  'ndvi_sc3_variance_std',
#  'ndvi_sc3_variance_sum',
#  'ndvi_sc5_mean_mean',
#  'ndvi_sc5_mean_std',
#  'ndvi_sc5_mean_sum',
#  'ndvi_sc5_variance_mean',
#  'ndvi_sc5_variance_std',
#  'ndvi_sc5_variance_sum',
#  'ndvi_sc7_mean_mean',
#  'ndvi_sc7_mean_std',
#  'ndvi_sc7_mean_sum',
#  'ndvi_sc7_variance_mean',
#  'ndvi_sc7_variance_std',
#  'ndvi_sc7_variance_sum',
#  'orb_sc31_kurtosis_mean',
#  'orb_sc31_kurtosis_std',
#  'orb_sc31_kurtosis_sum',
#  'orb_sc31_max_mean',
#  'orb_sc31_max_std',
#  'orb_sc31_max_sum',
#  'orb_sc31_mean_mean',
#  'orb_sc31_mean_std',
#  'orb_sc31_mean_sum',
#  'orb_sc31_skew_mean',
#  'orb_sc31_skew_std',
#  'orb_sc31_skew_sum',
#  'orb_sc31_variance_mean',
#  'orb_sc31_variance_std',
#  'orb_sc31_variance_sum',
#  'orb_sc51_kurtosis_mean',
#  'orb_sc51_kurtosis_std',
#  'orb_sc51_kurtosis_sum',
#  'orb_sc51_max_mean',
#  'orb_sc51_max_std',
#  'orb_sc51_max_sum',
#  'orb_sc51_mean_mean',
#  'orb_sc51_mean_std',
#  'orb_sc51_mean_sum',
#  'orb_sc51_skew_mean',
#  'orb_sc51_skew_std',
#  'orb_sc51_skew_sum',
#  'orb_sc51_variance_mean',
#  'orb_sc51_variance_std',
#  'orb_sc51_variance_sum',
#  'orb_sc71_kurtosis_mean',
#  'orb_sc71_kurtosis_std',
#  'orb_sc71_kurtosis_sum',
#  'orb_sc71_max_mean',
#  'orb_sc71_max_std',
#  'orb_sc71_max_sum',
#  'orb_sc71_mean_mean',
#  'orb_sc71_mean_std',
#  'orb_sc71_mean_sum',
#  'orb_sc71_skew_mean',
#  'orb_sc71_skew_std',
#  'orb_sc71_skew_sum',
#  'orb_sc71_variance_mean',
#  'orb_sc71_variance_std',
#  'orb_sc71_variance_sum',
#  'pantex_sc3_min_mean',
#  'pantex_sc3_min_std',
#  'pantex_sc3_min_sum',
#  'pantex_sc5_min_mean',
#  'pantex_sc5_min_std',
#  'pantex_sc5_min_sum',
#  'pantex_sc7_min_mean',
#  'pantex_sc7_min_std',
#  'pantex_sc7_min_sum',
#  'sfs_sc31_max_ll_mean',
#  'sfs_sc31_max_ll_std',
#  'sfs_sc31_max_ll_sum',
#  'sfs_sc31_mean_mean',
#  'sfs_sc31_mean_std',
#  'sfs_sc31_mean_sum',
#  'sfs_sc31_min_ll_mean',
#  'sfs_sc31_min_ll_std',
#  'sfs_sc31_min_ll_sum',
#  'sfs_sc31_roa_mean',
#  'sfs_sc31_roa_std',
#  'sfs_sc31_roa_sum',
#  'sfs_sc31_std_mean',
#  'sfs_sc31_std_std',
#  'sfs_sc31_std_sum',
#  'sfs_sc31_w_mean_mean',
#  'sfs_sc31_w_mean_std',
#  'sfs_sc31_w_mean_sum',
#  'sfs_sc51_max_ll_mean',
#  'sfs_sc51_max_ll_std',
#  'sfs_sc51_max_ll_sum',
#  'sfs_sc51_mean_mean',
#  'sfs_sc51_mean_std',
#  'sfs_sc51_mean_sum',
#  'sfs_sc51_min_ll_mean',
#  'sfs_sc51_min_ll_std',
#  'sfs_sc51_min_ll_sum',
#  'sfs_sc51_roa_mean',
#  'sfs_sc51_roa_std',
#  'sfs_sc51_roa_sum',
#  'sfs_sc51_std_mean',
#  'sfs_sc51_std_std',
#  'sfs_sc51_std_sum',
#  'sfs_sc51_w_mean_mean',
#  'sfs_sc51_w_mean_std',
#  'sfs_sc51_w_mean_sum',
#  'sfs_sc71_max_ll_mean',
#  'sfs_sc71_max_ll_std',
#  'sfs_sc71_max_ll_sum',
#  'sfs_sc71_mean_mean',
#  'sfs_sc71_mean_std',
#  'sfs_sc71_mean_sum',
#  'sfs_sc71_min_ll_mean',
#  'sfs_sc71_min_ll_std',
#  'sfs_sc71_min_ll_sum',
#  'sfs_sc71_roa_mean',
#  'sfs_sc71_roa_std',
#  'sfs_sc71_roa_sum',
#  'sfs_sc71_std_mean',
#  'sfs_sc71_std_std',
#  'sfs_sc71_std_sum',
#  'sfs_sc71_w_mean_mean',
#  'sfs_sc71_w_mean_std',
#  'sfs_sc71_w_mean_sum']

# %%
#Variable x is an empty list that will cotnain all significant (p < 0.05) independent variables
x = []
for x_var in all_x:
    #Calculate the Pearson statistics, returns the Pearson value and p value
    p = stats.pearsonr(df4[x_var],pop_density)
    # print back for mike
    print (y_var + " , " + x_var + " , " +  str(p[0]) + " , " + str(p[1]))
    #If p < 0.05 append to list x
    if p[1] < 0.05:
        x.append([x_var,abs(p[0])])
#List x is made into a DataFrame which is sorted by the absolute values of the Pearson values
x_df = pd.DataFrame(x,columns=["x_var","abs_r2"]).sort_values("abs_r2",ascending=False)
#The dependent variable dictionary is given an entry where the key is the name of the dependent variable
# and the value is a list of top 200 most significant values
y_dict[y_var] = list(x_df["x_var"][0:294])
#Print out each dependent variable and the number of x values that remain to check completion
for key in y_dict.keys():
    print(key,len(y_dict[key]))
# Out:
# PCNT_built , fourier_v2_sc31_mean_mean , 0.47540578100727426 , 1.2415863371862072e-210
# PCNT_built , fourier_v2_sc31_mean_std , -0.3381188266745482 , 7.196401498307723e-101
# PCNT_built , fourier_v2_sc31_mean_sum , -0.3406958438721048 , 1.7621523134425454e-102
# PCNT_built , fourier_v2_sc31_variance_mean , 0.18490584316337433 , 3.5857512685043876e-30
# PCNT_built , fourier_v2_sc31_variance_std , -0.28814616850620045 , 1.4650788705150776e-72
# PCNT_built , fourier_v2_sc31_variance_sum , -0.34265702511628576 , 1.022481406050078e-103
# PCNT_built , fourier_v2_sc51_mean_mean , 0.4612222309329879 , 8.844372068887909e-197
# PCNT_built , fourier_v2_sc51_mean_std , -0.2817255844769248 , 2.59436594925567e-69
# PCNT_built , fourier_v2_sc51_mean_sum , -0.3428666011310433 , 7.533610201847498e-104
# PCNT_built , fourier_v2_sc51_variance_mean , 0.19468211988579237 , 2.5226893960690392e-33
# PCNT_built , fourier_v2_sc51_variance_std , -0.28251625437544153 , 1.0438774798221267e-69
# PCNT_built , fourier_v2_sc51_variance_sum , -0.3430413721849215 , 5.838517529169815e-104
# PCNT_built , fourier_v2_sc71_mean_mean , 0.45167871233185586 , 8.047650460535919e-188
# PCNT_built , fourier_v2_sc71_mean_std , -0.23378924939211962 , 1.0844224528667773e-47
# PCNT_built , fourier_v2_sc71_mean_sum , -0.3438589386865088 , 1.768101157156293e-104
# PCNT_built , fourier_v2_sc71_variance_mean , 0.2046769549315565 , 9.98933093322412e-37
# PCNT_built , fourier_v2_sc71_variance_std , -0.2700699026846597 , 1.240667951052025e-63
# PCNT_built , fourier_v2_sc71_variance_sum , -0.3433147559065152 , 3.9173972519914275e-104
# PCNT_built , gabor_sc3_filter_1_mean , 0.3803818390858566 , 2.7246021919818375e-129
# PCNT_built , gabor_sc3_filter_1_std , 0.02283029550532466 , 0.16234716962757895
# PCNT_built , gabor_sc3_filter_1_sum , -0.325200802358256 , 5.056881129475564e-93
# PCNT_built , gabor_sc3_filter_10_mean , 0.3912227175532337 , 2.696458649415204e-137
# PCNT_built , gabor_sc7_filter_11_mean , 0.38015782684347765 , 3.9584709536794557e-129
# PCNT_built , gabor_sc7_filter_11_std , -0.030853660836919004 , 0.0589646720774214
# PCNT_built , gabor_sc7_filter_11_sum , -0.3253616212362751 , 4.0599505395028785e-93
# PCNT_built , gabor_sc7_filter_12_mean , 0.3892612778462745 , 7.971676716014039e-136
# PCNT_built , gabor_sc7_filter_12_std , -0.023052565709477925 , 0.158295499063508
# PCNT_built , gabor_sc7_filter_12_sum , -0.2940792305151009 , 1.2239487566284893e-75
# PCNT_built , gabor_sc7_filter_13_mean , 0.3815769981693704 , 3.6952150645750475e-130
# PCNT_built , gabor_sc7_filter_13_std , -0.01849694117510893 , 0.2576480654308389
# PCNT_built , gabor_sc7_filter_13_sum , -0.32529846792589145 , 4.425640874559317e-93
# PCNT_built , gabor_sc7_filter_14_mean , 0.3911649733407708 , 2.980133293646426e-137
# PCNT_built , gabor_sc7_filter_14_std , -0.012213925839998583 , 0.45480625301769584
# PCNT_built , gabor_sc7_filter_14_sum , -0.29355906187339903 , 2.293988878862556e-75
# PCNT_built , gabor_sc7_filter_2_mean , 0.3867807712067172 , 5.58739816875934e-134
# PCNT_built , gabor_sc7_filter_2_std , 0.004431798918616268 , 0.7862422969658514
# PCNT_built , gabor_sc7_filter_2_sum , -0.2933595483276645 , 2.917994468078843e-75
# PCNT_built , gabor_sc7_filter_3_mean , 0.37723022179391563 , 5.080833238679835e-127
# PCNT_built , gabor_sc7_filter_3_std , -0.018442674184256196 , 0.259047195280769
# PCNT_built , gabor_sc7_filter_3_sum , -0.3253420724915281 , 4.1698056381015645e-93
# PCNT_built , gabor_sc7_filter_4_mean , 0.38896502929475235 , 1.3268349503825529e-135
# PCNT_built , gabor_sc7_filter_4_std , -0.008406918162203004 , 0.6069388653333254
# PCNT_built , gabor_sc7_filter_4_sum , -0.2939806898726418 , 1.3787692846654893e-75
# PCNT_built , gabor_sc7_filter_5_mean , 0.37707378579903367 , 6.576387735883369e-127
# PCNT_built , gabor_sc7_filter_5_std , -0.01577759803892287 , 0.33428045736679457
# PCNT_built , gabor_sc7_filter_5_sum , -0.32541875461806663 , 3.7551556476421826e-93
# PCNT_built , gabor_sc7_filter_6_mean , 0.388885866804157 , 1.5202133967785987e-135
# PCNT_built , gabor_sc7_filter_6_std , -0.010399559603409061 , 0.5245220048555677
# PCNT_built , gabor_sc7_filter_6_sum , -0.2940831874024885 , 1.2181076228150587e-75
# PCNT_built , gabor_sc7_filter_7_mean , 0.3768085296440554 , 1.0182277225040393e-126
# PCNT_built , gabor_sc7_filter_7_std , -0.009755860984181465 , 0.5505087335731587
# PCNT_built , gabor_sc7_filter_7_sum , -0.3254550161958993 , 3.5736577751576147e-93
# PCNT_built , gabor_sc7_filter_8_mean , 0.38736153480847874 , 2.0725817258065451e-134
# PCNT_built , gabor_sc7_filter_8_std , -0.010201159011586003 , 0.5324641842003852
# PCNT_built , gabor_sc7_filter_8_sum , -0.2939945010294494 , 1.3559470968675386e-75
# PCNT_built , gabor_sc7_filter_9_mean , 0.37802487209398733 , 1.3670568899638881e-127
# PCNT_built , gabor_sc7_filter_9_std , -0.021617672521684412 , 0.18583866133922636
# PCNT_built , gabor_sc7_filter_9_sum , -0.32542786256797324 , 3.7087215320548768e-93
# PCNT_built , gabor_sc7_mean_mean , 0.3754543629145806 , 9.426082759465866e-126
# PCNT_built , gabor_sc7_mean_std , 0.016617699196790004 , 0.309179222514059
# PCNT_built , gabor_sc7_mean_sum , -0.32517840554419997 , 5.213854998804963e-93
# PCNT_built , gabor_sc7_variance_mean , 0.3842275969692333 , 4.269180062949543e-132
# PCNT_built , gabor_sc7_variance_std , 0.01133490093245439 , 0.4879135433158317
# PCNT_built , gabor_sc7_variance_sum , -0.29281933958761586 , 5.592316668775871e-75
# PCNT_built , hog_sc3_kurtosis_mean , 0.5255638528225828 , 3.239937140816927e-265
# PCNT_built , hog_sc3_kurtosis_std , 0.09467151793927103 , 6.39012320816168e-09
# PCNT_built , hog_sc3_kurtosis_sum , -0.3263798114572053 , 1.0078780425511376e-93
# PCNT_built , hog_sc3_mean_mean , 0.2898540823360494 , 1.93804210800281e-73
# PCNT_built , hog_sc3_mean_std , -0.46929236554269577 , 1.3966677433516998e-204
# PCNT_built , hog_sc3_mean_sum , -0.3449876068835585 , 3.378570101808198e-105
# PCNT_built , hog_sc3_skew_mean , 0.48439205327028856 , 9.394167307687335e-220
# PCNT_built , hog_sc3_skew_std , -0.38743402016130934 , 1.8310274802695102e-134
# PCNT_built , hog_sc3_skew_sum , -0.3342830042668789 , 1.6858077299747924e-98
# PCNT_built , hog_sc3_variance_mean , -0.4616339087565379 , 3.578880654220565e-197
# PCNT_built , hog_sc3_variance_std , -0.5049850861393107 , 1.0311982695251738e-241
# PCNT_built , hog_sc3_variance_sum , -0.35649433937038755 , 1.0698777875001777e-112
# PCNT_built , hog_sc5_kurtosis_mean , 0.5438392761676312 , 1.718269852609736e-287
# PCNT_built , hog_sc5_kurtosis_std , 0.07453342149599768 , 4.9422005390884474e-06
# PCNT_built , hog_sc5_kurtosis_sum , -0.286368731704227 , 1.1848038521648106e-71
# PCNT_built , hog_sc5_mean_mean , 0.08177293682045819 , 5.379127855537459e-07
# PCNT_built , hog_sc5_mean_std , -0.29754904764682505 , 1.7914147970962215e-77
# PCNT_built , hog_sc5_mean_sum , -0.34967469505067517 , 3.2496829634500627e-108
# PCNT_built , hog_sc5_skew_mean , 0.5161986490502154 , 2.552455904373771e-254
# PCNT_built , hog_sc5_skew_std , 0.2881992804892776 , 1.376048635637264e-72
# PCNT_built , hog_sc5_skew_sum , -0.3269680257551502 , 4.4953964780893737e-94
# PCNT_built , hog_sc5_variance_mean , -0.4729328754233193 , 3.6017976902629006e-208
# PCNT_built , hog_sc5_variance_std , -0.4201919042237943 , 3.242068880246751e-160
# PCNT_built , hog_sc5_variance_sum , -0.35478987922543737 , 1.4456732607892163e-111
# PCNT_built , hog_sc7_kurtosis_mean , 0.5821988969097474 , 0.0
# PCNT_built , lbpm_sc3_variance_sum , -0.3538501443994469 , 6.032726961526262e-111
# PCNT_built , lbpm_sc5_kurtosis_mean , 0.36806616705281425 , 1.4677690829357347e-120
# PCNT_built , lbpm_sc5_kurtosis_std , -0.2078449685413407 , 7.63745382328558e-38
# PCNT_built , lbpm_sc5_kurtosis_sum , -0.3232521295797964 , 7.15803318919424e-92
# PCNT_built , lbpm_sc5_max_mean , 0.21964786619671992 , 3.625918950176037e-42
# PCNT_built , lbpm_sc5_max_std , -0.11173514427778121 , 6.9431989362130075e-12
# PCNT_built , lbpm_sc5_max_sum , -0.34963445028731455 , 3.451162311080971e-108
# PCNT_built , lbpm_sc5_mean_mean , -0.27209914370214566 , 1.3328142587778206e-64
# PCNT_built , lbpm_sc5_mean_std , -0.2736713136177025 , 2.335435098400983e-65
# PCNT_built , lbpm_sc5_mean_sum , -0.3522927149543955 , 6.369974969315431e-110
# PCNT_built , lbpm_sc5_skew_mean , 0.3184304084507818 , 4.6359417447793264e-89
# PCNT_built , lbpm_sc5_skew_std , -0.3412601419969984 , 7.784105310697613e-103
# PCNT_built , lbpm_sc5_skew_sum , -0.3338444502543242 , 3.1303159208421444e-98
# PCNT_built , lbpm_sc5_variance_mean , -0.17760228465863168 , 6.281296904951682e-28
# PCNT_built , lbpm_sc5_variance_std , -0.30787267570927995 , 4.393652428356141e-83
# PCNT_built , lbpm_sc5_variance_sum , -0.34677247725342103 , 2.43207037470477e-106
# PCNT_built , lbpm_sc7_kurtosis_mean , 0.3199799038240731 , 5.865829298920872e-90
# PCNT_built , lbpm_sc7_kurtosis_std , -0.2258236687309509 , 1.5610367943223194e-44
# PCNT_built , lbpm_sc7_kurtosis_sum , -0.31600789247519545 , 1.14589654668735e-87
# PCNT_built , lbpm_sc7_max_mean , 0.301477870546062 , 1.3964669103539022e-79
# PCNT_built , lbpm_sc7_max_std , -0.246055713354277 , 8.59054849481607e-53
# PCNT_built , lbpm_sc7_max_sum , -0.3480022081374106 , 3.929073675109369e-107
# PCNT_built , lbpm_sc7_mean_mean , -0.12425539968030151 , 2.2922272651656016e-14
# PCNT_built , lbpm_sc7_mean_std , -0.36305593940990344 , 4.083063306283069e-117
# PCNT_built , lbpm_sc7_mean_sum , -0.352203562114612 , 7.287167902689291e-110
# PCNT_built , lbpm_sc7_skew_mean , 0.2709390338882589 , 4.78300266551973e-64
# PCNT_built , lbpm_sc7_skew_std , -0.3236603699734244 , 4.115152425492845e-92
# PCNT_built , lbpm_sc7_skew_sum , -0.32991639223864117 , 7.646337563352102e-96
# PCNT_built , lbpm_sc7_variance_mean , -0.13607378430511782 , 5.980612105090499e-17
# PCNT_built , lbpm_sc7_variance_std , -0.28577377614835114 , 2.377033715331894e-71
# PCNT_built , lbpm_sc7_variance_sum , -0.34187735394781543 , 3.178736549754991e-103
# PCNT_built , lsr_sc3_line_contrast_mean , 0.04787597080802372 , 0.0033752205962208496
# PCNT_built , lsr_sc3_line_contrast_std , -0.0007709220546340647 , 0.9623741380992132
# PCNT_built , lsr_sc3_line_contrast_sum , -0.29759576413399536 , 1.6916942148616e-77
# PCNT_built , lsr_sc3_line_length_mean , 0.02988990792446894 , 0.06733348998605085
# PCNT_built , lsr_sc3_line_length_std , 0.001571983097075604 , 0.9233670104913829
# PCNT_built , lsr_sc3_line_length_sum , -0.2981007798103714 , 9.101832907046425e-78
# PCNT_built , lsr_sc3_line_mean_mean , -0.10838899037023456 , 2.8878451341939753e-11
# PCNT_built , lsr_sc3_line_mean_std , -0.31259043963762645 , 1.0052923953772176e-85
# PCNT_built , lsr_sc3_line_mean_sum , -0.2953527006986021 , 2.614659945830666e-76
# PCNT_built , lsr_sc5_line_contrast_mean , 0.09232860035294879 , 1.4970782250822475e-08
# PCNT_built , lsr_sc5_line_contrast_std , -0.16037885499875199 , 5.187953268212103e-23
# PCNT_built , lsr_sc5_line_contrast_sum , -0.3125538152126608 , 1.054333786553797e-85
# PCNT_built , lsr_sc5_line_length_mean , 0.07531526748182302 , 3.9258107199112094e-06
# PCNT_built , lsr_sc5_line_length_std , -0.15458511968417588 , 1.7880221259037153e-21
# PCNT_built , lsr_sc5_line_length_sum , -0.3130314331966576 , 5.662205897533981e-86
# PCNT_built , lsr_sc5_line_mean_mean , -0.1264749260204772 , 7.816754029013248e-15
# PCNT_built , lsr_sc5_line_mean_std , -0.3225333847936938 , 1.892990096918272e-91
# PCNT_built , lsr_sc5_line_mean_sum , -0.3104338560024063 , 1.6419117378994707e-84
# PCNT_built , lsr_sc7_line_contrast_mean , 0.09874661648598845 , 1.3838809830746717e-09
# PCNT_built , lsr_sc7_line_contrast_std , -0.18692589531085033 , 8.264934493977621e-31
# PCNT_built , lsr_sc7_line_contrast_sum , -0.3239785767752575 , 2.6714016727228716e-92
# PCNT_built , lsr_sc7_line_length_mean , 0.08098288190377093 , 6.916828083124515e-07
# PCNT_built , lsr_sc7_line_length_std , -0.18106168393172867 , 5.588122409167563e-29
# PCNT_built , lsr_sc7_line_length_sum , -0.32463692223095175 , 1.0909189976489189e-92
# PCNT_built , lsr_sc7_line_mean_mean , -0.1357399541499229 , 7.12792507348201e-17
# PCNT_built , lsr_sc7_line_mean_std , -0.29485010717141485 , 4.8126864930053067e-76
# PCNT_built , lsr_sc7_line_mean_sum , -0.31706938624198605 , 2.8206895314916564e-88
# PCNT_built , mean_sc3_mean_mean , 0.38062009465488716 , 1.8307290615778355e-129
# PCNT_built , mean_sc3_mean_std , 0.046660650266363804 , 0.004278956852314321
# PCNT_built , mean_sc3_mean_sum , -0.32522588135019953 , 4.8866955724599915e-93
# PCNT_built , mean_sc3_variance_mean , 0.4603661070821623 , 5.781713268414952e-196
# PCNT_built , mean_sc3_variance_std , 0.13728570954713964 , 3.151065311063089e-17
# PCNT_built , mean_sc3_variance_sum , -0.220472880330056 , 1.7680576375308498e-42
# PCNT_built , mean_sc5_mean_mean , 0.38065235851682516 , 1.734719645372737e-129
# PCNT_built , mean_sc5_mean_std , -0.0010223236592414788 , 0.9501181780691216
# PCNT_built , orb_sc31_mean_mean , 0.15971622612418687 , 7.830320412695589e-23
# PCNT_built , orb_sc31_mean_std , 0.06764823056910914 , 3.408532884758758e-05
# PCNT_built , orb_sc31_mean_sum , -0.0499440444628867 , 0.002227449172120886
# PCNT_built , orb_sc31_skew_mean , 0.21194901170724592 , 2.5640548449594405e-39
# PCNT_built , orb_sc31_skew_std , 0.14194389790574002 , 2.5441969106210204e-18
# PCNT_built , orb_sc31_skew_sum , -0.10532343426577108 , 1.0266934769922179e-10
# PCNT_built , orb_sc31_variance_mean , 0.10898172290511811 , 2.2504669707283116e-11
# PCNT_built , orb_sc31_variance_std , 0.03659973513021653 , 0.025066699224469944
# PCNT_built , orb_sc31_variance_sum , -0.04475401807435561 , 0.006144385417096229
# PCNT_built , orb_sc51_kurtosis_mean , 0.1257708663766677 , 1.1018793200123412e-14
# PCNT_built , orb_sc51_kurtosis_std , 0.07433537830747654 , 5.237135099021187e-06
# PCNT_built , orb_sc51_kurtosis_sum , -0.16879187020432032 , 2.390056953456357e-25
# PCNT_built , orb_sc51_max_mean , 0.19819929585955948 , 1.680175097477462e-34
# PCNT_built , orb_sc51_max_std , 0.04733452754256672 , 0.003753901460607865
# PCNT_built , orb_sc51_max_sum , -0.06505034011259347 , 6.753641284075682e-05
# PCNT_built , orb_sc51_mean_mean , 0.18618907522016945 , 1.4143576446241396e-30
# PCNT_built , orb_sc51_mean_std , 0.05688227893847468 , 0.0004947566985358109
# PCNT_built , orb_sc51_mean_sum , -0.04801577575394471 , 0.003283262555554787
# PCNT_built , orb_sc51_skew_mean , 0.1355296450429616 , 7.959432929323149e-17
# PCNT_built , orb_sc51_skew_std , 0.06262910813608363 , 0.00012495948076278856
# PCNT_built , orb_sc51_skew_sum , -0.1654966889336507 , 2.0340112633645977e-24
# PCNT_built , orb_sc51_variance_mean , 0.11793410744262221 , 4.4229132150384615e-13
# PCNT_built , orb_sc51_variance_std , 0.03318608334968307 , 0.042225291216348236
# PCNT_built , orb_sc51_variance_sum , -0.03998562404339276 , 0.014373460707406482
# PCNT_built , orb_sc71_kurtosis_mean , 0.01993305811114706 , 0.2225136822290834
# PCNT_built , orb_sc71_kurtosis_std , -0.054133051905837615 , 0.0009165699379151019
# PCNT_built , orb_sc71_kurtosis_sum , -0.2273516489508671 , 3.9530492281394084e-45
# PCNT_built , orb_sc71_max_mean , 0.20401751096133455 , 1.6968455315524224e-36
# PCNT_built , orb_sc71_max_std , 0.02658124006317209 , 0.10376785820333752
# PCNT_built , orb_sc71_max_sum , -0.07080678183155102 , 1.4360412728500561e-05
# PCNT_built , orb_sc71_mean_mean , 0.21136113899356485 , 4.18775721501503e-39
# PCNT_built , orb_sc71_mean_std , 0.0493967961109722 , 0.00249002550306332
# PCNT_built , orb_sc71_mean_sum , -0.04591930146065505 , 0.00493277168308808
# PCNT_built , orb_sc71_skew_mean , 0.032960629415942536 , 0.04364487052570352
# PCNT_built , orb_sc71_skew_std , -0.05753467736153864 , 0.0004257275941432988
# PCNT_built , orb_sc71_skew_sum , -0.2256267818679275 , 1.8618779049490504e-44
# PCNT_built , orb_sc71_variance_mean , 0.1283872511865269 , 3.046632571300497e-15
# PCNT_built , orb_sc71_variance_std , 0.035907460893445 , 0.027951271849647845
# PCNT_built , orb_sc71_variance_sum , -0.0355426473096902 , 0.02958335552346739
# PCNT_built , pantex_sc3_min_mean , 0.47802752005561866 , 2.8907066069222395e-213
# PCNT_built , pantex_sc3_min_std , 0.38442117833926137 , 3.0771795110916755e-132
# PCNT_built , pantex_sc3_min_sum , -0.13141553423520447 , 6.6559014089801895e-16
# PCNT_built , pantex_sc5_min_mean , 0.5012158613276976 , 1.3996242085374525e-237
# PCNT_built , pantex_sc5_min_std , 0.23986139398771075 , 3.5179992298384885e-50
# PCNT_built , pantex_sc5_min_sum , -0.1775633662175398 , 6.452821558709264e-28
# PCNT_built , pantex_sc7_min_mean , 0.4978151115462278 , 6.76746636652623e-234
# PCNT_built , pantex_sc7_min_std , 0.15723190257411776 , 3.6080679328963e-22
# PCNT_built , pantex_sc7_min_sum , -0.18197311890346796 , 2.93003068344708e-29
# PCNT_built , sfs_sc31_max_ll_mean , 0.47510684999045144 , 2.470204710567901e-210
# PCNT_built , sfs_sc31_max_ll_std , -0.5277313312189926 , 8.701761317861616e-268
# PCNT_built , sfs_sc31_max_ll_sum , -0.30804190062818426 , 3.539547246217835e-83
# PCNT_built , sfs_sc31_mean_mean , 0.4998467958251725 , 4.30815944174099e-236
# PCNT_built , sfs_sc31_mean_std , -0.35605542200434953 , 2.0949678029043176e-112
# PCNT_built , sfs_sc31_mean_sum , -0.27643929096918163 , 1.0577786891444008e-66
# PCNT_built , sfs_sc31_min_ll_mean , -0.024179084234745796 , 0.13892914215235974
# PCNT_built , sfs_sc31_min_ll_std , -0.028867076731879646 , 0.0772597902979777
# PCNT_built , sfs_sc31_min_ll_sum , -0.10770777510414203 , 3.8399485378060687e-11
# PCNT_built , sfs_sc31_roa_mean , -0.362988205812903 , 4.540766438597274e-117
# PCNT_built , sfs_sc31_roa_std , 0.04154799508420648 , 0.010974288384720688
# PCNT_built , sfs_sc31_roa_sum , -0.3540453435220826 , 4.485496611240467e-111
# PCNT_built , sfs_sc31_std_mean , 0.17191789760912177 , 3.0099473790827245e-26
# PCNT_built , sfs_sc31_std_std , -0.46711463429250133 , 1.8666290849951496e-202
# PCNT_built , sfs_sc31_std_sum , -0.3523797734394554 , 5.585612897846618e-110
# PCNT_built , sfs_sc31_w_mean_mean , -0.29239602125695024 , 9.301226682914257e-75
# PCNT_built , sfs_sc31_w_mean_std , -0.4334606842541067 , 1.7115740322530916e-171
# PCNT_built , sfs_sc31_w_mean_sum , -0.3379771762793275 , 8.815073213772254e-101
# PCNT_built , sfs_sc51_max_ll_mean , -0.15461084883602275 , 1.760655198847973e-21
# PCNT_built , sfs_sc51_max_ll_std , -0.1275480763431309 , 4.614746500834227e-15
# PCNT_built , sfs_sc51_max_ll_sum , -0.364886419418352 , 2.2895023560827573e-118
# PCNT_built , sfs_sc51_mean_mean , 0.3690243833027556 , 3.1687552799395023e-121
# PCNT_built , sfs_sc51_mean_std , -0.2708530194680303 , 5.256980078189561e-64
# PCNT_built , sfs_sc51_mean_sum , -0.3330177859402509 , 1.0023918955896469e-97
# PCNT_built , sfs_sc51_min_ll_mean , -0.014905609581387083 , 0.3616847593813455
# PCNT_built , sfs_sc51_min_ll_std , -0.017510510263598053 , 0.2839038225645221
# PCNT_built , sfs_sc51_min_ll_sum , -0.1605568816631933 , 4.643361468185261e-23
# PCNT_built , sfs_sc51_roa_mean , -0.2944343955255281 , 7.964363856363979e-76
# PCNT_built , sfs_sc51_roa_std , -0.07869535869170319 , 1.4139193148664686e-06
# PCNT_built , sfs_sc51_roa_sum , -0.3529987721683998 , 2.1917774576445506e-110
# PCNT_built , sfs_sc51_std_mean , 0.28712755390543027 , 4.862969504025245e-72
# PCNT_built , sfs_sc51_std_std , -0.20388395067552303 , 1.8886416894776033e-36
# PCNT_built , sfs_sc51_std_sum , -0.34267835541927955 , 9.911946878314218e-104
# PCNT_built , sfs_sc51_w_mean_mean , -0.43431922353715485 , 3.0630909096596164e-172
# PCNT_built , sfs_sc51_w_mean_std , -0.4033509461867031 , 1.2928095277362826e-146
# PCNT_built , sfs_sc51_w_mean_sum , -0.34723012540328474 , 1.2352747255748366e-106
# PCNT_built , sfs_sc71_max_ll_mean , -0.3606033198986461 , 1.8823368995541038e-115
# PCNT_built , sfs_sc71_max_ll_std , -0.31847446974709587 , 4.37201345531243e-89
# PCNT_built , sfs_sc71_max_ll_sum , -0.37210819024682307 , 2.2020014267187618e-123
# PCNT_built , sfs_sc71_mean_mean , -0.1973296845909522 , 3.2986411909278245e-34
# PCNT_built , sfs_sc71_mean_std , -0.2712542009668521 , 3.382304468321524e-64
# PCNT_built , sfs_sc71_mean_sum , -0.36612004621859784 , 3.249784963975596e-119
# PCNT_built , sfs_sc71_min_ll_mean , -0.05177935398549404 , 0.0015211100229926126
# PCNT_built , sfs_sc71_min_ll_std , -0.11655178770212711 , 8.277748310748747e-13
# PCNT_built , sfs_sc71_min_ll_sum , -0.05402353063662634 , 0.0009388394671858056
# PCNT_built , sfs_sc71_roa_mean , -0.24264727734310354 , 2.4023185107833256e-51
# PCNT_built , sfs_sc71_roa_std , -0.12523002678811823 , 1.4325461548729147e-14
# PCNT_built , sfs_sc71_roa_sum , -0.35285168814175044 , 2.7378927779553546e-110
# PCNT_built , sfs_sc71_std_mean , -0.25775343455365884 , 6.258372225254967e-58
# PCNT_built , sfs_sc71_std_std , -0.2679732311293217 , 1.2189338565589008e-62
# PCNT_built , sfs_sc71_std_sum , -0.36863569554300724 , 5.905036416807349e-121
# PCNT_built , sfs_sc71_w_mean_mean , -0.4670853580579873 , 1.9931199982694675e-202
# PCNT_built , sfs_sc71_w_mean_std , -0.37813980654984514 , 1.1302928864499085e-127
# PCNT_built , sfs_sc71_w_mean_sum , -0.3450376580077444 , 3.1389881067255847e-105
# PCNT_built 294

# %% [markdown]
# ### Correlation Significance

# %%
x_df
# Out:
#                           x_var    abs_r2
# 146       hog_sc7_kurtosis_mean  0.582199
# 134       hog_sc5_kurtosis_mean  0.543839
# 152           hog_sc7_skew_mean  0.536919
# 323         sfs_sc31_max_ll_std  0.527731
# 122       hog_sc3_kurtosis_mean  0.525564
# 140           hog_sc5_skew_mean  0.516199
# 132        hog_sc3_variance_std  0.504985
# 316         pantex_sc5_min_mean  0.501216
# 325          sfs_sc31_mean_mean  0.499847
# 319         pantex_sc7_min_mean  0.497815
# 252          ndvi_sc3_mean_mean  0.495613
# 258          ndvi_sc5_mean_mean  0.495264
# 264          ndvi_sc7_mean_mean  0.494817
# 128           hog_sc3_skew_mean  0.484392
# 313         pantex_sc3_min_mean  0.478028
# 267      ndvi_sc7_variance_mean  0.476202
# 0     fourier_v2_sc31_mean_mean  0.475406
# 322        sfs_sc31_max_ll_mean  0.475107
# 143       hog_sc5_variance_mean  0.472933
# 158            lac_sc3_lac_mean  0.469902
# 161            lac_sc5_lac_mean  0.469902
# 164            lac_sc7_lac_mean  0.469902
# 126            hog_sc3_mean_std  0.469292
# 333            sfs_sc31_std_std  0.467115
# 369        sfs_sc71_w_mean_mean  0.467085
# 131       hog_sc3_variance_mean  0.461634
# 261      ndvi_sc5_variance_mean  0.461520
# 6     fourier_v2_sc51_mean_mean  0.461222
# 239      mean_sc3_variance_mean  0.460366
# 155       hog_sc7_variance_mean  0.451966
# ..                          ...       ...
# 159             lac_sc3_lac_std  0.068573
# 277           orb_sc31_mean_std  0.067648
# 290            orb_sc51_max_sum  0.065050
# 295           orb_sc51_skew_std  0.062629
# 275            orb_sc31_max_sum  0.059495
# 308           orb_sc71_skew_std  0.057535
# 292           orb_sc51_mean_std  0.056882
# 300       orb_sc71_kurtosis_std  0.054133
# 362         sfs_sc71_min_ll_sum  0.054024
# 360        sfs_sc71_min_ll_mean  0.051779
# 278           orb_sc31_mean_sum  0.049944
# 305           orb_sc71_mean_std  0.049397
# 293           orb_sc51_mean_sum  0.048016
# 212  lsr_sc3_line_contrast_mean  0.047876
# 256       ndvi_sc3_variance_std  0.047483
# 289            orb_sc51_max_std  0.047335
# 237           mean_sc3_mean_std  0.046661
# 306           orb_sc71_mean_sum  0.045919
# 171            lbpm_sc3_max_std  0.045422
# 284       orb_sc31_variance_sum  0.044754
# 149           hog_sc7_mean_mean  0.043522
# 330            sfs_sc31_roa_std  0.041548
# 245       mean_sc5_variance_std  0.041520
# 299       orb_sc51_variance_sum  0.039986
# 283       orb_sc31_variance_std  0.036600
# 311       orb_sc71_variance_std  0.035907
# 312       orb_sc71_variance_sum  0.035543
# 298       orb_sc51_variance_std  0.033186
# 307          orb_sc71_skew_mean  0.032961
# 248           mean_sc7_mean_std  0.032530
#
# [372 rows x 2 columns]

# %%
y = y_var
#Initialize the output dictionary, Y_D, with each key being a dependent variable and the values being the results of the analyses
Y_D = {}
#Dictionary Models is used to store each result object for later use if needed
Models ={}
#for each dependent variable y in the list of all dependent values, calibrate the model

#Add new key to the output dictionary where y is the dependent variable curently being processed
#and the values are empty for now
Y_D[y]={}
#Get independent variables from the variable dictionary and store in list x_vars
x_vars = y_dict[y]
#Create a new dataframe for scaled and centered values
scale_df = pd.DataFrame()
#Scale and center the values
scale_df[y] = scale(pop_density, with_mean=True, with_std=True)
for x in x_vars:
    scale_df[x] = scale(df4[x], with_mean=True, with_std=True)
result = ElasticNetCV(max_iter=1e8,
                    alphas = [0.0005, 0.001, 0.01, 0.03, 0.05, 0.1],
                    l1_ratio =[.1, .5, .7, .9, .95, .99, 1],
                    verbose= False,
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)
#Fit the model with the scaled data
result.fit(scale_df[x_vars],scale_df[y])
#Append the model to the Models dictionary
Models[y] = result
# Out:
# /Users/adbe/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:164: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
result
# Out:
# ElasticNetCV(alphas=[0.0005, 0.001, 0.01, 0.03, 0.05, 0.1], copy_X=True, cv=5,
#        eps=0.001, fit_intercept=False,
#        l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=100000000.0,
#        n_alphas=100, n_jobs=-1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='random',
#        tol=0.0001, verbose=False)

# %%
opt_alpha, opt_l1_ratio = result.alpha_, result.l1_ratio_
#Print update to ensure that the script is progressing properly
print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(result.score(scale_df[x_vars],scale_df[y]),
              result.alpha_, result.l1_ratio_))
#Record the overall R squared score and optimal alpha and l1 ratio values and store them in the output dictionary
Y_D[y]['Total R2'] = result.score(scale_df[x_vars],scale_df[y])
Y_D[y]['Alpha'] = opt_alpha
Y_D[y]['l1_ratio'] = opt_l1_ratio
#Create a list R2s to store out of sample R squared values
R2s = []
#Specify the number of trials to run
trials = 10
#Run the number of trials specified in trials, for each trial 34% of the observations are randomly selected to train the model
#Testing is done on the remaining 66% of observations and the R squared values are recorded
for i in range(trials):    
    X_train, X_test, y_train, y_test = train_test_split(scale_df[x_vars], scale_df[y], test_size=0.66)
    test_regr = ElasticNetCV(max_iter=1e8,
                    alphas = [opt_alpha],
                    l1_ratio =[opt_l1_ratio],
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)
    test_regr.fit(X_train,y_train)
    R2s.append(test_regr.score(X_test,y_test))

#print("Mean R2: {:.2f} StDev: {:.4f}".format(mean(R2s),pstdev(R2s)))
#Record the out of sample R squared values
Y_D[y]['Sampling']={'trials':trials,'R2':mean(R2s),'StDev':pstdev(R2s),'R2s':R2s}
coefs = [i for i in zip(list(scale_df[x_vars].axes[1]),result.coef_)]
remaining = [i for i in coefs if abs(i[1])>0.0]
Y_D[y]["Coefficients"]=remaining
# Out:
# R2: 0.55 Alpha: 0.01 l1_ratio: 0.7

# %%
y_vars = y_var
Y_D[y_var]
# Out:
# {'Total R2': 0.5461728236584515,
#  'Alpha': 0.01,
#  'l1_ratio': 0.7,
#  'Sampling': {'trials': 10,
#   'R2': 0.5202989708406005,
#   'StDev': 0.018317132943238022,
#   'R2s': [0.5473740291990039,
#    0.4989668926675461,
#    0.5337974664662575,
#    0.4893789246230993,
#    0.5033422324368821,
#    0.5107160712526526,
#    0.5320974576647002,
#    0.5408337711959741,
#    0.5172732994805342,
#    0.5292095634193549]},
#  'Coefficients': [('hog_sc7_kurtosis_mean', 0.23777450530169264),
#   ('hog_sc5_kurtosis_mean', 0.0035784772043072686),
#   ('hog_sc7_skew_mean', 0.059680849055744604),
#   ('sfs_sc31_max_ll_std', -0.13103499123972193),
#   ('ndvi_sc3_mean_mean', -0.1983557186855977),
#   ('ndvi_sc5_mean_mean', -0.16953743228891693),
#   ('ndvi_sc7_mean_mean', -0.12937121410887936),
#   ('ndvi_sc7_variance_mean', 0.12617088538202823),
#   ('lac_sc3_lac_mean', 0.04272599530319671),
#   ('lac_sc5_lac_mean', 0.031091362506085875),
#   ('lac_sc7_lac_mean', 0.03351486232369755),
#   ('ndvi_sc5_variance_mean', 0.033000641459099304),
#   ('fourier_v2_sc71_mean_mean', 0.17629649120591048),
#   ('sfs_sc51_w_mean_mean', -0.036012108985631314),
#   ('ndvi_sc7_variance_sum', 0.07237274657939448),
#   ('ndvi_sc3_mean_sum', 0.043411130774377804),
#   ('ndvi_sc5_mean_sum', 0.03847819877065064),
#   ('ndvi_sc7_mean_sum', 0.03866662298594057),
#   ('hog_sc3_skew_std', 4.024115594771073e-05),
#   ('hog_sc7_skew_std', -0.01712787335495725),
#   ('lbpm_sc3_variance_std', 0.00012382653353350872),
#   ('lbpm_sc5_skew_std', 0.08122694326655418),
#   ('fourier_v2_sc31_mean_std', -0.02227257888131218),
#   ('ndvi_sc3_variance_sum', -0.03329109623269974),
#   ('lbpm_sc7_kurtosis_mean', -0.12523990860828196),
#   ('lsr_sc3_line_mean_std', -0.031286963534986535),
#   ('sfs_sc51_roa_mean', -0.049048183021807974),
#   ('hog_sc5_skew_std', -0.005764804091112554),
#   ('lbpm_sc7_skew_mean', -0.047761764581490125),
#   ('sfs_sc51_mean_std', 0.06476878416170258),
#   ('fourier_v2_sc71_variance_std', -0.019179398829021043),
#   ('sfs_sc71_std_std', -0.03381961511201661),
#   ('lbpm_sc3_mean_mean', -0.09048781642089575),
#   ('hog_sc7_kurtosis_sum', -0.26931983636263906),
#   ('ndvi_sc3_variance_mean', -0.0217145772029629),
#   ('lbpm_sc5_max_mean', 0.011782796358554034),
#   ('orb_sc71_mean_mean', 0.014122394910989764),
#   ('orb_sc71_max_mean', 0.14751293588801237),
#   ('hog_sc7_kurtosis_std', -0.019169711358208212),
#   ('fourier_v2_sc31_variance_mean', -0.057809236324381216),
#   ('hog_sc7_mean_std', -0.00019796099294743788),
#   ('orb_sc51_skew_sum', -0.02592727738457967),
#   ('sfs_sc51_min_ll_sum', -0.007463058653182493),
#   ('lsr_sc5_line_contrast_std', -0.05169159577051595),
#   ('pantex_sc7_min_std', -0.1334833587232194),
#   ('sfs_sc51_max_ll_mean', 0.04710503814074993)]}
