# %% [markdown]
# ## Spatial Features Vs Urban Footprint Vs Population Size

# %%
import sklearn
import pandas as pd
import numpy as np
import csv
import scipy.stats as stats
from statistics import pstdev
from statistics import mean
from sklearn import preprocessing
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import ElasticNet, Lasso
from sklearn.datasets import make_regression
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from itertools import product
import copy

# %% [markdown]
# ### Read the Features data

# %%
# !ls spfeas
# Out:
# ls: spfeas: No such file or directory

# %%
spfeas = pd.read_excel('sri_spfeas_v3.xlsx', sheet_name=0)

# %%
spfeas['gid'] = spfeas['gid'].astype(int)
spfeas = spfeas.set_index('gid')

# %%
spfeas.head()
# Out:
#       fid              gnd_n    gnd_c  fourier_sc31_mean_mean  \
# gid
# 43      0  Karagaskada South  2148065               69.453586
# 564     1            Panvila  2115070               59.535572
# 7917    2          Ganepalla  9227135               50.730112
# 2263    3    Akkaraipattu 11  5236065               73.670361
# 8       4       Delgasthenna  2109125               66.878083
#
#       fourier_sc31_mean_std  fourier_sc31_mean_sum  \
# gid
# 43                 3.136141           2.376702e+05
# 564                7.845283           1.400872e+06
# 7917               5.682764           3.625884e+06
# 2263               1.821871           9.731855e+04
# 8                  2.710715           2.657735e+05
#
#       fourier_sc31_variance_mean  fourier_sc31_variance_std  \
# gid
# 43                     18.629130                   0.976240
# 564                    17.086123                   2.204723
# 7917                   14.450501                   2.109653
# 2263                   18.843218                   1.231690
# 8                      18.708531                   1.015577
#
#       fourier_sc31_variance_sum  fourier_sc51_mean_mean  ...  \
# gid                                                      ...
# 43                 6.374888e+04               78.493900  ...
# 564                4.020365e+05               69.651317  ...
# 7917               1.032835e+06               60.710447  ...
# 2263               2.489189e+04               82.544710  ...
# 8                  7.434770e+04               75.957167  ...
#
#       sfs_sc71_min_ll_sum  sfs_sc71_roa_mean  sfs_sc71_roa_std  \
# gid
# 43                   3933         136.394391          0.938602
# 564              40076188         137.910516          2.093903
# 7917           7900571136         139.556597          2.014015
# 2263                 1331         136.077853          0.267941
# 8                    4809         136.681028          1.377590
#
#       sfs_sc71_roa_sum  sfs_sc71_std_mean  sfs_sc71_std_std  sfs_sc71_std_sum  \
# gid
# 43              466878          16.233955          3.648450      55568.828125
# 564            3245724          14.498129          5.118067     341213.468750
# 7917           9974110           9.856942          7.202832     704475.625000
# 2263            180031          10.558998          4.329045      13969.554688
# 8               542487          15.218429          4.465160      60401.945312
#
#       sfs_sc71_w_mean_mean  sfs_sc71_w_mean_std  sfs_sc71_w_mean_sum
# gid
# 43                1.228705             0.707158          4205.858398
# 564               2.838843             3.471181         66812.164062
# 7917              3.388618             5.864246        242184.515625
# 2263              0.514668             0.239074           680.906372
# 8                 1.180995             0.868924          4687.369141
#
# [5 rows x 426 columns]

# %% [markdown]
# ### Load GUF

# %%
guf = pd.read_csv('sri_ghs.csv')

# %%
guf['gid'] = guf['gid'].astype(int)
guf = guf.set_index('gid')
guf.head()
# Out:
#                   gnd_n    gnd_c  prov_c  dis_c  dsd_c  ghs_count  ghs_sum  \
# gid
# 43    Karagaskada South  2148065       2     21   2148        235      635
# 564             Panvila  2115070       2     21   2115       1626     6326
# 7917          Ganepalla  9227135       9     92   9227       4929     6929
# 2263    Akkaraipattu 11  5236065       5     52   5236         89     5889
# 8          Delgasthenna  2109125       2     21   2109        274     2874
#
#        ghs_mean
# gid
# 43     2.702128
# 564    3.890529
# 7917   1.405762
# 2263  66.168539
# 8     10.489051

# %% [markdown]
# ### Merge population data with urbanfootprint and featuures

# %%
#guf['builtup_pct'] = guf['ghs_sum']/guf['ghs_count']
#guf.describe()

# %%
#spfeas_world_pop_merged = spfeas.merge(world_pop, left_on='gid', right_on='gid', how='outer')
spfeas_guf = spfeas.merge(guf, left_on='gid', right_on="gid", how='outer')

# %%
spfeas_guf = spfeas_guf.round(3)
spfeas_guf.head()
# Out:
#       fid            gnd_n_x  gnd_c_x  fourier_sc31_mean_mean  \
# gid
# 43      0  Karagaskada South  2148065                  69.454
# 564     1            Panvila  2115070                  59.536
# 7917    2          Ganepalla  9227135                  50.730
# 2263    3    Akkaraipattu 11  5236065                  73.670
# 8       4       Delgasthenna  2109125                  66.878
#
#       fourier_sc31_mean_std  fourier_sc31_mean_sum  \
# gid
# 43                    3.136             237670.172
# 564                   7.845            1400872.000
# 7917                  5.683            3625884.000
# 2263                  1.822              97318.547
# 8                     2.711             265773.500
#
#       fourier_sc31_variance_mean  fourier_sc31_variance_std  \
# gid
# 43                        18.629                      0.976
# 564                       17.086                      2.205
# 7917                      14.451                      2.110
# 2263                      18.843                      1.232
# 8                         18.709                      1.016
#
#       fourier_sc31_variance_sum  fourier_sc51_mean_mean  ...  \
# gid                                                      ...
# 43                    63748.883                  78.494  ...
# 564                  402036.469                  69.651  ...
# 7917                1032835.125                  60.710  ...
# 2263                  24891.891                  82.545  ...
# 8                     74347.703                  75.957  ...
#
#       sfs_sc71_w_mean_std  sfs_sc71_w_mean_sum            gnd_n_y  gnd_c_y  \
# gid
# 43                  0.707             4205.858  Karagaskada South  2148065
# 564                 3.471            66812.164            Panvila  2115070
# 7917                5.864           242184.516          Ganepalla  9227135
# 2263                0.239              680.906    Akkaraipattu 11  5236065
# 8                   0.869             4687.369       Delgasthenna  2109125
#
#       prov_c  dis_c  dsd_c  ghs_count  ghs_sum  ghs_mean
# gid
# 43         2     21   2148        235      635     2.702
# 564        2     21   2115       1626     6326     3.891
# 7917       9     92   9227       4929     6929     1.406
# 2263       5     52   5236         89     5889    66.169
# 8          2     21   2109        274     2874    10.489
#
# [5 rows x 434 columns]

# %% [markdown]
# ### Filter Dataset by Builtup Surface.
#
# Select Rows where  builtup is greater than or equal to 10 percent

# %%
#filter_by_builtup = spfeas_guf_wp[spfeas_guf_wp['ghs_mean']>=10]

# %%
#filter_by_builtup.shape

# %%
#np.sum(filter_by_builtup['stats_sum_y'])

# %%
#pop_density = filter_by_builtup['stats_sum_y']/filter_by_builtup['GN_area']

# %%
#pop_count = filter_by_builtup['LKA_ppp_v2b_2015_UNadj_sum']
#np.sum(pop_count)

# %%
# import matplotlib.pyplot as plt
# plt.subplots(figsize=(8,8))
# y = pop_count
# x = filter_by_builtup['ghs_mean']
# plt.scatter(x, y)

# z = np.polyfit(x, y, 1)
# p = np.poly1d(z)
# plt.plot(x,p(x),"r--")
# plt.show()

# %%
#filter_by_builtup.shape

# %%
spfeas_guf.shape
# Out:
# (14021, 434)

# %% [markdown]
# ### Analysis

# %% [markdown]
# Get the list of dependent variables from the DataFrame to store in list y_vars

# %%
#y_var = list(filter_by_builtup.axes[1])[440]

y_var = list(spfeas_guf.axes[1])[433]
y_var
# Out:
# 'ghs_mean'

# %% [markdown]
# Get a list of all independent variables from the DataFrame in list all_x

# %%
all_x = list(spfeas_guf.axes[1])[3:423]

#Check
all_x
# Out:
# ['fourier_sc31_mean_mean',
#  'fourier_sc31_mean_std',
#  'fourier_sc31_mean_sum',
#  'fourier_sc31_variance_mean',
#  'fourier_sc31_variance_std',
#  'fourier_sc31_variance_sum',
#  'fourier_sc51_mean_mean',
#  'fourier_sc51_mean_std',
#  'fourier_sc51_mean_sum',
#  'fourier_sc51_variance_mean',
#  'fourier_sc51_variance_std',
#  'fourier_sc51_variance_sum',
#  'fourier_sc71_mean_mean',
#  'fourier_sc71_mean_std',
#  'fourier_sc71_mean_sum',
#  'fourier_sc71_variance_mean',
#  'fourier_sc71_variance_std',
#  'fourier_sc71_variance_sum',
#  'gabor_sc3_filter_1_mean',
#  'gabor_sc3_filter_1_std',
#  'gabor_sc3_filter_1_sum',
#  'gabor_sc3_filter_10_mean',
#  'gabor_sc3_filter_10_std',
#  'gabor_sc3_filter_10_sum',
#  'gabor_sc3_filter_11_mean',
#  'gabor_sc3_filter_11_std',
#  'gabor_sc3_filter_11_sum',
#  'gabor_sc3_filter_12_mean',
#  'gabor_sc3_filter_12_std',
#  'gabor_sc3_filter_12_sum',
#  'gabor_sc3_filter_13_mean',
#  'gabor_sc3_filter_13_std',
#  'gabor_sc3_filter_13_sum',
#  'gabor_sc3_filter_14_mean',
#  'gabor_sc3_filter_14_std',
#  'gabor_sc3_filter_14_sum',
#  'gabor_sc3_filter_2_mean',
#  'gabor_sc3_filter_2_std',
#  'gabor_sc3_filter_2_sum',
#  'gabor_sc3_filter_3_mean',
#  'gabor_sc3_filter_3_std',
#  'gabor_sc3_filter_3_sum',
#  'gabor_sc3_filter_4_mean',
#  'gabor_sc3_filter_4_std',
#  'gabor_sc3_filter_4_sum',
#  'gabor_sc3_filter_5_mean',
#  'gabor_sc3_filter_5_std',
#  'gabor_sc3_filter_5_sum',
#  'gabor_sc3_filter_6_mean',
#  'gabor_sc3_filter_6_std',
#  'gabor_sc3_filter_6_sum',
#  'gabor_sc3_filter_7_mean',
#  'gabor_sc3_filter_7_std',
#  'gabor_sc3_filter_7_sum',
#  'gabor_sc3_filter_8_mean',
#  'gabor_sc3_filter_8_std',
#  'gabor_sc3_filter_8_sum',
#  'gabor_sc3_filter_9_mean',
#  'gabor_sc3_filter_9_std',
#  'gabor_sc3_filter_9_sum',
#  'gabor_sc3_mean_mean',
#  'gabor_sc3_mean_std',
#  'gabor_sc3_mean_sum',
#  'gabor_sc3_variance_mean',
#  'gabor_sc3_variance_std',
#  'gabor_sc3_variance_sum',
#  'gabor_sc5_filter_1_mean',
#  'gabor_sc5_filter_1_std',
#  'gabor_sc5_filter_1_sum',
#  'gabor_sc5_filter_10_mean',
#  'gabor_sc5_filter_10_std',
#  'gabor_sc5_filter_10_sum',
#  'gabor_sc5_filter_11_mean',
#  'gabor_sc5_filter_11_std',
#  'gabor_sc5_filter_11_sum',
#  'gabor_sc5_filter_12_mean',
#  'gabor_sc5_filter_12_std',
#  'gabor_sc5_filter_12_sum',
#  'gabor_sc5_filter_13_mean',
#  'gabor_sc5_filter_13_std',
#  'gabor_sc5_filter_13_sum',
#  'gabor_sc5_filter_14_mean',
#  'gabor_sc5_filter_14_std',
#  'gabor_sc5_filter_14_sum',
#  'gabor_sc5_filter_2_mean',
#  'gabor_sc5_filter_2_std',
#  'gabor_sc5_filter_2_sum',
#  'gabor_sc5_filter_3_mean',
#  'gabor_sc5_filter_3_std',
#  'gabor_sc5_filter_3_sum',
#  'gabor_sc5_filter_4_mean',
#  'gabor_sc5_filter_4_std',
#  'gabor_sc5_filter_4_sum',
#  'gabor_sc5_filter_5_mean',
#  'gabor_sc5_filter_5_std',
#  'gabor_sc5_filter_5_sum',
#  'gabor_sc5_filter_6_mean',
#  'gabor_sc5_filter_6_std',
#  'gabor_sc5_filter_6_sum',
#  'gabor_sc5_filter_7_mean',
#  'gabor_sc5_filter_7_std',
#  'gabor_sc5_filter_7_sum',
#  'gabor_sc5_filter_8_mean',
#  'gabor_sc5_filter_8_std',
#  'gabor_sc5_filter_8_sum',
#  'gabor_sc5_filter_9_mean',
#  'gabor_sc5_filter_9_std',
#  'gabor_sc5_filter_9_sum',
#  'gabor_sc5_mean_mean',
#  'gabor_sc5_mean_std',
#  'gabor_sc5_mean_sum',
#  'gabor_sc5_variance_mean',
#  'gabor_sc5_variance_std',
#  'gabor_sc5_variance_sum',
#  'gabor_sc7_filter_1_mean',
#  'gabor_sc7_filter_1_std',
#  'gabor_sc7_filter_1_sum',
#  'gabor_sc7_filter_10_mean',
#  'gabor_sc7_filter_10_std',
#  'gabor_sc7_filter_10_sum',
#  'gabor_sc7_filter_11_mean',
#  'gabor_sc7_filter_11_std',
#  'gabor_sc7_filter_11_sum',
#  'gabor_sc7_filter_12_mean',
#  'gabor_sc7_filter_12_std',
#  'gabor_sc7_filter_12_sum',
#  'gabor_sc7_filter_13_mean',
#  'gabor_sc7_filter_13_std',
#  'gabor_sc7_filter_13_sum',
#  'gabor_sc7_filter_14_mean',
#  'gabor_sc7_filter_14_std',
#  'gabor_sc7_filter_14_sum',
#  'gabor_sc7_filter_2_mean',
#  'gabor_sc7_filter_2_std',
#  'gabor_sc7_filter_2_sum',
#  'gabor_sc7_filter_3_mean',
#  'gabor_sc7_filter_3_std',
#  'gabor_sc7_filter_3_sum',
#  'gabor_sc7_filter_4_mean',
#  'gabor_sc7_filter_4_std',
#  'gabor_sc7_filter_4_sum',
#  'gabor_sc7_filter_5_mean',
#  'gabor_sc7_filter_5_std',
#  'gabor_sc7_filter_5_sum',
#  'gabor_sc7_filter_6_mean',
#  'gabor_sc7_filter_6_std',
#  'gabor_sc7_filter_6_sum',
#  'gabor_sc7_filter_7_mean',
#  'gabor_sc7_filter_7_std',
#  'gabor_sc7_filter_7_sum',
#  'gabor_sc7_filter_8_mean',
#  'gabor_sc7_filter_8_std',
#  'gabor_sc7_filter_8_sum',
#  'gabor_sc7_filter_9_mean',
#  'gabor_sc7_filter_9_std',
#  'gabor_sc7_filter_9_sum',
#  'gabor_sc7_mean_mean',
#  'gabor_sc7_mean_std',
#  'gabor_sc7_mean_sum',
#  'gabor_sc7_variance_mean',
#  'gabor_sc7_variance_std',
#  'gabor_sc7_variance_sum',
#  'hog_sc3_kurtosis_mean',
#  'hog_sc3_kurtosis_std',
#  'hog_sc3_kurtosis_sum',
#  'hog_sc3_mean_mean',
#  'hog_sc3_mean_std',
#  'hog_sc3_mean_sum',
#  'hog_sc3_skew_mean',
#  'hog_sc3_skew_std',
#  'hog_sc3_skew_sum',
#  'hog_sc3_variance_mean',
#  'hog_sc3_variance_std',
#  'hog_sc3_variance_sum',
#  'hog_sc5_kurtosis_mean',
#  'hog_sc5_kurtosis_std',
#  'hog_sc5_kurtosis_sum',
#  'hog_sc5_mean_mean',
#  'hog_sc5_mean_std',
#  'hog_sc5_mean_sum',
#  'hog_sc5_skew_mean',
#  'hog_sc5_skew_std',
#  'hog_sc5_skew_sum',
#  'hog_sc5_variance_mean',
#  'hog_sc5_variance_std',
#  'hog_sc5_variance_sum',
#  'hog_sc7_kurtosis_mean',
#  'hog_sc7_kurtosis_std',
#  'hog_sc7_kurtosis_sum',
#  'hog_sc7_mean_mean',
#  'hog_sc7_mean_std',
#  'hog_sc7_mean_sum',
#  'hog_sc7_skew_mean',
#  'hog_sc7_skew_std',
#  'hog_sc7_skew_sum',
#  'hog_sc7_variance_mean',
#  'hog_sc7_variance_std',
#  'hog_sc7_variance_sum',
#  'lac_sc3_lac_mean',
#  'lac_sc3_lac_std',
#  'lac_sc3_lac_sum',
#  'lac_sc5_lac_mean',
#  'lac_sc5_lac_std',
#  'lac_sc5_lac_sum',
#  'lac_sc7_lac_mean',
#  'lac_sc7_lac_std',
#  'lac_sc7_lac_sum',
#  'lbpm_sc3_kurtosis_mean',
#  'lbpm_sc3_kurtosis_std',
#  'lbpm_sc3_kurtosis_sum',
#  'lbpm_sc3_max_mean',
#  'lbpm_sc3_max_std',
#  'lbpm_sc3_max_sum',
#  'lbpm_sc3_mean_mean',
#  'lbpm_sc3_mean_std',
#  'lbpm_sc3_mean_sum',
#  'lbpm_sc3_skew_mean',
#  'lbpm_sc3_skew_std',
#  'lbpm_sc3_skew_sum',
#  'lbpm_sc3_variance_mean',
#  'lbpm_sc3_variance_std',
#  'lbpm_sc3_variance_sum',
#  'lbpm_sc5_kurtosis_mean',
#  'lbpm_sc5_kurtosis_std',
#  'lbpm_sc5_kurtosis_sum',
#  'lbpm_sc5_max_mean',
#  'lbpm_sc5_max_std',
#  'lbpm_sc5_max_sum',
#  'lbpm_sc5_mean_mean',
#  'lbpm_sc5_mean_std',
#  'lbpm_sc5_mean_sum',
#  'lbpm_sc5_skew_mean',
#  'lbpm_sc5_skew_std',
#  'lbpm_sc5_skew_sum',
#  'lbpm_sc5_variance_mean',
#  'lbpm_sc5_variance_std',
#  'lbpm_sc5_variance_sum',
#  'lbpm_sc7_kurtosis_mean',
#  'lbpm_sc7_kurtosis_std',
#  'lbpm_sc7_kurtosis_sum',
#  'lbpm_sc7_max_mean',
#  'lbpm_sc7_max_std',
#  'lbpm_sc7_max_sum',
#  'lbpm_sc7_mean_mean',
#  'lbpm_sc7_mean_std',
#  'lbpm_sc7_mean_sum',
#  'lbpm_sc7_skew_mean',
#  'lbpm_sc7_skew_std',
#  'lbpm_sc7_skew_sum',
#  'lbpm_sc7_variance_mean',
#  'lbpm_sc7_variance_std',
#  'lbpm_sc7_variance_sum',
#  'lsr_sc3_line_contrast_mean',
#  'lsr_sc3_line_contrast_std',
#  'lsr_sc3_line_contrast_sum',
#  'lsr_sc3_line_length_mean',
#  'lsr_sc3_line_length_std',
#  'lsr_sc3_line_length_sum',
#  'lsr_sc3_line_mean_mean',
#  'lsr_sc3_line_mean_std',
#  'lsr_sc3_line_mean_sum',
#  'lsr_sc5_line_contrast_mean',
#  'lsr_sc5_line_contrast_std',
#  'lsr_sc5_line_contrast_sum',
#  'lsr_sc5_line_length_mean',
#  'lsr_sc5_line_length_std',
#  'lsr_sc5_line_length_sum',
#  'lsr_sc5_line_mean_mean',
#  'lsr_sc5_line_mean_std',
#  'lsr_sc5_line_mean_sum',
#  'lsr_sc7_line_contrast_mean',
#  'lsr_sc7_line_contrast_std',
#  'lsr_sc7_line_contrast_sum',
#  'lsr_sc7_line_length_mean',
#  'lsr_sc7_line_length_std',
#  'lsr_sc7_line_length_sum',
#  'lsr_sc7_line_mean_mean',
#  'lsr_sc7_line_mean_std',
#  'lsr_sc7_line_mean_sum',
#  'mean_sc3_mean_mean',
#  'mean_sc3_mean_std',
#  'mean_sc3_mean_sum',
#  'mean_sc3_variance_mean',
#  'mean_sc3_variance_std',
#  'mean_sc3_variance_sum',
#  'mean_sc5_mean_mean',
#  'mean_sc5_mean_std',
#  'mean_sc5_mean_sum',
#  'mean_sc5_variance_mean',
#  'mean_sc5_variance_std',
#  'mean_sc5_variance_sum',
#  'mean_sc7_mean_mean',
#  'mean_sc7_mean_std',
#  'mean_sc7_mean_sum',
#  'mean_sc7_variance_mean',
#  'mean_sc7_variance_std',
#  'mean_sc7_variance_sum',
#  'ndvi_sc3_mean_mean',
#  'ndvi_sc3_mean_std',
#  'ndvi_sc3_mean_sum',
#  'ndvi_sc3_variance_mean',
#  'ndvi_sc3_variance_std',
#  'ndvi_sc3_variance_sum',
#  'ndvi_sc5_mean_mean',
#  'ndvi_sc5_mean_std',
#  'ndvi_sc5_mean_sum',
#  'ndvi_sc5_variance_mean',
#  'ndvi_sc5_variance_std',
#  'ndvi_sc5_variance_sum',
#  'ndvi_sc7_mean_mean',
#  'ndvi_sc7_mean_std',
#  'ndvi_sc7_mean_sum',
#  'ndvi_sc7_variance_mean',
#  'ndvi_sc7_variance_std',
#  'ndvi_sc7_variance_sum',
#  'orb_sc31_kurtosis_mean',
#  'orb_sc31_kurtosis_std',
#  'orb_sc31_kurtosis_sum',
#  'orb_sc31_max_mean',
#  'orb_sc31_max_std',
#  'orb_sc31_max_sum',
#  'orb_sc31_mean_mean',
#  'orb_sc31_mean_std',
#  'orb_sc31_mean_sum',
#  'orb_sc31_skew_mean',
#  'orb_sc31_skew_std',
#  'orb_sc31_skew_sum',
#  'orb_sc31_variance_mean',
#  'orb_sc31_variance_std',
#  'orb_sc31_variance_sum',
#  'orb_sc51_kurtosis_mean',
#  'orb_sc51_kurtosis_std',
#  'orb_sc51_kurtosis_sum',
#  'orb_sc51_max_mean',
#  'orb_sc51_max_std',
#  'orb_sc51_max_sum',
#  'orb_sc51_mean_mean',
#  'orb_sc51_mean_std',
#  'orb_sc51_mean_sum',
#  'orb_sc51_skew_mean',
#  'orb_sc51_skew_std',
#  'orb_sc51_skew_sum',
#  'orb_sc51_variance_mean',
#  'orb_sc51_variance_std',
#  'orb_sc51_variance_sum',
#  'orb_sc71_kurtosis_mean',
#  'orb_sc71_kurtosis_std',
#  'orb_sc71_kurtosis_sum',
#  'orb_sc71_max_mean',
#  'orb_sc71_max_std',
#  'orb_sc71_max_sum',
#  'orb_sc71_mean_mean',
#  'orb_sc71_mean_std',
#  'orb_sc71_mean_sum',
#  'orb_sc71_skew_mean',
#  'orb_sc71_skew_std',
#  'orb_sc71_skew_sum',
#  'orb_sc71_variance_mean',
#  'orb_sc71_variance_std',
#  'orb_sc71_variance_sum',
#  'pantex_sc3_min_mean',
#  'pantex_sc3_min_std',
#  'pantex_sc3_min_sum',
#  'pantex_sc5_min_mean',
#  'pantex_sc5_min_std',
#  'pantex_sc5_min_sum',
#  'pantex_sc7_min_mean',
#  'pantex_sc7_min_std',
#  'pantex_sc7_min_sum',
#  'sfs_sc31_max_ll_mean',
#  'sfs_sc31_max_ll_std',
#  'sfs_sc31_max_ll_sum',
#  'sfs_sc31_mean_mean',
#  'sfs_sc31_mean_std',
#  'sfs_sc31_mean_sum',
#  'sfs_sc31_min_ll_mean',
#  'sfs_sc31_min_ll_std',
#  'sfs_sc31_min_ll_sum',
#  'sfs_sc31_roa_mean',
#  'sfs_sc31_roa_std',
#  'sfs_sc31_roa_sum',
#  'sfs_sc31_std_mean',
#  'sfs_sc31_std_std',
#  'sfs_sc31_std_sum',
#  'sfs_sc31_w_mean_mean',
#  'sfs_sc31_w_mean_std',
#  'sfs_sc31_w_mean_sum',
#  'sfs_sc51_max_ll_mean',
#  'sfs_sc51_max_ll_std',
#  'sfs_sc51_max_ll_sum',
#  'sfs_sc51_mean_mean',
#  'sfs_sc51_mean_std',
#  'sfs_sc51_mean_sum',
#  'sfs_sc51_min_ll_mean',
#  'sfs_sc51_min_ll_std',
#  'sfs_sc51_min_ll_sum',
#  'sfs_sc51_roa_mean',
#  'sfs_sc51_roa_std',
#  'sfs_sc51_roa_sum',
#  'sfs_sc51_std_mean',
#  'sfs_sc51_std_std',
#  'sfs_sc51_std_sum',
#  'sfs_sc51_w_mean_mean',
#  'sfs_sc51_w_mean_std',
#  'sfs_sc51_w_mean_sum',
#  'sfs_sc71_max_ll_mean',
#  'sfs_sc71_max_ll_std',
#  'sfs_sc71_max_ll_sum',
#  'sfs_sc71_mean_mean',
#  'sfs_sc71_mean_std',
#  'sfs_sc71_mean_sum',
#  'sfs_sc71_min_ll_mean',
#  'sfs_sc71_min_ll_std',
#  'sfs_sc71_min_ll_sum',
#  'sfs_sc71_roa_mean',
#  'sfs_sc71_roa_std',
#  'sfs_sc71_roa_sum',
#  'sfs_sc71_std_mean',
#  'sfs_sc71_std_std',
#  'sfs_sc71_std_sum']

# %% [markdown]
# ### Compute Coorelation of features with population density

# %% [markdown]
# Store all features with the least correlation (stat. significance (p < 0.05))

# %% [markdown]
# The Pearson correlation coefficient **measures the linear relationship
# between two datasets.** Strictly speaking, Pearson's correlation requires
# that each dataset be **normally distributed, and not necessarily zero-mean.**
#
# Like other correlation coefficients, this one varies between -1 and +1
# with 0 implying no correlation. Correlations of -1 or +1 imply an exact
# linear relationship. Positive correlations imply that as x increases, so
# does y. Negative correlations imply that as x increases, y decreases.
#
# The p-value roughly indicates **the probability of an uncorrelated system**
# producing datasets that have a Pearson correlation at least as extreme
# as the one computed from these datasets.
#
# ***The p-values are not entirely
# reliable but are probably reasonable for datasets larger than 500 or so.***

# %%
spfeas_guf[y_var] = spfeas_guf[y_var].fillna(0)
spfeas_guf[y_var].isnull().values.any()
# Out:
# False

# %%
y_dict = {}
x = []

for x_var in all_x:
    
    #Calculate the Pearson statistics, 
    # returns the Pearson value and p value
    
    p = stats.skew(spfeas_guf[x_var])
    
    #print(y_var, x_var, p)
    # print back for mike
    #print (y_var + " , " + x_var + " , " +  p)

# %%
y_dict = {}
x = []

for x_var in all_x:
    
    #Calculate the Pearson statistics, 
    # returns the Pearson value and p value
    
    p = stats.pearsonr(spfeas_guf[x_var],spfeas_guf[y_var])
    
    # print back for mike
    #print (y_var + " , " + x_var + " , " +  str(p[0]) + " , " + str(p[1]))
    
    #If p < 0.05 append to list x
    if p[1] < 0.05:
        x.append([x_var,abs(p[0])])

#List x is made into a DataFrame 
# which is sorted by the absolute values of the Pearson values
x_df = pd.DataFrame(x,columns=["x_var","abs_r2"]).sort_values("abs_r2",ascending=False)


#The dependent variable dictionary is given an entry 
# where the key is the name of the dependent variable
# and the value is a list of top 200 most significant values

y_dict[y_var] = list(x_df["x_var"][0:200])
#y_dict[y_var]
#Print out each dependent variable and 
#the number of x values that remain to check completion

# %%
x_df.head(15)
# Out:
#                         x_var    abs_r2
# 186     hog_sc7_kurtosis_mean  0.793919
# 281    mean_sc3_variance_mean  0.768958
# 174     hog_sc5_kurtosis_mean  0.766846
# 192         hog_sc7_skew_mean  0.748357
# 371        sfs_sc31_mean_mean  0.734304
# 63    gabor_sc3_variance_mean  0.726576
# 33   gabor_sc3_filter_14_mean  0.726186
# 36    gabor_sc3_filter_2_mean  0.725070
# 180         hog_sc5_skew_mean  0.724472
# 27   gabor_sc3_filter_12_mean  0.724284
# 21   gabor_sc3_filter_10_mean  0.723418
# 54    gabor_sc3_filter_8_mean  0.723347
# 42    gabor_sc3_filter_4_mean  0.723155
# 48    gabor_sc3_filter_6_mean  0.722689
# 162     hog_sc3_kurtosis_mean  0.710457

# %%
#check 

for key in y_dict.keys():
    print(key,len(y_dict[key]))
# Out:
# ghs_mean 200

# %% [markdown]
# ### Correlation Significance

# %% [markdown]
# For each dependent variable y in the list of all dependent values, calibrate the model.
# Add new key to the output dictionary where y is the dependent variable curently being processed and the values are empty for now

# %%
#Initialize the output dictionary, Y_D, 
# with each key being a dependent variable and the values being the results of the analyses

Y_D = {}

Y_D[y_var]={}

#Dictionary Models is used to store each result object for later use if needed

Models ={}

#Get independent variables from the variable dictionary and store in list x_vars
x_vars = y_dict[y_var]


vars_df = pd.DataFrame()

vars_df[y_var] = spfeas_guf[y_var]


for x in x_vars:
    vars_df[x] = spfeas_guf[x]

# %%
vars_df.head()
# Out:
#       ghs_mean  hog_sc7_kurtosis_mean  mean_sc3_variance_mean  \
# gid
# 43       2.702            1232837.607                   3.930
# 564      3.891             582042.462                   2.222
# 7917     1.406             191063.090                   1.108
# 2263    66.169            1713686.816                   6.590
# 8       10.489            1341415.447                   3.319
#
#       hog_sc5_kurtosis_mean  hog_sc7_skew_mean  sfs_sc31_mean_mean  \
# gid
# 43               332095.664           5621.894               4.617
# 564              180522.707           3684.138               3.057
# 7917              89183.994           2482.967               1.646
# 2263             424855.492           5412.451               6.650
# 8                306488.279           4976.435               4.773
#
#       gabor_sc3_variance_mean  gabor_sc3_filter_14_mean  \
# gid
# 43                      1.111                     1.095
# 564                     0.754                     0.737
# 7917                    0.448                     0.448
# 2263                    1.931                     1.904
# 8                       1.041                     1.048
#
#       gabor_sc3_filter_2_mean  hog_sc5_skew_mean  ...  \
# gid                                               ...
# 43                      1.094           2818.422  ...
# 564                     0.746           2076.286  ...
# 7917                    0.446           1514.059  ...
# 2263                    1.903           3254.023  ...
# 8                       1.036           2506.209  ...
#
#       gabor_sc7_filter_10_std  gabor_sc7_filter_6_std  \
# gid
# 43                     10.627                   9.938
# 564                    12.589                  12.906
# 7917                    6.762                   6.661
# 2263                   24.696                  34.773
# 8                      18.068                  17.722
#
#       gabor_sc7_filter_11_std  orb_sc51_skew_std  gabor_sc7_filter_12_std  \
# gid
# 43                      0.545           4458.473                   10.235
# 564                     0.582           3583.986                   12.216
# 7917                    0.346              0.000                    6.563
# 2263                    0.812              0.000                   21.315
# 8                       0.776           2556.833                   17.332
#
#       gabor_sc7_filter_3_std  orb_sc51_mean_std  sfs_sc31_std_mean  \
# gid
# 43                     0.494              0.025              6.886
# 564                    0.603              0.020              6.168
# 7917                   0.341              0.000              4.184
# 2263                   1.507              0.000              6.442
# 8                      0.747              0.007              7.101
#
#       gabor_sc7_filter_4_std  orb_sc51_max_std
# gid
# 43                     9.323             0.654
# 564                   12.926             0.740
# 7917                   6.385             0.000
# 2263                  44.066             0.000
# 8                     16.609             0.261
#
# [5 rows x 201 columns]

# %% [markdown]
# ### Scale/Normalize Data

# %%
minmax_scaler = preprocessing.MinMaxScaler()
standard_scaler = preprocessing.StandardScaler()

names = vars_df.columns
scaled_df = standard_scaler.fit_transform(vars_df)
scaled_df = pd.DataFrame(scaled_df, columns=names)
scaled_df.head()
# Out:
#    ghs_mean  hog_sc7_kurtosis_mean  mean_sc3_variance_mean  \
# 0 -0.405118               1.399884                0.799661
# 1 -0.355411              -0.066859               -0.208227
# 2 -0.459298              -0.948036               -0.865597
# 3  2.248177               2.483608                2.369324
# 4 -0.079575               1.644594                0.439111
#
#    hog_sc5_kurtosis_mean  hog_sc7_skew_mean  sfs_sc31_mean_mean  \
# 0               1.444500           1.531891            1.075406
# 1              -0.164669          -0.206404           -0.018677
# 2              -1.134362          -1.283933           -1.008261
# 3               2.429280           1.344007            2.501221
# 4               1.172640           0.952872            1.184814
#
#    gabor_sc3_variance_mean  gabor_sc3_filter_14_mean  gabor_sc3_filter_2_mean  \
# 0                 0.576564                  0.556021                 0.557298
# 1                -0.247507                 -0.279333                -0.257276
# 2                -0.953854                 -0.953684                -0.959496
# 3                 2.469389                  2.443736                 2.450949
# 4                 0.414981                  0.446352                 0.421536
#
#    hog_sc5_skew_mean  ...  gabor_sc7_filter_10_std  gabor_sc7_filter_6_std  \
# 0           1.509675  ...                -0.297894               -0.365046
# 1          -0.189176  ...                -0.113674               -0.083272
# 2          -1.476190  ...                -0.660794               -0.676156
# 3           2.506825  ...                 1.023100                1.992722
# 4           0.794977  ...                 0.400771                0.373946
#
#    gabor_sc7_filter_11_std  orb_sc51_skew_std  gabor_sc7_filter_12_std  \
# 0                -0.061538           1.693247                -0.294011
# 1                 0.061047           1.165526                -0.098695
# 2                -0.720845          -0.997278                -0.656050
# 3                 0.823060          -0.997278                 0.798418
# 4                 0.703789           0.545677                 0.405716
#
#    gabor_sc7_filter_3_std  orb_sc51_mean_std  sfs_sc31_std_mean  \
# 0               -0.221706           0.236982           0.975934
# 1                0.146810           0.078307           0.173998
# 2               -0.738982          -0.556395          -2.041938
# 3                3.203129          -0.556395           0.480029
# 4                0.633657          -0.334249           1.216069
#
#    gabor_sc7_filter_4_std  orb_sc51_max_std
# 0               -0.387930          0.139299
# 1               -0.026150          0.241595
# 2               -0.682936         -0.638623
# 3                3.100637         -0.638623
# 4                0.343662         -0.328168
#
# [5 rows x 201 columns]

# %%
# #Create a new dataframe for scaled and centered values
# scaled_df = pd.DataFrame()

# #Scale and center the values
# scaled_df[y_var] = scale(pop_count, with_mean=True, with_std=True)


# for x in x_vars:
#     scaled_df[x] = scale(spfeas_world_pop_merged[x], with_mean=True, with_std=True)

# scaled_df = scaled_df.round(3)

# %%
# Y = preprocessing.minmax_scale(vars_df[y_var])
# name='pop_sum'
# Y = pd.DataFrame(Y)
# #X = pd.DataFrame()

# X = scaler.fit_transform(vars_df[x_vars])
# X = pd.DataFrame(X, columns=x_vars)
# Y.head()

# %%
#X.head()

# %% [markdown]
# ### Scale the variables

# %% [markdown]
# ### Set Elastic net's parameters

# %%
enet_result = ElasticNetCV(max_iter=1e8,
                    alphas = [0.0005, 0.001, 0.01, 0.03, 0.05, 0.1],
                    l1_ratio =[.1, .5, .7, .9, .95, .99, 1],
                    verbose= False,
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)

# %%
scaled_df.shape
# Out:
# (14021, 201)

# %%
# Fit the mode

# %%
#Fit the model with the scaled data
X_train, X_test, y_train, y_test = train_test_split(scaled_df[x_vars],scaled_df[y_var], test_size=0.34)
enet_result.fit(X_train,y_train)
#Append the model to the Models dictionary
Models[y_var] = enet_result

# %%
enet_result
# Out:
# ElasticNetCV(alphas=[0.0005, 0.001, 0.01, 0.03, 0.05, 0.1], copy_X=True, cv=5,
#        eps=0.001, fit_intercept=False,
#        l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=100000000.0,
#        n_alphas=100, n_jobs=-1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='random',
#        tol=0.0001, verbose=False)

# %%
opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_

#Print update to ensure that the script is progressing properly
print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[x_vars],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.81 Alpha: 0.0005 l1_ratio: 0.1

# %% [markdown]
# Record the overall R squared score and optimal alpha
# and l1 ratio values and store them in the output dictionary

# %%
Y_D[y_var]['Total R2'] = enet_result.score(scaled_df[x_vars],scaled_df[y_var])
Y_D[y_var]['Alpha'] = opt_alpha
Y_D[y_var]['l1_ratio'] = opt_l1_ratio

# %% [markdown]
# ### Ten Fold Cross validated regression

# %%
#Create a list R2s to store out of sample R squared values

R2s = []

#Specify the number of trials to run

trials = 10

#Run the number of trials specified in trials, 
#for each trial 66% of the observations are randomly selected to train the model
#Testing is done on the remaining 33% of observations and the R squared values are recorded

for i in range(trials):    
    X_train, X_test, y_train, y_test = train_test_split(scaled_df[x_vars],scaled_df[y_var], test_size=0.34)
    enet_regr = ElasticNetCV(max_iter=1e8,
                    alphas = [opt_alpha],
                    l1_ratio =[opt_l1_ratio],
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)
    enet_regr.fit(X_train,y_train)
    R2s.append(enet_regr.score(X_test,y_test))

#print("Mean R2: {:.2f} StDev: {:.4f}".format(mean(R2s),pstdev(R2s)))
#Record the out of sample R squared values
Y_D[y_var]['Sampling']={'trials':trials,'R2':mean(R2s),'StDev':pstdev(R2s),'R2s':R2s}
coefs = [i for i in zip(list(scaled_df[x_vars].axes[1]),enet_result.coef_)]
remaining = [i for i in coefs if abs(i[1])>0.0]
Y_D[y_var]["Coefficients"]=remaining

# %%
Y_D[y_var]
# Out:
# {'Total R2': 0.8133796952192605,
#  'Alpha': 0.01,
#  'l1_ratio': 0.1,
#  'Sampling': {'trials': 10,
#   'R2': 0.8127367522549835,
#   'StDev': 0.004876911949278502,
#   'R2s': [0.8172555343673286,
#    0.8082334554863153,
#    0.8127897744080191,
#    0.8042827592991347,
#    0.8084479130523512,
#    0.8143859182837081,
#    0.8094488205972372,
#    0.8197821402844279,
#    0.8133957761343042,
#    0.8193454306370094]},
#  'Coefficients': [('hog_sc7_kurtosis_mean', 0.18936066528190254),
#   ('mean_sc3_variance_mean', 0.13322126184690722),
#   ('hog_sc5_kurtosis_mean', 0.08487440383463327),
#   ('hog_sc7_skew_mean', 0.03127327861971739),
#   ('gabor_sc3_filter_14_mean', 0.03829858747537948),
#   ('hog_sc5_skew_mean', 0.03435877289137731),
#   ('gabor_sc3_filter_12_mean', 0.045079139127919686),
#   ('gabor_sc3_filter_10_mean', 0.010947240870508742),
#   ('hog_sc3_kurtosis_mean', 0.06365143345903068),
#   ('fourier_sc31_mean_mean', 0.024943235428885338),
#   ('hog_sc3_variance_std', -0.03630845213608007),
#   ('ndvi_sc3_variance_mean', 0.26806836102443454),
#   ('fourier_sc51_mean_mean', 0.08606304457506561),
#   ('sfs_sc31_max_ll_mean', 0.052511283069816006),
#   ('fourier_sc71_mean_mean', 0.1614019764769466),
#   ('hog_sc3_mean_std', -0.037562832349881066),
#   ('hog_sc5_variance_mean', 0.07039167747561939),
#   ('lbpm_sc7_kurtosis_mean', -0.03667015224947907),
#   ('pantex_sc3_min_std', 0.06139493325166643),
#   ('hog_sc7_variance_mean', 0.07373193291895264),
#   ('lbpm_sc3_kurtosis_mean', 0.06853610171864803),
#   ('ndvi_sc7_mean_mean', -0.11345131758653447),
#   ('ndvi_sc5_mean_mean', -0.10501897030274775),
#   ('ndvi_sc3_mean_mean', -0.10126326201176071),
#   ('sfs_sc51_mean_mean', 0.04427181785623478),
#   ('sfs_sc31_w_mean_std', 0.029163371037813923),
#   ('sfs_sc51_w_mean_std', -0.007956173507583769),
#   ('lbpm_sc3_skew_mean', 0.0420116206858205),
#   ('hog_sc3_variance_mean', -0.08396410410232245),
#   ('orb_sc31_kurtosis_mean', 0.031885338817430386),
#   ('mean_sc5_variance_mean', -0.06090838679550821),
#   ('fourier_sc71_variance_mean', -0.10800118029142043),
#   ('sfs_sc31_max_ll_std', -0.06684641840073248),
#   ('hog_sc5_skew_std', -0.019381489189958374),
#   ('fourier_sc51_variance_mean', -0.04245244572823793),
#   ('sfs_sc71_max_ll_mean', -0.005617796098290865),
#   ('sfs_sc51_std_std', 0.022888565899659596),
#   ('ndvi_sc5_variance_mean', 0.0445728451444005),
#   ('sfs_sc51_roa_mean', -0.04566177919208244),
#   ('fourier_sc31_variance_mean', -0.01909006376410351),
#   ('gabor_sc5_filter_8_mean', -0.016730299491975076),
#   ('pantex_sc5_min_mean', -0.09256799734520468),
#   ('gabor_sc5_filter_14_mean', -0.051114335546283696),
#   ('gabor_sc5_filter_10_mean', -0.02112317281921318),
#   ('gabor_sc5_filter_12_mean', -0.03613967805052173),
#   ('mean_sc7_variance_mean', -0.05616217641513665),
#   ('gabor_sc5_filter_6_mean', -0.030788063166521454),
#   ('gabor_sc7_filter_14_mean', -0.011575498185551989),
#   ('gabor_sc5_variance_mean', -0.0658152354480036),
#   ('gabor_sc5_filter_2_mean', -0.06127439162689974),
#   ('gabor_sc5_filter_4_mean', -0.046624267142966136),
#   ('gabor_sc7_variance_mean', -0.025704185594200884),
#   ('gabor_sc7_filter_4_mean', -0.0037517796278442282),
#   ('gabor_sc7_filter_2_mean', -0.024290723371926278),
#   ('lbpm_sc3_variance_std', 0.03233674831006788),
#   ('pantex_sc7_min_mean', -0.1030605359504971),
#   ('sfs_sc71_roa_mean', 0.019442652190243402),
#   ('orb_sc71_max_mean', 0.08498198265393415),
#   ('hog_sc7_variance_std', 0.04033777589326288),
#   ('orb_sc71_mean_mean', 0.11185577196616824),
#   ('gabor_sc7_filter_9_mean', 0.07007733812025528),
#   ('gabor_sc7_filter_7_mean', 0.09468461551999821),
#   ('gabor_sc7_filter_11_mean', 0.023085884465441492),
#   ('gabor_sc7_filter_5_mean', 0.08075044531968907),
#   ('gabor_sc5_filter_9_mean', 0.013436001374089493),
#   ('gabor_sc5_filter_7_mean', 0.02564835563148359),
#   ('gabor_sc5_filter_5_mean', 0.01877155086464048),
#   ('gabor_sc7_filter_3_mean', 0.043623033879753435),
#   ('gabor_sc5_filter_3_mean', 0.004381332030307779),
#   ('gabor_sc7_filter_1_mean', 0.007967202178341053),
#   ('orb_sc31_skew_std', -0.012900370603826608),
#   ('orb_sc31_kurtosis_std', -0.001388240324538824),
#   ('orb_sc31_mean_mean', -0.03683842136638269),
#   ('ndvi_sc3_variance_std', -0.0651902616098493),
#   ('mean_sc5_variance_std', -0.018996121656098236),
#   ('lac_sc5_lac_mean', 0.03337554287788612),
#   ('lac_sc7_lac_mean', 0.03718325992158572),
#   ('lac_sc3_lac_mean', 0.033967694470951736),
#   ('hog_sc3_kurtosis_std', -0.12102020153894553),
#   ('gabor_sc3_mean_std', -0.009846676323756551),
#   ('lbpm_sc5_variance_mean', -0.034400347301978274),
#   ('gabor_sc5_filter_8_std', -0.011506520269852378),
#   ('lbpm_sc3_skew_std', 0.044491387748035495),
#   ('gabor_sc5_filter_6_std', -0.01467206416890493),
#   ('gabor_sc5_filter_10_std', -0.0010319485336255762),
#   ('gabor_sc5_filter_4_std', -0.002748946908902587),
#   ('hog_sc7_kurtosis_std', -0.028388197849494128),
#   ('sfs_sc51_max_ll_std', 0.10125403647911374),
#   ('gabor_sc5_mean_std', -0.006230219505881403),
#   ('gabor_sc7_variance_std', 0.036522302357038294),
#   ('mean_sc7_variance_std', -0.04611111040133117),
#   ('gabor_sc7_filter_14_std', 0.05705822461916867),
#   ('lbpm_sc7_variance_mean', -0.020207842885447375),
#   ('orb_sc51_skew_std', -0.031157196047636792),
#   ('sfs_sc31_std_mean', -0.0018448609293002663),
#   ('gabor_sc7_filter_4_std', -0.0030032843731158027),
#   ('mean_sc7_mean_std', -0.017676142833701683),
#   ('orb_sc51_variance_mean', -0.05868622338984441),
#   ('orb_sc71_variance_mean', -0.02492388080192018),
#   ('lbpm_sc5_mean_std', 0.00045811686084664256),
#   ('lbpm_sc3_mean_std', 0.010611939413719075),
#   ('lbpm_sc7_max_std', -0.11776850276294298),
#   ('orb_sc71_max_std', -0.030479166876235954),
#   ('fourier_sc51_mean_std', -0.01694188755411542),
#   ('ndvi_sc3_mean_std', -0.005545509023133657),
#   ('sfs_sc71_min_ll_std', -0.022768063820870335),
#   ('lbpm_sc3_max_mean', 0.1300427549619717),
#   ('fourier_sc71_variance_std', -0.0361604496903329),
#   ('fourier_sc31_mean_std', -0.04713943996875027),
#   ('ndvi_sc5_mean_std', -0.06273210571029289),
#   ('orb_sc71_kurtosis_std', 0.03041140707124672),
#   ('lsr_sc7_line_mean_std', 0.04634378313113717),
#   ('lac_sc3_lac_std', 0.006633770727288216),
#   ('lac_sc5_lac_std', 0.0062152097032444785),
#   ('lac_sc7_lac_std', 0.006322614014777518),
#   ('lsr_sc5_line_mean_std', 0.0014139631494556716),
#   ('fourier_sc31_variance_std', 0.1119546074215084),
#   ('orb_sc51_variance_std', 0.0037581050975778545),
#   ('ndvi_sc7_mean_std', -0.10924370510251614),
#   ('hog_sc5_kurtosis_std', -0.009022563543326041),
#   ('orb_sc71_variance_std', 0.019335627069588326),
#   ('lbpm_sc7_kurtosis_std', -0.06038272995653941),
#   ('lsr_sc3_line_mean_std', -0.09597373449171077),
#   ('lsr_sc3_line_length_std', 0.005884055462241628),
#   ('lbpm_sc5_max_std', 0.058144422924401376),
#   ('ndvi_sc5_variance_std', 0.1637038645989176),
#   ('sfs_sc31_w_mean_mean', -0.029660342238838695),
#   ('lbpm_sc5_skew_std', 0.06188767457797357),
#   ('sfs_sc51_max_ll_sum', 0.015109227329178472),
#   ('lsr_sc5_line_contrast_mean', 0.012453207250474317),
#   ('lbpm_sc5_max_mean', 0.08182017278661752),
#   ('sfs_sc71_max_ll_sum', 0.08331017001971716),
#   ('sfs_sc31_roa_std', 0.0033957841670271345),
#   ('sfs_sc71_roa_std', -0.030948022618424987),
#   ('sfs_sc71_min_ll_mean', -0.032380962080685444),
#   ('orb_sc31_max_sum', -0.015596667820664184),
#   ('sfs_sc51_mean_sum', -0.04159205988680035),
#   ('hog_sc5_mean_mean', 0.007209606360891588),
#   ('orb_sc71_mean_sum', 0.008161652873033364),
#   ('lsr_sc7_line_contrast_mean', 0.02481259227373558),
#   ('sfs_sc31_w_mean_sum', 0.04106225506164068),
#   ('hog_sc3_variance_sum', 0.009032503929752233),
#   ('hog_sc5_skew_sum', -0.002674226866919176),
#   ('hog_sc7_skew_sum', -0.1267648690256817),
#   ('lsr_sc5_line_mean_sum', 0.0033117213687703286),
#   ('lbpm_sc3_kurtosis_std', -0.0376412657435664),
#   ('lsr_sc7_line_mean_sum', 0.02061015814323416)]}

# %%
y_df = pd.DataFrame([i for i in zip(list(scaled_df[x_vars].axes[1]),enet_result.coef_)], 
                    columns=["features","Coeff"]).sort_values("Coeff", ascending=False)

y_df.head(50)
# Out:
#                        features     Coeff
# 14        hog_sc3_kurtosis_mean  0.792804
# 45             hog_sc3_skew_std  0.615455
# 56       ndvi_sc5_variance_mean  0.591431
# 183     gabor_sc7_filter_14_std  0.454253
# 1        mean_sc3_variance_mean  0.438303
# 6      gabor_sc3_filter_14_mean  0.407949
# 87           orb_sc71_mean_mean  0.389849
# 177      gabor_sc7_variance_std  0.383471
# 32       lbpm_sc3_kurtosis_mean  0.358033
# 92      gabor_sc7_filter_5_mean  0.354090
# 89      gabor_sc7_filter_7_mean  0.343500
# 53   fourier_sc51_variance_mean  0.339479
# 20       fourier_sc71_mean_mean  0.305427
# 106           orb_sc31_max_mean  0.301246
# 135      lbpm_sc3_variance_mean  0.295873
# 17       ndvi_sc3_variance_mean  0.260144
# 88      gabor_sc7_filter_9_mean  0.258871
# 100     gabor_sc7_filter_3_mean  0.256187
# 168      gabor_sc5_filter_7_std  0.241485
# 0         hog_sc7_kurtosis_mean  0.209930
# 191      gabor_sc7_filter_6_std  0.205805
# 141          orb_sc51_skew_mean  0.178386
# 9      gabor_sc3_filter_12_mean  0.162233
# 19         sfs_sc31_max_ll_mean  0.157919
# 28       lbpm_sc5_kurtosis_mean  0.151624
# 133           mean_sc3_mean_std  0.149132
# 82            sfs_sc71_roa_mean  0.143977
# 175      gabor_sc5_filter_5_std  0.140013
# 114     gabor_sc7_filter_1_mean  0.127226
# 23        hog_sc5_variance_mean  0.124981
# 40           lbpm_sc5_skew_mean  0.115636
# 25          pantex_sc3_min_mean  0.115067
# 2         hog_sc5_kurtosis_mean  0.113930
# 128      gabor_sc3_filter_6_std  0.113795
# 55             sfs_sc51_std_std  0.105735
# 31        hog_sc7_variance_mean  0.099439
# 27            sfs_sc31_roa_mean  0.095787
# 174          lbpm_sc5_mean_mean  0.094807
# 158      gabor_sc5_filter_6_std  0.093981
# 148      gabor_sc3_filter_5_std  0.092286
# 30           pantex_sc3_min_std  0.091640
# 86         hog_sc7_variance_std  0.091061
# 136       lbpm_sc7_variance_std  0.083132
# 76      gabor_sc7_variance_mean  0.081677
# 90     gabor_sc7_filter_11_mean  0.081192
# 116     gabor_sc3_filter_14_std  0.080651
# 95      gabor_sc5_filter_7_mean  0.075207
# 144      gabor_sc3_filter_7_std  0.071844
# 139            lac_sc3_lac_mean  0.068161
# 83            orb_sc71_max_mean  0.067997

# %% [markdown]
# ## HOG

# %%
filter_var = [col for col in scaled_df if col.startswith('hog')]
X_train, X_test, y_train, y_test = train_test_split(scaled_df[filter_var],scaled_df[y_var], test_size=0.34)
enet_result.fit(X_train,y_train)

Models[y_var] = enet_result

opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_


print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[filter_var],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.70 Alpha: 0.0005 l1_ratio: 1.0

# %% [markdown]
# ## LBPM

# %%
filter_var = [col for col in scaled_df if col.startswith('lbpm')]
X_train, X_test, y_train, y_test = train_test_split(scaled_df[filter_var],scaled_df[y_var], test_size=0.34)
enet_result.fit(X_train,y_train)

Models[y_var] = enet_result

opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_


print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[filter_var],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.65 Alpha: 0.0005 l1_ratio: 1.0

# %% [markdown]
# ## Gabor

# %%
filter_var = [col for col in scaled_df if col.startswith('gabor')]
X_train, X_test, y_train, y_test = train_test_split(scaled_df[filter_var],scaled_df[y_var], test_size=0.34)
enet_result.fit(X_train,y_train)

Models[y_var] = enet_result

opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_


print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[filter_var],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.64 Alpha: 0.0005 l1_ratio: 0.1

# %% [markdown]
# ## Fourier

# %%
ilter_var = [col for col in scaled_df if col.startswith('fourier')]
X_train, X_test, y_train, y_test = train_test_split(scaled_df[filter_var],scaled_df[y_var], test_size=0.34)
enet_result.fit(X_train,y_train)

Models[y_var] = enet_result

opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_


print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[filter_var],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.64 Alpha: 0.0005 l1_ratio: 0.1
