# %% [markdown]
# # Introduction

# %%
import sklearn
import pandas as pd
import numpy as np
import csv
import scipy.stats as stats
from statistics import pstdev
from statistics import mean
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from itertools import product
import copy

# %%
df = pd.read_excel('sri_spfeas_v3.xlsx', sheet_name=0)

# %%
#Ensure that the GN_Code field is of type int and make it the index
df['gid'] = df['gid'].astype(int)
df = df.set_index('gid')

# %%
df.head()
# Out:
#       fid              gnd_n    gnd_c  fourier_sc31_mean_mean  \
# gid
# 43      0  Karagaskada South  2148065               69.453586
# 564     1            Panvila  2115070               59.535572
# 7917    2          Ganepalla  9227135               50.730112
# 2263    3    Akkaraipattu 11  5236065               73.670361
# 8       4       Delgasthenna  2109125               66.878083
#
#       fourier_sc31_mean_std  fourier_sc31_mean_sum  \
# gid
# 43                 3.136141           2.376702e+05
# 564                7.845283           1.400872e+06
# 7917               5.682764           3.625884e+06
# 2263               1.821871           9.731855e+04
# 8                  2.710715           2.657735e+05
#
#       fourier_sc31_variance_mean  fourier_sc31_variance_std  \
# gid
# 43                     18.629130                   0.976240
# 564                    17.086123                   2.204723
# 7917                   14.450501                   2.109653
# 2263                   18.843218                   1.231690
# 8                      18.708531                   1.015577
#
#       fourier_sc31_variance_sum  fourier_sc51_mean_mean  ...  \
# gid                                                      ...
# 43                 6.374888e+04               78.493900  ...
# 564                4.020365e+05               69.651317  ...
# 7917               1.032835e+06               60.710447  ...
# 2263               2.489189e+04               82.544710  ...
# 8                  7.434770e+04               75.957167  ...
#
#       sfs_sc71_min_ll_sum  sfs_sc71_roa_mean  sfs_sc71_roa_std  \
# gid
# 43                   3933         136.394391          0.938602
# 564              40076188         137.910516          2.093903
# 7917           7900571136         139.556597          2.014015
# 2263                 1331         136.077853          0.267941
# 8                    4809         136.681028          1.377590
#
#       sfs_sc71_roa_sum  sfs_sc71_std_mean  sfs_sc71_std_std  sfs_sc71_std_sum  \
# gid
# 43              466878          16.233955          3.648450      55568.828125
# 564            3245724          14.498129          5.118067     341213.468750
# 7917           9974110           9.856942          7.202832     704475.625000
# 2263            180031          10.558998          4.329045      13969.554688
# 8               542487          15.218429          4.465160      60401.945312
#
#       sfs_sc71_w_mean_mean  sfs_sc71_w_mean_std  sfs_sc71_w_mean_sum
# gid
# 43                1.228705             0.707158          4205.858398
# 564               2.838843             3.471181         66812.164062
# 7917              3.388618             5.864246        242184.515625
# 2263              0.514668             0.239074           680.906372
# 8                 1.180995             0.868924          4687.369141
#
# [5 rows x 426 columns]

# %%
df.shape
# Out:
# (14021, 426)

# %%
depvar = pd.read_csv("sri_ghs.csv")

# %%
depvar.shape
# Out:
# (14021, 13)

# %%
depvar['gid'] = depvar['gid'].astype(int)
depvar = depvar.set_index('gid')

# %%
depvar.head()
# Out:
#                   gnd_n    gnd_c  prov_c  dis_c  dsd_c      GN_Area  \
# gid
# 43    Karagaskada South  2148065       2     21   2148   337190.326
# 564             Panvila  2115070       2     21   2115  2316039.056
# 7917          Ganepalla  9227135       9     92   9227  7042858.261
# 2263    Akkaraipattu 11  5236065       5     52   5236   130560.240
# 8          Delgasthenna  2109125       2     21   2109   390874.578
#
#       lka_count      lka_sum    lka_mean  ghs_count  ghs_sum   ghs_mean
# gid
# 43         34.0  1158.294682   34.067491        235      635   2.702128
# 564       232.0  2185.832124    9.421690       1626     6326   3.890529
# 7917      706.0  1836.615909    2.601439       4929     6929   1.405762
# 2263       11.0  1248.624039  113.511276         89     5889  66.168539
# 8          38.0  1701.824509   44.784855        274     2874  10.489051

# %%
merged = df.merge(depvar, left_on='gnd_c', right_on='gnd_c', how='outer')

# %%
stats.describe(merged['ghs_mean'])
# Out:
# DescribeResult(nobs=14021, minmax=(1.0, 101.0), mean=12.392446343557369, variance=572.2103732068704, skewness=2.44133226610882, kurtosis=4.875565418551456)

# %%
#Get the list of dependent variables from the DataFrame to store in list y_vars
y_var = list(merged.axes[1])[436]
#Initialize a dictionary to store independent variables for each dependent variable 
y_dict = {}
#Get a list of all independent variables from the DataFrame in list all_x
all_x = list(merged.axes[1])[3:426]
y_var
# Out:
# 'ghs_mean'

# %%
all_x
# Out:
# ['fourier_sc31_mean_mean',
#  'fourier_sc31_mean_std',
#  'fourier_sc31_mean_sum',
#  'fourier_sc31_variance_mean',
#  'fourier_sc31_variance_std',
#  'fourier_sc31_variance_sum',
#  'fourier_sc51_mean_mean',
#  'fourier_sc51_mean_std',
#  'fourier_sc51_mean_sum',
#  'fourier_sc51_variance_mean',
#  'fourier_sc51_variance_std',
#  'fourier_sc51_variance_sum',
#  'fourier_sc71_mean_mean',
#  'fourier_sc71_mean_std',
#  'fourier_sc71_mean_sum',
#  'fourier_sc71_variance_mean',
#  'fourier_sc71_variance_std',
#  'fourier_sc71_variance_sum',
#  'gabor_sc3_filter_1_mean',
#  'gabor_sc3_filter_1_std',
#  'gabor_sc3_filter_1_sum',
#  'gabor_sc3_filter_10_mean',
#  'gabor_sc3_filter_10_std',
#  'gabor_sc3_filter_10_sum',
#  'gabor_sc3_filter_11_mean',
#  'gabor_sc3_filter_11_std',
#  'gabor_sc3_filter_11_sum',
#  'gabor_sc3_filter_12_mean',
#  'gabor_sc3_filter_12_std',
#  'gabor_sc3_filter_12_sum',
#  'gabor_sc3_filter_13_mean',
#  'gabor_sc3_filter_13_std',
#  'gabor_sc3_filter_13_sum',
#  'gabor_sc3_filter_14_mean',
#  'gabor_sc3_filter_14_std',
#  'gabor_sc3_filter_14_sum',
#  'gabor_sc3_filter_2_mean',
#  'gabor_sc3_filter_2_std',
#  'gabor_sc3_filter_2_sum',
#  'gabor_sc3_filter_3_mean',
#  'gabor_sc3_filter_3_std',
#  'gabor_sc3_filter_3_sum',
#  'gabor_sc3_filter_4_mean',
#  'gabor_sc3_filter_4_std',
#  'gabor_sc3_filter_4_sum',
#  'gabor_sc3_filter_5_mean',
#  'gabor_sc3_filter_5_std',
#  'gabor_sc3_filter_5_sum',
#  'gabor_sc3_filter_6_mean',
#  'gabor_sc3_filter_6_std',
#  'gabor_sc3_filter_6_sum',
#  'gabor_sc3_filter_7_mean',
#  'gabor_sc3_filter_7_std',
#  'gabor_sc3_filter_7_sum',
#  'gabor_sc3_filter_8_mean',
#  'gabor_sc3_filter_8_std',
#  'gabor_sc3_filter_8_sum',
#  'gabor_sc3_filter_9_mean',
#  'gabor_sc3_filter_9_std',
#  'gabor_sc3_filter_9_sum',
#  'gabor_sc3_mean_mean',
#  'gabor_sc3_mean_std',
#  'gabor_sc3_mean_sum',
#  'gabor_sc3_variance_mean',
#  'gabor_sc3_variance_std',
#  'gabor_sc3_variance_sum',
#  'gabor_sc5_filter_1_mean',
#  'gabor_sc5_filter_1_std',
#  'gabor_sc5_filter_1_sum',
#  'gabor_sc5_filter_10_mean',
#  'gabor_sc5_filter_10_std',
#  'gabor_sc5_filter_10_sum',
#  'gabor_sc5_filter_11_mean',
#  'gabor_sc5_filter_11_std',
#  'gabor_sc5_filter_11_sum',
#  'gabor_sc5_filter_12_mean',
#  'gabor_sc5_filter_12_std',
#  'gabor_sc5_filter_12_sum',
#  'gabor_sc5_filter_13_mean',
#  'gabor_sc5_filter_13_std',
#  'gabor_sc5_filter_13_sum',
#  'gabor_sc5_filter_14_mean',
#  'gabor_sc5_filter_14_std',
#  'gabor_sc5_filter_14_sum',
#  'gabor_sc5_filter_2_mean',
#  'gabor_sc5_filter_2_std',
#  'gabor_sc5_filter_2_sum',
#  'gabor_sc5_filter_3_mean',
#  'gabor_sc5_filter_3_std',
#  'gabor_sc5_filter_3_sum',
#  'gabor_sc5_filter_4_mean',
#  'gabor_sc5_filter_4_std',
#  'gabor_sc5_filter_4_sum',
#  'gabor_sc5_filter_5_mean',
#  'gabor_sc5_filter_5_std',
#  'gabor_sc5_filter_5_sum',
#  'gabor_sc5_filter_6_mean',
#  'gabor_sc5_filter_6_std',
#  'gabor_sc5_filter_6_sum',
#  'gabor_sc5_filter_7_mean',
#  'gabor_sc5_filter_7_std',
#  'gabor_sc5_filter_7_sum',
#  'gabor_sc5_filter_8_mean',
#  'gabor_sc5_filter_8_std',
#  'gabor_sc5_filter_8_sum',
#  'gabor_sc5_filter_9_mean',
#  'gabor_sc5_filter_9_std',
#  'gabor_sc5_filter_9_sum',
#  'gabor_sc5_mean_mean',
#  'gabor_sc5_mean_std',
#  'gabor_sc5_mean_sum',
#  'gabor_sc5_variance_mean',
#  'gabor_sc5_variance_std',
#  'gabor_sc5_variance_sum',
#  'gabor_sc7_filter_1_mean',
#  'gabor_sc7_filter_1_std',
#  'gabor_sc7_filter_1_sum',
#  'gabor_sc7_filter_10_mean',
#  'gabor_sc7_filter_10_std',
#  'gabor_sc7_filter_10_sum',
#  'gabor_sc7_filter_11_mean',
#  'gabor_sc7_filter_11_std',
#  'gabor_sc7_filter_11_sum',
#  'gabor_sc7_filter_12_mean',
#  'gabor_sc7_filter_12_std',
#  'gabor_sc7_filter_12_sum',
#  'gabor_sc7_filter_13_mean',
#  'gabor_sc7_filter_13_std',
#  'gabor_sc7_filter_13_sum',
#  'gabor_sc7_filter_14_mean',
#  'gabor_sc7_filter_14_std',
#  'gabor_sc7_filter_14_sum',
#  'gabor_sc7_filter_2_mean',
#  'gabor_sc7_filter_2_std',
#  'gabor_sc7_filter_2_sum',
#  'gabor_sc7_filter_3_mean',
#  'gabor_sc7_filter_3_std',
#  'gabor_sc7_filter_3_sum',
#  'gabor_sc7_filter_4_mean',
#  'gabor_sc7_filter_4_std',
#  'gabor_sc7_filter_4_sum',
#  'gabor_sc7_filter_5_mean',
#  'gabor_sc7_filter_5_std',
#  'gabor_sc7_filter_5_sum',
#  'gabor_sc7_filter_6_mean',
#  'gabor_sc7_filter_6_std',
#  'gabor_sc7_filter_6_sum',
#  'gabor_sc7_filter_7_mean',
#  'gabor_sc7_filter_7_std',
#  'gabor_sc7_filter_7_sum',
#  'gabor_sc7_filter_8_mean',
#  'gabor_sc7_filter_8_std',
#  'gabor_sc7_filter_8_sum',
#  'gabor_sc7_filter_9_mean',
#  'gabor_sc7_filter_9_std',
#  'gabor_sc7_filter_9_sum',
#  'gabor_sc7_mean_mean',
#  'gabor_sc7_mean_std',
#  'gabor_sc7_mean_sum',
#  'gabor_sc7_variance_mean',
#  'gabor_sc7_variance_std',
#  'gabor_sc7_variance_sum',
#  'hog_sc3_kurtosis_mean',
#  'hog_sc3_kurtosis_std',
#  'hog_sc3_kurtosis_sum',
#  'hog_sc3_mean_mean',
#  'hog_sc3_mean_std',
#  'hog_sc3_mean_sum',
#  'hog_sc3_skew_mean',
#  'hog_sc3_skew_std',
#  'hog_sc3_skew_sum',
#  'hog_sc3_variance_mean',
#  'hog_sc3_variance_std',
#  'hog_sc3_variance_sum',
#  'hog_sc5_kurtosis_mean',
#  'hog_sc5_kurtosis_std',
#  'hog_sc5_kurtosis_sum',
#  'hog_sc5_mean_mean',
#  'hog_sc5_mean_std',
#  'hog_sc5_mean_sum',
#  'hog_sc5_skew_mean',
#  'hog_sc5_skew_std',
#  'hog_sc5_skew_sum',
#  'hog_sc5_variance_mean',
#  'hog_sc5_variance_std',
#  'hog_sc5_variance_sum',
#  'hog_sc7_kurtosis_mean',
#  'hog_sc7_kurtosis_std',
#  'hog_sc7_kurtosis_sum',
#  'hog_sc7_mean_mean',
#  'hog_sc7_mean_std',
#  'hog_sc7_mean_sum',
#  'hog_sc7_skew_mean',
#  'hog_sc7_skew_std',
#  'hog_sc7_skew_sum',
#  'hog_sc7_variance_mean',
#  'hog_sc7_variance_std',
#  'hog_sc7_variance_sum',
#  'lac_sc3_lac_mean',
#  'lac_sc3_lac_std',
#  'lac_sc3_lac_sum',
#  'lac_sc5_lac_mean',
#  'lac_sc5_lac_std',
#  'lac_sc5_lac_sum',
#  'lac_sc7_lac_mean',
#  'lac_sc7_lac_std',
#  'lac_sc7_lac_sum',
#  'lbpm_sc3_kurtosis_mean',
#  'lbpm_sc3_kurtosis_std',
#  'lbpm_sc3_kurtosis_sum',
#  'lbpm_sc3_max_mean',
#  'lbpm_sc3_max_std',
#  'lbpm_sc3_max_sum',
#  'lbpm_sc3_mean_mean',
#  'lbpm_sc3_mean_std',
#  'lbpm_sc3_mean_sum',
#  'lbpm_sc3_skew_mean',
#  'lbpm_sc3_skew_std',
#  'lbpm_sc3_skew_sum',
#  'lbpm_sc3_variance_mean',
#  'lbpm_sc3_variance_std',
#  'lbpm_sc3_variance_sum',
#  'lbpm_sc5_kurtosis_mean',
#  'lbpm_sc5_kurtosis_std',
#  'lbpm_sc5_kurtosis_sum',
#  'lbpm_sc5_max_mean',
#  'lbpm_sc5_max_std',
#  'lbpm_sc5_max_sum',
#  'lbpm_sc5_mean_mean',
#  'lbpm_sc5_mean_std',
#  'lbpm_sc5_mean_sum',
#  'lbpm_sc5_skew_mean',
#  'lbpm_sc5_skew_std',
#  'lbpm_sc5_skew_sum',
#  'lbpm_sc5_variance_mean',
#  'lbpm_sc5_variance_std',
#  'lbpm_sc5_variance_sum',
#  'lbpm_sc7_kurtosis_mean',
#  'lbpm_sc7_kurtosis_std',
#  'lbpm_sc7_kurtosis_sum',
#  'lbpm_sc7_max_mean',
#  'lbpm_sc7_max_std',
#  'lbpm_sc7_max_sum',
#  'lbpm_sc7_mean_mean',
#  'lbpm_sc7_mean_std',
#  'lbpm_sc7_mean_sum',
#  'lbpm_sc7_skew_mean',
#  'lbpm_sc7_skew_std',
#  'lbpm_sc7_skew_sum',
#  'lbpm_sc7_variance_mean',
#  'lbpm_sc7_variance_std',
#  'lbpm_sc7_variance_sum',
#  'lsr_sc3_line_contrast_mean',
#  'lsr_sc3_line_contrast_std',
#  'lsr_sc3_line_contrast_sum',
#  'lsr_sc3_line_length_mean',
#  'lsr_sc3_line_length_std',
#  'lsr_sc3_line_length_sum',
#  'lsr_sc3_line_mean_mean',
#  'lsr_sc3_line_mean_std',
#  'lsr_sc3_line_mean_sum',
#  'lsr_sc5_line_contrast_mean',
#  'lsr_sc5_line_contrast_std',
#  'lsr_sc5_line_contrast_sum',
#  'lsr_sc5_line_length_mean',
#  'lsr_sc5_line_length_std',
#  'lsr_sc5_line_length_sum',
#  'lsr_sc5_line_mean_mean',
#  'lsr_sc5_line_mean_std',
#  'lsr_sc5_line_mean_sum',
#  'lsr_sc7_line_contrast_mean',
#  'lsr_sc7_line_contrast_std',
#  'lsr_sc7_line_contrast_sum',
#  'lsr_sc7_line_length_mean',
#  'lsr_sc7_line_length_std',
#  'lsr_sc7_line_length_sum',
#  'lsr_sc7_line_mean_mean',
#  'lsr_sc7_line_mean_std',
#  'lsr_sc7_line_mean_sum',
#  'mean_sc3_mean_mean',
#  'mean_sc3_mean_std',
#  'mean_sc3_mean_sum',
#  'mean_sc3_variance_mean',
#  'mean_sc3_variance_std',
#  'mean_sc3_variance_sum',
#  'mean_sc5_mean_mean',
#  'mean_sc5_mean_std',
#  'mean_sc5_mean_sum',
#  'mean_sc5_variance_mean',
#  'mean_sc5_variance_std',
#  'mean_sc5_variance_sum',
#  'mean_sc7_mean_mean',
#  'mean_sc7_mean_std',
#  'mean_sc7_mean_sum',
#  'mean_sc7_variance_mean',
#  'mean_sc7_variance_std',
#  'mean_sc7_variance_sum',
#  'ndvi_sc3_mean_mean',
#  'ndvi_sc3_mean_std',
#  'ndvi_sc3_mean_sum',
#  'ndvi_sc3_variance_mean',
#  'ndvi_sc3_variance_std',
#  'ndvi_sc3_variance_sum',
#  'ndvi_sc5_mean_mean',
#  'ndvi_sc5_mean_std',
#  'ndvi_sc5_mean_sum',
#  'ndvi_sc5_variance_mean',
#  'ndvi_sc5_variance_std',
#  'ndvi_sc5_variance_sum',
#  'ndvi_sc7_mean_mean',
#  'ndvi_sc7_mean_std',
#  'ndvi_sc7_mean_sum',
#  'ndvi_sc7_variance_mean',
#  'ndvi_sc7_variance_std',
#  'ndvi_sc7_variance_sum',
#  'orb_sc31_kurtosis_mean',
#  'orb_sc31_kurtosis_std',
#  'orb_sc31_kurtosis_sum',
#  'orb_sc31_max_mean',
#  'orb_sc31_max_std',
#  'orb_sc31_max_sum',
#  'orb_sc31_mean_mean',
#  'orb_sc31_mean_std',
#  'orb_sc31_mean_sum',
#  'orb_sc31_skew_mean',
#  'orb_sc31_skew_std',
#  'orb_sc31_skew_sum',
#  'orb_sc31_variance_mean',
#  'orb_sc31_variance_std',
#  'orb_sc31_variance_sum',
#  'orb_sc51_kurtosis_mean',
#  'orb_sc51_kurtosis_std',
#  'orb_sc51_kurtosis_sum',
#  'orb_sc51_max_mean',
#  'orb_sc51_max_std',
#  'orb_sc51_max_sum',
#  'orb_sc51_mean_mean',
#  'orb_sc51_mean_std',
#  'orb_sc51_mean_sum',
#  'orb_sc51_skew_mean',
#  'orb_sc51_skew_std',
#  'orb_sc51_skew_sum',
#  'orb_sc51_variance_mean',
#  'orb_sc51_variance_std',
#  'orb_sc51_variance_sum',
#  'orb_sc71_kurtosis_mean',
#  'orb_sc71_kurtosis_std',
#  'orb_sc71_kurtosis_sum',
#  'orb_sc71_max_mean',
#  'orb_sc71_max_std',
#  'orb_sc71_max_sum',
#  'orb_sc71_mean_mean',
#  'orb_sc71_mean_std',
#  'orb_sc71_mean_sum',
#  'orb_sc71_skew_mean',
#  'orb_sc71_skew_std',
#  'orb_sc71_skew_sum',
#  'orb_sc71_variance_mean',
#  'orb_sc71_variance_std',
#  'orb_sc71_variance_sum',
#  'pantex_sc3_min_mean',
#  'pantex_sc3_min_std',
#  'pantex_sc3_min_sum',
#  'pantex_sc5_min_mean',
#  'pantex_sc5_min_std',
#  'pantex_sc5_min_sum',
#  'pantex_sc7_min_mean',
#  'pantex_sc7_min_std',
#  'pantex_sc7_min_sum',
#  'sfs_sc31_max_ll_mean',
#  'sfs_sc31_max_ll_std',
#  'sfs_sc31_max_ll_sum',
#  'sfs_sc31_mean_mean',
#  'sfs_sc31_mean_std',
#  'sfs_sc31_mean_sum',
#  'sfs_sc31_min_ll_mean',
#  'sfs_sc31_min_ll_std',
#  'sfs_sc31_min_ll_sum',
#  'sfs_sc31_roa_mean',
#  'sfs_sc31_roa_std',
#  'sfs_sc31_roa_sum',
#  'sfs_sc31_std_mean',
#  'sfs_sc31_std_std',
#  'sfs_sc31_std_sum',
#  'sfs_sc31_w_mean_mean',
#  'sfs_sc31_w_mean_std',
#  'sfs_sc31_w_mean_sum',
#  'sfs_sc51_max_ll_mean',
#  'sfs_sc51_max_ll_std',
#  'sfs_sc51_max_ll_sum',
#  'sfs_sc51_mean_mean',
#  'sfs_sc51_mean_std',
#  'sfs_sc51_mean_sum',
#  'sfs_sc51_min_ll_mean',
#  'sfs_sc51_min_ll_std',
#  'sfs_sc51_min_ll_sum',
#  'sfs_sc51_roa_mean',
#  'sfs_sc51_roa_std',
#  'sfs_sc51_roa_sum',
#  'sfs_sc51_std_mean',
#  'sfs_sc51_std_std',
#  'sfs_sc51_std_sum',
#  'sfs_sc51_w_mean_mean',
#  'sfs_sc51_w_mean_std',
#  'sfs_sc51_w_mean_sum',
#  'sfs_sc71_max_ll_mean',
#  'sfs_sc71_max_ll_std',
#  'sfs_sc71_max_ll_sum',
#  'sfs_sc71_mean_mean',
#  'sfs_sc71_mean_std',
#  'sfs_sc71_mean_sum',
#  'sfs_sc71_min_ll_mean',
#  'sfs_sc71_min_ll_std',
#  'sfs_sc71_min_ll_sum',
#  'sfs_sc71_roa_mean',
#  'sfs_sc71_roa_std',
#  'sfs_sc71_roa_sum',
#  'sfs_sc71_std_mean',
#  'sfs_sc71_std_std',
#  'sfs_sc71_std_sum',
#  'sfs_sc71_w_mean_mean',
#  'sfs_sc71_w_mean_std',
#  'sfs_sc71_w_mean_sum']

# %% [markdown]
# # With the whole dataset

# %% [markdown]
# Check Relationship with pearson Correlation

# %%
#Variable x is an empty list that will cotnain all significant (p < 0.05) independent variables
x = []
for x_var in all_x:
    #Calculate the Pearson statistics, returns the Pearson value and p value
    p = stats.pearsonr(merged[x_var],merged[y_var])
    # print back for mike
    print (y_var + " , " + x_var + " , " +  str(p[0]) + " , " + str(p[1]))
    #If p < 0.05 append to list x
    if p[1] < 0.05:
        x.append([x_var,abs(p[0])])
        
#List x is made into a DataFrame which is sorted by the absolute values of the Pearson values
x_df = pd.DataFrame(x,columns=["x_var","abs_r2"]).sort_values("abs_r2",ascending=False)

#The dependent variable dictionary is given an entry where the key is the name of the dependent variable
# and the value is a list of top 200 most significant values

y_dict[y_var] = list(x_df["x_var"][0:294])
#Print out each dependent variable and the number of x values that remain to check completion
for key in y_dict.keys():
    print(key,len(y_dict[key]))
# Out:
# ghs_mean , fourier_sc31_mean_mean , 0.7091570337201256 , 0.0
# ghs_mean , fourier_sc31_mean_std , -0.2729866171423062 , 4.327445325382961e-238
# ghs_mean , fourier_sc31_mean_sum , -0.13569405284815386 , 1.3172600036163263e-58
# ghs_mean , fourier_sc31_variance_mean , 0.5352570739373398 , 0.0
# ghs_mean , fourier_sc31_variance_std , -0.2381526041439328 , 5.075104732805422e-180
# ghs_mean , fourier_sc31_variance_sum , -0.13692813314696234 , 1.180862546425526e-59
# ghs_mean , fourier_sc51_mean_mean , 0.6933276662890375 , 0.0
# ghs_mean , fourier_sc51_mean_std , -0.3008458243860631 , 3.5480408285857185e-291
# ghs_mean , fourier_sc51_mean_sum , -0.13529429510440508 , 2.8634289095873156e-58
# ghs_mean , fourier_sc51_variance_mean , 0.5443127257599042 , 0.0
# ghs_mean , gabor_sc7_mean_sum , -0.1326836205713875 , 4.304703931601505e-56
# ghs_mean , gabor_sc7_variance_mean , 0.5230865598435687 , 0.0
# ghs_mean , gabor_sc7_variance_std , 0.3745471710628882 , 0.0
# ghs_mean , gabor_sc7_variance_sum , -0.1314781663653008 , 4.211748928673211e-55
# ghs_mean , hog_sc3_kurtosis_mean , 0.7104575301649356 , 0.0
# ghs_mean , hog_sc3_kurtosis_std , 0.4185581717795075 , 0.0
# ghs_mean , hog_sc3_kurtosis_sum , -0.1384159606884757 , 6.25677767212336e-61
# ghs_mean , hog_sc3_mean_mean , 0.4673740416910117 , 0.0
# ghs_mean , hog_sc3_mean_std , -0.6659985384173226 , 0.0
# ghs_mean , hog_sc3_mean_sum , -0.1390135332970565 , 1.9050817658139257e-61
# ghs_mean , hog_sc3_skew_mean , 0.6640575340768096 , 0.0
# ghs_mean , hog_sc3_skew_std , -0.5715069494369025 , 0.0
# ghs_mean , hog_sc3_skew_sum , -0.13892289097821256 , 2.2824258963618982e-61
# ghs_mean , hog_sc3_variance_mean , -0.5628854264388988 , 0.0
# ghs_mean , hog_sc3_variance_std , -0.6973271206166354 , 0.0
# ghs_mean , hog_sc3_variance_sum , -0.13833237149058714 , 7.385970533635667e-61
# ghs_mean , hog_sc5_kurtosis_mean , 0.7668457806943393 , 0.0
# ghs_mean , hog_sc5_kurtosis_std , 0.22409732442872646 , 4.2399491199448086e-159
# ghs_mean , hog_sc5_kurtosis_sum , -0.13118889042118898 , 7.257353849114516e-55
# ghs_mean , hog_sc5_mean_mean , 0.14896274298658282 , 2.203918489794577e-70
# ghs_mean , hog_sc5_mean_std , -0.45452961580829054 , 0.0
# ghs_mean , hog_sc5_mean_sum , -0.13525190351292968 , 3.1087491145304514e-58
# ghs_mean , hog_sc5_skew_mean , 0.7244725935512946 , 0.0
# ghs_mean , hog_sc5_skew_std , 0.5454321322404352 , 0.0
# ghs_mean , hog_sc5_skew_sum , -0.1382163754795492 , 9.296636311496269e-61
# ghs_mean , hog_sc5_variance_mean , -0.654427404964111 , 0.0
# ghs_mean , hog_sc5_variance_std , -0.5907977540556129 , 0.0
# ghs_mean , hog_sc5_variance_sum , -0.12659212459638236 , 3.5021428808311346e-51
# ghs_mean , hog_sc7_kurtosis_mean , 0.7939191287290982 , 0.0
# ghs_mean , hog_sc7_kurtosis_std , 0.389281993797465 , 0.0
# ghs_mean , hog_sc7_kurtosis_sum , -0.11114184818161789 , 8.764393014634086e-40
# ghs_mean , hog_sc7_mean_mean , 0.04618472405211815 , 4.470514614835566e-08
# ghs_mean , hog_sc7_mean_std , -0.31780326240563445 , 0.0
# ghs_mean , hog_sc7_mean_sum , -0.13352596770913006 , 8.635211574479422e-57
# ghs_mean , hog_sc7_skew_mean , 0.7483570917372063 , 0.0
# ghs_mean , hog_sc7_skew_std , 0.6493009697480147 , 0.0
# ghs_mean , hog_sc7_skew_sum , -0.13802886046246687 , 1.3479298342797565e-60
# ghs_mean , hog_sc7_variance_mean , -0.6185943471223991 , 0.0
# ghs_mean , lbpm_sc5_skew_std , -0.16513876964638316 , 2.749033000552297e-86
# ghs_mean , lbpm_sc5_skew_sum , -0.14352795812192462 , 2.0143811330681333e-65
# ghs_mean , lbpm_sc5_variance_mean , -0.3995932498485913 , 0.0
# ghs_mean , lbpm_sc5_variance_std , -0.46743788738256714 , 0.0
# ghs_mean , lbpm_sc5_variance_sum , -0.11775794042167624 , 1.7638012122043612e-44
# ghs_mean , lbpm_sc7_kurtosis_mean , 0.6250318964810562 , 0.0
# ghs_mean , lbpm_sc7_kurtosis_std , 0.20828336444879392 , 3.1348850164837297e-137
# ghs_mean , lbpm_sc7_kurtosis_sum , -0.14226990729917724 , 2.6624889613838447e-64
# ghs_mean , lbpm_sc7_max_mean , -0.0348291923807005 , 3.7070416648457213e-05
# ghs_mean , lbpm_sc7_max_std , -0.3043144819145488 , 3.243078892348144e-298
# ghs_mean , lbpm_sc7_max_sum , -0.1271348485550512 , 1.3074922531450861e-51
# ghs_mean , lbpm_sc7_mean_mean , -0.20178056715187728 , 9.633519889946553e-129
# ghs_mean , lbpm_sc7_mean_std , -0.45354653354028457 , 0.0
# ghs_mean , lbpm_sc7_mean_sum , -0.1326313960064297 , 4.753884479100531e-56
# ghs_mean , lbpm_sc7_skew_mean , 0.5781629118174999 , 0.0
# ghs_mean , lbpm_sc7_skew_std , -0.08847006117089719 , 9.067662463301212e-26
# ghs_mean , lbpm_sc7_skew_sum , -0.14349259966748593 , 2.1666652598015865e-65
# ghs_mean , lbpm_sc7_variance_mean , -0.3676281458913428 , 0.0
# ghs_mean , lbpm_sc7_variance_std , -0.4335286796009273 , 0.0
# ghs_mean , lbpm_sc7_variance_sum , -0.1163105933885657 , 1.9833227930334488e-43
# ghs_mean , lsr_sc3_line_contrast_mean , -0.2114551508756203 , 1.778881395042362e-141
# ghs_mean , lsr_sc3_line_contrast_std , 0.18419793218463912 , 3.0457851135451196e-107
# ghs_mean , lsr_sc3_line_contrast_sum , -0.14611948479591658 , 9.170842139023238e-68
# ghs_mean , lsr_sc3_line_length_mean , -0.23006206331451862 , 8.337121338378984e-168
# ghs_mean , lsr_sc3_line_length_std , 0.19210370281948813 , 1.1931012076561551e-116
# ghs_mean , lsr_sc3_line_length_sum , -0.1451265623131681 , 7.324136417444295e-67
# ghs_mean , lsr_sc3_line_mean_mean , -0.021099765964121952 , 0.012472539836902143
# ghs_mean , lsr_sc3_line_mean_std , -0.20040856771339707 , 5.4616384338083344e-127
# ghs_mean , lsr_sc3_line_mean_sum , -0.13692367211325523 , 1.191251383690977e-59
# ghs_mean , lsr_sc5_line_contrast_mean , -0.15772706123744526 , 8.684586209236781e-79
# ghs_mean , lsr_sc5_line_contrast_std , 0.09516298626179169 , 1.4224998145603297e-29
# ghs_mean , lsr_sc5_line_contrast_sum , -0.14226403212065902 , 2.6946333715008127e-64
# ghs_mean , lsr_sc5_line_length_mean , -0.1741975880330525 , 6.035715301998802e-96
# ghs_mean , lsr_sc5_line_length_std , 0.10535126190418755 , 6.7177608488606e-36
# ghs_mean , lsr_sc5_line_length_sum , -0.1419887089861857 , 4.725949230191259e-64
# ghs_mean , ndvi_sc5_mean_mean , -0.6041117026850801 , 0.0
# ghs_mean , ndvi_sc5_mean_std , 0.2554481358368532 , 9.966423530330171e-208
# ghs_mean , ndvi_sc5_mean_sum , -0.1337255733980653 , 5.892302331365985e-57
# ghs_mean , ndvi_sc5_variance_mean , -0.542310399669059 , 0.0
# ghs_mean , ndvi_sc5_variance_std , 0.17673444338669486 , 9.511588053104728e-99
# ghs_mean , ndvi_sc5_variance_sum , -0.13401609454343077 , 3.374721142469557e-57
# ghs_mean , ndvi_sc7_mean_mean , -0.6042959871016871 , 0.0
# ghs_mean , ndvi_sc7_mean_std , 0.22503431767322005 , 1.8898245409804644e-160
# ghs_mean , ndvi_sc7_mean_sum , -0.13372873429922957 , 5.856719586175559e-57
# ghs_mean , ndvi_sc7_variance_mean , -0.5760526582862332 , 0.0
# ghs_mean , ndvi_sc7_variance_std , 0.0364082717802011 , 1.616675725143954e-05
# ghs_mean , ndvi_sc7_variance_sum , -0.13393016467670274 , 3.980031150593177e-57
# ghs_mean , orb_sc31_kurtosis_mean , 0.5505144931090384 , 0.0
# ghs_mean , orb_sc31_kurtosis_std , 0.4716223807598114 , 0.0
# ghs_mean , orb_sc31_kurtosis_sum , 0.08096407841975015 , 7.849004478076087e-22
# ghs_mean , orb_sc31_max_mean , 0.4913529340600076 , 0.0
# ghs_mean , orb_sc31_max_std , 0.3861414509717044 , 0.0
# ghs_mean , orb_sc31_max_sum , 0.14785477568740066 , 2.344703228001711e-69
# ghs_mean , orb_sc31_mean_mean , 0.4520150947936818 , 0.0
# ghs_mean , orb_sc31_mean_std , 0.36798555163701435 , 0.0
# ghs_mean , orb_sc31_mean_sum , 0.14165621494814598 , 9.300178631425736e-64
# ghs_mean , orb_sc31_skew_mean , 0.5403419438081537 , 0.0
# ghs_mean , orb_sc31_skew_std , 0.4720154884946904 , 0.0
# ghs_mean , orb_sc31_skew_sum , 0.07566381451009767 , 2.926669753190282e-19
# ghs_mean , orb_sc31_variance_mean , 0.3411840083528639 , 0.0
# ghs_mean , orb_sc31_variance_std , 0.26183393274556066 , 1.6258037799932963e-218
# ghs_mean , orb_sc31_variance_sum , 0.11397230748298505 , 9.275600053483028e-42
# ghs_mean , orb_sc51_kurtosis_mean , 0.40634551169907046 , 0.0
# ghs_mean , orb_sc51_kurtosis_std , 0.3805426247495572 , 0.0
# ghs_mean , orb_sc51_kurtosis_sum , -0.036907330204496026 , 1.2350457306433791e-05
# ghs_mean , orb_sc51_max_mean , 0.5032701829781266 , 0.0
# ghs_mean , orb_sc51_max_std , 0.3416960792167099 , 0.0
# ghs_mean , orb_sc51_max_sum , 0.1313042558518985 , 5.842488231482656e-55
# ghs_mean , orb_sc51_mean_mean , 0.4778077896999522 , 0.0
# ghs_mean , orb_sc51_mean_std , 0.3534907207265525 , 0.0
# ghs_mean , orb_sc51_mean_sum , 0.14264603448899565 , 1.233565305374142e-64
# ghs_mean , orb_sc51_skew_mean , 0.4205964227604032 , 0.0
# ghs_mean , orb_sc51_skew_std , 0.3600937630938366 , 0.0
# ghs_mean , orb_sc51_skew_sum , -0.0302218511798723 , 0.00034480988112547246
# ghs_mean , orb_sc51_variance_mean , 0.3273813318632198 , 0.0
# ghs_mean , orb_sc51_variance_std , 0.23489744178738287 , 4.751295984301415e-175
# ghs_mean , orb_sc51_variance_sum , 0.10399159443199023 , 5.115417202525426e-35
# ghs_mean , orb_sc71_kurtosis_mean , 0.2692006910836366 , 2.4362249649195676e-231
# ghs_mean , orb_sc71_kurtosis_std , 0.25266058134166225 , 4.097591186716244e-203
# ghs_mean , orb_sc71_kurtosis_sum , -0.11139835553779906 , 5.8315164386118604e-40
# ghs_mean , orb_sc71_max_mean , 0.508988884589984 , 0.0
# ghs_mean , orb_sc71_max_std , 0.3017397979920818 , 5.56011184224009e-293
# ghs_mean , orb_sc71_max_sum , 0.11594111345793319 , 3.660670899160275e-43
# ghs_mean , orb_sc71_mean_mean , 0.500700926850752 , 0.0
# ghs_mean , orb_sc71_mean_std , 0.33962775121441297 , 0.0
# ghs_mean , orb_sc71_mean_sum , 0.14357135645797808 , 1.8419750788925458e-65
# ghs_mean , orb_sc71_skew_mean , 0.2906742073675947 , 4.3381848366901315e-271
# ghs_mean , orb_sc71_skew_std , 0.23527834156106034 , 1.2561292345813243e-175
# ghs_mean , orb_sc71_skew_sum , -0.1056432749822407 , 4.328768480351171e-36
# ghs_mean , orb_sc71_variance_mean , 0.32452941796835894 , 0.0
# ghs_mean , orb_sc71_variance_std , 0.2207729752805642 , 2.345599098401224e-154
# ghs_mean , orb_sc71_variance_sum , 0.09930894962855899 , 4.5385309339326637e-32
# ghs_mean , pantex_sc3_min_mean , 0.6480972847666158 , 0.0
# ghs_mean , pantex_sc3_min_std , 0.6202249081614697 , 0.0
# ghs_mean , pantex_sc3_min_sum , -0.07754931579545245 , 3.726676127152681e-20
# ghs_mean , pantex_sc5_min_mean , 0.5319732762311763 , 0.0
# ghs_mean , pantex_sc5_min_std , 0.5069115917297038 , 0.0
# ghs_mean , pantex_sc5_min_sum , -0.09336878853481585 , 1.5854799965469435e-28
# ghs_mean , pantex_sc7_min_mean , 0.5193784757421354 , 0.0
# ghs_mean , pantex_sc7_min_std , 0.4266291552946696 , 0.0
# ghs_mean , pantex_sc7_min_sum , -0.09416407898558798 , 5.476308773369563e-29
# ghs_mean , sfs_sc31_max_ll_mean , 0.6906323033525482 , 0.0
# ghs_mean , sfs_sc31_max_ll_std , -0.5457074639382165 , 0.0
# ghs_mean , sfs_sc31_max_ll_sum , -0.1309758300740416 , 1.0826550883762378e-54
# ghs_mean , sfs_sc31_mean_mean , 0.7343035524673873 , 0.0
# ghs_mean , sfs_sc31_mean_std , 0.1332095860800519 , 1.5806910966013785e-56
# ghs_mean , sfs_sc31_mean_sum , -0.12483822574538066 , 8.209817689181215e-50
# ghs_mean , sfs_sc31_min_ll_mean , -0.041895235562067513 , 6.9568634610948e-07
# ghs_mean , sfs_sc31_min_ll_std , -0.0628976226696078 , 9.02477277201974e-14
# ghs_mean , sfs_sc31_min_ll_sum , -0.10940611718900443 , 1.3464105932270564e-38
# ghs_mean , sfs_sc31_roa_mean , -0.6367636161936754 , 0.0
# ghs_mean , sfs_sc31_roa_std , 0.1527249932732354 , 6.2623676493055824e-74
# ghs_mean , sfs_sc31_roa_sum , -0.1329203489191375 , 2.7436750352174295e-56
# ghs_mean , sfs_sc31_std_mean , 0.35198267934913136 , 0.0
# ghs_mean , sfs_sc31_std_std , -0.6383413879442018 , 0.0
# ghs_mean , sfs_sc31_std_sum , -0.15231438375572617 , 1.5426676943611624e-73
# ghs_mean , sfs_sc31_w_mean_mean , -0.17121795973016257 , 1.0414275099089096e-92
# ghs_mean , sfs_sc31_w_mean_std , -0.5883976089865176 , 0.0
# ghs_mean , sfs_sc31_w_mean_sum , -0.14069084048771952 , 6.577634547178844e-63
# ghs_mean , sfs_sc51_max_ll_mean , 0.14532486728523789 , 4.8422889602401165e-67
# ghs_mean , sfs_sc51_max_ll_std , -0.38572084369605314 , 0.0
# ghs_mean , sfs_sc51_max_ll_sum , -0.15778016827903057 , 7.696523975860046e-79
# ghs_mean , sfs_sc51_mean_mean , 0.5887955808759332 , 0.0
# ghs_mean , sfs_sc51_mean_std , -0.5842308908889844 , 0.0
# ghs_mean , sfs_sc51_mean_sum , -0.14661977796743275 , 3.201370203716465e-68
# ghs_mean , sfs_sc51_min_ll_mean , -0.02054580319058062 , 0.014979484708050569
# ghs_mean , sfs_sc51_min_ll_std , -0.0351975175445187 , 3.06383895668815e-05
# ghs_mean , sfs_sc51_min_ll_sum , -0.10472745116866228 , 1.7106490999586909e-35
# ghs_mean , sfs_sc51_roa_mean , -0.5402035454422327 , 0.0
# ghs_mean , sfs_sc51_roa_std , -0.06379860562613758 , 3.9862452882942615e-14
# ghs_mean , sfs_sc51_roa_sum , -0.13267597653543475 , 4.367708481360373e-56
# ghs_mean , sfs_sc51_std_mean , 0.5222815401709804 , 0.0
# ghs_mean , sfs_sc51_std_std , -0.541971213617206 , 0.0
# ghs_mean , sfs_sc51_std_sum , -0.1498605814794802 , 3.2004604320249912e-71
# ghs_mean , sfs_sc51_w_mean_mean , -0.5825828010229235 , 0.0
# ghs_mean , sfs_sc51_w_mean_std , -0.5878414948162343 , 0.0
# ghs_mean , sfs_sc51_w_mean_sum , -0.14771563741589516 , 3.1512446985519216e-69
# ghs_mean , sfs_sc71_max_ll_mean , -0.5430993836218437 , 0.0
# ghs_mean , sfs_sc71_max_ll_std , -0.12963470937382113 , 1.3221352433073603e-53
# ghs_mean , sfs_sc71_max_ll_sum , -0.15326822722242708 , 1.8925794360682345e-74
# ghs_mean , sfs_sc71_mean_mean , 0.10038798256697688 , 9.766094667849077e-33
# ghs_mean , sfs_sc71_mean_std , -0.36820579675504117 , 0.0
# ghs_mean , sfs_sc71_mean_sum , -0.15836793915760708 , 2.0161033536236506e-79
# ghs_mean , sfs_sc71_min_ll_mean , -0.14893606491284067 , 2.3335387715766407e-70
# ghs_mean , sfs_sc71_min_ll_std , -0.2916162615092766 , 6.476790514916252e-273
# ghs_mean , sfs_sc71_min_ll_sum , -0.05077569705803305 , 1.7909995968974891e-09
# ghs_mean , sfs_sc71_roa_mean , -0.516571723366778 , 0.0
# ghs_mean , sfs_sc71_roa_std , -0.15167318382019285 , 6.273194931812265e-73
# ghs_mean , sfs_sc71_roa_sum , -0.13250325378150188 , 6.063750224378973e-56
# ghs_mean , sfs_sc71_std_mean , -0.003964592775643328 , 0.6387775846561281
# ghs_mean , sfs_sc71_std_std , -0.003949440271592063 , 0.640060257215205
# ghs_mean , sfs_sc71_std_sum , -0.00453505157248056 , 0.5913009652345598
# ghs_mean , sfs_sc71_w_mean_mean , -0.6562404952773517 , 0.0
# ghs_mean , sfs_sc71_w_mean_std , -0.5375700328764682 , 0.0
# ghs_mean , sfs_sc71_w_mean_sum , -0.14672613693767603 , 2.558328377423027e-68
# ghs_mean 294

# %% [markdown]
# ### Correlation absolute value

# %%
x_df
# Out:
#                          x_var    abs_r2
# 186      hog_sc7_kurtosis_mean  0.793919
# 281     mean_sc3_variance_mean  0.768957
# 174      hog_sc5_kurtosis_mean  0.766846
# 192          hog_sc7_skew_mean  0.748357
# 371         sfs_sc31_mean_mean  0.734304
# 63     gabor_sc3_variance_mean  0.726578
# 33    gabor_sc3_filter_14_mean  0.726192
# 36     gabor_sc3_filter_2_mean  0.725072
# 180          hog_sc5_skew_mean  0.724473
# 27    gabor_sc3_filter_12_mean  0.724289
# 21    gabor_sc3_filter_10_mean  0.723417
# 54     gabor_sc3_filter_8_mean  0.723350
# 42     gabor_sc3_filter_4_mean  0.723151
# 48     gabor_sc3_filter_6_mean  0.722686
# 299     ndvi_sc3_variance_mean  0.721034
# 162      hog_sc3_kurtosis_mean  0.710458
# 0       fourier_sc31_mean_mean  0.709157
# 172       hog_sc3_variance_std  0.697327
# 6       fourier_sc51_mean_mean  0.693328
# 368       sfs_sc31_max_ll_mean  0.690632
# 12      fourier_sc71_mean_mean  0.680665
# 166           hog_sc3_mean_std  0.665999
# 168          hog_sc3_skew_mean  0.664058
# 416       sfs_sc71_w_mean_mean  0.656240
# 183      hog_sc5_variance_mean  0.654427
# 193           hog_sc7_skew_std  0.649301
# 359        pantex_sc3_min_mean  0.648097
# 381           sfs_sc31_std_std  0.638341
# 377          sfs_sc31_roa_mean  0.636764
# 222     lbpm_sc5_kurtosis_mean  0.630168
# ..                         ...       ...
# 355          orb_sc71_skew_sum  0.105643
# 265    lsr_sc5_line_length_std  0.105351
# 394        sfs_sc51_min_ll_sum  0.104727
# 343      orb_sc51_variance_sum  0.103992
# 407         sfs_sc71_mean_mean  0.100388
# 358      orb_sc71_variance_sum  0.099309
# 262  lsr_sc5_line_contrast_std  0.095163
# 367         pantex_sc7_min_sum  0.094164
# 364         pantex_sc5_min_sum  0.093369
# 213         lbpm_sc3_mean_mean  0.092317
# 247          lbpm_sc7_skew_std  0.088470
# 316      orb_sc31_kurtosis_sum  0.080964
# 361         pantex_sc3_min_sum  0.077549
# 325          orb_sc31_skew_sum  0.075664
# 396           sfs_sc51_roa_std  0.063799
# 375        sfs_sc31_min_ll_std  0.062898
# 412        sfs_sc71_min_ll_sum  0.050776
# 273    lsr_sc7_line_length_std  0.048985
# 189          hog_sc7_mean_mean  0.046185
# 374       sfs_sc31_min_ll_mean  0.041895
# 270  lsr_sc7_line_contrast_std  0.040450
# 331      orb_sc51_kurtosis_sum  0.036907
# 312      ndvi_sc7_variance_std  0.036408
# 393        sfs_sc51_min_ll_std  0.035198
# 240          lbpm_sc7_max_mean  0.034829
# 340          orb_sc51_skew_sum  0.030222
# 211           lbpm_sc3_max_std  0.025612
# 258     lsr_sc3_line_mean_mean  0.021100
# 392       sfs_sc51_min_ll_mean  0.020546
# 275     lsr_sc7_line_mean_mean  0.017977
#
# [419 rows x 2 columns]

# %%
y = y_var
#Initialize the output dictionary, Y_D, with each key being a dependent variable and the values being the results of the analyses
Y_D = {}
#Dictionary Models is used to store each result object for later use if needed
Models ={}
#for each dependent variable y in the list of all dependent values, calibrate the model

#Add new key to the output dictionary where y is the dependent variable curently being processed
#and the values are empty for now
Y_D[y]={}
#Get independent variables from the variable dictionary and store in list x_vars
x_vars = y_dict[y]
#Create a new dataframe for scaled and centered values
scale_df = pd.DataFrame()
#Scale and center the values
scale_df[y] = scale(merged[y_var], with_mean=True, with_std=True)
for x in x_vars:
    scale_df[x] = scale(merged[x], with_mean=True, with_std=True)
result = ElasticNetCV(max_iter=1e8,
                    alphas = [0.0005, 0.001, 0.01, 0.03, 0.05, 0.1],
                    l1_ratio =[.1, .5, .7, .9, .95, .99, 1],
                    verbose= False,
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)
#Fit the model with the scaled data
result.fit(scale_df[x_vars],scale_df[y])
#Append the model to the Models dictionary
Models[y] = result
# Out:
# /Users/adbe/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# /Users/adbe/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:164: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
result
# Out:
# ElasticNetCV(alphas=[0.0005, 0.001, 0.01, 0.03, 0.05, 0.1], copy_X=True, cv=5,
#        eps=0.001, fit_intercept=False,
#        l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=100000000.0,
#        n_alphas=100, n_jobs=-1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='random',
#        tol=0.0001, verbose=False)

# %%
opt_alpha, opt_l1_ratio = result.alpha_, result.l1_ratio_
#Print update to ensure that the script is progressing properly
print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(result.score(scale_df[x_vars],scale_df[y]),
              result.alpha_, result.l1_ratio_))
#Record the overall R squared score and optimal alpha and l1 ratio values and store them in the output dictionary
Y_D[y]['Total R2'] = result.score(scale_df[x_vars],scale_df[y])
Y_D[y]['Alpha'] = opt_alpha
Y_D[y]['l1_ratio'] = opt_l1_ratio
#Create a list R2s to store out of sample R squared values
R2s = []
#Specify the number of trials to run
trials = 10
#Run the number of trials specified in trials, for each trial 34% of the observations are randomly selected to train the model
#Testing is done on the remaining 66% of observations and the R squared values are recorded
for i in range(trials):    
    X_train, X_test, y_train, y_test = train_test_split(scale_df[x_vars], scale_df[y], test_size=0.66)
    test_regr = ElasticNetCV(max_iter=1e8,
                    alphas = [opt_alpha],
                    l1_ratio =[opt_l1_ratio],
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)
    test_regr.fit(X_train,y_train)
    R2s.append(test_regr.score(X_test,y_test))

#print("Mean R2: {:.2f} StDev: {:.4f}".format(mean(R2s),pstdev(R2s)))
#Record the out of sample R squared values
Y_D[y]['Sampling']={'trials':trials,'R2':mean(R2s),'StDev':pstdev(R2s),'R2s':R2s}
coefs = [i for i in zip(list(scale_df[x_vars].axes[1]),result.coef_)]
remaining = [i for i in coefs if abs(i[1])>0.0]
Y_D[y]["Coefficients"]=remaining
# Out:
# R2: 0.82 Alpha: 0.01 l1_ratio: 0.1

# %%
y_vars = y_var
Y_D[y_var]
# Out:
# {'Total R2': 0.8216149480519188,
#  'Alpha': 0.01,
#  'l1_ratio': 0.1,
#  'Sampling': {'trials': 10,
#   'R2': 0.8146108544396765,
#   'StDev': 0.0026515664964481753,
#   'R2s': [0.8160652506968857,
#    0.8194653905136783,
#    0.814700660544187,
#    0.8167673517499754,
#    0.8104926208459506,
#    0.8147658220525544,
#    0.8169645147712374,
#    0.8121438346860141,
#    0.8115563890136596,
#    0.8131867095226221]},
#  'Coefficients': [('hog_sc7_kurtosis_mean', 0.20065283078019489),
#   ('mean_sc3_variance_mean', 0.10317386650156868),
#   ('hog_sc5_kurtosis_mean', 0.06969838218349107),
#   ('hog_sc7_skew_mean', 0.011735608446083201),
#   ('sfs_sc31_mean_mean', 0.00921849225645454),
#   ('gabor_sc3_filter_14_mean', 0.01987217012268506),
#   ('hog_sc5_skew_mean', 0.02102412306322438),
#   ('gabor_sc3_filter_12_mean', 0.02651967731808506),
#   ('ndvi_sc3_variance_mean', 0.50888864518865),
#   ('hog_sc3_kurtosis_mean', 0.04202893537918417),
#   ('hog_sc3_variance_std', -0.06273521639699982),
#   ('fourier_sc51_mean_mean', 0.054905225106004124),
#   ('sfs_sc31_max_ll_mean', 0.023957449753695678),
#   ('fourier_sc71_mean_mean', 0.13849313303750282),
#   ('hog_sc3_mean_std', -0.029553120239993014),
#   ('sfs_sc71_w_mean_mean', -0.024834507976702395),
#   ('hog_sc5_variance_mean', 0.10201702353988386),
#   ('pantex_sc3_min_mean', 0.002904049834715583),
#   ('lbpm_sc7_kurtosis_mean', -0.05342342336227108),
#   ('pantex_sc3_min_std', 0.06224139346956731),
#   ('hog_sc7_variance_mean', 0.09414955944381853),
#   ('lbpm_sc3_kurtosis_mean', 0.058687451585675926),
#   ('ndvi_sc7_mean_mean', -0.10587053586029838),
#   ('ndvi_sc5_mean_mean', -0.10296343354391424),
#   ('ndvi_sc3_mean_mean', -0.10020687971373321),
#   ('sfs_sc51_mean_mean', 0.04376691579991065),
#   ('sfs_sc31_w_mean_std', 0.02020817965164314),
#   ('lbpm_sc3_skew_mean', 0.04448715801028765),
#   ('hog_sc3_variance_mean', -0.08443050910603495),
#   ('orb_sc31_kurtosis_mean', 0.02030804669038952),
#   ('mean_sc5_variance_mean', -0.044967779877540026),
#   ('fourier_sc71_variance_mean', -0.08870203704591446),
#   ('sfs_sc31_max_ll_std', -0.053514221327513614),
#   ('hog_sc5_skew_std', -0.02019683559311587),
#   ('fourier_sc51_variance_mean', -0.04124774834388346),
#   ('sfs_sc71_max_ll_mean', -0.0180328695665342),
#   ('ndvi_sc5_variance_mean', 0.03371623663733337),
#   ('sfs_sc51_std_std', 0.031162954093983106),
#   ('sfs_sc51_roa_mean', -0.04757920946313019),
#   ('sfs_sc71_w_mean_std', -0.009574406263403721),
#   ('fourier_sc31_variance_mean', -0.03356252317813137),
#   ('gabor_sc5_filter_8_mean', -0.005269960413016616),
#   ('pantex_sc5_min_mean', -0.07654239850367442),
#   ('gabor_sc5_filter_14_mean', -0.03545304674138068),
#   ('gabor_sc5_filter_10_mean', -0.007852872559113284),
#   ('gabor_sc5_filter_12_mean', -0.02047829171842386),
#   ('mean_sc7_variance_mean', -0.03908293669691153),
#   ('gabor_sc5_filter_6_mean', -0.018382366313772786),
#   ('gabor_sc7_filter_14_mean', -0.003158866446148831),
#   ('gabor_sc5_variance_mean', -0.044550209617954944),
#   ('gabor_sc5_filter_2_mean', -0.04369188745969067),
#   ('gabor_sc5_filter_4_mean', -0.03096592214121769),
#   ('gabor_sc7_variance_mean', -0.006619482857410041),
#   ('gabor_sc7_filter_2_mean', -0.009482322980342685),
#   ('lbpm_sc3_variance_std', 0.01956797557787621),
#   ('pantex_sc7_min_mean', -0.09730762653919729),
#   ('sfs_sc71_roa_mean', 0.021268868620890075),
#   ('orb_sc71_max_mean', 0.05883049387483644),
#   ('hog_sc7_variance_std', 0.029528856760674495),
#   ('orb_sc71_mean_mean', 0.1016138052734105),
#   ('gabor_sc7_filter_9_mean', 0.05066251326619791),
#   ('gabor_sc7_filter_7_mean', 0.07392686205421034),
#   ('gabor_sc7_filter_11_mean', 0.0068787244859729495),
#   ('gabor_sc7_filter_5_mean', 0.06292416439186695),
#   ('gabor_sc5_filter_9_mean', 0.0020284027115499603),
#   ('gabor_sc5_filter_7_mean', 0.013251158953233404),
#   ('gabor_sc5_filter_5_mean', 0.008424677214417201),
#   ('gabor_sc7_filter_3_mean', 0.03239014657433726),
#   ('gabor_sc7_filter_1_mean', 0.0034654294039658438),
#   ('orb_sc31_skew_std', -0.006886364928463684),
#   ('orb_sc31_kurtosis_std', -0.002867377268725058),
#   ('lbpm_sc5_variance_std', 0.004015046468501273),
#   ('hog_sc3_mean_mean', -0.00299408999762779),
#   ('hog_sc5_mean_std', 0.0014057856515713575),
#   ('lbpm_sc7_mean_std', -7.296145844922541e-05),
#   ('ndvi_sc3_variance_std', -0.18775147246291285),
#   ('orb_sc31_mean_mean', -0.023772193471826554),
#   ('mean_sc5_variance_std', -0.016183537526555807),
#   ('lbpm_sc3_variance_mean', -0.010090753727418222),
#   ('lbpm_sc7_variance_std', 0.018594850931645333),
#   ('lac_sc3_lac_mean', 0.033253496966377374),
#   ('lac_sc5_lac_mean', 0.033528808524748425),
#   ('lac_sc7_lac_mean', 0.03331886011142852),
#   ('hog_sc3_kurtosis_std', -0.13481436114914533),
#   ('gabor_sc3_mean_std', -0.014186403941965613),
#   ('lbpm_sc5_variance_mean', -0.03984999898852988),
#   ('gabor_sc5_filter_8_std', -0.011667987725014291),
#   ('gabor_sc5_filter_6_std', -0.013048832906892379),
#   ('gabor_sc5_filter_10_std', -0.0019785868328800896),
#   ('gabor_sc5_filter_4_std', -0.004753720648393111),
#   ('hog_sc7_kurtosis_std', -0.0290591160621658),
#   ('sfs_sc51_max_ll_std', 0.08186805234248001),
#   ('gabor_sc5_mean_std', -0.0021479222546991494),
#   ('gabor_sc7_variance_std', 0.04797405065508705),
#   ('mean_sc7_variance_std', -0.04350881984021739),
#   ('gabor_sc7_filter_14_std', 0.04626732519450672),
#   ('lbpm_sc7_variance_mean', -0.02158879255706637),
#   ('gabor_sc7_filter_6_std', -0.002696326947945532),
#   ('orb_sc51_skew_std', -0.02115192360048704),
#   ('gabor_sc7_filter_4_std', -0.009436454332600692),
#   ('mean_sc7_mean_std', -0.019442090659412038),
#   ('orb_sc51_variance_mean', -0.05146536092461758),
#   ('orb_sc71_variance_mean', -0.012296556240509572),
#   ('hog_sc7_mean_std', 3.733624181078561e-05),
#   ('lbpm_sc3_mean_std', 0.015613813874381346),
#   ('lbpm_sc7_max_std', -0.11550611967897521),
#   ('orb_sc71_max_std', -0.02931440164452538),
#   ('fourier_sc51_mean_std', -0.015430863831685635),
#   ('ndvi_sc3_mean_std', -0.05533255636131183),
#   ('sfs_sc71_min_ll_std', -0.029615967119304327),
#   ('lbpm_sc3_max_mean', 0.12345229412342135),
#   ('fourier_sc71_mean_std', -0.004471090816905908),
#   ('fourier_sc71_variance_std', -0.03377492228975898),
#   ('fourier_sc31_mean_std', -0.02516596642517292),
#   ('ndvi_sc5_mean_std', -0.060833688678019575),
#   ('orb_sc71_kurtosis_std', 0.021786576440811493),
#   ('lsr_sc7_line_mean_std', 0.04875508376423472),
#   ('lac_sc3_lac_std', 0.004986367947506632),
#   ('lac_sc5_lac_std', 0.004949089158025084),
#   ('lac_sc7_lac_std', 0.006482924823444181),
#   ('fourier_sc31_variance_std', 0.11546543158960951),
#   ('ndvi_sc7_mean_std', -0.04734530877247909),
#   ('hog_sc5_kurtosis_std', -0.006784336460267269),
#   ('orb_sc71_variance_std', 0.018340012963119958),
#   ('lbpm_sc5_kurtosis_std', -0.014449782762654738),
#   ('lbpm_sc7_kurtosis_std', -0.05291925207632835),
#   ('lsr_sc3_line_mean_std', -0.09440067375233399),
#   ('lsr_sc3_line_length_std', 0.0022822940292830584),
#   ('lbpm_sc5_max_std', 0.0714035513555454),
#   ('ndvi_sc5_variance_std', 0.14046118436367744),
#   ('sfs_sc31_w_mean_mean', -0.013786746077431895),
#   ('lbpm_sc5_skew_std', 0.06980911195651904),
#   ('lsr_sc7_line_length_mean', 0.00573602184511517),
#   ('sfs_sc51_max_ll_sum', 0.008427059359406068),
#   ('lsr_sc5_line_contrast_mean', 0.013519319774688898),
#   ('lbpm_sc5_max_mean', 0.09830396819884016),
#   ('sfs_sc71_max_ll_sum', 0.07222344345946005),
#   ('sfs_sc71_roa_std', -0.028091465268923158),
#   ('hog_sc5_mean_mean', 0.05006099732677568),
#   ('sfs_sc71_min_ll_mean', -0.05408403920338639),
#   ('orb_sc31_max_sum', -0.0034985177796627645),
#   ('sfs_sc51_mean_sum', -0.028374853137007064),
#   ('orb_sc71_mean_sum', 0.0010543316712711866),
#   ('lsr_sc7_line_contrast_mean', 0.02067876900225419),
#   ('sfs_sc31_w_mean_sum', 0.02815723147902309),
#   ('hog_sc3_variance_sum', 0.011205877846834552),
#   ('hog_sc7_skew_sum', -0.11296408195202667),
#   ('lsr_sc3_line_mean_sum', 0.004183341842486168),
#   ('lsr_sc5_line_mean_sum', 0.016677830181464907)]}

# %%
df2 = merged[merged['ghs_mean']>=10]

# %%
df2.head()
# Out:
#     fid                      gnd_n_x    gnd_c  fourier_sc31_mean_mean  \
# 3     3              Akkaraipattu 11  5236065               73.670361
# 4     4                 Delgasthenna  2109125               66.878083
# 6     6                   Santhiveli  5110065               67.196778
# 7     7               Nawayalathenna  2112235               66.658046
# 14   14  Kattankudy division 1 South  5124010               75.893946
#
#     fourier_sc31_mean_std  fourier_sc31_mean_sum  fourier_sc31_variance_mean  \
# 3                1.821871           9.731855e+04                   18.843218
# 4                2.710715           2.657735e+05                   18.708531
# 6                9.780546           1.303147e+06                   19.325224
# 7                3.350067           4.336772e+05                   19.087925
# 14               3.789219           1.028363e+05                   18.512343
#
#     fourier_sc31_variance_std  fourier_sc31_variance_sum  \
# 3                    1.231690               24891.890625
# 4                    1.015577               74347.703125
# 6                    2.683984              374774.062500
# 7                    1.260433              124186.039062
# 14                   1.067105               25084.224609
#
#     fourier_sc51_mean_mean  ...  prov_c  dis_c  dsd_c      GN_Area  lka_count  \
# 3                82.544710  ...       5     52   5236   130560.240       11.0
# 4                75.957167  ...       2     21   2109   390874.578       38.0
# 6                77.062510  ...       5     51   5110  1907449.335      138.0
# 7                75.722050  ...       2     21   2112   640533.554       62.0
# 14               84.043323  ...       5     51   5124   133748.420       13.0
#
#         lka_sum    lka_mean  ghs_count  ghs_sum   ghs_mean
# 3   1248.624039  113.511276         89     5889  66.168539
# 4   1701.824509   44.784855        274     2874  10.489051
# 6   2688.887347   19.484691       1343    33943  25.274013
# 7   2096.300272   33.811295        449    16449  36.634744
# 14  1779.547729  136.888287         94     8494  90.361702
#
# [5 rows x 437 columns]

# %%
#df4.shape, pop_density.shape
df2.shape
# Out:
# (3131, 437)

# %%
# import matplotlib.pyplot as plt
# plt.subplots(figsize=(15,15))
# y = pop_density
# x = df4['PCNT_built']
# plt.scatter(x, y)

# z = np.polyfit(x, y, 1)
# p = np.poly1d(z)
# plt.plot(x,p(x),"r--")
# plt.show()

# %%
df2.columns
# Out:
# Index(['fid', 'gnd_n_x', 'gnd_c', 'fourier_sc31_mean_mean',
#        'fourier_sc31_mean_std', 'fourier_sc31_mean_sum',
#        'fourier_sc31_variance_mean', 'fourier_sc31_variance_std',
#        'fourier_sc31_variance_sum', 'fourier_sc51_mean_mean',
#        ...
#        'prov_c', 'dis_c', 'dsd_c', 'GN_Area', 'lka_count', 'lka_sum',
#        'lka_mean', 'ghs_count', 'ghs_sum', 'ghs_mean'],
#       dtype='object', length=437)
