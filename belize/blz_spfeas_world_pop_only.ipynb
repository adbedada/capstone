# %% [markdown]
# ## Spatial Features Vs Urban Footprint Vs Population Size

# %%
import sklearn
import pandas as pd
import numpy as np
import csv
import scipy.stats as stats
from statistics import pstdev
from statistics import mean
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from itertools import product
import copy

# %% [markdown]
# ### Read the Features data

# %%
# !ls spfeas
# Out:
# Belize_spfeas.xlsx

# %%
spfeas = pd.read_excel('spfeas/Belize_spfeas.xlsx', sheet_name=0)

# %%
spfeas['OBJECTID'] = spfeas['OBJECTID'].astype(int)
spfeas = spfeas.set_index('OBJECTID')

# %%
spfeas.head()
# Out:
#           FID            Administra Administ_1               Area Urban_Rura  \
# OBJECTID
# 1           0       Toledo District     BLZ006       Toledo Rural      Rural
# 2           1  Stann Creek District     BLZ005  Stann Creek Rural      Rural
# 3           2                   NaN        NaN                NaN        NaN
# 4           3                   NaN        NaN                NaN        NaN
# 5           4                   NaN        NaN                NaN        NaN
#
#          CTV_2018  ED_2018  Cluster_Nu  fourier_sc31_variance_mean  \
# OBJECTID
# 1           Cayes      217         665                    1.871010
# 2           Cayes      201         602                    2.608672
# 3           Cayes      126           0                    6.380702
# 4           Cayes      122           0                    2.894536
# 5           Cayes      123           0                    4.566548
#
#           fourier_sc31_variance_std  ...  sfs_sc51_std_sum  \
# OBJECTID                             ...
# 1                          4.929879  ...        42799652.0
# 2                          6.141846  ...        92699568.0
# 3                          8.840365  ...        10851945.0
# 4                          6.357571  ...        65703932.0
# 5                          7.459406  ...        44759044.0
#
#           sfs_sc71_max_ratio_of_orthgonal_angles_mean  \
# OBJECTID
# 1                                          140.709890
# 2                                          140.376936
# 3                                          139.219940
# 4                                          139.365071
# 5                                          140.065461
#
#           sfs_sc71_max_ratio_of_orthgonal_angles_std  \
# OBJECTID
# 1                                           1.065200
# 2                                           4.624142
# 3                                           8.347895
# 4                                          12.484677
# 5                                           2.836504
#
#           sfs_sc71_max_ratio_of_orthgonal_angles_sum  sfs_sc31_std_mean  \
# OBJECTID
# 1                                         4286729472           1.193974
# 2                                         7790784512           1.375928
# 3                                          461388384           2.413110
# 4                                         5233991680           1.457598
# 5                                         2403786496           1.953999
#
#           sfs_sc31_std_std  sfs_sc31_std_sum  sfs_sc71_min_line_length_mean  \
# OBJECTID
# 1                 1.408849        36374452.0                  874775.350589
# 2                 1.689124        76362680.0                  824859.818661
# 3                 2.699090         7997279.0                  614737.965726
# 4                 1.841355        54741532.0                  814288.179976
# 5                 2.401075        33534290.0                  692178.805971
#
#           sfs_sc71_min_line_length_std  sfs_sc71_min_line_length_sum
# OBJECTID
# 1                        330970.948840                26650047676400
# 2                        380083.243379                45778923946000
# 3                        486655.097810                 2037301248000
# 4                        388871.179731                30581389787100
# 5                        461589.477238                11879088914400
#
# [5 rows x 440 columns]

# %% [markdown]
# Check data

# %% [markdown]
# Convert the GN_Code column to an integer index

# %% [markdown]
# ### Load the Global Urban Foot Print Data

# %%
#guf = pd.read_csv("guf.csv")

# %%
#guf['gid'] = guf['gid'].astype(int)
#guf = guf.set_index('gid')

# %%
#guf.head()

# %% [markdown]
# ### Load World Pop Data

# %%
world_pop = pd.read_csv("world_pop/blz_ppp_v2b_2015_UNadj_qgis.csv")

# %%
world_pop['OBJECTID'] = world_pop['OBJECTID'].astype(int)
world_pop = world_pop.set_index('OBJECTID')

# %%
world_pop.head()
# Out:
#                     Administra Administ_1               Area Urban_Rura  \
# OBJECTID
# 1              Toledo District     BLZ006       Toledo Rural      Rural
# 2         Stann Creek District     BLZ005  Stann Creek Rural      Rural
# 3                          NaN        NaN                NaN        NaN
# 4                          NaN        NaN                NaN        NaN
# 5                          NaN        NaN                NaN        NaN
#
#          CTV_2018  ED_2018  Cluster_Nu     Shape_Leng    Shape_Area   _count  \
# OBJECTID
# 1           Cayes      217         665  294022.358507  2.934572e+09    535.0
# 2           Cayes      201         602  431082.304407  5.345558e+09   1246.0
# 3           Cayes      126           0   69417.179782  3.192064e+08   1931.0
# 4           Cayes      122           0  247650.430790  3.617347e+09  12463.0
# 5           Cayes      123           0  240469.134053  1.652992e+09   1942.0
#
#                  _sum     _mean
# OBJECTID
# 1            6.136642  0.011470
# 2          262.607626  0.210761
# 3           43.015828  0.022276
# 4          108.512611  0.008707
# 5         1265.180093  0.651483

# %%
# Total Population size

# %%
np.sum(world_pop['_sum'])
# Out:
# 344026.97329303942

# %% [markdown]
# ### Merge population data with urbanfootprint and featuures

# %%
#guf_spfeas_merged = spfeas.merge(guf, left_on='gnd_c', right_on='code', how='outer')

# %%
spfeas_world_pop_merged = spfeas.merge(world_pop, left_on='OBJECTID', right_on='OBJECTID', how='outer')

# %%
spfeas_world_pop_merged = spfeas_world_pop_merged.round(3)
spfeas_world_pop_merged.head()
# Out:
#           FID          Administra_x Administ_1_x             Area_x  \
# OBJECTID
# 1           0       Toledo District       BLZ006       Toledo Rural
# 2           1  Stann Creek District       BLZ005  Stann Creek Rural
# 3           2                   NaN          NaN                NaN
# 4           3                   NaN          NaN                NaN
# 5           4                   NaN          NaN                NaN
#
#          Urban_Rura_x CTV_2018_x  ED_2018_x  Cluster_Nu_x  \
# OBJECTID
# 1               Rural      Cayes        217           665
# 2               Rural      Cayes        201           602
# 3                 NaN      Cayes        126             0
# 4                 NaN      Cayes        122             0
# 5                 NaN      Cayes        123             0
#
#           fourier_sc31_variance_mean  fourier_sc31_variance_std  ...  \
# OBJECTID                                                         ...
# 1                              1.871                      4.930  ...
# 2                              2.609                      6.142  ...
# 3                              6.381                      8.840  ...
# 4                              2.895                      6.358  ...
# 5                              4.567                      7.459  ...
#
#                      Area_y  Urban_Rura_y  CTV_2018_y  ED_2018_y  \
# OBJECTID
# 1              Toledo Rural         Rural       Cayes        217
# 2         Stann Creek Rural         Rural       Cayes        201
# 3                       NaN           NaN       Cayes        126
# 4                       NaN           NaN       Cayes        122
# 5                       NaN           NaN       Cayes        123
#
#           Cluster_Nu_y  Shape_Leng    Shape_Area   _count      _sum  _mean
# OBJECTID
# 1                  665  294022.359  2.934572e+09    535.0     6.137  0.011
# 2                  602  431082.304  5.345558e+09   1246.0   262.608  0.211
# 3                    0   69417.180  3.192064e+08   1931.0    43.016  0.022
# 4                    0  247650.431  3.617347e+09  12463.0   108.513  0.009
# 5                    0  240469.134  1.652992e+09   1942.0  1265.180  0.651
#
# [5 rows x 452 columns]

# %% [markdown]
# ### Filter Dataset by Builtup Surface.
#
# Select Rows where  builtup is greater than or equal to 10 percent

# %%
#filter_by_builtup = guf_spfeas_world_pop_merged[guf_spfeas_world_pop_merged['PCNT_built']>=0.1]

# %%
#filter_by_builtup.head()

# %%
#np.sum(filter_by_builtup['stats_sum_y'])

# %%
#pop_density = filter_by_builtup['stats_sum_y']/filter_by_builtup['GN_area']

# %%
pop_count = spfeas_world_pop_merged['_sum']

# %%
#filter_by_builtup.shape, pop_count.shape

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(8,8))
y = pop_count
x = spfeas_world_pop_merged['fourier_sc31_variance_mean']
plt.scatter(x, y)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.show()

# %%
spfeas_world_pop_merged.shape
# Out:
# (723, 452)

# %% [markdown]
# ### Analysis

# %% [markdown]
# Get the list of dependent variables from the DataFrame to store in list y_vars

# %%
y_var = list(spfeas_world_pop_merged.axes[1])[450]
y_var
# Out:
# '_sum'

# %% [markdown]
# Get a list of all independent variables from the DataFrame in list all_x

# %%
all_x = list(spfeas_world_pop_merged.axes[1])[8:440]

#Check
all_x
# Out:
# ['fourier_sc31_variance_mean',
#  'fourier_sc31_variance_std',
#  'fourier_sc31_variance_sum',
#  'fourier_sc71_mean_mean',
#  'fourier_sc71_mean_std',
#  'fourier_sc71_mean_sum',
#  'fourier_sc51_mean_mean',
#  'fourier_sc51_mean_std',
#  'fourier_sc51_mean_sum',
#  'fourier_sc31_mean_mean',
#  'fourier_sc31_mean_std',
#  'fourier_sc31_mean_sum',
#  'fourier_sc51_variance_mean',
#  'fourier_sc51_variance_std',
#  'fourier_sc51_variance_sum',
#  'fourier_sc71_variance_mean',
#  'fourier_sc71_variance_std',
#  'fourier_sc71_variance_sum',
#  'gabor_sc3_filter_5_mean',
#  'gabor_sc3_filter_5_std',
#  'gabor_sc3_filter_5_sum',
#  'gabor_sc3_filter_4_mean',
#  'gabor_sc3_filter_4_std',
#  'gabor_sc3_filter_4_sum',
#  'gabor_sc3_filter_7_mean',
#  'gabor_sc3_filter_7_std',
#  'gabor_sc3_filter_7_sum',
#  'gabor_sc3_filter_6_mean',
#  'gabor_sc3_filter_6_std',
#  'gabor_sc3_filter_6_sum',
#  'gabor_sc3_filter_1_mean',
#  'gabor_sc3_filter_1_std',
#  'gabor_sc3_filter_1_sum',
#  'gabor_sc3_mean_mean',
#  'gabor_sc3_mean_std',
#  'gabor_sc3_mean_sum',
#  'gabor_sc3_filter_3_mean',
#  'gabor_sc3_filter_3_std',
#  'gabor_sc3_filter_3_sum',
#  'gabor_sc3_filter_2_mean',
#  'gabor_sc3_filter_2_std',
#  'gabor_sc3_filter_2_sum',
#  'gabor_sc3_filter_9_mean',
#  'gabor_sc3_filter_9_std',
#  'gabor_sc3_filter_9_sum',
#  'gabor_sc3_filter_13_mean',
#  'gabor_sc3_filter_13_std',
#  'gabor_sc3_filter_13_sum',
#  'gabor_sc3_filter_8_mean',
#  'gabor_sc3_filter_8_std',
#  'gabor_sc3_filter_8_sum',
#  'gabor_sc3_filter_10_mean',
#  'gabor_sc3_filter_10_std',
#  'gabor_sc3_filter_10_sum',
#  'gabor_sc3_variance_mean',
#  'gabor_sc3_variance_std',
#  'gabor_sc3_variance_sum',
#  'gabor_sc3_filter_11_mean',
#  'gabor_sc3_filter_11_std',
#  'gabor_sc3_filter_11_sum',
#  'gabor_sc3_filter_12_mean',
#  'gabor_sc3_filter_12_std',
#  'gabor_sc3_filter_12_sum',
#  'gabor_sc3_filter_14_mean',
#  'gabor_sc3_filter_14_std',
#  'gabor_sc3_filter_14_sum',
#  'gabor_sc5_filter_4_mean',
#  'gabor_sc5_filter_4_std',
#  'gabor_sc5_filter_4_sum',
#  'gabor_sc5_variance_mean',
#  'gabor_sc5_variance_std',
#  'gabor_sc5_variance_sum',
#  'gabor_sc5_mean_mean',
#  'gabor_sc5_mean_std',
#  'gabor_sc5_mean_sum',
#  'gabor_sc5_filter_6_mean',
#  'gabor_sc5_filter_6_std',
#  'gabor_sc5_filter_6_sum',
#  'gabor_sc5_filter_3_mean',
#  'gabor_sc5_filter_3_std',
#  'gabor_sc5_filter_3_sum',
#  'gabor_sc5_filter_9_mean',
#  'gabor_sc5_filter_9_std',
#  'gabor_sc5_filter_9_sum',
#  'gabor_sc5_filter_8_mean',
#  'gabor_sc5_filter_8_std',
#  'gabor_sc5_filter_8_sum',
#  'gabor_sc5_filter_2_mean',
#  'gabor_sc5_filter_2_std',
#  'gabor_sc5_filter_2_sum',
#  'gabor_sc5_filter_13_mean',
#  'gabor_sc5_filter_13_std',
#  'gabor_sc5_filter_13_sum',
#  'gabor_sc5_filter_12_mean',
#  'gabor_sc5_filter_12_std',
#  'gabor_sc5_filter_12_sum',
#  'gabor_sc5_filter_11_mean',
#  'gabor_sc5_filter_11_std',
#  'gabor_sc5_filter_11_sum',
#  'gabor_sc5_filter_10_mean',
#  'gabor_sc5_filter_10_std',
#  'gabor_sc5_filter_10_sum',
#  'gabor_sc5_filter_7_mean',
#  'gabor_sc5_filter_7_std',
#  'gabor_sc5_filter_7_sum',
#  'gabor_sc5_filter_1_mean',
#  'gabor_sc5_filter_1_std',
#  'gabor_sc5_filter_1_sum',
#  'gabor_sc5_filter_5_mean',
#  'gabor_sc5_filter_5_std',
#  'gabor_sc5_filter_5_sum',
#  'gabor_sc5_filter_14_mean',
#  'gabor_sc5_filter_14_std',
#  'gabor_sc5_filter_14_sum',
#  'gabor_sc7_filter_9_mean',
#  'gabor_sc7_filter_9_std',
#  'gabor_sc7_filter_9_sum',
#  'gabor_sc7_mean_mean',
#  'gabor_sc7_mean_std',
#  'gabor_sc7_mean_sum',
#  'gabor_sc7_variance_mean',
#  'gabor_sc7_variance_std',
#  'gabor_sc7_variance_sum',
#  'gabor_sc7_filter_1_mean',
#  'gabor_sc7_filter_1_std',
#  'gabor_sc7_filter_1_sum',
#  'gabor_sc7_filter_5_mean',
#  'gabor_sc7_filter_5_std',
#  'gabor_sc7_filter_5_sum',
#  'gabor_sc7_filter_3_mean',
#  'gabor_sc7_filter_3_std',
#  'gabor_sc7_filter_3_sum',
#  'gabor_sc7_filter_2_mean',
#  'gabor_sc7_filter_2_std',
#  'gabor_sc7_filter_2_sum',
#  'gabor_sc7_filter_11_mean',
#  'gabor_sc7_filter_11_std',
#  'gabor_sc7_filter_11_sum',
#  'gabor_sc7_filter_10_mean',
#  'gabor_sc7_filter_10_std',
#  'gabor_sc7_filter_10_sum',
#  'gabor_sc7_filter_7_mean',
#  'gabor_sc7_filter_7_std',
#  'gabor_sc7_filter_7_sum',
#  'gabor_sc7_filter_4_mean',
#  'gabor_sc7_filter_4_std',
#  'gabor_sc7_filter_4_sum',
#  'gabor_sc7_filter_12_mean',
#  'gabor_sc7_filter_12_std',
#  'gabor_sc7_filter_12_sum',
#  'gabor_sc7_filter_13_mean',
#  'gabor_sc7_filter_13_std',
#  'gabor_sc7_filter_13_sum',
#  'gabor_sc7_filter_14_mean',
#  'gabor_sc7_filter_14_std',
#  'gabor_sc7_filter_14_sum',
#  'gabor_sc7_filter_6_mean',
#  'gabor_sc7_filter_6_std',
#  'gabor_sc7_filter_6_sum',
#  'gabor_sc7_filter_8_mean',
#  'gabor_sc7_filter_8_std',
#  'gabor_sc7_filter_8_sum',
#  'hog_sc7_mean_mean',
#  'hog_sc7_mean_std',
#  'hog_sc7_mean_sum',
#  'hog_sc5_kurtosis_mean',
#  'hog_sc5_kurtosis_std',
#  'hog_sc5_kurtosis_sum',
#  'hog_sc5_skew_mean',
#  'hog_sc5_skew_std',
#  'hog_sc5_skew_sum',
#  'hog_sc7_variance_mean',
#  'hog_sc7_variance_std',
#  'hog_sc7_variance_sum',
#  'hog_sc7_skew_mean',
#  'hog_sc7_skew_std',
#  'hog_sc7_skew_sum',
#  'hog_sc5_mean_mean',
#  'hog_sc5_mean_std',
#  'hog_sc5_mean_sum',
#  'hog_sc3_skew_mean',
#  'hog_sc3_skew_std',
#  'hog_sc3_skew_sum',
#  'hog_sc5_max_mean',
#  'hog_sc5_max_std',
#  'hog_sc5_max_sum',
#  'hog_sc5_variance_mean',
#  'hog_sc5_variance_std',
#  'hog_sc5_variance_sum',
#  'hog_sc7_kurtosis_mean',
#  'hog_sc7_kurtosis_std',
#  'hog_sc7_kurtosis_sum',
#  'hog_sc3_max_mean',
#  'hog_sc3_max_std',
#  'hog_sc3_max_sum',
#  'hog_sc3_variance_mean',
#  'hog_sc3_variance_std',
#  'hog_sc3_variance_sum',
#  'hog_sc3_kurtosis_mean',
#  'hog_sc3_kurtosis_std',
#  'hog_sc3_kurtosis_sum',
#  'hog_sc7_max_mean',
#  'hog_sc7_max_std',
#  'hog_sc7_max_sum',
#  'hog_sc3_mean_mean',
#  'hog_sc3_mean_std',
#  'hog_sc3_mean_sum',
#  'lac_sc3_lac_mean',
#  'lac_sc3_lac_std',
#  'lac_sc3_lac_sum',
#  'lac_sc5_lac_mean',
#  'lac_sc5_lac_std',
#  'lac_sc5_lac_sum',
#  'lac_sc7_lac_mean',
#  'lac_sc7_lac_std',
#  'lac_sc7_lac_sum',
#  'lbpm_sc7_mean_mean',
#  'lbpm_sc7_mean_std',
#  'lbpm_sc7_mean_sum',
#  'lbpm_sc5_variance_mean',
#  'lbpm_sc5_variance_std',
#  'lbpm_sc5_variance_sum',
#  'lbpm_sc3_max_mean',
#  'lbpm_sc3_max_std',
#  'lbpm_sc3_max_sum',
#  'lbpm_sc5_skew_mean',
#  'lbpm_sc5_skew_std',
#  'lbpm_sc5_skew_sum',
#  'lbpm_sc5_mean_mean',
#  'lbpm_sc5_mean_std',
#  'lbpm_sc5_mean_sum',
#  'lbpm_sc3_mean_mean',
#  'lbpm_sc3_mean_std',
#  'lbpm_sc3_mean_sum',
#  'lbpm_sc7_skew_mean',
#  'lbpm_sc7_skew_std',
#  'lbpm_sc7_skew_sum',
#  'lbpm_sc7_kurtosis_mean',
#  'lbpm_sc7_kurtosis_std',
#  'lbpm_sc7_kurtosis_sum',
#  'lbpm_sc7_max_mean',
#  'lbpm_sc7_max_std',
#  'lbpm_sc7_max_sum',
#  'lbpm_sc3_skew_mean',
#  'lbpm_sc3_skew_std',
#  'lbpm_sc3_skew_sum',
#  'lbpm_sc3_kurtosis_mean',
#  'lbpm_sc3_kurtosis_std',
#  'lbpm_sc3_kurtosis_sum',
#  'lbpm_sc5_max_mean',
#  'lbpm_sc5_max_std',
#  'lbpm_sc5_max_sum',
#  'lbpm_sc7_variance_mean',
#  'lbpm_sc7_variance_std',
#  'lbpm_sc7_variance_sum',
#  'lbpm_sc5_kurtosis_mean',
#  'lbpm_sc5_kurtosis_std',
#  'lbpm_sc5_kurtosis_sum',
#  'lbpm_sc3_variance_mean',
#  'lbpm_sc3_variance_std',
#  'lbpm_sc3_variance_sum',
#  'lsr_sc71_line_contrast_mean',
#  'lsr_sc71_line_contrast_std',
#  'lsr_sc71_line_contrast_sum',
#  'lsr_sc71_line_length_mean',
#  'lsr_sc71_line_length_std',
#  'lsr_sc71_line_length_sum',
#  'lsr_sc31_line_mean_mean',
#  'lsr_sc31_line_mean_std',
#  'lsr_sc31_line_mean_sum',
#  'lsr_sc51_line_length_mean',
#  'lsr_sc51_line_length_std',
#  'lsr_sc51_line_length_sum',
#  'lsr_sc71_line_mean_mean',
#  'lsr_sc71_line_mean_std',
#  'lsr_sc71_line_mean_sum',
#  'lsr_sc31_line_contrast_mean',
#  'lsr_sc31_line_contrast_std',
#  'lsr_sc31_line_contrast_sum',
#  'lsr_sc31_line_length_mean',
#  'lsr_sc31_line_length_std',
#  'lsr_sc31_line_length_sum',
#  'lsr_sc51_line_contrast_mean',
#  'lsr_sc51_line_contrast_std',
#  'lsr_sc51_line_contrast_sum',
#  'lsr_sc51_line_mean_mean',
#  'lsr_sc51_line_mean_std',
#  'lsr_sc51_line_mean_sum',
#  'mean_sc3_mean_mean',
#  'mean_sc3_mean_std',
#  'mean_sc3_mean_sum',
#  'mean_sc7_variance_mean',
#  'mean_sc7_variance_std',
#  'mean_sc7_variance_sum',
#  'mean_sc3_variance_mean',
#  'mean_sc3_variance_std',
#  'mean_sc3_variance_sum',
#  'mean_sc7_mean_mean',
#  'mean_sc7_mean_std',
#  'mean_sc7_mean_sum',
#  'mean_sc5_variance_mean',
#  'mean_sc5_variance_std',
#  'mean_sc5_variance_sum',
#  'mean_sc5_mean_mean',
#  'mean_sc5_mean_std',
#  'mean_sc5_mean_sum',
#  'ndvi_sc3_variance_mean',
#  'ndvi_sc3_variance_std',
#  'ndvi_sc3_variance_sum',
#  'ndvi_sc3_mean_mean',
#  'ndvi_sc3_mean_std',
#  'ndvi_sc3_mean_sum',
#  'ndvi_sc7_mean_mean',
#  'ndvi_sc7_mean_std',
#  'ndvi_sc7_mean_sum',
#  'ndvi_sc7_variance_mean',
#  'ndvi_sc7_variance_std',
#  'ndvi_sc7_variance_sum',
#  'ndvi_sc5_variance_mean',
#  'ndvi_sc5_variance_std',
#  'ndvi_sc5_variance_sum',
#  'ndvi_sc5_mean_mean',
#  'ndvi_sc5_mean_std',
#  'ndvi_sc5_mean_sum',
#  'orb_sc71_skew_mean',
#  'orb_sc71_skew_std',
#  'orb_sc71_skew_sum',
#  'orb_sc71_mean_mean',
#  'orb_sc71_mean_std',
#  'orb_sc71_mean_sum',
#  'orb_sc31_max_mean',
#  'orb_sc31_max_std',
#  'orb_sc31_max_sum',
#  'orb_sc71_variance_mean',
#  'orb_sc71_variance_std',
#  'orb_sc71_variance_sum',
#  'orb_sc51_skew_mean',
#  'orb_sc51_skew_std',
#  'orb_sc51_skew_sum',
#  'orb_sc31_variance_mean',
#  'orb_sc31_variance_std',
#  'orb_sc31_variance_sum',
#  'orb_sc31_mean_mean',
#  'orb_sc31_mean_std',
#  'orb_sc31_mean_sum',
#  'orb_sc31_kurtosis_mean',
#  'orb_sc31_kurtosis_std',
#  'orb_sc31_kurtosis_sum',
#  'orb_sc31_skew_mean',
#  'orb_sc31_skew_std',
#  'orb_sc31_skew_sum',
#  'orb_sc51_max_mean',
#  'orb_sc51_max_std',
#  'orb_sc51_max_sum',
#  'orb_sc51_mean_mean',
#  'orb_sc51_mean_std',
#  'orb_sc51_mean_sum',
#  'orb_sc51_kurtosis_mean',
#  'orb_sc51_kurtosis_std',
#  'orb_sc51_kurtosis_sum',
#  'orb_sc51_variance_mean',
#  'orb_sc51_variance_std',
#  'orb_sc51_variance_sum',
#  'orb_sc71_kurtosis_mean',
#  'orb_sc71_kurtosis_std',
#  'orb_sc71_kurtosis_sum',
#  'orb_sc71_max_mean',
#  'orb_sc71_max_std',
#  'orb_sc71_max_sum',
#  'pantex_sc5_min_mean',
#  'pantex_sc5_min_std',
#  'pantex_sc5_min_sum',
#  'pantex_sc7_min_mean',
#  'pantex_sc7_min_std',
#  'pantex_sc7_min_sum',
#  'pantex_sc3_min_mean',
#  'pantex_sc3_min_std',
#  'pantex_sc3_min_sum',
#  'sfs_sc31_max_ratio_of_orthgonal_angles_mean',
#  'sfs_sc31_max_ratio_of_orthgonal_angles_std',
#  'sfs_sc31_max_ratio_of_orthgonal_angles_sum',
#  'sfs_sc71_std_mean',
#  'sfs_sc71_std_std',
#  'sfs_sc71_std_sum',
#  'sfs_sc51_min_line_length_mean',
#  'sfs_sc51_min_line_length_std',
#  'sfs_sc51_min_line_length_sum',
#  'sfs_sc51_max_line_length_mean',
#  'sfs_sc51_max_line_length_std',
#  'sfs_sc51_max_line_length_sum',
#  'sfs_sc31_mean_mean',
#  'sfs_sc31_mean_std',
#  'sfs_sc31_mean_sum',
#  'sfs_sc71_max_line_length_mean',
#  'sfs_sc71_max_line_length_std',
#  'sfs_sc71_max_line_length_sum',
#  'sfs_sc71_mean_mean',
#  'sfs_sc71_mean_std',
#  'sfs_sc71_mean_sum',
#  'sfs_sc31_min_line_length_mean',
#  'sfs_sc31_min_line_length_std',
#  'sfs_sc31_min_line_length_sum',
#  'sfs_sc71_w_mean_mean',
#  'sfs_sc71_w_mean_std',
#  'sfs_sc71_w_mean_sum',
#  'sfs_sc51_mean_mean',
#  'sfs_sc51_mean_std',
#  'sfs_sc51_mean_sum',
#  'sfs_sc31_w_mean_mean',
#  'sfs_sc31_w_mean_std',
#  'sfs_sc31_w_mean_sum',
#  'sfs_sc51_max_ratio_of_orthgonal_angles_mean',
#  'sfs_sc51_max_ratio_of_orthgonal_angles_std',
#  'sfs_sc51_max_ratio_of_orthgonal_angles_sum',
#  'sfs_sc31_max_line_length_mean',
#  'sfs_sc31_max_line_length_std',
#  'sfs_sc31_max_line_length_sum',
#  'sfs_sc51_w_mean_mean',
#  'sfs_sc51_w_mean_std',
#  'sfs_sc51_w_mean_sum',
#  'sfs_sc51_std_mean',
#  'sfs_sc51_std_std',
#  'sfs_sc51_std_sum',
#  'sfs_sc71_max_ratio_of_orthgonal_angles_mean',
#  'sfs_sc71_max_ratio_of_orthgonal_angles_std',
#  'sfs_sc71_max_ratio_of_orthgonal_angles_sum',
#  'sfs_sc31_std_mean',
#  'sfs_sc31_std_std',
#  'sfs_sc31_std_sum',
#  'sfs_sc71_min_line_length_mean',
#  'sfs_sc71_min_line_length_std',
#  'sfs_sc71_min_line_length_sum']

# %% [markdown]
# ### Compute Coorelation of features with population density

# %% [markdown]
# Store all features with the least correlation (stat. significance (p < 0.05))

# %% [markdown]
# The Pearson correlation coefficient measures the linear relationship
# between two datasets. Strictly speaking, Pearson's correlation requires
# that each dataset be normally distributed, and not necessarily zero-mean.
#
# Like other correlation coefficients, this one varies between -1 and +1
# with 0 implying no correlation. Correlations of -1 or +1 imply an exact
# linear relationship. Positive correlations imply that as x increases, so
# does y. Negative correlations imply that as x increases, y decreases.
#
# The p-value roughly indicates the probability of an uncorrelated system
# producing datasets that have a Pearson correlation at least as extreme
# as the one computed from these datasets. The p-values are not entirely
# reliable but are probably reasonable for datasets larger than 500 or so.

# %%
y_dict = {}
x = []

for x_var in all_x:
    
    #Calculate the Pearson statistics, 
    # returns the Pearson value and p value
    
    p = stats.skew(spfeas_world_pop_merged[x_var])
    
    print(y_var, x_var, p)
    # print back for mike
    #print (y_var + " , " + x_var + " , " +  p)
# Out:
# _sum fourier_sc31_variance_mean -1.4616923765132483
# _sum fourier_sc31_variance_std 1.5229818957230805
# _sum fourier_sc31_variance_sum 7.394662134735632
# _sum fourier_sc71_mean_mean -0.6771168726779779
# _sum fourier_sc71_mean_std 3.0014159816521495
# _sum fourier_sc71_mean_sum 7.862943729619969
# _sum fourier_sc51_mean_mean -0.5599512064399966
# _sum fourier_sc51_mean_std 2.0478761429705132
# _sum fourier_sc51_mean_sum 7.8997584889507655
# _sum fourier_sc31_mean_mean -0.40134411736103376
# _sum fourier_sc31_mean_std 1.0693539416211884
# _sum fourier_sc31_mean_sum 7.9379202480789575
# _sum fourier_sc51_variance_mean -1.540668291729564
# _sum fourier_sc51_variance_std 1.896037348436762
# _sum fourier_sc51_variance_sum 7.292575318101691
# _sum fourier_sc71_variance_mean -1.5661091142446384
# _sum fourier_sc71_variance_std 2.2590809559440994
# _sum fourier_sc71_variance_sum 7.260798343531496
# _sum gabor_sc3_filter_5_mean 0.5520925849606606
# _sum gabor_sc3_filter_5_std 1.4834270344090212
# _sum gabor_sc3_filter_5_sum 7.274314461613656
# _sum gabor_sc3_filter_4_mean 1.641876145600964
# _sum gabor_sc3_filter_4_std 2.5313438318656707
# _sum gabor_sc3_filter_4_sum 9.411425841460355
# _sum gabor_sc3_filter_7_mean 0.5525882248533747
# _sum gabor_sc3_filter_7_std 1.4792937389265675
# _sum gabor_sc3_filter_7_sum 7.273967603555155
# _sum gabor_sc3_filter_6_mean 1.6578498396031924
# _sum gabor_sc3_filter_6_std 2.6292336532442535
# _sum gabor_sc3_filter_6_sum 9.37566212292887
# _sum gabor_sc3_filter_1_mean 0.5528656166342049
# _sum gabor_sc3_filter_1_std 1.4707920087029294
# _sum gabor_sc3_filter_1_sum 7.274227540853613
# _sum gabor_sc3_mean_mean 0.5537920973323157
# _sum gabor_sc3_mean_std 1.461684562668144
# _sum gabor_sc3_mean_sum 7.273789801364615
# _sum gabor_sc3_filter_3_mean 0.5526737859508665
# _sum gabor_sc3_filter_3_std 1.48352277163691
# _sum gabor_sc3_filter_3_sum 7.273391281672551
# _sum gabor_sc3_filter_2_mean 1.6249623685703063
# _sum gabor_sc3_filter_2_std 2.450756971292738
# _sum gabor_sc3_filter_2_sum 9.446109934086927
# _sum gabor_sc3_filter_9_mean 0.5524219314577917
# _sum gabor_sc3_filter_9_std 1.4825332513878535
# _sum gabor_sc3_filter_9_sum 7.273636123312256
# _sum gabor_sc3_filter_13_mean 0.5523977635015647
# _sum gabor_sc3_filter_13_std 1.4756037805085598
# _sum gabor_sc3_filter_13_sum 7.2732709524105426
# _sum gabor_sc3_filter_8_mean 1.6725974082032953
# _sum gabor_sc3_filter_8_std 2.7300148637718635
# _sum gabor_sc3_filter_8_sum 9.335089866024795
# _sum gabor_sc3_filter_10_mean 1.6681197591333365
# _sum gabor_sc3_filter_10_std 2.7769419587794024
# _sum gabor_sc3_filter_10_sum 9.30794067175108
# _sum gabor_sc3_variance_mean 1.6184258494182615
# _sum gabor_sc3_variance_std 2.4489164645005848
# _sum gabor_sc3_variance_sum 9.422972322445405
# _sum gabor_sc3_filter_11_mean 0.5518642983961521
# _sum gabor_sc3_filter_11_std 1.485365074067834
# _sum gabor_sc3_filter_11_sum 7.272231795021812
# _sum gabor_sc3_filter_12_mean 1.6426602122494087
# _sum gabor_sc3_filter_12_std 2.7208666581810355
# _sum gabor_sc3_filter_12_sum 9.324216816038668
# _sum gabor_sc3_filter_14_mean 1.6083017564864799
# _sum gabor_sc3_filter_14_std 2.543166502567292
# _sum gabor_sc3_filter_14_sum 9.386370379135672
# _sum gabor_sc5_filter_4_mean 1.2201127736806792
# _sum gabor_sc5_filter_4_std 2.396398322317494
# _sum gabor_sc5_filter_4_sum 7.18998604345006
# _sum gabor_sc5_variance_mean 1.2271765820735467
# _sum gabor_sc5_variance_std 2.368129262804402
# _sum gabor_sc5_variance_sum 7.190645951789468
# _sum gabor_sc5_mean_mean 0.5534512987465026
# _sum gabor_sc5_mean_std 1.6516609816372847
# _sum gabor_sc5_mean_sum 7.270614644157072
# _sum gabor_sc5_filter_6_mean 1.215099957112308
# _sum gabor_sc5_filter_6_std 2.4962883021424602
# _sum gabor_sc5_filter_6_sum 7.189125725392663
# _sum gabor_sc5_filter_3_mean 0.5480101399021865
# _sum gabor_sc5_filter_3_std 1.7831501275900175
# _sum gabor_sc5_filter_3_sum 7.271293607266928
# _sum gabor_sc5_filter_9_mean 0.5449520437593222
# _sum gabor_sc5_filter_9_std 1.7573782532442486
# _sum gabor_sc5_filter_9_sum 7.270192718934189
# _sum gabor_sc5_filter_8_mean 1.20648525188633
# _sum gabor_sc5_filter_8_std 2.6424755658985806
# _sum gabor_sc5_filter_8_sum 7.187788489442382
# _sum gabor_sc5_filter_2_mean 1.2258510859701064
# _sum gabor_sc5_filter_2_std 2.357844002850051
# _sum gabor_sc5_filter_2_sum 7.192224016127159
# _sum gabor_sc5_filter_13_mean 0.5419907125649007
# _sum gabor_sc5_filter_13_std 1.7353708732678328
# _sum gabor_sc5_filter_13_sum 7.269264330765491
# _sum gabor_sc5_filter_12_mean 1.1862517759450812
# _sum gabor_sc5_filter_12_std 2.5619094400213474
# _sum gabor_sc5_filter_12_sum 7.186973409027723
# _sum gabor_sc5_filter_11_mean 0.5424838606119382
# _sum gabor_sc5_filter_11_std 1.7994588787684207
# _sum gabor_sc5_filter_11_sum 7.269328541625152
# _sum gabor_sc5_filter_10_mean 1.197053241333724
# _sum gabor_sc5_filter_10_std 2.68614075186942
# _sum gabor_sc5_filter_10_sum 7.184836696809827
# _sum gabor_sc5_filter_7_mean 0.547526553362151
# _sum gabor_sc5_filter_7_std 1.7103224891849245
# _sum gabor_sc5_filter_7_sum 7.270999685681891
# _sum gabor_sc5_filter_1_mean 0.5515045714027828
# _sum gabor_sc5_filter_1_std 1.7105551936424819
# _sum gabor_sc5_filter_1_sum 7.271017442456916
# _sum gabor_sc5_filter_5_mean 0.5479045695484763
# _sum gabor_sc5_filter_5_std 1.752162716338178
# _sum gabor_sc5_filter_5_sum 7.271337717182101
# _sum gabor_sc5_filter_14_mean 1.1762904516969699
# _sum gabor_sc5_filter_14_std 2.3949098575447203
# _sum gabor_sc5_filter_14_sum 7.198553191791688
# _sum gabor_sc7_filter_9_mean 0.544156275311321
# _sum gabor_sc7_filter_9_std 1.7866041708093452
# _sum gabor_sc7_filter_9_sum 7.2694430074055125
# _sum gabor_sc7_mean_mean 0.5717940037557666
# _sum gabor_sc7_mean_std 1.5446219985598542
# _sum gabor_sc7_mean_sum 7.269162575499036
# _sum gabor_sc7_variance_mean 1.2486580343913696
# _sum gabor_sc7_variance_std 2.5693873949881008
# _sum gabor_sc7_variance_sum 7.189418735422575
# _sum gabor_sc7_filter_1_mean 0.5614907904432735
# _sum gabor_sc7_filter_1_std 1.6870113049769773
# _sum gabor_sc7_filter_1_sum 7.269631603202078
# _sum gabor_sc7_filter_5_mean 0.5506237547235083
# _sum gabor_sc7_filter_5_std 1.773989604407988
# _sum gabor_sc7_filter_5_sum 7.270550804556572
# _sum gabor_sc7_filter_3_mean 0.5494167351882012
# _sum gabor_sc7_filter_3_std 1.8843487110807688
# _sum gabor_sc7_filter_3_sum 7.27024358062042
# _sum gabor_sc7_filter_2_mean 1.2465254998507735
# _sum gabor_sc7_filter_2_std 2.4906882011827625
# _sum gabor_sc7_filter_2_sum 7.1861664052992795
# _sum gabor_sc7_filter_11_mean 0.5328684249155808
# _sum gabor_sc7_filter_11_std 1.9183193509900376
# _sum gabor_sc7_filter_11_sum 7.2679473721439445
# _sum gabor_sc7_filter_10_mean 1.1809831232396184
# _sum gabor_sc7_filter_10_std 2.906351233725527
# _sum gabor_sc7_filter_10_sum 7.176046802611393
# _sum gabor_sc7_filter_7_mean 0.5541945379997223
# _sum gabor_sc7_filter_7_std 1.6521519408617504
# _sum gabor_sc7_filter_7_sum 7.270260303708047
# _sum gabor_sc7_filter_4_mean 1.2285905980528764
# _sum gabor_sc7_filter_4_std 2.4406094418434625
# _sum gabor_sc7_filter_4_sum 7.177762909988327
# _sum gabor_sc7_filter_12_mean 1.159507320569328
# _sum gabor_sc7_filter_12_std 2.686219252977328
# _sum gabor_sc7_filter_12_sum 7.175548965460618
# _sum gabor_sc7_filter_13_mean 0.5349486583606835
# _sum gabor_sc7_filter_13_std 1.7349688375895516
# _sum gabor_sc7_filter_13_sum 7.267659927747876
# _sum gabor_sc7_filter_14_mean 1.156189812775722
# _sum gabor_sc7_filter_14_std 2.4733855530590834
# _sum gabor_sc7_filter_14_sum 7.202303518563455
# _sum gabor_sc7_filter_6_mean 1.2149214652245528
# _sum gabor_sc7_filter_6_std 2.5937538076077185
# _sum gabor_sc7_filter_6_sum 7.182538322685418
# _sum gabor_sc7_filter_8_mean 1.2032481557818842
# _sum gabor_sc7_filter_8_std 2.8756683666975937
# _sum gabor_sc7_filter_8_sum 7.186481183545434
# _sum hog_sc7_mean_mean -9.300417241355126
# _sum hog_sc7_mean_std 1.4322668008029174
# _sum hog_sc7_mean_sum 8.844077305562578
# _sum hog_sc5_kurtosis_mean 0.40246745708929094
# _sum hog_sc5_kurtosis_std 4.601904756740107
# _sum hog_sc5_kurtosis_sum 7.385915660639485
# _sum hog_sc5_skew_mean 0.04038362500520424
# _sum hog_sc5_skew_std 1.678898632104797
# _sum hog_sc5_skew_sum 8.363504629601396
# _sum hog_sc7_variance_mean 0.26983418239977736
# _sum hog_sc7_variance_std 0.1621161309073575
# _sum hog_sc7_variance_sum 8.821030323955203
# _sum hog_sc7_skew_mean 0.40093745102236633
# _sum hog_sc7_skew_std 3.6606842388438308
# _sum hog_sc7_skew_sum 7.9793705710220335
# _sum hog_sc5_mean_mean -6.590043273745824
# _sum hog_sc5_mean_std 0.5882941872098914
# _sum hog_sc5_mean_sum 8.960824273409466
# _sum hog_sc3_skew_mean -0.4368986736836173
# _sum hog_sc3_skew_std -0.10593732373147395
# _sum hog_sc3_skew_sum 8.581638097065614
# _sum hog_sc5_max_mean -1.025637871743048
# _sum hog_sc5_max_std 0.3355447681339954
# _sum hog_sc5_max_sum 9.017565217537387
# _sum hog_sc5_variance_mean 0.05427252521436971
# _sum hog_sc5_variance_std 0.07175359089710547
# _sum hog_sc5_variance_sum 9.10821679871363
# _sum hog_sc7_kurtosis_mean 0.6151948699418566
# _sum hog_sc7_kurtosis_std 6.979747098778921
# _sum hog_sc7_kurtosis_sum 6.82332286741574
# _sum hog_sc3_max_mean -4.592199800362986
# _sum hog_sc3_max_std 0.15581428958951188
# _sum hog_sc3_max_sum 8.971357597882259
# _sum hog_sc3_variance_mean -3.0066148562881767
# _sum hog_sc3_variance_std 0.02204368068389279
# _sum hog_sc3_variance_sum 9.078932268408376
# _sum hog_sc3_kurtosis_mean -0.21452364766368268
# _sum hog_sc3_kurtosis_std -1.5274801376412368
# _sum hog_sc3_kurtosis_sum 8.377737603908951
# _sum hog_sc7_max_mean -0.264570437205369
# _sum hog_sc7_max_std 0.274277584875929
# _sum hog_sc7_max_sum 8.8237488249762
# _sum hog_sc3_mean_mean -1.605226350470604
# _sum hog_sc3_mean_std -0.02614132599282376
# _sum hog_sc3_mean_sum 8.81941821037942
# _sum lac_sc3_lac_mean 0.09383276812057416
# _sum lac_sc3_lac_std -0.304010904049982
# _sum lac_sc3_lac_sum 14.567702657203714
# _sum lac_sc5_lac_mean -0.17230589670424368
# _sum lac_sc5_lac_std -0.8574902420785302
# _sum lac_sc5_lac_sum 13.096443044150966
# _sum lac_sc7_lac_mean -0.28179594279017817
# _sum lac_sc7_lac_std -1.1836981216903353
# _sum lac_sc7_lac_sum 13.18127650158775
# _sum lbpm_sc7_mean_mean 5.785619385594869
# _sum lbpm_sc7_mean_std 3.6802678095851595
# _sum lbpm_sc7_mean_sum 12.300533216066144
# _sum lbpm_sc5_variance_mean 2.2038457743063122
# _sum lbpm_sc5_variance_std 0.55671527012355
# _sum lbpm_sc5_variance_sum 14.435220922550197
# _sum lbpm_sc3_max_mean 1.3541676956769322
# _sum lbpm_sc3_max_std -1.3819113328197095
# _sum lbpm_sc3_max_sum 13.111205919064519
# _sum lbpm_sc5_skew_mean -0.3673175944196987
# _sum lbpm_sc5_skew_std -0.16073582793770522
# _sum lbpm_sc5_skew_sum 7.601173963044629
# _sum lbpm_sc5_mean_mean 2.9201686505645874
# _sum lbpm_sc5_mean_std 2.7359809481140562
# _sum lbpm_sc5_mean_sum 12.285719508416726
# _sum lbpm_sc3_mean_mean 1.101667753111432
# _sum lbpm_sc3_mean_std 1.3293908232941878
# _sum lbpm_sc3_mean_sum 12.251600755362196
# _sum lbpm_sc7_skew_mean -0.22949881460081964
# _sum lbpm_sc7_skew_std -0.034573763180087404
# _sum lbpm_sc7_skew_sum 7.42566394053456
# _sum lbpm_sc7_kurtosis_mean -0.06845368360518306
# _sum lbpm_sc7_kurtosis_std 0.020182739702669292
# _sum lbpm_sc7_kurtosis_sum 6.866326848772566
# _sum lbpm_sc7_max_mean 1.5975666246533897
# _sum lbpm_sc7_max_std 0.034850823288314826
# _sum lbpm_sc7_max_sum 13.361106031549898
# _sum lbpm_sc3_skew_mean -0.5873692750177618
# _sum lbpm_sc3_skew_std -0.09213583816319569
# _sum lbpm_sc3_skew_sum 8.18617591466823
# _sum lbpm_sc3_kurtosis_mean -0.4215198731629711
# _sum lbpm_sc3_kurtosis_std -1.3288106205449028
# _sum lbpm_sc3_kurtosis_sum 7.511332356300035
# _sum lbpm_sc5_max_mean 1.4459311095735556
# _sum lbpm_sc5_max_std -0.05991697607347857
# _sum lbpm_sc5_max_sum 13.28826873179224
# _sum lbpm_sc7_variance_mean 2.5561784540883092
# _sum lbpm_sc7_variance_std 0.7506429172945557
# _sum lbpm_sc7_variance_sum 14.543536870927081
# _sum lbpm_sc5_kurtosis_mean -0.22312626691864282
# _sum lbpm_sc5_kurtosis_std -0.3431699137784222
# _sum lbpm_sc5_kurtosis_sum 6.982802497233202
# _sum lbpm_sc3_variance_mean 1.8058145954797462
# _sum lbpm_sc3_variance_std 0.32018897129176044
# _sum lbpm_sc3_variance_sum 14.154343825381588
# _sum lsr_sc71_line_contrast_mean -1.888686200228016
# _sum lsr_sc71_line_contrast_std 1.6495611665895138
# _sum lsr_sc71_line_contrast_sum 10.398002688406713
# _sum lsr_sc71_line_length_mean -1.929685018615436
# _sum lsr_sc71_line_length_std 1.6788688777078324
# _sum lsr_sc71_line_length_sum 10.29209055438402
# _sum lsr_sc31_line_mean_mean 1.3035859768225715
# _sum lsr_sc31_line_mean_std 0.9032957514847819
# _sum lsr_sc31_line_mean_sum 12.655516187413106
# _sum lsr_sc51_line_length_mean -1.7136008178950974
# _sum lsr_sc51_line_length_std 1.396302182494457
# _sum lsr_sc51_line_length_sum 10.44963140587169
# _sum lsr_sc71_line_mean_mean 1.2491722725044758
# _sum lsr_sc71_line_mean_std 0.6333369690028166
# _sum lsr_sc71_line_mean_sum 12.155716096274801
# _sum lsr_sc31_line_contrast_mean -1.1285090715933113
# _sum lsr_sc31_line_contrast_std 0.6356456475710857
# _sum lsr_sc31_line_contrast_sum 10.734336024737667
# _sum lsr_sc31_line_length_mean -1.1564741317464924
# _sum lsr_sc31_line_length_std 0.6548217868258357
# _sum lsr_sc31_line_length_sum 10.67852806280775
# _sum lsr_sc51_line_contrast_mean -1.6636129341897716
# _sum lsr_sc51_line_contrast_std 1.360680500453641
# _sum lsr_sc51_line_contrast_sum 10.543341441581
# _sum lsr_sc51_line_mean_mean 1.2808888870769177
# _sum lsr_sc51_line_mean_std 0.7649922660983585
# _sum lsr_sc51_line_mean_sum 12.389594260032554
# _sum mean_sc3_mean_mean 0.5579674545517127
# _sum mean_sc3_mean_std 1.2522963495602284
# _sum mean_sc3_mean_sum 7.273940153157988
# _sum mean_sc7_variance_mean 1.1719800514977468
# _sum mean_sc7_variance_std 2.3374138093159145
# _sum mean_sc7_variance_sum 7.187349483806087
# _sum mean_sc3_variance_mean 1.4273060921056142
# _sum mean_sc3_variance_std 2.19258919721953
# _sum mean_sc3_variance_sum 10.519032651893019
# _sum mean_sc7_mean_mean 0.5434357385782455
# _sum mean_sc7_mean_std 2.0725951472697997
# _sum mean_sc7_mean_sum 7.273973431446704
# _sum mean_sc5_variance_mean 1.196812361882922
# _sum mean_sc5_variance_std 2.2833415313603664
# _sum mean_sc5_variance_sum 7.226252787206391
# _sum mean_sc5_mean_mean 0.5516499732164458
# _sum mean_sc5_mean_std 1.6829153232069036
# _sum mean_sc5_mean_sum 7.273945208418653
# _sum ndvi_sc3_variance_mean 0.2512689909922932
# _sum ndvi_sc3_variance_std 1.5513220973053465
# _sum ndvi_sc3_variance_sum 6.487751903116147
# _sum ndvi_sc3_mean_mean -0.4426424208625703
# _sum ndvi_sc3_mean_std 2.548561221444162
# _sum ndvi_sc3_mean_sum 10.467110097399063
# _sum ndvi_sc7_mean_mean -0.4449459985937856
# _sum ndvi_sc7_mean_std 2.6038026356424098
# _sum ndvi_sc7_mean_sum 10.468350610400549
# _sum ndvi_sc7_variance_mean 0.08282129048044053
# _sum ndvi_sc7_variance_std 0.38624244197787844
# _sum ndvi_sc7_variance_sum 11.106948510405761
# _sum ndvi_sc5_variance_mean -0.01592780679686623
# _sum ndvi_sc5_variance_std 0.6667699504005843
# _sum ndvi_sc5_variance_sum 11.036500072277953
# _sum ndvi_sc5_mean_mean -0.443401894129957
# _sum ndvi_sc5_mean_std 2.6087748586990163
# _sum ndvi_sc5_mean_sum 10.467645324041271
# _sum orb_sc71_skew_mean 3.2443576644176493
# _sum orb_sc71_skew_std 0.7775485765961279
# _sum orb_sc71_skew_sum 14.168214584555761
# _sum orb_sc71_mean_mean 1.9721375731725668
# _sum orb_sc71_mean_std 2.331476565559387
# _sum orb_sc71_mean_sum 11.58694922144965
# _sum orb_sc31_max_mean 1.9175729685657583
# _sum orb_sc31_max_std 1.395462919196848
# _sum orb_sc31_max_sum 11.856313367775984
# _sum orb_sc71_variance_mean 3.2263275328790018
# _sum orb_sc71_variance_std 2.9311991610273824
# _sum orb_sc71_variance_sum 10.395132895187212
# _sum orb_sc51_skew_mean 3.3724165039899257
# _sum orb_sc51_skew_std 0.7557815550361666
# _sum orb_sc51_skew_sum 14.220235764999089
# _sum orb_sc31_variance_mean 3.9086254975332655
# _sum orb_sc31_variance_std 2.8231838115490526
# _sum orb_sc31_variance_sum 10.661323963694214
# _sum orb_sc31_mean_mean 2.5500813474948414
# _sum orb_sc31_mean_std 1.728332558596822
# _sum orb_sc31_mean_sum 11.590174199468581
# _sum orb_sc31_kurtosis_mean 1.6474181261258407
# _sum orb_sc31_kurtosis_std 0.6706830314453075
# _sum orb_sc31_kurtosis_sum 14.066988435769694
# _sum orb_sc31_skew_mean 1.3841745578931122
# _sum orb_sc31_skew_std 0.6311652635608398
# _sum orb_sc31_skew_sum 14.14822435466426
# _sum orb_sc51_max_mean 1.8638702864541656
# _sum orb_sc51_max_std 1.5279921104869212
# _sum orb_sc51_max_sum 12.000783051268382
# _sum orb_sc51_mean_mean 2.1914235525352517
# _sum orb_sc51_mean_std 1.8951224812217435
# _sum orb_sc51_mean_sum 11.584844528725862
# _sum orb_sc51_kurtosis_mean 3.5096295991175923
# _sum orb_sc51_kurtosis_std 0.7887362013194367
# _sum orb_sc51_kurtosis_sum 14.21717378887908
# _sum orb_sc51_variance_mean 3.7086125898703033
# _sum orb_sc51_variance_std 2.696282245376385
# _sum orb_sc51_variance_sum 10.527904406613327
# _sum orb_sc71_kurtosis_mean 3.382277365696069
# _sum orb_sc71_kurtosis_std 0.7819728300991156
# _sum orb_sc71_kurtosis_sum 14.168065021728195
# _sum orb_sc71_max_mean 1.826365197666112
# _sum orb_sc71_max_std 1.6610756097606185
# _sum orb_sc71_max_sum 12.139963854249471
# _sum pantex_sc5_min_mean 0.9711557410533683
# _sum pantex_sc5_min_std 2.2269694065131063
# _sum pantex_sc5_min_sum 7.828592355250065
# _sum pantex_sc7_min_mean 0.9783638655392959
# _sum pantex_sc7_min_std 2.287328895249428
# _sum pantex_sc7_min_sum 7.815436557966666
# _sum pantex_sc3_min_mean 1.200224209192803
# _sum pantex_sc3_min_std 1.2282709090887203
# _sum pantex_sc3_min_sum 7.624656968203904
# _sum sfs_sc31_max_ratio_of_orthgonal_angles_mean 0.095447222072389
# _sum sfs_sc31_max_ratio_of_orthgonal_angles_std 5.081374097088938
# _sum sfs_sc31_max_ratio_of_orthgonal_angles_sum 12.147235136679377
# _sum sfs_sc71_std_mean 19.476353952124324
# _sum sfs_sc71_std_std nan
# _sum sfs_sc71_std_sum 16.919470404318083
# _sum sfs_sc51_min_line_length_mean 6.7895417710939805
# _sum sfs_sc51_min_line_length_std 3.5730300562381303
# _sum sfs_sc51_min_line_length_sum 12.891125615308548
# _sum sfs_sc51_max_line_length_mean 0.12341093084237703
# _sum sfs_sc51_max_line_length_std 0.020158396305833597
# _sum sfs_sc51_max_line_length_sum 6.307623318146959
# _sum sfs_sc31_mean_mean -0.08957501363945336
# _sum sfs_sc31_mean_std -0.01594099290270981
# _sum sfs_sc31_mean_sum 10.78067225932302
# _sum sfs_sc71_max_line_length_mean 0.16036307866740968
# _sum sfs_sc71_max_line_length_std 0.048689883758332504
# _sum sfs_sc71_max_line_length_sum 6.440211181122062
# _sum sfs_sc71_mean_mean 0.24479584432681628
# _sum sfs_sc71_mean_std 0.015333287508078674
# _sum sfs_sc71_mean_sum 5.903541740121574
# _sum sfs_sc31_min_line_length_mean 4.369458917712199
# _sum sfs_sc31_min_line_length_std 2.7002305092351366
# _sum sfs_sc31_min_line_length_sum 12.546675588876456
# _sum sfs_sc71_w_mean_mean 0.5212796692945342
# _sum sfs_sc71_w_mean_std 0.48787284464048664
# _sum sfs_sc71_w_mean_sum 6.043918988598755
# _sum sfs_sc51_mean_mean -0.21959215070894536
# _sum sfs_sc51_mean_std -0.04617061273024771
# _sum sfs_sc51_mean_sum 7.821575580842488
# _sum sfs_sc31_w_mean_mean 1.0730088850440451
# _sum sfs_sc31_w_mean_std 0.327600548351931
# _sum sfs_sc31_w_mean_sum 6.357457686664393
# _sum sfs_sc51_max_ratio_of_orthgonal_angles_mean 0.5110289921187686
# _sum sfs_sc51_max_ratio_of_orthgonal_angles_std 7.3489263668226625
# _sum sfs_sc51_max_ratio_of_orthgonal_angles_sum 12.155206231024671
# _sum sfs_sc31_max_line_length_mean -0.43195095880162054
# _sum sfs_sc31_max_line_length_std 0.24255057326400692
# _sum sfs_sc31_max_line_length_sum 8.771615456961701
# _sum sfs_sc51_w_mean_mean 0.5480266731937691
# _sum sfs_sc51_w_mean_std 0.42078808824118946
# _sum sfs_sc51_w_mean_sum 6.25930199910996
# _sum sfs_sc51_std_mean -0.15332667907170447
# _sum sfs_sc51_std_std -0.0504557934093086
# _sum sfs_sc51_std_sum 7.449305288879837
# _sum sfs_sc71_max_ratio_of_orthgonal_angles_mean 0.7097332738619807
# _sum sfs_sc71_max_ratio_of_orthgonal_angles_std 5.769721072618038
# _sum sfs_sc71_max_ratio_of_orthgonal_angles_sum 12.16669431453963
# _sum sfs_sc31_std_mean -0.8342036921837227
# _sum sfs_sc31_std_std 0.23441365819985738
# _sum sfs_sc31_std_sum 7.791040465638011
# _sum sfs_sc71_min_line_length_mean 3.1179466603746615
# _sum sfs_sc71_min_line_length_std 1.1554125400845665
# _sum sfs_sc71_min_line_length_sum 14.138413380002351

# %%
y_dict = {}
x = []

for x_var in all_x:
    
    #Calculate the Pearson statistics, 
    # returns the Pearson value and p value
    
    p = stats.pearsonr(spfeas_world_pop_merged[x_var],pop_count)
    
    # print back for mike
    print (y_var + " , " + x_var + " , " +  str(p[0]) + " , " + str(p[1]))
    
    #If p < 0.05 append to list x
    if p[1] < 0.05:
        x.append([x_var,abs(p[0])])

#List x is made into a DataFrame 
# which is sorted by the absolute values of the Pearson values
x_df = pd.DataFrame(x,columns=["x_var","abs_r2"]).sort_values("abs_r2",ascending=False)


#The dependent variable dictionary is given an entry 
# where the key is the name of the dependent variable
# and the value is a list of top 200 most significant values

y_dict[y_var] = list(x_df["x_var"][0:200])

#Print out each dependent variable and 
#the number of x values that remain to check completion
# Out:
# _sum , fourier_sc31_variance_mean , 0.138978962701 , 0.000177754405549
# _sum , fourier_sc31_variance_std , -0.122948261419 , 0.000923769029304
# _sum , fourier_sc31_variance_sum , 0.165513164032 , 7.69074989603e-06
# _sum , fourier_sc71_mean_mean , 0.20207218502 , 4.23682220943e-08
# _sum , fourier_sc71_mean_std , -0.165147188919 , 8.05989317448e-06
# _sum , fourier_sc71_mean_sum , 0.16392965013 , 9.41347615991e-06
# _sum , fourier_sc51_mean_mean , 0.199896728647 , 5.94476351768e-08
# _sum , fourier_sc51_mean_std , -0.185236459538 , 5.28654095921e-07
# _sum , fourier_sc51_mean_sum , 0.16661144862 , 6.67733747124e-06
# _sum , fourier_sc31_mean_mean , 0.200597705875 , 5.33231592559e-08
# _sum , fourier_sc31_mean_std , -0.199079867812 , 6.74444128035e-08
# _sum , fourier_sc31_mean_sum , 0.169134838726 , 4.80962457153e-06
# _sum , fourier_sc51_variance_mean , 0.129060035023 , 0.000503653692574
# _sum , fourier_sc51_variance_std , -0.114716450745 , 0.0020053488473
# _sum , fourier_sc51_variance_sum , 0.16078842902 , 1.39784036043e-05
# _sum , fourier_sc71_variance_mean , 0.119921223463 , 0.00123527679815
# _sum , fourier_sc71_variance_std , -0.105111870771 , 0.00466546142882
# _sum , fourier_sc71_variance_sum , 0.156796598085 , 2.28575171666e-05
# _sum , gabor_sc3_filter_5_mean , 0.254681425684 , 3.62363265689e-12
# _sum , gabor_sc3_filter_5_std , 0.20536094265 , 2.52095451876e-08
# _sum , gabor_sc3_filter_5_sum , 0.163788216151 , 9.58408024364e-06
# _sum , gabor_sc3_filter_4_mean , 0.244729066403 , 2.5450483149e-11
# _sum , gabor_sc3_filter_4_std , 0.241332917373 , 4.8548585978e-11
# _sum , gabor_sc3_filter_4_sum , 0.088743242731 , 0.0169971864043
# _sum , gabor_sc3_filter_7_mean , 0.254879194263 , 3.48294991883e-12
# _sum , gabor_sc3_filter_7_std , 0.206534515332 , 2.09024831218e-08
# _sum , gabor_sc3_filter_7_sum , 0.163778442219 , 9.59597824788e-06
# _sum , gabor_sc3_filter_6_mean , 0.245406957964 , 2.23460878233e-11
# _sum , gabor_sc3_filter_6_std , 0.239581799123 , 6.74748466195e-11
# _sum , gabor_sc3_filter_6_sum , 0.0896232039726 , 0.0159293365508
# _sum , gabor_sc3_filter_1_mean , 0.254754143313 , 3.57127029946e-12
# _sum , gabor_sc3_filter_1_std , 0.205748155747 , 2.37012526018e-08
# _sum , gabor_sc3_filter_1_sum , 0.163801601614 , 9.56780866593e-06
# _sum , gabor_sc3_mean_mean , 0.255153486459 , 3.29664275466e-12
# _sum , gabor_sc3_mean_std , 0.206777397198 , 2.01047381773e-08
# _sum , gabor_sc3_mean_sum , 0.163802075983 , 9.56723249976e-06
# _sum , gabor_sc3_filter_3_mean , 0.254590863167 , 3.68989589631e-12
# _sum , gabor_sc3_filter_3_std , 0.204834811217 , 2.74086713625e-08
# _sum , gabor_sc3_filter_3_sum , 0.163799438744 , 9.57043609948e-06
# _sum , gabor_sc3_filter_2_mean , 0.246114426743 , 1.95011829453e-11
# _sum , gabor_sc3_filter_2_std , 0.248734428189 , 1.17335301399e-11
# _sum , gabor_sc3_filter_2_sum , 0.087939081485 , 0.0180273481056
# _sum , gabor_sc3_filter_9_mean , 0.255469607939 , 3.0940015149e-12
# _sum , gabor_sc3_filter_9_std , 0.20719442173 , 1.8803316115e-08
# _sum , gabor_sc3_filter_9_sum , 0.163768345437 , 9.60828404802e-06
# _sum , gabor_sc3_filter_13_mean , 0.256899598038 , 2.31964289889e-12
# _sum , gabor_sc3_filter_13_std , 0.208215919968 , 1.5950956685e-08
# _sum , gabor_sc3_filter_13_sum , 0.163746867067 , 9.63451160915e-06
# _sum , gabor_sc3_filter_8_mean , 0.246858680956 , 1.68906157198e-11
# _sum , gabor_sc3_filter_8_std , 0.242656591605 , 3.77887029655e-11
# _sum , gabor_sc3_filter_8_sum , 0.090394084464 , 0.0150427040703
# _sum , gabor_sc3_filter_10_mean , 0.248443965891 , 1.24169304899e-11
# _sum , gabor_sc3_filter_10_std , 0.247441914172 , 1.50865641614e-11
# _sum , gabor_sc3_filter_10_sum , 0.0908313269573 , 0.0145593351391
# _sum , gabor_sc3_variance_mean , 0.247875585228 , 1.38686111968e-11
# _sum , gabor_sc3_variance_std , 0.255035543461 , 3.37552645887e-12
# _sum , gabor_sc3_variance_sum , 0.0881637223552 , 0.01773422012
# _sum , gabor_sc3_filter_11_mean , 0.256159907739 , 2.69294388473e-12
# _sum , gabor_sc3_filter_11_std , 0.207766686362 , 1.7149549342e-08
# _sum , gabor_sc3_filter_11_sum , 0.163760231025 , 9.61818466907e-06
# _sum , gabor_sc3_filter_12_mean , 0.251165430538 , 7.285025453e-12
# _sum , gabor_sc3_filter_12_std , 0.252961348696 , 5.10616250428e-12
# _sum , gabor_sc3_filter_12_sum , 0.0902992667296 , 0.01514936671
# _sum , gabor_sc3_filter_14_mean , 0.252494415271 , 5.60192926166e-12
# _sum , gabor_sc3_filter_14_std , 0.257049869716 , 2.25024734729e-12
# _sum , gabor_sc3_filter_14_sum , 0.0890630702282 , 0.0166020292198
# _sum , gabor_sc5_filter_4_mean , 0.262226351091 , 7.80956928646e-13
# _sum , gabor_sc5_filter_4_std , 0.230321104628 , 3.6865443697e-10
# _sum , gabor_sc5_filter_4_sum , 0.129547301319 , 0.000479325871336
# _sum , gabor_sc5_variance_mean , 0.267352411631 , 2.67583901925e-13
# _sum , gabor_sc5_variance_std , 0.247988336946 , 1.35680320471e-11
# _sum , gabor_sc5_variance_sum , 0.129465860055 , 0.000483314359395
# _sum , gabor_sc5_mean_mean , 0.253918897568 , 4.21999852382e-12
# _sum , gabor_sc5_mean_std , 0.194630268543 , 1.32890233167e-07
# _sum , gabor_sc5_mean_sum , 0.163823089498 , 9.54174271833e-06
# _sum , gabor_sc5_filter_6_mean , 0.262602386275 , 7.22510655949e-13
# _sum , gabor_sc5_filter_6_std , 0.229361113921 , 4.3781603408e-10
# _sum , gabor_sc5_filter_6_sum , 0.129601147768 , 0.000476705653424
# _sum , gabor_sc5_filter_3_mean , 0.252864264819 , 5.20557360519e-12
# _sum , gabor_sc5_filter_3_std , 0.18299973806 , 7.27043584886e-07
# _sum , gabor_sc5_filter_3_sum , 0.163818114248 , 9.5477719327e-06
# _sum , gabor_sc5_filter_9_mean , 0.254697707429 , 3.61184365624e-12
# _sum , gabor_sc5_filter_9_std , 0.19954372961 , 6.27840024686e-08
# _sum , gabor_sc5_filter_9_sum , 0.163754579187 , 9.62508637941e-06
# _sum , gabor_sc5_filter_8_mean , 0.264765567844 , 4.60743213073e-13
# _sum , gabor_sc5_filter_8_std , 0.232734557792 , 2.38463367211e-10
# _sum , gabor_sc5_filter_8_sum , 0.129644991956 , 0.000474582009111
# _sum , gabor_sc5_filter_2_mean , 0.263948509093 , 5.46346190146e-13
# _sum , gabor_sc5_filter_2_std , 0.238799142814 , 7.81046094779e-11
# _sum , gabor_sc5_filter_2_sum , 0.129453091956 , 0.000483942455504
# _sum , gabor_sc5_filter_13_mean , 0.259065876455 , 1.49431118402e-12
# _sum , gabor_sc5_filter_13_std , 0.198399133802 , 7.4894167085e-08
# _sum , gabor_sc5_filter_13_sum , 0.163680844636 , 9.71556058671e-06
# _sum , gabor_sc5_filter_12_mean , 0.272417764208 , 9.07608273774e-14
# _sum , gabor_sc5_filter_12_std , 0.245564794444 , 2.16782023507e-11
# _sum , gabor_sc5_filter_12_sum , 0.129645285626 , 0.000474567814602
# _sum , gabor_sc5_filter_11_mean , 0.256909852538 , 2.31484150481e-12
# _sum , gabor_sc5_filter_11_std , 0.199182620106 , 6.63840759319e-08
# _sum , gabor_sc5_filter_11_sum , 0.163722394515 , 9.66447858985e-06
# _sum , gabor_sc5_filter_10_mean , 0.267954819175 , 2.35577557781e-13
# _sum , gabor_sc5_filter_10_std , 0.238547188108 , 8.18619864152e-11
# _sum , gabor_sc5_filter_10_sum , 0.129712148665 , 0.000471346264606
# _sum , gabor_sc5_filter_7_mean , 0.253174322897 , 4.89454367432e-12
# _sum , gabor_sc5_filter_7_std , 0.196492183087 , 1.00245890578e-07
# _sum , gabor_sc5_filter_7_sum , 0.16377304564 , 9.60255364331e-06
# _sum , gabor_sc5_filter_1_mean , 0.253074442475 , 4.9926979469e-12
# _sum , gabor_sc5_filter_1_std , 0.187164272965 , 4.00444936298e-07
# _sum , gabor_sc5_filter_1_sum , 0.163824662992 , 9.53983664951e-06
# _sum , gabor_sc5_filter_5_mean , 0.252671506158 , 5.40859568402e-12
# _sum , gabor_sc5_filter_5_std , 0.188561301191 , 3.26845255016e-07
# _sum , gabor_sc5_filter_5_sum , 0.16379687481 , 9.57355163342e-06
# _sum , gabor_sc5_filter_14_mean , 0.276808340258 , 3.49023902558e-14
# _sum , gabor_sc5_filter_14_std , 0.251136933167 , 7.32605800948e-12
# _sum , gabor_sc5_filter_14_sum , 0.129347047935 , 0.0004891884702
# _sum , gabor_sc7_filter_9_mean , 0.252923663573 , 5.1445284974e-12
# _sum , gabor_sc7_filter_9_std , 0.207814078331 , 1.7019097294e-08
# _sum , gabor_sc7_filter_9_sum , 0.163703829911 , 9.68727045063e-06
# _sum , gabor_sc7_mean_mean , 0.251196500847 , 7.24054427539e-12
# _sum , gabor_sc7_mean_std , 0.192795205866 , 1.74982766496e-07
# _sum , gabor_sc7_mean_sum , 0.163775778699 , 9.59922304432e-06
# _sum , gabor_sc7_variance_mean , 0.264977866443 , 4.40744879713e-13
# _sum , gabor_sc7_variance_std , 0.243271606007 , 3.36189852552e-11
# _sum , gabor_sc7_variance_sum , 0.1293892179 , 0.000487096008993
# _sum , gabor_sc7_filter_1_mean , 0.250690696954 , 7.99884300747e-12
# _sum , gabor_sc7_filter_1_std , 0.174677526614 , 2.30012082744e-06
# _sum , gabor_sc7_filter_1_sum , 0.16379231244 , 9.57909793206e-06
# _sum , gabor_sc7_filter_5_mean , 0.249830234489 , 9.47096353093e-12
# _sum , gabor_sc7_filter_5_std , 0.183423509393 , 6.84652757815e-07
# _sum , gabor_sc7_filter_5_sum , 0.163752547719 , 9.62756824917e-06
# _sum , gabor_sc7_filter_3_mean , 0.250736453709 , 7.92716714839e-12
# _sum , gabor_sc7_filter_3_std , 0.164826904197 , 8.39676417987e-06
# _sum , gabor_sc7_filter_3_sum , 0.163799791155 , 9.57000794702e-06
# _sum , gabor_sc7_filter_2_mean , 0.258338880427 , 1.73272988625e-12
# _sum , gabor_sc7_filter_2_std , 0.226488556497 , 7.29040398448e-10
# _sum , gabor_sc7_filter_2_sum , 0.129522215874 , 0.000480551123978
# _sum , gabor_sc7_filter_11_mean , 0.257759229632 , 1.94916042492e-12
# _sum , gabor_sc7_filter_11_std , 0.201839764434 , 4.39372967195e-08
# _sum , gabor_sc7_filter_11_sum , 0.163654423942 , 9.74817630424e-06
# _sum , gabor_sc7_filter_10_mean , 0.267909356867 , 2.37855997575e-13
# _sum , gabor_sc7_filter_10_std , 0.231464591881 , 3.00082319649e-10
# _sum , gabor_sc7_filter_10_sum , 0.129919957877 , 0.000461463238323
# _sum , gabor_sc7_filter_7_mean , 0.249671856545 , 9.76940581393e-12
# _sum , gabor_sc7_filter_7_std , 0.204503945509 , 2.88855784764e-08
# _sum , gabor_sc7_filter_7_sum , 0.163707614137 , 9.68262038298e-06
# _sum , gabor_sc7_filter_4_mean , 0.256407056275 , 2.56210485688e-12
# _sum , gabor_sc7_filter_4_std , 0.213620858571 , 6.58684738563e-09
# _sum , gabor_sc7_filter_4_sum , 0.129809077343 , 0.000466712246334
# _sum , gabor_sc7_filter_12_mean , 0.275443159075 , 4.70662432102e-14
# _sum , gabor_sc7_filter_12_std , 0.239220499184 , 7.2193730959e-11
# _sum , gabor_sc7_filter_12_sum , 0.129929391807 , 0.000461019189376
# _sum , gabor_sc7_filter_13_mean , 0.261575230011 , 8.93297998968e-13
# _sum , gabor_sc7_filter_13_std , 0.198099661642 , 7.84178744526e-08
# _sum , gabor_sc7_filter_13_sum , 0.163539036629 , 9.89184643197e-06
# _sum , gabor_sc7_filter_14_mean , 0.28207665874 , 1.08368632447e-14
# _sum , gabor_sc7_filter_14_std , 0.243042880953 , 3.5114385183e-11
# _sum , gabor_sc7_filter_14_sum , 0.129242797398 , 0.000494397306338
# _sum , gabor_sc7_filter_6_mean , 0.258945420255 , 1.53146492737e-12
# _sum , gabor_sc7_filter_6_std , 0.216276813381 , 4.22836669679e-09
# _sum , gabor_sc7_filter_6_sum , 0.129734084936 , 0.000470293789084
# _sum , gabor_sc7_filter_8_mean , 0.262820585933 , 6.90584196089e-13
# _sum , gabor_sc7_filter_8_std , 0.223009214283 , 1.33977625364e-09
# _sum , gabor_sc7_filter_8_sum , 0.129649824183 , 0.000474348494123
# _sum , hog_sc7_mean_mean , 0.0395520883812 , 0.288200242181
# _sum , hog_sc7_mean_std , -0.121096535376 , 0.00110432982499
# _sum , hog_sc7_mean_sum , 0.181530837051 , 8.94393711807e-07
# _sum , hog_sc5_kurtosis_mean , 0.205144278651 , 2.60936391799e-08
# _sum , hog_sc5_kurtosis_std , 0.143496812545 , 0.000108027695334
# _sum , hog_sc5_kurtosis_sum , 0.161716772148 , 1.24464890257e-05
# _sum , hog_sc5_skew_mean , 0.18323898453 , 7.02810618199e-07
# _sum , hog_sc5_skew_std , 0.200708941133 , 5.24091798695e-08
# _sum , hog_sc5_skew_sum , 0.176604720328 , 1.7700108508e-06
# _sum , hog_sc7_variance_mean , -0.164098148716 , 9.21400405328e-06
# _sum , hog_sc7_variance_std , -0.164039140779 , 9.28339587652e-06
# _sum , hog_sc7_variance_sum , 0.181718553431 , 8.71107373678e-07
# _sum , hog_sc7_skew_mean , 0.209477446156 , 1.30031501214e-08
# _sum , hog_sc7_skew_std , 0.14656348543 , 7.63889642045e-05
# _sum , hog_sc7_skew_sum , 0.173245105284 , 2.78943878078e-06
# _sum , hog_sc5_mean_mean , 0.0719622769251 , 0.0530972458555
# _sum , hog_sc5_mean_std , -0.162751517915 , 1.09276611743e-05
# _sum , hog_sc5_mean_sum , 0.182061679597 , 8.30039676971e-07
# _sum , hog_sc3_skew_mean , 0.176316082632 , 1.84117347797e-06
# _sum , hog_sc3_skew_std , -0.194854419383 , 1.28474587594e-07
# _sum , hog_sc3_skew_sum , 0.178404674208 , 1.38228167353e-06
# _sum , hog_sc5_max_mean , -0.150170185649 , 5.03711716405e-05
# _sum , hog_sc5_max_std , -0.153689952757 , 3.32407218148e-05
# _sum , hog_sc5_max_sum , 0.182909626545 , 7.36377503017e-07
# _sum , hog_sc5_variance_mean , -0.169970619835 , 4.30976763347e-06
# _sum , hog_sc5_variance_std , -0.16813833132 , 5.4781340169e-06
# _sum , hog_sc5_variance_sum , 0.183618414752 , 6.6596357246e-07
# _sum , hog_sc7_kurtosis_mean , 0.192230805123 , 1.90335211674e-07
# _sum , hog_sc7_kurtosis_std , 0.0691828017425 , 0.0629928255172
# _sum , hog_sc7_kurtosis_sum , 0.132938183941 , 0.000338029250263
# _sum , hog_sc3_max_mean , 0.0360580974719 , 0.33294891006
# _sum , hog_sc3_max_std , -0.183372829581 , 6.89594379909e-07
# _sum , hog_sc3_max_sum , 0.182069066889 , 8.29176311571e-07
# _sum , hog_sc3_variance_mean , -0.106440475219 , 0.00416702616025
# _sum , hog_sc3_variance_std , -0.189292304006 , 2.93715894003e-07
# _sum , hog_sc3_variance_sum , 0.182959179786 , 7.31230522488e-07
# _sum , hog_sc3_kurtosis_mean , 0.183904213474 , 6.39443332988e-07
# _sum , hog_sc3_kurtosis_std , 0.0761812320245 , 0.0405753407958
# _sum , hog_sc3_kurtosis_sum , 0.176450773467 , 1.80763106582e-06
# _sum , hog_sc7_max_mean , -0.160195955566 , 1.50481558005e-05
# _sum , hog_sc7_max_std , -0.151908585053 , 4.10701098882e-05
# _sum , hog_sc7_max_sum , 0.181909257636 , 8.48047515614e-07
# _sum , hog_sc3_mean_mean , 0.142097093913 , 0.000126251307147
# _sum , hog_sc3_mean_std , -0.191807466255 , 2.02695143359e-07
# _sum , hog_sc3_mean_sum , 0.180688948725 , 1.00639197622e-06
# _sum , lac_sc3_lac_mean , 0.183326915117 , 6.94100944688e-07
# _sum , lac_sc3_lac_std , 0.162728022969 , 1.09600978636e-05
# _sum , lac_sc3_lac_sum , -0.00675913250876 , 0.856028805463
# _sum , lac_sc5_lac_mean , 0.147871733958 , 6.57525729999e-05
# _sum , lac_sc5_lac_std , 0.136208073307 , 0.000239487219767
# _sum , lac_sc5_lac_sum , 0.00829358924951 , 0.82383012891
# _sum , lac_sc7_lac_mean , 0.0970217254996 , 0.00904282158812
# _sum , lac_sc7_lac_std , 0.131666169946 , 0.000385720845854
# _sum , lac_sc7_lac_sum , 0.00796158781518 , 0.830773683373
# _sum , lbpm_sc7_mean_mean , -0.0796052747228 , 0.0323408106086
# _sum , lbpm_sc7_mean_std , -0.128155289389 , 0.000551898239196
# _sum , lbpm_sc7_mean_sum , 0.0549314218552 , 0.140053763754
# _sum , lbpm_sc5_variance_mean , -0.115349065023 , 0.00189258498831
# _sum , lbpm_sc5_variance_std , -0.163293029883 , 1.02049199363e-05
# _sum , lbpm_sc5_variance_sum , 0.013810495842 , 0.710845448744
# _sum , lbpm_sc3_max_mean , -0.0669486170554 , 0.0720087872388
# _sum , lbpm_sc3_max_std , -0.0458948298825 , 0.217738210021
# _sum , lbpm_sc3_max_sum , 0.0412280743353 , 0.268241939788
# _sum , lbpm_sc5_skew_mean , 0.140993476843 , 0.000142618855481
# _sum , lbpm_sc5_skew_std , -0.14432866823 , 9.84023803471e-05
# _sum , lbpm_sc5_skew_sum , 0.133421939265 , 0.000321382861749
# _sum , lbpm_sc5_mean_mean , -0.118993202571 , 0.00134862356129
# _sum , lbpm_sc5_mean_std , -0.0868877103827 , 0.0194562448306
# _sum , lbpm_sc5_mean_sum , 0.0551837691673 , 0.138239257421
# _sum , lbpm_sc3_mean_mean , 0.000699962390295 , 0.98500983842
# _sum , lbpm_sc3_mean_std , 0.113513199771 , 0.00223697119478
# _sum , lbpm_sc3_mean_sum , 0.0557268304781 , 0.134395736541
# _sum , lbpm_sc7_skew_mean , 0.132779867615 , 0.000343649579372
# _sum , lbpm_sc7_skew_std , -0.119623032136 , 0.00127070244967
# _sum , lbpm_sc7_skew_sum , 0.133687192654 , 0.000312583509039
# _sum , lbpm_sc7_kurtosis_mean , 0.138264660073 , 0.00019205499648
# _sum , lbpm_sc7_kurtosis_std , -0.0570520462792 , 0.125362808698
# _sum , lbpm_sc7_kurtosis_sum , 0.137085823432 , 0.00021803872274
# _sum , lbpm_sc7_max_mean , -0.0143529640091 , 0.700026989391
# _sum , lbpm_sc7_max_std , -0.115756256657 , 0.00182310909103
# _sum , lbpm_sc7_max_sum , 0.0367212125875 , 0.324129047729
# _sum , lbpm_sc3_skew_mean , 0.14674328362 , 7.48365203815e-05
# _sum , lbpm_sc3_skew_std , -0.17216922727 , 3.22096306133e-06
# _sum , lbpm_sc3_skew_sum , 0.125901032008 , 0.000691411821963
# _sum , lbpm_sc3_kurtosis_mean , 0.156429038871 , 2.39020126838e-05
# _sum , lbpm_sc3_kurtosis_std , -0.0296424261797 , 0.426124533004
# _sum , lbpm_sc3_kurtosis_sum , 0.142791984986 , 0.000116870128319
# _sum , lbpm_sc5_max_mean , -0.0386108542147 , 0.299836367949
# _sum , lbpm_sc5_max_std , -0.108655167007 , 0.00344233583909
# _sum , lbpm_sc5_max_sum , 0.0380622709371 , 0.306760570339
# _sum , lbpm_sc7_variance_mean , -0.106273392789 , 0.00422694005957
# _sum , lbpm_sc7_variance_std , -0.157952037491 , 1.98491676392e-05
# _sum , lbpm_sc7_variance_sum , 0.0110160016816 , 0.767457693424
# _sum , lbpm_sc5_kurtosis_mean , 0.147946320059 , 6.51904178276e-05
# _sum , lbpm_sc5_kurtosis_std , -0.0605720460447 , 0.103656953825
# _sum , lbpm_sc5_kurtosis_sum , 0.142316196429 , 0.000123219516634
# _sum , lbpm_sc3_variance_mean , -0.126100488883 , 0.000677860155827
# _sum , lbpm_sc3_variance_std , -0.171380799643 , 3.57701890943e-06
# _sum , lbpm_sc3_variance_sum , 0.0204193987048 , 0.583583833862
# _sum , lsr_sc71_line_contrast_mean , 0.0833928745617 , 0.0249387825459
# _sum , lsr_sc71_line_contrast_std , -0.0454436257005 , 0.22230022692
# _sum , lsr_sc71_line_contrast_sum , 0.19333172214 , 1.61501026626e-07
# _sum , lsr_sc71_line_length_mean , 0.0693240251798 , 0.0624557150977
# _sum , lsr_sc71_line_length_std , -0.0415767146236 , 0.264212211024
# _sum , lsr_sc71_line_length_sum , 0.193000273374 , 1.69706292769e-07
# _sum , lsr_sc31_line_mean_mean , 0.0471837975759 , 0.20507675169
# _sum , lsr_sc31_line_mean_std , -0.171071459226 , 3.72675653102e-06
# _sum , lsr_sc31_line_mean_sum , 0.18773035861 , 3.68878075273e-07
# _sum , lsr_sc51_line_length_mean , 0.0707902035135 , 0.0570996210287
# _sum , lsr_sc51_line_length_std , -0.060427426105 , 0.104485795593
# _sum , lsr_sc51_line_length_sum , 0.19347706771 , 1.58024871506e-07
# _sum , lsr_sc71_line_mean_mean , 0.0514001320717 , 0.167401387919
# _sum , lsr_sc71_line_mean_std , -0.203246497252 , 3.52338240871e-08
# _sum , lsr_sc71_line_mean_sum , 0.185847678271 , 4.84241101988e-07
# _sum , lsr_sc31_line_contrast_mean , 0.0802113726946 , 0.0310430790588
# _sum , lsr_sc31_line_contrast_std , -0.0896406149194 , 0.0159088157934
# _sum , lsr_sc31_line_contrast_sum , 0.193405656587 , 1.5972365439e-07
# _sum , lsr_sc31_line_length_mean , 0.0690284333493 , 0.0635842827134
# _sum , lsr_sc31_line_length_std , -0.0863644395328 , 0.0202035164509
# _sum , lsr_sc31_line_length_sum , 0.193331959447 , 1.61495291373e-07
# _sum , lsr_sc51_line_contrast_mean , 0.0828396703569 , 0.0259190133799
# _sum , lsr_sc51_line_contrast_std , -0.0635755458476 , 0.0875933619357
# _sum , lsr_sc51_line_contrast_sum , 0.193661219864 , 1.53724183609e-07
# _sum , lsr_sc51_line_mean_mean , 0.048421706938 , 0.193427984258
# _sum , lsr_sc51_line_mean_std , -0.201223089962 , 4.83778211837e-08
# _sum , lsr_sc51_line_mean_sum , 0.187224854519 , 3.96946257207e-07
# _sum , mean_sc3_mean_mean , 0.2560418956 , 2.75770369286e-12
# _sum , mean_sc3_mean_std , 0.215716280363 , 4.64522983293e-09
# _sum , mean_sc3_mean_sum , 0.163863699508 , 9.49266536894e-06
# _sum , mean_sc7_variance_mean , 0.269862952778 , 1.570244124e-13
# _sum , mean_sc7_variance_std , 0.239178273488 , 7.27658214896e-11
# _sum , mean_sc7_variance_sum , 0.129763164895 , 0.000468901940432
# _sum , mean_sc3_variance_mean , 0.241830601838 , 4.4191548266e-11
# _sum , mean_sc3_variance_std , 0.252902012814 , 5.16669781192e-12
# _sum , mean_sc3_variance_sum , 0.0703824272739 , 0.0585495257163
# _sum , mean_sc7_mean_mean , 0.257411912529 , 2.09129415864e-12
# _sum , mean_sc7_mean_std , 0.178604348513 , 1.34467726577e-06
# _sum , mean_sc7_mean_sum , 0.163867190694 , 9.48845751035e-06
# _sum , mean_sc5_variance_mean , 0.26780607436 , 2.43112802272e-13
# _sum , mean_sc5_variance_std , 0.250859309509 , 7.73781173846e-12
# _sum , mean_sc5_variance_sum , 0.128756438937 , 0.000519387113997
# _sum , mean_sc5_mean_mean , 0.256588123568 , 2.47021823363e-12
# _sum , mean_sc5_mean_std , 0.197109955431 , 9.12397331114e-08
# _sum , mean_sc5_mean_sum , 0.163865547515 , 9.49043778052e-06
# _sum , ndvi_sc3_variance_mean , 0.202441997827 , 3.99827646524e-08
# _sum , ndvi_sc3_variance_std , 0.127189912121 , 0.000608089936057
# _sum , ndvi_sc3_variance_sum , 0.145121280579 , 8.99877384352e-05
# _sum , ndvi_sc3_mean_mean , -0.218559108009 , 2.87582922283e-09
# _sum , ndvi_sc3_mean_std , 0.0548865878197 , 0.140378047791
# _sum , ndvi_sc3_mean_sum , 0.1990752091 , 6.74928736415e-08
# _sum , ndvi_sc7_mean_mean , -0.218182073914 , 3.06581582646e-09
# _sum , ndvi_sc7_mean_std , 0.0193446683254 , 0.603551010447
# _sum , ndvi_sc7_mean_sum , 0.199080599066 , 6.74368092153e-08
# _sum , ndvi_sc7_variance_mean , -0.195937592602 , 1.0905776416e-07
# _sum , ndvi_sc7_variance_std , -0.0719864732204 , 0.0530171504134
# _sum , ndvi_sc7_variance_sum , 0.1972095015 , 8.98636530105e-08
# _sum , ndvi_sc5_variance_mean , -0.185366322606 , 5.18901679499e-07
# _sum , ndvi_sc5_variance_std , 0.0120334644092 , 0.74668345572
# _sum , ndvi_sc5_variance_sum , 0.196953895766 , 9.34380951943e-08
# _sum , ndvi_sc5_mean_mean , -0.21832782056 , 2.99097110037e-09
# _sum , ndvi_sc5_mean_std , 0.0339317228424 , 0.36226259091
# _sum , ndvi_sc5_mean_sum , 0.199077424726 , 6.74698220773e-08
# _sum , orb_sc71_skew_mean , -0.146472058918 , 7.71899810348e-05
# _sum , orb_sc71_skew_std , -0.20417848095 , 3.04134058535e-08
# _sum , orb_sc71_skew_sum , 0.00516622143827 , 0.889708290027
# _sum , orb_sc71_mean_mean , 0.266200211913 , 3.41108168813e-13
# _sum , orb_sc71_mean_std , 0.229735069439 , 4.09489978217e-10
# _sum , orb_sc71_mean_sum , 0.0494946861927 , 0.18372994338
# _sum , orb_sc31_max_mean , 0.245043023233 , 2.39636191849e-11
# _sum , orb_sc31_max_std , 0.244746949402 , 2.53634231033e-11
# _sum , orb_sc31_max_sum , 0.0431804570553 , 0.246213120168
# _sum , orb_sc71_variance_mean , 0.259188943215 , 1.45726392858e-12
# _sum , orb_sc71_variance_std , 0.275997546773 , 4.1693125115e-14
# _sum , orb_sc71_variance_sum , 0.0822490864593 , 0.0270019930248
# _sum , orb_sc51_skew_mean , -0.0680558211574 , 0.0674169476485
# _sum , orb_sc51_skew_std , -0.168464362662 , 5.25020504298e-06
# _sum , orb_sc51_skew_sum , 0.00333523240173 , 0.928664682231
# _sum , orb_sc31_variance_mean , 0.240123274495 , 6.09613571783e-11
# _sum , orb_sc31_variance_std , 0.281185875553 , 1.32298516059e-14
# _sum , orb_sc31_variance_sum , 0.0752929273383 , 0.0429808190005
# _sum , orb_sc31_mean_mean , 0.229992597246 , 3.91029529935e-10
# _sum , orb_sc31_mean_std , 0.27118197979 , 1.18404767688e-13
# _sum , orb_sc31_mean_sum , 0.0534283631232 , 0.151242515793
# _sum , orb_sc31_kurtosis_mean , 0.048405915717 , 0.193573460902
# _sum , orb_sc31_kurtosis_std , 0.0268321665894 , 0.471301943205
# _sum , orb_sc31_kurtosis_sum , 0.00588370146188 , 0.874510010373
# _sum , orb_sc31_skew_mean , 0.0375121176033 , 0.313809928874
# _sum , orb_sc31_skew_std , 0.0245476193998 , 0.509889473713
# _sum , orb_sc31_skew_sum , 0.0047139825548 , 0.899309193026
# _sum , orb_sc51_max_mean , 0.254415595847 , 3.82152081093e-12
# _sum , orb_sc51_max_std , 0.247600637893 , 1.4629127664e-11
# _sum , orb_sc51_max_sum , 0.0403158677336 , 0.278984185186
# _sum , orb_sc51_mean_mean , 0.245898988044 , 2.03277850332e-11
# _sum , orb_sc51_mean_std , 0.25182766969 , 6.39234563557e-12
# _sum , orb_sc51_mean_sum , 0.0511106162397 , 0.169809753643
# _sum , orb_sc51_kurtosis_mean , -0.0737725824606 , 0.0473767990725
# _sum , orb_sc51_kurtosis_std , -0.16985601412 , 4.37524566158e-06
# _sum , orb_sc51_kurtosis_sum , 0.00381813070791 , 0.918370011338
# _sum , orb_sc51_variance_mean , 0.247452111071 , 1.50567615327e-11
# _sum , orb_sc51_variance_std , 0.302971081108 , 8.15768420995e-17
# _sum , orb_sc51_variance_sum , 0.0788384154585 , 0.0340489826422
# _sum , orb_sc71_kurtosis_mean , -0.142315632624 , 0.000123227229539
# _sum , orb_sc71_kurtosis_std , -0.203684880629 , 3.28808205961e-08
# _sum , orb_sc71_kurtosis_sum , 0.0058099773216 , 0.876069668148
# _sum , orb_sc71_max_mean , 0.261856969394 , 8.42868477888e-13
# _sum , orb_sc71_max_std , 0.201639066277 , 4.53373224016e-08
# _sum , orb_sc71_max_sum , 0.0388095084427 , 0.297354813542
# _sum , pantex_sc5_min_mean , 0.233802131969 , 1.96362800335e-10
# _sum , pantex_sc5_min_std , 0.23408973905 , 1.86320710563e-10
# _sum , pantex_sc5_min_sum , 0.0608683355793 , 0.101975157037
# _sum , pantex_sc7_min_mean , 0.233103937665 , 2.22986740159e-10
# _sum , pantex_sc7_min_std , 0.221683556597 , 1.68495678785e-09
# _sum , pantex_sc7_min_sum , 0.0603585687524 , 0.104882270304
# _sum , pantex_sc3_min_mean , 0.228974981867 , 4.69065044957e-10
# _sum , pantex_sc3_min_std , 0.246669125432 , 1.75211118421e-11
# _sum , pantex_sc3_min_sum , 0.0761281974173 , 0.0407156884047
# _sum , sfs_sc31_max_ratio_of_orthgonal_angles_mean , -0.211881986439 , 8.7774579221e-09
# _sum , sfs_sc31_max_ratio_of_orthgonal_angles_std , -0.102586768263 , 0.00576361235262
# _sum , sfs_sc31_max_ratio_of_orthgonal_angles_sum , 0.0575901365186 , 0.121832774113
# _sum , sfs_sc71_std_mean , 0.0442872669431 , 0.234302614972
# _sum , sfs_sc71_std_std , nan , 1.0
# _sum , sfs_sc71_std_sum , 0.041517176591 , 0.264897410609
# _sum , sfs_sc51_min_line_length_mean , -0.00218784776465 , 0.95316989303
# _sum , sfs_sc51_min_line_length_std , 0.0315008199569 , 0.39768712565
# _sum , sfs_sc51_min_line_length_sum , 0.0518933064905 , 0.1633579706
# _sum , sfs_sc51_max_line_length_mean , -0.25933920644 , 1.41324742818e-12
# _sum , sfs_sc51_max_line_length_std , -0.216453892345 , 4.10439821828e-09
# _sum , sfs_sc51_max_line_length_sum , 0.131250808232 , 0.000402606166335
# _sum , sfs_sc31_mean_mean , 0.140247320387 , 0.000154793223205
# _sum , sfs_sc31_mean_std , -0.172684972278 , 3.00668380092e-06
# _sum , sfs_sc31_mean_sum , 0.0666686332422 , 0.0732095800305
# _sum , sfs_sc71_max_line_length_mean , -0.262165249989 , 7.9088128329e-13
# _sum , sfs_sc71_max_line_length_std , -0.188671284584 , 3.21640256612e-07
# _sum , sfs_sc71_max_line_length_sum , 0.161649234678 , 1.25523123612e-05
# _sum , sfs_sc71_mean_mean , -0.252493094465 , 5.60339630494e-12
# _sum , sfs_sc71_mean_std , -0.207607806163 , 1.7593993999e-08
# _sum , sfs_sc71_mean_sum , 0.150007248039 , 5.13383553976e-05
# _sum , sfs_sc31_min_line_length_mean , -0.0211036994649 , 0.571032573936
# _sum , sfs_sc31_min_line_length_std , 0.00344903348206 , 0.926237475283
# _sum , sfs_sc31_min_line_length_sum , 0.0591718250601 , 0.111904437753
# _sum , sfs_sc71_w_mean_mean , -0.221467957083 , 1.7487232616e-09
# _sum , sfs_sc71_w_mean_std , -0.172972890091 , 2.89306859398e-06
# _sum , sfs_sc71_w_mean_sum , 0.157558546585 , 2.0828710986e-05
# _sum , sfs_sc51_mean_mean , -0.14939967794 , 5.51019353655e-05
# _sum , sfs_sc51_mean_std , -0.233594563366 , 2.03936125261e-10
# _sum , sfs_sc51_mean_sum , 0.105039308454 , 0.00469417465344
# _sum , sfs_sc31_w_mean_mean , -0.21938187861 , 2.50011402142e-09
# _sum , sfs_sc31_w_mean_std , -0.228735144248 , 4.89557286563e-10
# _sum , sfs_sc31_w_mean_sum , 0.128529551696 , 0.000531442374408
# _sum , sfs_sc51_max_ratio_of_orthgonal_angles_mean , -0.132851407377 , 0.000341099155027
# _sum , sfs_sc51_max_ratio_of_orthgonal_angles_std , -0.0691515855709 , 0.0631120617194
# _sum , sfs_sc51_max_ratio_of_orthgonal_angles_sum , 0.0574553811143 , 0.12270944637
# _sum , sfs_sc31_max_line_length_mean , 0.0491722402923 , 0.186605797565
# _sum , sfs_sc31_max_line_length_std , -0.241182823247 , 4.99430052297e-11
# _sum , sfs_sc31_max_line_length_sum , 0.0807861166841 , 0.0298539398982
# _sum , sfs_sc51_w_mean_mean , -0.223437469728 , 1.24376006117e-09
# _sum , sfs_sc51_w_mean_std , -0.190237504592 , 2.55648811644e-07
# _sum , sfs_sc51_w_mean_sum , 0.163126679748 , 1.04219483372e-05
# _sum , sfs_sc51_std_mean , -0.193506386444 , 1.57332475176e-07
# _sum , sfs_sc51_std_std , -0.229273641399 , 4.44712307442e-10
# _sum , sfs_sc51_std_sum , 0.111805314578 , 0.00260786048261
# _sum , sfs_sc71_max_ratio_of_orthgonal_angles_mean , -0.13185018601 , 0.000378453358501
# _sum , sfs_sc71_max_ratio_of_orthgonal_angles_std , -0.0909933868198 , 0.0143836811058
# _sum , sfs_sc71_max_ratio_of_orthgonal_angles_sum , 0.0573059759298 , 0.123687165552
# _sum , sfs_sc31_std_mean , -0.0824357138355 , 0.0266556287091
# _sum , sfs_sc31_std_std , -0.17571223326 , 1.99902720227e-06
# _sum , sfs_sc31_std_sum , 0.111850093428 , 0.00259745984674
# _sum , sfs_sc71_min_line_length_mean , -0.00895467573663 , 0.810045426855
# _sum , sfs_sc71_min_line_length_std , -0.0672902424631 , 0.0705654817702
# _sum , sfs_sc71_min_line_length_sum , 0.0219840173205 , 0.555077171886

# %%
#check 

for key in y_dict.keys():
    print(key,len(y_dict[key]))
# Out:
# _sum 200

# %% [markdown]
# ### Correlation Significance

# %% [markdown]
# For each dependent variable y in the list of all dependent values, calibrate the model.
# Add new key to the output dictionary where y is the dependent variable curently being processed and the values are empty for now

# %%
#Initialize the output dictionary, Y_D, 
# with each key being a dependent variable and the values being the results of the analyses

Y_D = {}

Y_D[y_var]={}

#Dictionary Models is used to store each result object for later use if needed

Models ={}

#Get independent variables from the variable dictionary and store in list x_vars
x_vars = y_dict[y_var]


vars_df = pd.DataFrame()

vars_df[y_var] = spfeas_world_pop_merged[y_var]


for x in x_vars:
    vars_df[x] = spfeas_world_pop_merged[x]

# %%
vars_df.head()
# Out:
#               _sum  orb_sc51_variance_std  gabor_sc7_filter_14_mean  \
# OBJECTID
# 1            6.137                  0.050                    14.120
# 2          262.608                  0.165                    19.366
# 3           43.016                  0.355                    54.734
# 4          108.513                  0.058                    19.639
# 5         1265.180                  0.166                    36.086
#
#           orb_sc31_variance_std  gabor_sc5_filter_14_mean  \
# OBJECTID
# 1                         0.017                     6.724
# 2                         0.045                     9.212
# 3                         0.101                    25.966
# 4                         0.019                     9.357
# 5                         0.040                    17.150
#
#           orb_sc71_variance_std  gabor_sc7_filter_12_mean  \
# OBJECTID
# 1                         0.089                    13.998
# 2                         0.367                    19.153
# 3                         0.737                    54.097
# 4                         0.108                    19.503
# 5                         0.457                    35.695
#
#           gabor_sc5_filter_12_mean  orb_sc31_mean_std  mean_sc7_variance_mean  \
# OBJECTID
# 1                            6.698              0.006                  31.713
# 2                            9.171              0.013                  43.306
# 3                           25.844              0.024                 121.695
# 4                            9.329              0.007                  44.129
# 5                           17.069              0.011                  80.619
#
#           ...  hog_sc7_max_sum  hog_sc7_variance_sum  hog_sc7_mean_sum  \
# OBJECTID  ...
# 1         ...      1633047.625            109074.211        400523.625
# 2         ...      3444789.750            219205.703        883100.125
# 3         ...       426383.469             22852.414        121547.195
# 4         ...      2570719.000            154279.344        684993.438
# 5         ...      1813205.250            106684.805        483537.156
#
#           hog_sc3_mean_sum  mean_sc7_mean_std  hog_sc3_skew_sum  \
# OBJECTID
# 1               277890.344              4.584      2.208210e+09
# 2               658231.625              5.259      5.473134e+09
# 3               102249.820              7.913      8.632499e+08
# 4               522591.188              5.289      4.353483e+09
# 5               378277.469              6.736      3.064286e+09
#
#           hog_sc5_skew_sum  hog_sc3_kurtosis_sum  hog_sc3_skew_mean  \
# OBJECTID
# 1             4.975729e+09          4.910322e+10             72.472
# 2             1.272578e+10          1.258099e+11             98.618
# 3             2.047544e+09          2.008743e+10            260.487
# 4             1.030828e+10          1.005272e+11            115.926
# 5             7.068155e+09          6.933264e+10            178.558
#
#           sfs_sc31_std_std
# OBJECTID
# 1                    1.409
# 2                    1.689
# 3                    2.699
# 4                    1.841
# 5                    2.401
#
# [5 rows x 201 columns]

# %%
vars_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Normalize

# %%
from sklearn import preprocessing


#norm_df = preprocessing.normalize(vars_df)

#names = vars_df.columns
#scaled_df = scaler(vars_df)
#norm_df = pd.DataFrame(norm_df, columns=names

# %% [markdown]
# ### Min-MaxScaler

# %%
# Y = preprocessing.minmax_scale(vars_df[y_var])
# name='pop_sum'
# Y = pd.DataFrame(Y)
# #X = pd.DataFrame()

# X = scaler.fit_transform(vars_df[x_vars])
# X = pd.DataFrame(X, columns=x_vars)
# Y.head()

# %%
quantile_scaler = preprocessing.scale()

# %%
minmax_scaler = preprocessing.MinMaxScaler()
robust_scaler = preprocessing.RobustScaler()
names = vars_df.columns
scaled_df = robust_scaler.fit_transform(vars_df)
scaled_df = pd.DataFrame(scaled_df, columns=names)
scaled_df.head()
# Out:
#        _sum  orb_sc51_variance_std  gabor_sc7_filter_14_mean  \
# 0 -0.430752              -0.345786                 -0.919301
# 1  0.112525              -0.145960                 -0.868722
# 2 -0.352632               0.184188                 -0.527724
# 3 -0.213891              -0.331885                 -0.866090
# 4  2.236252              -0.144222                 -0.707517
#
#    orb_sc31_variance_std  gabor_sc5_filter_14_mean  orb_sc71_variance_std  \
# 0              -0.356546                 -0.915170              -0.352174
# 1              -0.200557                 -0.866133              -0.110435
# 2               0.111421                 -0.535921               0.211304
# 3              -0.345404                 -0.863275              -0.335652
# 4              -0.228412                 -0.709679              -0.032174
#
#    gabor_sc7_filter_12_mean  gabor_sc5_filter_12_mean  orb_sc31_mean_std  \
# 0                 -0.936556                 -0.911120          -0.583333
# 1                 -0.886081                 -0.862443          -0.437500
# 2                 -0.543927                 -0.534264          -0.208333
# 3                 -0.882654                 -0.859333          -0.562500
# 4                 -0.724110                 -0.706985          -0.479167
#
#    mean_sc7_variance_mean  ...  hog_sc7_max_sum  hog_sc7_variance_sum  \
# 0               -0.919410  ...        21.953652             25.798419
# 1               -0.871490  ...        46.336765             51.867312
# 2               -0.547471  ...         5.713909              5.389118
# 3               -0.868088  ...        34.573189             36.498790
# 4               -0.717258  ...        24.378282             25.232830
#
#    hog_sc7_mean_sum  hog_sc3_mean_sum  mean_sc7_mean_std  hog_sc3_skew_sum  \
# 0         20.287623         17.621932           2.761510         17.410232
# 1         44.769367         41.791172           3.383057         43.218850
# 2          6.134780          6.460646           5.826888          6.778572
# 3         34.719153         33.171739           3.410681         34.368222
# 4         24.499009         24.001152           4.743094         24.177355
#
#    hog_sc5_skew_sum  hog_sc3_kurtosis_sum  hog_sc3_skew_mean  sfs_sc31_std_std
# 0         17.077269             17.439645          -1.942371         -0.531157
# 1         43.752854             44.760972          -1.886833         -0.323442
# 2          6.998494              7.104818          -1.543005          0.425816
# 3         35.431862             35.755803          -1.850069         -0.210682
# 4         24.279375             24.644949          -1.717032          0.204748
#
# [5 rows x 201 columns]

# %% [markdown]
# ### Scale the variables

# %%
# #Create a new dataframe for scaled and centered values
# scaled_df = pd.DataFrame()

# #Scale and center the values
# scaled_df[y_var] = scale(pop_count, with_mean=True, with_std=True)


# for x in x_vars:
#     scaled_df[x] = scale(spfeas_world_pop_merged[x], with_mean=True, with_std=True)

# scaled_df = scaled_df.round(3)

# %% [markdown]
# ### Set Elastic net's parameters

# %%
result = ElasticNetCV(max_iter=1e8,
                    alphas = [0.0005, 0.001, 0.01, 0.03, 0.05, 0.1],
                    l1_ratio =[.1, .5, .7, .9, .95, .99, 1],
                    verbose= False,
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)

# %%
scaled_df.shape
# Out:
# (723, 201)

# %%
# Fit the mode

# %%
#Fit the model with the scaled data
result.fit(scaled_df[x_vars],scaled_df[y_var])
#Append the model to the Models dictionary
Models[y_var] = result

# %%
result
# Out:
# ElasticNetCV(alphas=[0.0005, 0.001, 0.01, 0.03, 0.05, 0.1], copy_X=True, cv=5,
#        eps=0.001, fit_intercept=False,
#        l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=100000000.0,
#        n_alphas=100, n_jobs=-1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='random',
#        tol=0.0001, verbose=False)

# %%
opt_alpha, opt_l1_ratio = result.alpha_, result.l1_ratio_

#Print update to ensure that the script is progressing properly
print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(result.score(scaled_df[x_vars],scaled_df[y_var]),
              result.alpha_, result.l1_ratio_))
# Out:
# R2: 0.15 Alpha: 0.1 l1_ratio: 1.0

# %% [markdown]
# Record the overall R squared score and optimal alpha
# and l1 ratio values and store them in the output dictionary

# %%
Y_D[y_var]['Total R2'] = result.score(scaled_df[x_vars],scaled_df[y_var])
Y_D[y_var]['Alpha'] = opt_alpha
Y_D[y_var]['l1_ratio'] = opt_l1_ratio

# %% [markdown]
# ### Ten Fold Cross validated regression

# %%
#Create a list R2s to store out of sample R squared values

R2s = []

#Specify the number of trials to run

trials = 10

#Run the number of trials specified in trials, 
#for each trial 34% of the observations are randomly selected to train the model
#Testing is done on the remaining 66% of observations and the R squared values are recorded

for i in range(trials):    
    X_train, X_test, y_train, y_test = train_test_split(scaled_df[x_vars],scaled_df[y_var], test_size=0.66)
    test_regr = ElasticNetCV(max_iter=1e8,
                    alphas = [opt_alpha],
                    l1_ratio =[opt_l1_ratio],
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)
    test_regr.fit(X_train,y_train)
    R2s.append(test_regr.score(X_test,y_test))

#print("Mean R2: {:.2f} StDev: {:.4f}".format(mean(R2s),pstdev(R2s)))
#Record the out of sample R squared values
Y_D[y_var]['Sampling']={'trials':trials,'R2':mean(R2s),'StDev':pstdev(R2s),'R2s':R2s}
coefs = [i for i in zip(list(scaled_df[x_vars].axes[1]),result.coef_)]
remaining = [i for i in coefs if abs(i[1])>0.0]
Y_D[y_var]["Coefficients"]=remaining

# %%
Y_D[y_var]
# Out:
# {'Total R2': 0.15022938368209371,
#  'Alpha': 0.10000000000000001,
#  'l1_ratio': 1.0,
#  'Sampling': {'trials': 10,
#   'R2': 0.096955524794979292,
#   'StDev': 0.017565504229756054,
#   'R2s': [0.086740999540138919,
#    0.082111583872249039,
#    0.11241073515881117,
#    0.099827436202382547,
#    0.10642146275462971,
#    0.10990039845788258,
#    0.10751541003271736,
#    0.08799013315539439,
#    0.057371647471978322,
#    0.11926544130360894]},
#  'Coefficients': [('orb_sc51_variance_std', 0.24427371896237485),
#   ('gabor_sc7_filter_14_mean', 0.16888980880893451),
#   ('orb_sc71_variance_std', 0.0043338986510297215),
#   ('orb_sc71_variance_mean', 0.027288639264800969),
#   ('gabor_sc3_filter_14_std', 0.010756878176986657),
#   ('hog_sc5_skew_std', 0.079192058310745425),
#   ('ndvi_sc7_mean_sum', 0.010316078489919304),
#   ('ndvi_sc5_mean_sum', 0.012295296197832076),
#   ('ndvi_sc3_mean_sum', 0.0099508733046463262),
#   ('lsr_sc31_line_mean_sum', -0.012671149613084758),
#   ('hog_sc7_variance_sum', 0.016257601560910714),
#   ('hog_sc5_skew_sum', 0.014301744483608762),
#   ('hog_sc3_kurtosis_sum', 0.0097241480304320442)]}

# %%
# Lasso Regression

# %%
# Lasso
from sklearn.linear_model import Lasso
