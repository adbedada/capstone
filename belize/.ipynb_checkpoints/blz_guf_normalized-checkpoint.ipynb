# %% [markdown]
# ## Spatial Features Vs Urban Footprint Vs Population Size

# %% [markdown]
# Steps:
#
#     1) read zonal stats for spatial features (Independent vars) and GUF (Dependent var)
#     2) merge the two files with id
#     3) Locate the dependant and Independent variables (exclude columns like name)
#     4) Standardize the dataset with μ=0 and σ=1  (using StandardScaler from sklearn)
#     5) Run Pearson Correlation (Dependent vs Independent vars)
#     6) Create a new dataset by selecting those independent variables with high statistical signficance
#     7) Split the new dataset into train(2/3) and test(1/3) sets
#     7) Run Elastic Net with 10 fold cross validation

# %%
import sklearn
import pandas as pd
import numpy as np
import csv
import scipy.stats as stats
from statistics import pstdev
from statistics import mean
from sklearn import preprocessing
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import ElasticNet, Lasso
from sklearn.datasets import make_regression
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from itertools import product
import copy

# %% [markdown]
# ### Read the Features data

# %%
spfeas = pd.read_excel('blz_spfeas_v3.xlsx', sheet_name=0)
spfeas['OBJECTID'] = spfeas['OBJECTID'].astype(int)
spfeas = spfeas.set_index('OBJECTID')
spfeas.head()
# Out:
#           FID            Administra Administ_1               Area Urban_Rura  \
# OBJECTID
# 1           0       Toledo District     BLZ006       Toledo Rural      Rural
# 2           1  Stann Creek District     BLZ005  Stann Creek Rural      Rural
# 3           2                   NaN        NaN                NaN        NaN
# 4           3                   NaN        NaN                NaN        NaN
# 5           4                   NaN        NaN                NaN        NaN
#
#          CTV_2018  ED_2018  Cluster_Nu  fourier_sc31_variance_mean  \
# OBJECTID
# 1           Cayes      217         665                    1.871010
# 2           Cayes      201         602                    2.608672
# 3           Cayes      126           0                    6.380702
# 4           Cayes      122           0                    2.894536
# 5           Cayes      123           0                    4.566548
#
#           fourier_sc31_variance_std  ...  sfs_sc51_std_sum  \
# OBJECTID                             ...
# 1                          4.929879  ...        42799652.0
# 2                          6.141846  ...        92699568.0
# 3                          8.840365  ...        10851945.0
# 4                          6.357571  ...        65703932.0
# 5                          7.459406  ...        44759044.0
#
#           sfs_sc71_max_ratio_of_orthgonal_angles_mean  \
# OBJECTID
# 1                                          140.709890
# 2                                          140.376936
# 3                                          139.219940
# 4                                          139.365071
# 5                                          140.065461
#
#           sfs_sc71_max_ratio_of_orthgonal_angles_std  \
# OBJECTID
# 1                                           1.065200
# 2                                           4.624142
# 3                                           8.347895
# 4                                          12.484677
# 5                                           2.836504
#
#           sfs_sc71_max_ratio_of_orthgonal_angles_sum  sfs_sc31_std_mean  \
# OBJECTID
# 1                                         4286729472           1.193974
# 2                                         7790784512           1.375928
# 3                                          461388384           2.413110
# 4                                         5233991680           1.457598
# 5                                         2403786496           1.953999
#
#           sfs_sc31_std_std  sfs_sc31_std_sum  sfs_sc71_min_line_length_mean  \
# OBJECTID
# 1                 1.408849        36374452.0                  874775.350589
# 2                 1.689124        76362680.0                  824859.818661
# 3                 2.699090         7997279.0                  614737.965726
# 4                 1.841355        54741532.0                  814288.179976
# 5                 2.401075        33534290.0                  692178.805971
#
#           sfs_sc71_min_line_length_std  sfs_sc71_min_line_length_sum
# OBJECTID
# 1                        330970.948840                26650047676400
# 2                        380083.243379                45778923946000
# 3                        486655.097810                 2037301248000
# 4                        388871.179731                30581389787100
# 5                        461589.477238                11879088914400
#
# [5 rows x 440 columns]

# %%
print(spfeas.columns)
# Out:
# Index(['FID', 'Administra', 'Administ_1', 'Area', 'Urban_Rura', 'CTV_2018',
#        'ED_2018', 'Cluster_Nu', 'fourier_sc31_variance_mean',
#        'fourier_sc31_variance_std',
#        ...
#        'sfs_sc51_std_sum', 'sfs_sc71_max_ratio_of_orthgonal_angles_mean',
#        'sfs_sc71_max_ratio_of_orthgonal_angles_std',
#        'sfs_sc71_max_ratio_of_orthgonal_angles_sum', 'sfs_sc31_std_mean',
#        'sfs_sc31_std_std', 'sfs_sc31_std_sum', 'sfs_sc71_min_line_length_mean',
#        'sfs_sc71_min_line_length_std', 'sfs_sc71_min_line_length_sum'],
#       dtype='object', length=440)

# %% [markdown]
# ### Load GUF

# %%
guf = pd.read_csv('blz_guf.csv')
guf['OBJECTID'] = guf['OBJECTID'].astype(int)
guf = guf.set_index('OBJECTID')
guf.head()
# Out:
#                     Administra Administ_1               Area Urban_Rura  \
# OBJECTID
# 1              Toledo District     BLZ006       Toledo Rural      Rural
# 2         Stann Creek District     BLZ005  Stann Creek Rural      Rural
# 3                          NaN        NaN                NaN        NaN
# 4                          NaN        NaN                NaN        NaN
# 5                          NaN        NaN                NaN        NaN
#
#          CTV_2018  ED_2018  Cluster_Nu     Shape_Leng    Shape_Area  \
# OBJECTID
# 1           Cayes      217         665  294022.358507  2.934572e+09
# 2           Cayes      201         602  431082.304407  5.345558e+09
# 3           Cayes      126           0   69417.179782  3.192064e+08
# 4           Cayes      122           0  247650.430790  3.617347e+09
# 5           Cayes      123           0  240469.134053  1.652992e+09
#
#           guf_count  guf_sum  guf_mean
# OBJECTID
# 1          19997649    15555  0.000778
# 2          29936453   105315  0.003518
# 3           2201594    57375  0.026061
# 4          24922037     6120  0.000246
# 5          11387124   205530  0.018049

# %% [markdown]
# ### Merge population data with urbanfootprint and featuures

# %%
spfeas_guf = spfeas.merge(guf, left_on='OBJECTID', right_on="OBJECTID", how='outer')

# %%
spfeas_guf = spfeas_guf.round(3)
spfeas_guf.head()
# Out:
#           FID          Administra_x Administ_1_x             Area_x  \
# OBJECTID
# 1           0       Toledo District       BLZ006       Toledo Rural
# 2           1  Stann Creek District       BLZ005  Stann Creek Rural
# 3           2                   NaN          NaN                NaN
# 4           3                   NaN          NaN                NaN
# 5           4                   NaN          NaN                NaN
#
#          Urban_Rura_x CTV_2018_x  ED_2018_x  Cluster_Nu_x  \
# OBJECTID
# 1               Rural      Cayes        217           665
# 2               Rural      Cayes        201           602
# 3                 NaN      Cayes        126             0
# 4                 NaN      Cayes        122             0
# 5                 NaN      Cayes        123             0
#
#           fourier_sc31_variance_mean  fourier_sc31_variance_std  ...  \
# OBJECTID                                                         ...
# 1                              1.871                      4.930  ...
# 2                              2.609                      6.142  ...
# 3                              6.381                      8.840  ...
# 4                              2.895                      6.358  ...
# 5                              4.567                      7.459  ...
#
#                      Area_y  Urban_Rura_y  CTV_2018_y  ED_2018_y  \
# OBJECTID
# 1              Toledo Rural         Rural       Cayes        217
# 2         Stann Creek Rural         Rural       Cayes        201
# 3                       NaN           NaN       Cayes        126
# 4                       NaN           NaN       Cayes        122
# 5                       NaN           NaN       Cayes        123
#
#           Cluster_Nu_y  Shape_Leng    Shape_Area  guf_count  guf_sum  guf_mean
# OBJECTID
# 1                  665  294022.359  2.934572e+09   19997649    15555     0.001
# 2                  602  431082.304  5.345558e+09   29936453   105315     0.004
# 3                    0   69417.180  3.192064e+08    2201594    57375     0.026
# 4                    0  247650.431  3.617347e+09   24922037     6120     0.000
# 5                    0  240469.134  1.652992e+09   11387124   205530     0.018
#
# [5 rows x 452 columns]

# %% [markdown]
# ### Filter Dataset by Builtup Surface.
#
# Select Rows where  builtup is greater than or equal to 10 percent

# %%
#filter_by_builtup.shape

# %%
spfeas_guf.shape
# Out:
# (723, 452)

# %% [markdown]
# ### Analysis

# %% [markdown]
# Get the list of dependent variables from the DataFrame to store in list y_vars

# %%
#y_var = list(filter_by_builtup.axes[1])[440]

y_var = list(spfeas_guf.axes[1])[451]
y_var
# Out:
# 'guf_mean'

# %% [markdown]
# Get a list of all independent variables from the DataFrame in list all_x

# %%
all_x = list(spfeas_guf.axes[1])[8:440]

#Check
all_x
# Out:
# ['fourier_sc31_variance_mean',
#  'fourier_sc31_variance_std',
#  'fourier_sc31_variance_sum',
#  'fourier_sc71_mean_mean',
#  'fourier_sc71_mean_std',
#  'fourier_sc71_mean_sum',
#  'fourier_sc51_mean_mean',
#  'fourier_sc51_mean_std',
#  'fourier_sc51_mean_sum',
#  'fourier_sc31_mean_mean',
#  'fourier_sc31_mean_std',
#  'fourier_sc31_mean_sum',
#  'fourier_sc51_variance_mean',
#  'fourier_sc51_variance_std',
#  'fourier_sc51_variance_sum',
#  'fourier_sc71_variance_mean',
#  'fourier_sc71_variance_std',
#  'fourier_sc71_variance_sum',
#  'gabor_sc3_filter_5_mean',
#  'gabor_sc3_filter_5_std',
#  'gabor_sc3_filter_5_sum',
#  'gabor_sc3_filter_4_mean',
#  'gabor_sc3_filter_4_std',
#  'gabor_sc3_filter_4_sum',
#  'gabor_sc3_filter_7_mean',
#  'gabor_sc3_filter_7_std',
#  'gabor_sc3_filter_7_sum',
#  'gabor_sc3_filter_6_mean',
#  'gabor_sc3_filter_6_std',
#  'gabor_sc3_filter_6_sum',
#  'gabor_sc3_filter_1_mean',
#  'gabor_sc3_filter_1_std',
#  'gabor_sc3_filter_1_sum',
#  'gabor_sc3_mean_mean',
#  'gabor_sc3_mean_std',
#  'gabor_sc3_mean_sum',
#  'gabor_sc3_filter_3_mean',
#  'gabor_sc3_filter_3_std',
#  'gabor_sc3_filter_3_sum',
#  'gabor_sc3_filter_2_mean',
#  'gabor_sc3_filter_2_std',
#  'gabor_sc3_filter_2_sum',
#  'gabor_sc3_filter_9_mean',
#  'gabor_sc3_filter_9_std',
#  'gabor_sc3_filter_9_sum',
#  'gabor_sc3_filter_13_mean',
#  'gabor_sc3_filter_13_std',
#  'gabor_sc3_filter_13_sum',
#  'gabor_sc3_filter_8_mean',
#  'gabor_sc3_filter_8_std',
#  'gabor_sc3_filter_8_sum',
#  'gabor_sc3_filter_10_mean',
#  'gabor_sc3_filter_10_std',
#  'gabor_sc3_filter_10_sum',
#  'gabor_sc3_variance_mean',
#  'gabor_sc3_variance_std',
#  'gabor_sc3_variance_sum',
#  'gabor_sc3_filter_11_mean',
#  'gabor_sc3_filter_11_std',
#  'gabor_sc3_filter_11_sum',
#  'gabor_sc3_filter_12_mean',
#  'gabor_sc3_filter_12_std',
#  'gabor_sc3_filter_12_sum',
#  'gabor_sc3_filter_14_mean',
#  'gabor_sc3_filter_14_std',
#  'gabor_sc3_filter_14_sum',
#  'gabor_sc5_filter_4_mean',
#  'gabor_sc5_filter_4_std',
#  'gabor_sc5_filter_4_sum',
#  'gabor_sc5_variance_mean',
#  'gabor_sc5_variance_std',
#  'gabor_sc5_variance_sum',
#  'gabor_sc5_mean_mean',
#  'gabor_sc5_mean_std',
#  'gabor_sc5_mean_sum',
#  'gabor_sc5_filter_6_mean',
#  'gabor_sc5_filter_6_std',
#  'gabor_sc5_filter_6_sum',
#  'gabor_sc5_filter_3_mean',
#  'gabor_sc5_filter_3_std',
#  'gabor_sc5_filter_3_sum',
#  'gabor_sc5_filter_9_mean',
#  'gabor_sc5_filter_9_std',
#  'gabor_sc5_filter_9_sum',
#  'gabor_sc5_filter_8_mean',
#  'gabor_sc5_filter_8_std',
#  'gabor_sc5_filter_8_sum',
#  'gabor_sc5_filter_2_mean',
#  'gabor_sc5_filter_2_std',
#  'gabor_sc5_filter_2_sum',
#  'gabor_sc5_filter_13_mean',
#  'gabor_sc5_filter_13_std',
#  'gabor_sc5_filter_13_sum',
#  'gabor_sc5_filter_12_mean',
#  'gabor_sc5_filter_12_std',
#  'gabor_sc5_filter_12_sum',
#  'gabor_sc5_filter_11_mean',
#  'gabor_sc5_filter_11_std',
#  'gabor_sc5_filter_11_sum',
#  'gabor_sc5_filter_10_mean',
#  'gabor_sc5_filter_10_std',
#  'gabor_sc5_filter_10_sum',
#  'gabor_sc5_filter_7_mean',
#  'gabor_sc5_filter_7_std',
#  'gabor_sc5_filter_7_sum',
#  'gabor_sc5_filter_1_mean',
#  'gabor_sc5_filter_1_std',
#  'gabor_sc5_filter_1_sum',
#  'gabor_sc5_filter_5_mean',
#  'gabor_sc5_filter_5_std',
#  'gabor_sc5_filter_5_sum',
#  'gabor_sc5_filter_14_mean',
#  'gabor_sc5_filter_14_std',
#  'gabor_sc5_filter_14_sum',
#  'gabor_sc7_filter_9_mean',
#  'gabor_sc7_filter_9_std',
#  'gabor_sc7_filter_9_sum',
#  'gabor_sc7_mean_mean',
#  'gabor_sc7_mean_std',
#  'gabor_sc7_mean_sum',
#  'gabor_sc7_variance_mean',
#  'gabor_sc7_variance_std',
#  'gabor_sc7_variance_sum',
#  'gabor_sc7_filter_1_mean',
#  'gabor_sc7_filter_1_std',
#  'gabor_sc7_filter_1_sum',
#  'gabor_sc7_filter_5_mean',
#  'gabor_sc7_filter_5_std',
#  'gabor_sc7_filter_5_sum',
#  'gabor_sc7_filter_3_mean',
#  'gabor_sc7_filter_3_std',
#  'gabor_sc7_filter_3_sum',
#  'gabor_sc7_filter_2_mean',
#  'gabor_sc7_filter_2_std',
#  'gabor_sc7_filter_2_sum',
#  'gabor_sc7_filter_11_mean',
#  'gabor_sc7_filter_11_std',
#  'gabor_sc7_filter_11_sum',
#  'gabor_sc7_filter_10_mean',
#  'gabor_sc7_filter_10_std',
#  'gabor_sc7_filter_10_sum',
#  'gabor_sc7_filter_7_mean',
#  'gabor_sc7_filter_7_std',
#  'gabor_sc7_filter_7_sum',
#  'gabor_sc7_filter_4_mean',
#  'gabor_sc7_filter_4_std',
#  'gabor_sc7_filter_4_sum',
#  'gabor_sc7_filter_12_mean',
#  'gabor_sc7_filter_12_std',
#  'gabor_sc7_filter_12_sum',
#  'gabor_sc7_filter_13_mean',
#  'gabor_sc7_filter_13_std',
#  'gabor_sc7_filter_13_sum',
#  'gabor_sc7_filter_14_mean',
#  'gabor_sc7_filter_14_std',
#  'gabor_sc7_filter_14_sum',
#  'gabor_sc7_filter_6_mean',
#  'gabor_sc7_filter_6_std',
#  'gabor_sc7_filter_6_sum',
#  'gabor_sc7_filter_8_mean',
#  'gabor_sc7_filter_8_std',
#  'gabor_sc7_filter_8_sum',
#  'hog_sc7_mean_mean',
#  'hog_sc7_mean_std',
#  'hog_sc7_mean_sum',
#  'hog_sc5_kurtosis_mean',
#  'hog_sc5_kurtosis_std',
#  'hog_sc5_kurtosis_sum',
#  'hog_sc5_skew_mean',
#  'hog_sc5_skew_std',
#  'hog_sc5_skew_sum',
#  'hog_sc7_variance_mean',
#  'hog_sc7_variance_std',
#  'hog_sc7_variance_sum',
#  'hog_sc7_skew_mean',
#  'hog_sc7_skew_std',
#  'hog_sc7_skew_sum',
#  'hog_sc5_mean_mean',
#  'hog_sc5_mean_std',
#  'hog_sc5_mean_sum',
#  'hog_sc3_skew_mean',
#  'hog_sc3_skew_std',
#  'hog_sc3_skew_sum',
#  'hog_sc5_max_mean',
#  'hog_sc5_max_std',
#  'hog_sc5_max_sum',
#  'hog_sc5_variance_mean',
#  'hog_sc5_variance_std',
#  'hog_sc5_variance_sum',
#  'hog_sc7_kurtosis_mean',
#  'hog_sc7_kurtosis_std',
#  'hog_sc7_kurtosis_sum',
#  'hog_sc3_max_mean',
#  'hog_sc3_max_std',
#  'hog_sc3_max_sum',
#  'hog_sc3_variance_mean',
#  'hog_sc3_variance_std',
#  'hog_sc3_variance_sum',
#  'hog_sc3_kurtosis_mean',
#  'hog_sc3_kurtosis_std',
#  'hog_sc3_kurtosis_sum',
#  'hog_sc7_max_mean',
#  'hog_sc7_max_std',
#  'hog_sc7_max_sum',
#  'hog_sc3_mean_mean',
#  'hog_sc3_mean_std',
#  'hog_sc3_mean_sum',
#  'lac_sc3_lac_mean',
#  'lac_sc3_lac_std',
#  'lac_sc3_lac_sum',
#  'lac_sc5_lac_mean',
#  'lac_sc5_lac_std',
#  'lac_sc5_lac_sum',
#  'lac_sc7_lac_mean',
#  'lac_sc7_lac_std',
#  'lac_sc7_lac_sum',
#  'lbpm_sc7_mean_mean',
#  'lbpm_sc7_mean_std',
#  'lbpm_sc7_mean_sum',
#  'lbpm_sc5_variance_mean',
#  'lbpm_sc5_variance_std',
#  'lbpm_sc5_variance_sum',
#  'lbpm_sc3_max_mean',
#  'lbpm_sc3_max_std',
#  'lbpm_sc3_max_sum',
#  'lbpm_sc5_skew_mean',
#  'lbpm_sc5_skew_std',
#  'lbpm_sc5_skew_sum',
#  'lbpm_sc5_mean_mean',
#  'lbpm_sc5_mean_std',
#  'lbpm_sc5_mean_sum',
#  'lbpm_sc3_mean_mean',
#  'lbpm_sc3_mean_std',
#  'lbpm_sc3_mean_sum',
#  'lbpm_sc7_skew_mean',
#  'lbpm_sc7_skew_std',
#  'lbpm_sc7_skew_sum',
#  'lbpm_sc7_kurtosis_mean',
#  'lbpm_sc7_kurtosis_std',
#  'lbpm_sc7_kurtosis_sum',
#  'lbpm_sc7_max_mean',
#  'lbpm_sc7_max_std',
#  'lbpm_sc7_max_sum',
#  'lbpm_sc3_skew_mean',
#  'lbpm_sc3_skew_std',
#  'lbpm_sc3_skew_sum',
#  'lbpm_sc3_kurtosis_mean',
#  'lbpm_sc3_kurtosis_std',
#  'lbpm_sc3_kurtosis_sum',
#  'lbpm_sc5_max_mean',
#  'lbpm_sc5_max_std',
#  'lbpm_sc5_max_sum',
#  'lbpm_sc7_variance_mean',
#  'lbpm_sc7_variance_std',
#  'lbpm_sc7_variance_sum',
#  'lbpm_sc5_kurtosis_mean',
#  'lbpm_sc5_kurtosis_std',
#  'lbpm_sc5_kurtosis_sum',
#  'lbpm_sc3_variance_mean',
#  'lbpm_sc3_variance_std',
#  'lbpm_sc3_variance_sum',
#  'lsr_sc71_line_contrast_mean',
#  'lsr_sc71_line_contrast_std',
#  'lsr_sc71_line_contrast_sum',
#  'lsr_sc71_line_length_mean',
#  'lsr_sc71_line_length_std',
#  'lsr_sc71_line_length_sum',
#  'lsr_sc31_line_mean_mean',
#  'lsr_sc31_line_mean_std',
#  'lsr_sc31_line_mean_sum',
#  'lsr_sc51_line_length_mean',
#  'lsr_sc51_line_length_std',
#  'lsr_sc51_line_length_sum',
#  'lsr_sc71_line_mean_mean',
#  'lsr_sc71_line_mean_std',
#  'lsr_sc71_line_mean_sum',
#  'lsr_sc31_line_contrast_mean',
#  'lsr_sc31_line_contrast_std',
#  'lsr_sc31_line_contrast_sum',
#  'lsr_sc31_line_length_mean',
#  'lsr_sc31_line_length_std',
#  'lsr_sc31_line_length_sum',
#  'lsr_sc51_line_contrast_mean',
#  'lsr_sc51_line_contrast_std',
#  'lsr_sc51_line_contrast_sum',
#  'lsr_sc51_line_mean_mean',
#  'lsr_sc51_line_mean_std',
#  'lsr_sc51_line_mean_sum',
#  'mean_sc3_mean_mean',
#  'mean_sc3_mean_std',
#  'mean_sc3_mean_sum',
#  'mean_sc7_variance_mean',
#  'mean_sc7_variance_std',
#  'mean_sc7_variance_sum',
#  'mean_sc3_variance_mean',
#  'mean_sc3_variance_std',
#  'mean_sc3_variance_sum',
#  'mean_sc7_mean_mean',
#  'mean_sc7_mean_std',
#  'mean_sc7_mean_sum',
#  'mean_sc5_variance_mean',
#  'mean_sc5_variance_std',
#  'mean_sc5_variance_sum',
#  'mean_sc5_mean_mean',
#  'mean_sc5_mean_std',
#  'mean_sc5_mean_sum',
#  'ndvi_sc3_variance_mean',
#  'ndvi_sc3_variance_std',
#  'ndvi_sc3_variance_sum',
#  'ndvi_sc3_mean_mean',
#  'ndvi_sc3_mean_std',
#  'ndvi_sc3_mean_sum',
#  'ndvi_sc7_mean_mean',
#  'ndvi_sc7_mean_std',
#  'ndvi_sc7_mean_sum',
#  'ndvi_sc7_variance_mean',
#  'ndvi_sc7_variance_std',
#  'ndvi_sc7_variance_sum',
#  'ndvi_sc5_variance_mean',
#  'ndvi_sc5_variance_std',
#  'ndvi_sc5_variance_sum',
#  'ndvi_sc5_mean_mean',
#  'ndvi_sc5_mean_std',
#  'ndvi_sc5_mean_sum',
#  'orb_sc71_skew_mean',
#  'orb_sc71_skew_std',
#  'orb_sc71_skew_sum',
#  'orb_sc71_mean_mean',
#  'orb_sc71_mean_std',
#  'orb_sc71_mean_sum',
#  'orb_sc31_max_mean',
#  'orb_sc31_max_std',
#  'orb_sc31_max_sum',
#  'orb_sc71_variance_mean',
#  'orb_sc71_variance_std',
#  'orb_sc71_variance_sum',
#  'orb_sc51_skew_mean',
#  'orb_sc51_skew_std',
#  'orb_sc51_skew_sum',
#  'orb_sc31_variance_mean',
#  'orb_sc31_variance_std',
#  'orb_sc31_variance_sum',
#  'orb_sc31_mean_mean',
#  'orb_sc31_mean_std',
#  'orb_sc31_mean_sum',
#  'orb_sc31_kurtosis_mean',
#  'orb_sc31_kurtosis_std',
#  'orb_sc31_kurtosis_sum',
#  'orb_sc31_skew_mean',
#  'orb_sc31_skew_std',
#  'orb_sc31_skew_sum',
#  'orb_sc51_max_mean',
#  'orb_sc51_max_std',
#  'orb_sc51_max_sum',
#  'orb_sc51_mean_mean',
#  'orb_sc51_mean_std',
#  'orb_sc51_mean_sum',
#  'orb_sc51_kurtosis_mean',
#  'orb_sc51_kurtosis_std',
#  'orb_sc51_kurtosis_sum',
#  'orb_sc51_variance_mean',
#  'orb_sc51_variance_std',
#  'orb_sc51_variance_sum',
#  'orb_sc71_kurtosis_mean',
#  'orb_sc71_kurtosis_std',
#  'orb_sc71_kurtosis_sum',
#  'orb_sc71_max_mean',
#  'orb_sc71_max_std',
#  'orb_sc71_max_sum',
#  'pantex_sc5_min_mean',
#  'pantex_sc5_min_std',
#  'pantex_sc5_min_sum',
#  'pantex_sc7_min_mean',
#  'pantex_sc7_min_std',
#  'pantex_sc7_min_sum',
#  'pantex_sc3_min_mean',
#  'pantex_sc3_min_std',
#  'pantex_sc3_min_sum',
#  'sfs_sc31_max_ratio_of_orthgonal_angles_mean',
#  'sfs_sc31_max_ratio_of_orthgonal_angles_std',
#  'sfs_sc31_max_ratio_of_orthgonal_angles_sum',
#  'sfs_sc71_std_mean',
#  'sfs_sc71_std_std',
#  'sfs_sc71_std_sum',
#  'sfs_sc51_min_line_length_mean',
#  'sfs_sc51_min_line_length_std',
#  'sfs_sc51_min_line_length_sum',
#  'sfs_sc51_max_line_length_mean',
#  'sfs_sc51_max_line_length_std',
#  'sfs_sc51_max_line_length_sum',
#  'sfs_sc31_mean_mean',
#  'sfs_sc31_mean_std',
#  'sfs_sc31_mean_sum',
#  'sfs_sc71_max_line_length_mean',
#  'sfs_sc71_max_line_length_std',
#  'sfs_sc71_max_line_length_sum',
#  'sfs_sc71_mean_mean',
#  'sfs_sc71_mean_std',
#  'sfs_sc71_mean_sum',
#  'sfs_sc31_min_line_length_mean',
#  'sfs_sc31_min_line_length_std',
#  'sfs_sc31_min_line_length_sum',
#  'sfs_sc71_w_mean_mean',
#  'sfs_sc71_w_mean_std',
#  'sfs_sc71_w_mean_sum',
#  'sfs_sc51_mean_mean',
#  'sfs_sc51_mean_std',
#  'sfs_sc51_mean_sum',
#  'sfs_sc31_w_mean_mean',
#  'sfs_sc31_w_mean_std',
#  'sfs_sc31_w_mean_sum',
#  'sfs_sc51_max_ratio_of_orthgonal_angles_mean',
#  'sfs_sc51_max_ratio_of_orthgonal_angles_std',
#  'sfs_sc51_max_ratio_of_orthgonal_angles_sum',
#  'sfs_sc31_max_line_length_mean',
#  'sfs_sc31_max_line_length_std',
#  'sfs_sc31_max_line_length_sum',
#  'sfs_sc51_w_mean_mean',
#  'sfs_sc51_w_mean_std',
#  'sfs_sc51_w_mean_sum',
#  'sfs_sc51_std_mean',
#  'sfs_sc51_std_std',
#  'sfs_sc51_std_sum',
#  'sfs_sc71_max_ratio_of_orthgonal_angles_mean',
#  'sfs_sc71_max_ratio_of_orthgonal_angles_std',
#  'sfs_sc71_max_ratio_of_orthgonal_angles_sum',
#  'sfs_sc31_std_mean',
#  'sfs_sc31_std_std',
#  'sfs_sc31_std_sum',
#  'sfs_sc71_min_line_length_mean',
#  'sfs_sc71_min_line_length_std',
#  'sfs_sc71_min_line_length_sum']

# %% [markdown]
# ### Compute Coorelation of features with population density

# %% [markdown]
# Store all features with the least correlation (stat. significance (p < 0.05))

# %% [markdown]
# The Pearson correlation coefficient **measures the linear relationship
# between two datasets.** Strictly speaking, Pearson's correlation requires
# that each dataset be **normally distributed, and not necessarily zero-mean.**
#
# Like other correlation coefficients, this one varies between -1 and +1
# with 0 implying no correlation. Correlations of -1 or +1 imply an exact
# linear relationship. Positive correlations imply that as x increases, so
# does y. Negative correlations imply that as x increases, y decreases.
#
# The p-value roughly indicates **the probability of an uncorrelated system**
# producing datasets that have a Pearson correlation at least as extreme
# as the one computed from these datasets.
#
# ***The p-values are not entirely
# reliable but are probably reasonable for datasets larger than 500 or so.***

# %%
spfeas_guf[y_var] = spfeas_guf[y_var].fillna(0)
spfeas_guf[y_var].isnull().values.any()
# Out:
# False

# %%
y_dict = {}
x = []

for x_var in all_x:
    
    #Calculate the Pearson statistics, 
    # returns the Pearson value and p value
    
    p = stats.skew(spfeas_guf[x_var])
    
    #print(y_var, x_var, p)
    # print back for mike
    #print (y_var + " , " + x_var + " , " +  p)

# %%
y_dict = {}
x = []

for x_var in all_x:
    
    #Calculate the Pearson statistics, 
    # returns the Pearson value and p value
    
    p = stats.pearsonr(spfeas_guf[x_var],spfeas_guf[y_var])
    
    #print back for mike
    print (y_var + " , " + x_var + " , " +  str(p[0]) + " , " + str(p[1]))
    
    #If p < 0.05 append to list x
    if p[1] < 0.05:
        x.append([x_var,abs(p[0])])

#List x is made into a DataFrame 
# which is sorted by the absolute values of the Pearson values
x_df = pd.DataFrame(x,columns=["x_var","abs_r2"]).sort_values("abs_r2",ascending=False)


#The dependent variable dictionary is given an entry 
# where the key is the name of the dependent variable
# and the value is a list of top 200 most significant values

y_dict[y_var] = list(x_df["x_var"][0:200])
#y_dict[y_var]
#Print out each dependent variable and 
#the number of x values that remain to check completion
# Out:
# guf_mean , fourier_sc31_variance_mean , 0.5531049153284179 , 3.5946710523852053e-59
# guf_mean , fourier_sc31_variance_std , -0.6942343564705571 , 4.552340233930312e-105
# guf_mean , fourier_sc31_variance_sum , -0.2504564341649655 , 8.375848718813707e-12
# guf_mean , fourier_sc71_mean_mean , 0.7798984906413732 , 7.302622441699035e-149
# guf_mean , fourier_sc71_mean_std , -0.6303140966908208 , 2.511384043908478e-81
# guf_mean , fourier_sc71_mean_sum , -0.23728684299027752 , 1.0346860813575387e-10
# guf_mean , fourier_sc51_mean_mean , 0.7889228438322723 , 1.2467057744687107e-154
# guf_mean , fourier_sc51_mean_std , -0.6799596376807764 , 3.063311194116338e-99
# guf_mean , fourier_sc51_mean_sum , -0.23891688124834207 , 7.640700334534671e-11
# guf_mean , fourier_sc31_mean_mean , 0.8027781328674961 , 4.638625859734778e-164
# guf_mean , fourier_sc31_mean_std , -0.7182128859013315 , 1.1424101839172244e-115
# guf_mean , fourier_sc31_mean_sum , -0.24078827391621258 , 5.3797609073378695e-11
# guf_mean , fourier_sc51_variance_mean , 0.5527351640720256 , 4.447875174699084e-59
# guf_mean , fourier_sc51_variance_std , -0.6607246952102654 , 6.814215951816193e-92
# guf_mean , fourier_sc51_variance_sum , -0.24937547036940247 , 1.0352806373441077e-11
# guf_mean , fourier_sc71_variance_mean , 0.5590785015637771 , 1.109647975405459e-60
# guf_mean , fourier_sc71_variance_std , -0.6289923032373917 , 6.8016969815058305e-81
# guf_mean , fourier_sc71_variance_sum , -0.2478110537909498 , 1.404356044416527e-11
# guf_mean , gabor_sc3_filter_5_mean , 0.8169009110973628 , 1.768624283967679e-174
# guf_mean , gabor_sc3_filter_5_std , 0.3940230451800996 , 2.876313632300602e-28
# guf_mean , gabor_sc3_filter_5_sum , -0.2445020586112987 , 2.6581324703836592e-11
# guf_mean , gabor_sc3_filter_4_mean , 0.6915056737346656 , 6.288741121541019e-104
# guf_mean , gabor_sc3_filter_4_std , 0.457357116237536 , 1.1700369921827412e-38
# guf_mean , gabor_sc3_filter_4_sum , -0.20466659289772127 , 2.815017878467113e-08
# guf_mean , gabor_sc3_filter_7_mean , 0.8169575479958756 , 1.599741283719977e-174
# guf_mean , gabor_sc3_filter_7_std , 0.39611606615447414 , 1.4117803664918598e-28
# guf_mean , gabor_sc3_filter_7_sum , -0.24449886833872359 , 2.6597561698450386e-11
# guf_mean , gabor_sc3_filter_6_mean , 0.6914197346072034 , 6.827653296693437e-104
# guf_mean , gabor_sc3_filter_6_std , 0.4554508887901182 , 2.594724705692953e-38
# guf_mean , gabor_sc3_filter_6_sum , -0.20535930110575235 , 2.521613311878218e-08
# guf_mean , gabor_sc3_filter_1_mean , 0.81643038185932 , 4.065881929700927e-174
# guf_mean , gabor_sc3_filter_1_std , 0.39567563611031165 , 1.6405445055070659e-28
# guf_mean , gabor_sc3_filter_1_sum , -0.24451066239886818 , 2.653758370251173e-11
# guf_mean , gabor_sc3_mean_mean , 0.8161564262804443 , 6.594208223415478e-174
# guf_mean , gabor_sc3_mean_std , 0.39821052321038675 , 6.890687804062766e-29
# guf_mean , gabor_sc3_mean_sum , -0.24451441581534536 , 2.6518523652803966e-11
# guf_mean , gabor_sc3_filter_3_mean , 0.8166598819343499 , 2.7099066958186937e-174
# guf_mean , gabor_sc3_filter_3_std , 0.3930913313731228 , 3.941920745834159e-28
# guf_mean , gabor_sc3_filter_3_sum , -0.24451447291213574 , 2.6518233815526963e-11
# guf_mean , gabor_sc3_filter_2_mean , 0.6937120119103273 , 7.542477528974408e-105
# guf_mean , gabor_sc3_filter_2_std , 0.4631812671397579 , 9.948274825982456e-40
# guf_mean , gabor_sc3_filter_2_sum , -0.20402501469271658 , 3.1160688476969345e-08
# guf_mean , gabor_sc3_filter_9_mean , 0.8170228000517009 , 1.4250011659550254e-174
# guf_mean , gabor_sc3_filter_9_std , 0.39589243875442304 , 1.523684962408518e-28
# guf_mean , gabor_sc3_filter_9_sum , -0.24449425795724403 , 2.662104350112192e-11
# guf_mean , gabor_sc3_filter_13_mean , 0.8168141917287425 , 2.062255854579268e-174
# guf_mean , gabor_sc3_filter_13_std , 0.3951937768712456 , 1.9329979311705513e-28
# guf_mean , gabor_sc3_filter_13_sum , -0.24448015518249894 , 2.6692998171559895e-11
# guf_mean , gabor_sc3_filter_8_mean , 0.6925737211915937 , 2.2580857794105663e-104
# guf_mean , gabor_sc3_filter_8_std , 0.45364303174438453 , 5.496917001171738e-38
# guf_mean , gabor_sc3_filter_8_sum , -0.20611776135403906 , 2.2343304173003764e-08
# guf_mean , gabor_sc3_filter_10_mean , 0.694152509729957 , 4.927480832550041e-105
# guf_mean , gabor_sc3_filter_10_std , 0.4522778239939833 , 9.66111529208893e-38
# guf_mean , gabor_sc3_filter_10_sum , -0.2064307716063998 , 2.125249916392522e-08
# guf_mean , gabor_sc3_variance_mean , 0.6960010926497818 , 8.185743369749965e-106
# guf_mean , gabor_sc3_variance_std , 0.4647832330673074 , 5.008122147077387e-40
# guf_mean , gabor_sc3_variance_sum , -0.2044207419086875 , 2.9268935725168955e-08
# guf_mean , gabor_sc3_filter_11_mean , 0.8170686026397956 , 1.3138383039479017e-174
# guf_mean , gabor_sc3_filter_11_std , 0.3945688073461326 , 2.390335397765904e-28
# guf_mean , gabor_sc3_filter_11_sum , -0.24449730751331233 , 2.6605509098511283e-11
# guf_mean , gabor_sc3_filter_12_mean , 0.696521449038444 , 4.9265649366050485e-106
# guf_mean , gabor_sc3_filter_12_std , 0.4524776887237177 , 8.896973895246574e-38
# guf_mean , gabor_sc3_filter_12_sum , -0.20605365575637782 , 2.2573301991279544e-08
# guf_mean , gabor_sc3_filter_14_mean , 0.6993293854948361 , 3.1216053080935595e-107
# guf_mean , gabor_sc3_filter_14_std , 0.460510438673782 , 3.09883418338638e-39
# guf_mean , gabor_sc3_filter_14_sum , -0.204923469733579 , 2.702551124891584e-08
# guf_mean , gabor_sc5_filter_4_mean , 0.7785471950147786 , 5.0534662664260756e-148
# guf_mean , gabor_sc5_filter_4_std , 0.366102617283597 , 2.3713384192718684e-24
# guf_mean , gabor_sc5_filter_4_sum , -0.23425774882225234 , 1.8068804617556722e-10
# guf_mean , gabor_sc5_variance_mean , 0.7790153738189537 , 2.589362291158736e-148
# guf_mean , gabor_sc5_variance_std , 0.38416098146462835 , 7.684258515230463e-27
# guf_mean , gabor_sc5_variance_sum , -0.23424642415363572 , 1.810624385740715e-10
# guf_mean , gabor_sc5_mean_mean , 0.8162257050671842 , 5.835638563478149e-174
# guf_mean , gabor_sc5_mean_std , 0.3410503746611315 , 3.764720379764879e-21
# guf_mean , gabor_sc5_mean_sum , -0.24455743509494093 , 2.6301022117487242e-11
# guf_mean , gabor_sc5_filter_6_mean , 0.7789589631958359 , 2.806857033734583e-148
# guf_mean , gabor_sc5_filter_6_std , 0.36306508509968 , 6.0043615630201015e-24
# guf_mean , gabor_sc5_filter_6_sum , -0.23430903688925675 , 1.7900189640740523e-10
# guf_mean , gabor_sc5_filter_3_mean , 0.8175324334174396 , 5.76473212344423e-175
# guf_mean , gabor_sc5_filter_3_std , 0.30982268801256213 , 1.501960425734623e-17
# guf_mean , gabor_sc5_filter_3_sum , -0.24455286720450442 , 2.6324034006176533e-11
# guf_mean , gabor_sc5_filter_9_mean , 0.8188667296049149 , 5.319762139200946e-176
# guf_mean , gabor_sc5_filter_9_std , 0.3285544708469591 , 1.1669016943752951e-19
# guf_mean , gabor_sc5_filter_9_sum , -0.24452048312916233 , 2.6487741783506803e-11
# guf_mean , gabor_sc5_filter_8_mean , 0.7806126176634459 , 2.6126786796270473e-149
# guf_mean , gabor_sc5_filter_8_std , 0.3650366219243646 , 3.2891352846994173e-24
# guf_mean , gabor_sc5_filter_8_sum , -0.2343584007167213 , 1.7739350197012512e-10
# guf_mean , gabor_sc5_filter_2_mean , 0.7783996020073249 , 6.237193700426511e-148
# guf_mean , gabor_sc5_filter_2_std , 0.3788041938789473 , 4.369763537507921e-26
# guf_mean , gabor_sc5_filter_2_sum , -0.23421584515220398 , 1.8207715977550643e-10
# guf_mean , gabor_sc5_filter_13_mean , 0.8186704571070739 , 7.562359670909532e-176
# guf_mean , gabor_sc5_filter_13_std , 0.32824284903538187 , 1.2686858332171655e-19
# guf_mean , gabor_sc5_filter_13_sum , -0.2444707913759996 , 2.6740878757552874e-11
# guf_mean , gabor_sc5_filter_12_mean , 0.7862254727312047 , 7.064061946352189e-153
# guf_mean , gabor_sc5_filter_12_std , 0.36289005737996033 , 6.33262879503478e-24
# guf_mean , gabor_sc5_filter_12_sum , -0.23429382786746772 , 1.7950030249438932e-10
# guf_mean , gabor_sc5_filter_11_mean , 0.818966746130005 , 4.446054751370389e-176
# guf_mean , gabor_sc5_filter_11_std , 0.31944015661416403 , 1.2944704254014185e-18
# guf_mean , gabor_sc5_filter_11_sum , -0.24450460177163738 , 2.656838814366657e-11
# guf_mean , gabor_sc5_filter_10_mean , 0.7835035048831089 , 3.914782564932339e-151
# guf_mean , gabor_sc5_filter_10_std , 0.3628924109536011 , 6.3280991115006225e-24
# guf_mean , gabor_sc5_filter_10_sum , -0.23438011871822056 , 1.766903478251386e-10
# guf_mean , gabor_sc5_filter_7_mean , 0.8183731412566247 , 1.2874044587499433e-175
# guf_mean , gabor_sc5_filter_7_std , 0.3342898902602827 , 2.4606007553698056e-20
# guf_mean , gabor_sc5_filter_7_sum , -0.24452556834937808 , 2.646196934883727e-11
# guf_mean , gabor_sc5_filter_1_mean , 0.8167392993561878 , 2.3546335703071213e-174
# guf_mean , gabor_sc5_filter_1_std , 0.32549133196544927 , 2.643801883100697e-19
# guf_mean , gabor_sc5_filter_1_sum , -0.24455753521626425 , 2.630051795145775e-11
# guf_mean , gabor_sc5_filter_5_mean , 0.8180425864387882 , 2.3233086410801938e-175
# guf_mean , gabor_sc5_filter_5_std , 0.3198095440718169 , 1.1760536449923268e-18
# guf_mean , gabor_sc5_filter_5_sum , -0.2445385571810783 , 2.6396251710290688e-11
# guf_mean , gabor_sc5_filter_14_mean , 0.7879116351889981 , 5.7023203913422484e-154
# guf_mean , gabor_sc5_filter_14_std , 0.3738873690172756 , 2.094384423673171e-25
# guf_mean , gabor_sc5_filter_14_sum , -0.234062731501619 , 1.8724198947302266e-10
# guf_mean , gabor_sc7_filter_9_mean , 0.8197202462459522 , 1.1465926976270666e-176
# guf_mean , gabor_sc7_filter_9_std , 0.31368231161300436 , 5.676692798010987e-18
# guf_mean , gabor_sc7_filter_9_sum , -0.2444968591480163 , 2.6607792510676405e-11
# guf_mean , gabor_sc7_mean_mean , 0.813801430791195 , 4.074452900495588e-172
# guf_mean , gabor_sc7_mean_std , 0.3445388399776767 , 1.4031569502322063e-21
# guf_mean , gabor_sc7_mean_sum , -0.2445389646176415 , 2.6394192845769993e-11
# guf_mean , gabor_sc7_variance_mean , 0.7745107364319985 , 1.5070120727180816e-145
# guf_mean , gabor_sc7_variance_std , 0.3529532371296873 , 1.232350330998624e-22
# guf_mean , gabor_sc7_variance_sum , -0.23424794144277403 , 1.8101223330375408e-10
# guf_mean , gabor_sc7_filter_1_mean , 0.8152807697091531 , 3.0765946876309064e-173
# guf_mean , gabor_sc7_filter_1_std , 0.3080976602434191 , 2.309479590421634e-17
# guf_mean , gabor_sc7_filter_1_sum , -0.24455077684654328 , 2.6334571264678406e-11
# guf_mean , gabor_sc7_filter_5_mean , 0.817937178613856 , 2.8038561672746933e-175
# guf_mean , gabor_sc7_filter_5_std , 0.29633618667544837 , 4.026041831871467e-16
# guf_mean , gabor_sc7_filter_5_sum , -0.2445220552066718 , 2.647977171098589e-11
# guf_mean , gabor_sc7_filter_3_mean , 0.8172752785694323 , 9.104459010894043e-175
# guf_mean , gabor_sc7_filter_3_std , 0.26734289095295377 , 2.681224989958296e-13
# guf_mean , gabor_sc7_filter_3_sum , -0.24455660867452372 , 2.6305183960233663e-11
# guf_mean , gabor_sc7_filter_2_mean , 0.7741926573752052 , 2.3492168234281935e-145
# guf_mean , gabor_sc7_filter_2_std , 0.3369375578865353 , 1.186133970778921e-20
# guf_mean , gabor_sc7_filter_2_sum , -0.23429661357993614 , 1.7940891241199175e-10
# guf_mean , gabor_sc7_filter_11_mean , 0.820903550553664 , 1.3475262903035537e-177
# guf_mean , gabor_sc7_filter_11_std , 0.28818036089592153 , 2.708470378295804e-15
# guf_mean , gabor_sc7_filter_11_sum , -0.244474912257121 , 2.6719796849749897e-11
# guf_mean , gabor_sc7_filter_10_mean , 0.7840850598587639 , 1.6684086726053996e-151
# guf_mean , gabor_sc7_filter_10_std , 0.32517734056537156 , 2.873495455956233e-19
# guf_mean , gabor_sc7_filter_10_sum , -0.23455121400411508 , 1.7124509939182067e-10
# guf_mean , gabor_sc7_filter_7_mean , 0.8182285160594645 , 1.6670805392332357e-175
# guf_mean , gabor_sc7_filter_7_std , 0.3328675556684768 , 3.630922502985592e-20
# guf_mean , gabor_sc7_filter_7_sum , -0.24449268555493192 , 2.6629056761478342e-11
# guf_mean , gabor_sc7_filter_4_mean , 0.7762561137608155 , 1.3016209926350932e-146
# guf_mean , gabor_sc7_filter_4_std , 0.3117741990848696 , 9.199799539863256e-18
# guf_mean , gabor_sc7_filter_4_sum , -0.23445550941596816 , 1.742704834849714e-10
# guf_mean , gabor_sc7_filter_12_mean , 0.7903143709146329 , 1.5176720531646281e-155
# guf_mean , gabor_sc7_filter_12_std , 0.3232326384054728 , 4.803518434806157e-19
# guf_mean , gabor_sc7_filter_12_sum , -0.23447121044908437 , 1.7377059826046926e-10
# guf_mean , gabor_sc7_filter_13_mean , 0.8200212468883894 , 6.660767306730873e-177
# guf_mean , gabor_sc7_filter_13_std , 0.316237859690026 , 2.9571582064566005e-18
# guf_mean , gabor_sc7_filter_13_sum , -0.24438716342077696 , 2.7172236357885175e-11
# guf_mean , gabor_sc7_filter_14_mean , 0.7907740730598666 , 7.54233639853935e-156
# guf_mean , gabor_sc7_filter_14_std , 0.3422318508772666 , 2.6988114404137686e-21
# guf_mean , gabor_sc7_filter_14_sum , -0.2339336421443036 , 1.917071759011309e-10
# guf_mean , gabor_sc7_filter_6_mean , 0.7763609472794356 , 1.122774309171815e-146
# guf_mean , gabor_sc7_filter_6_std , 0.31548339241814927 , 3.587356974409361e-18
# guf_mean , gabor_sc7_filter_6_sum , -0.23443817805657297 , 1.7482390268096508e-10
# guf_mean , gabor_sc7_filter_8_mean , 0.7776332739265918 , 1.855331119720676e-147
# guf_mean , gabor_sc7_filter_8_std , 0.3264053334116653 , 2.0733199468836504e-19
# guf_mean , gabor_sc7_filter_8_sum , -0.2344235873607449 , 1.752911361362884e-10
# guf_mean , hog_sc7_mean_mean , 0.1901371054808941 , 2.5945466887338854e-07
# guf_mean , hog_sc7_mean_std , -0.6298510526114142 , 3.5623322691455462e-81
# guf_mean , hog_sc7_mean_sum , -0.23430310831472853 , 1.7919601762914784e-10
# guf_mean , hog_sc5_kurtosis_mean , 0.8828977881013811 , 6.599352061137273e-239
# guf_mean , hog_sc5_kurtosis_std , 0.4842995139040847 , 8.68159494971565e-44
# guf_mean , hog_sc5_kurtosis_sum , -0.2466660086838402 , 1.7531668530237423e-11
# guf_mean , hog_sc5_skew_mean , 0.8397708156753487 , 2.0187753722779731e-193
# guf_mean , hog_sc5_skew_std , 0.744305479685806 , 1.5455680125436336e-128
# guf_mean , hog_sc5_skew_sum , -0.2393599642364231 , 7.033522067133021e-11
# guf_mean , hog_sc7_variance_mean , -0.8089925184377013 , 1.5458880857564212e-168
# guf_mean , hog_sc7_variance_std , -0.8229841082439842 , 3.0046413731445792e-179
# guf_mean , hog_sc7_variance_sum , -0.2310208628453752 , 3.250722487171171e-10
# guf_mean , hog_sc7_skew_mean , 0.813321049013013 , 9.381184440375569e-172
# guf_mean , hog_sc7_skew_std , 0.672400335336402 , 2.7538539142424825e-96
# guf_mean , hog_sc7_skew_sum , -0.24395027879111852 , 2.9538588446564086e-11
# guf_mean , hog_sc5_mean_mean , 0.36767318191857035 , 1.4610868624615942e-24
# guf_mean , hog_sc5_mean_std , -0.7447200944521439 , 9.375200339806555e-129
# guf_mean , hog_sc5_mean_sum , -0.232918221368187 , 2.3064152794851475e-10
# guf_mean , hog_sc3_skew_mean , 0.8107957833336044 , 7.229375651573346e-170
# guf_mean , hog_sc3_skew_std , -0.842367132703091 , 9.265083965170366e-196
# guf_mean , hog_sc3_skew_sum , -0.2361691736235692 , 1.2721388505903945e-10
# guf_mean , hog_sc5_max_mean , -0.7299056702125221 , 3.0021951145036222e-121
# guf_mean , hog_sc5_max_std , -0.8066150480605356 , 8.341915450782748e-167
# guf_mean , hog_sc5_max_sum , -0.23235237593192457 , 2.555773401283429e-10
# guf_mean , hog_sc5_variance_mean , -0.8199705781690755 , 7.2989885375376054e-177
# guf_mean , hog_sc5_variance_std , -0.837229229962126 , 3.5801945734171176e-191
# guf_mean , hog_sc5_variance_sum , -0.23061145863549923 , 3.4992023073293626e-10
# guf_mean , hog_sc7_kurtosis_mean , 0.8734704142587172 , 1.4481707625020977e-227
# guf_mean , hog_sc7_kurtosis_std , 0.4493063110028665 , 3.2679316968554434e-37
# guf_mean , hog_sc7_kurtosis_sum , -0.2511428431647604 , 7.317529838341076e-12
# guf_mean , hog_sc3_max_mean , 0.2209199555407854 , 1.921547517535139e-09
# guf_mean , hog_sc3_max_std , -0.8348954618044744 , 3.845348212919349e-189
# guf_mean , hog_sc3_max_sum , -0.2323017723053733 , 2.5793123024340007e-10
# guf_mean , hog_sc3_variance_mean , -0.43679973981280734 , 4.845393494242762e-35
# guf_mean , hog_sc3_variance_std , -0.8550338368891305 , 8.280946405392493e-208
# guf_mean , hog_sc3_variance_sum , -0.2311397733989785 , 3.1818329707825115e-10
# guf_mean , hog_sc3_kurtosis_mean , 0.8391802033394967 , 6.778940129331259e-193
# guf_mean , hog_sc3_kurtosis_std , 0.45044462052158096 , 2.0518683840833873e-37
# guf_mean , hog_sc3_kurtosis_sum , -0.23838728487650626 , 8.433749225336894e-11
# guf_mean , hog_sc7_max_mean , -0.7786155179223653 , 4.584111477509882e-148
# guf_mean , hog_sc7_max_std , -0.8025340324171717 , 6.902047802112642e-164
# guf_mean , hog_sc7_max_sum , -0.23363450154422147 , 2.0245715825885583e-10
# guf_mean , hog_sc3_mean_mean , 0.6777908383975565 , 2.2014723396456672e-98
# guf_mean , hog_sc3_mean_std , -0.8577047372379341 , 1.7002743949856996e-210
# guf_mean , hog_sc3_mean_sum , -0.23370391489761516 , 1.9991152534428033e-10
# guf_mean , lac_sc3_lac_mean , 0.8552426549668611 , 5.127571236420418e-208
# guf_mean , lac_sc3_lac_std , 0.8110715436376973 , 4.5127488679924785e-170
# guf_mean , lac_sc3_lac_sum , -0.10387369927632828 , 0.00517781698916016
# guf_mean , lac_sc5_lac_mean , 0.7827943144944859 , 1.103713139621028e-150
# guf_mean , lac_sc5_lac_std , 0.682454579126866 , 3.102054342444931e-100
# guf_mean , lac_sc5_lac_sum , -0.14774908021955865 , 6.668697998368539e-05
# guf_mean , lac_sc7_lac_mean , 0.6813655527728869 , 8.452439828014484e-100
# guf_mean , lac_sc7_lac_std , 0.5991875497598028 , 1.1487636144110269e-71
# guf_mean , lac_sc7_lac_sum , -0.14655558838400287 , 7.645784204669011e-05
# guf_mean , lbpm_sc7_mean_mean , -0.4270017438835763 , 2.108808706450928e-33
# guf_mean , lbpm_sc7_mean_std , -0.654113804567455 , 1.7164052859619472e-89
# guf_mean , lbpm_sc7_mean_sum , -0.14922271165588585 , 5.6246281783902726e-05
# guf_mean , lbpm_sc5_variance_mean , -0.6006773998285246 , 4.1870673510498366e-72
# guf_mean , lbpm_sc5_variance_std , -0.7545637609494327 , 4.903994615597833e-134
# guf_mean , lbpm_sc5_variance_sum , -0.10749582654573207 , 0.0038060266468707975
# guf_mean , lbpm_sc3_max_mean , -0.44825457611047054 , 5.015864173681376e-37
# guf_mean , lbpm_sc3_max_std , -0.3355254516984907 , 1.7520071062377134e-20
# guf_mean , lbpm_sc3_max_sum , -0.13533053867870562 , 0.00026289293244753653
# guf_mean , lbpm_sc5_skew_mean , 0.7096129826065707 , 9.641591535008352e-112
# guf_mean , lbpm_sc5_skew_std , -0.5074950024075742 , 1.3834288280626182e-48
# guf_mean , lbpm_sc5_skew_sum , -0.2288573158997272 , 4.790120565351013e-10
# guf_mean , lbpm_sc5_mean_mean , -0.6090370598753244 , 1.3155463461010941e-74
# guf_mean , lbpm_sc5_mean_std , -0.6131685371168956 , 7.151602066569236e-76
# guf_mean , lbpm_sc5_mean_sum , -0.1494735058715655 , 5.4631066465068745e-05
# guf_mean , lbpm_sc3_mean_mean , -0.4052150192637443 , 6.028114255287847e-30
# guf_mean , lbpm_sc3_mean_std , 0.07635066576245907 , 0.04012970085963241
# guf_mean , lbpm_sc3_mean_sum , -0.1501266162662087 , 5.0628093897320926e-05
# guf_mean , lbpm_sc7_skew_mean , 0.6748968472492812 , 2.9799059411054754e-97
# guf_mean , lbpm_sc7_skew_std , -0.4843569633841659 , 8.45601959755397e-44
# guf_mean , lbpm_sc7_skew_sum , -0.23275436161880614 , 2.3760768363182563e-10
# guf_mean , lbpm_sc7_kurtosis_mean , 0.6965045025003337 , 5.0087943156955385e-106
# guf_mean , lbpm_sc7_kurtosis_std , -0.1641234848366331 , 9.18436142818924e-06
# guf_mean , lbpm_sc7_kurtosis_sum , -0.24539032248745013 , 2.2417641011062307e-11
# guf_mean , lbpm_sc7_max_mean , -0.2246260879942983 , 1.0110146009468536e-09
# guf_mean , lbpm_sc7_max_std , -0.739630403528403 , 4.058336919931098e-126
# guf_mean , lbpm_sc7_max_sum , -0.13063420449047453 , 0.00042894700665369214
# guf_mean , lbpm_sc3_skew_mean , 0.7422023450825082 , 1.922738491756913e-127
# guf_mean , lbpm_sc3_skew_std , -0.6363933236895922 , 2.4127656327985004e-83
# guf_mean , lbpm_sc3_skew_sum , -0.21567884985360314 , 4.674445014397888e-09
# guf_mean , lbpm_sc3_kurtosis_mean , 0.7722087346901709 , 3.6847301211554716e-144
# guf_mean , lbpm_sc3_kurtosis_std , 0.07156620754844795 , 0.05442273435842092
# guf_mean , lbpm_sc3_kurtosis_sum , -0.231629662102448 , 2.912721311079114e-10
# guf_mean , lbpm_sc5_max_mean , -0.3309216730739404 , 6.162573662554049e-20
# guf_mean , lbpm_sc5_max_std , -0.6568113249276958 , 1.8287610742733912e-90
# guf_mean , lbpm_sc5_max_sum , -0.13203316565907583 , 0.0003713536124254544
# guf_mean , lbpm_sc7_variance_mean , -0.5667373441854434 , 1.1564752868018083e-62
# guf_mean , lbpm_sc7_variance_std , -0.7379139509725048 , 3.044623436717486e-125
# guf_mean , lbpm_sc7_variance_sum , -0.10444996070297302 , 0.004933360870003282
# guf_mean , lbpm_sc5_kurtosis_mean , 0.7350156696179657 , 8.82615132058135e-124
# guf_mean , lbpm_sc5_kurtosis_std , -0.08204891316070473 , 0.027377800054256815
# guf_mean , lbpm_sc5_kurtosis_sum , -0.24369687775652846 , 3.1002126136823224e-11
# guf_mean , lbpm_sc3_variance_mean , -0.6428687314541548 , 1.524518683460518e-85
# guf_mean , lbpm_sc3_variance_std , -0.7861122572171856 , 8.357711240842372e-153
# guf_mean , lbpm_sc3_variance_sum , -0.11452928675672344 , 0.0020398715691186545
# guf_mean , lsr_sc71_line_contrast_mean , 0.3838229817030387 , 8.583147585950837e-27
# guf_mean , lsr_sc71_line_contrast_std , -0.5033661595752482 , 1.0522632843228252e-47
# guf_mean , lsr_sc71_line_contrast_sum , -0.21337806814629684 , 6.857272082032833e-09
# guf_mean , lsr_sc71_line_length_mean , 0.34310098734522915 , 2.1107273428770488e-21
# guf_mean , lsr_sc71_line_length_std , -0.48919733644750635 , 9.036432953559439e-45
# guf_mean , lsr_sc71_line_length_sum , -0.21490432291433506 , 5.3206113853270546e-09
# guf_mean , lsr_sc31_line_mean_mean , 0.40371559562946907 , 1.020487861904652e-29
# guf_mean , lsr_sc31_line_mean_std , -0.46839519761198767 , 1.0514293043182166e-40
# guf_mean , lsr_sc31_line_mean_sum , -0.19011218655075587 , 2.6040770384286424e-07
# guf_mean , lsr_sc51_line_length_mean , 0.3463076732175767 , 8.466264668592278e-22
# guf_mean , lsr_sc51_line_length_std , -0.5269276539635291 , 6.721448685166171e-53
# guf_mean , lsr_sc51_line_length_sum , -0.21109757642552376 , 9.983212304159806e-09
# guf_mean , lsr_sc71_line_mean_mean , 0.39072845707613574 , 8.727016140268229e-28
# guf_mean , lsr_sc71_line_mean_std , -0.6698262484648259 , 2.6656897863163054e-95
# guf_mean , lsr_sc71_line_mean_sum , -0.20132684278490712 , 4.7601499423301394e-08
# guf_mean , lsr_sc31_line_contrast_mean , 0.35805162637230165 , 2.722632397584328e-23
# guf_mean , lsr_sc31_line_contrast_std , -0.5532378220905723 , 3.3295395007321506e-59
# guf_mean , lsr_sc31_line_contrast_sum , -0.2052047337181049 , 2.5843977798914632e-08
# guf_mean , lsr_sc31_line_length_mean , 0.3097224569139247 , 1.5401016000800227e-17
# guf_mean , lsr_sc31_line_length_std , -0.5420814450881073 , 1.8372678999273906e-56
# guf_mean , lsr_sc31_line_length_sum , -0.2058488467664984 , 2.3323586090569906e-08
# guf_mean , lsr_sc51_line_contrast_mean , 0.38687401082909845 , 3.1471833176034038e-27
# guf_mean , lsr_sc51_line_contrast_std , -0.5411289754143277 , 3.115376803583487e-56
# guf_mean , lsr_sc51_line_contrast_sum , -0.20979211734407527 , 1.235456491109738e-08
# guf_mean , lsr_sc51_line_mean_mean , 0.3932440582694723 , 3.743706438302229e-28
# guf_mean , lsr_sc51_line_mean_std , -0.6213074315098769 , 2.0296319140650291e-78
# guf_mean , lsr_sc51_line_mean_sum , -0.1968020951456618 , 9.562550649111151e-08
# guf_mean , mean_sc3_mean_mean , 0.8159341750964956 , 9.756119711237106e-174
# guf_mean , mean_sc3_mean_std , 0.45297175106702303 , 7.255721085968951e-38
# guf_mean , mean_sc3_mean_sum , -0.24448509767256857 , 2.666775917965549e-11
# guf_mean , mean_sc7_variance_mean , 0.7895171908240242 , 5.081319276531026e-155
# guf_mean , mean_sc7_variance_std , 0.3486438831200544 , 4.322565834222503e-22
# guf_mean , mean_sc7_variance_sum , -0.23424838839513287 , 1.809974467766065e-10
# guf_mean , mean_sc3_variance_mean , 0.7330665287653907 , 8.28607335931677e-123
# guf_mean , mean_sc3_variance_std , 0.5202840511160011 , 2.1559321139394573e-51
# guf_mean , mean_sc3_variance_sum , -0.1893454285779072 , 2.914387310231705e-07
# guf_mean , mean_sc7_mean_mean , 0.8180421146474448 , 2.3252651095223025e-175
# guf_mean , mean_sc7_mean_std , 0.2478170389087796 , 1.4027244041954671e-11
# guf_mean , mean_sc7_mean_sum , -0.24449015744126412 , 2.6641945447865947e-11
# guf_mean , mean_sc5_variance_mean , 0.7847783218564681 , 6.015096491959997e-152
# guf_mean , mean_sc5_variance_std , 0.4184500715289646 , 5.140141848479678e-32
# guf_mean , mean_sc5_variance_sum , -0.23368937364948628 , 2.0044220720920956e-10
# guf_mean , mean_sc5_mean_mean , 0.8168861394609942 , 1.8155191941988493e-174
# guf_mean , mean_sc5_mean_std , 0.3420279348311791 , 2.858690521750614e-21
# guf_mean , mean_sc5_mean_sum , -0.24448773629713705 , 2.665429450035202e-11
# guf_mean , ndvi_sc3_variance_mean , 0.7207834122075377 , 7.170847710838298e-117
# guf_mean , ndvi_sc3_variance_std , 0.23644444321987443 , 1.2091446291208903e-10
# guf_mean , ndvi_sc3_variance_sum , -0.2716595154545172 , 1.0686085322916271e-13
# guf_mean , ndvi_sc3_mean_mean , -0.7133477027029955 , 1.980975822382824e-113
# guf_mean , ndvi_sc3_mean_std , -0.16412613595656012 , 9.181264944664388e-06
# guf_mean , ndvi_sc3_mean_sum , -0.18908065472111968 , 3.029595565962666e-07
# guf_mean , ndvi_sc7_mean_mean , -0.7122044682212473 , 6.549945064754475e-113
# guf_mean , ndvi_sc7_mean_std , -0.31639605821307837 , 2.8395649113772243e-18
# guf_mean , ndvi_sc7_mean_sum , -0.189086509361422 , 3.0270013001126747e-07
# guf_mean , ndvi_sc7_variance_mean , -0.7688323714718521 , 3.743801755137938e-142
# guf_mean , ndvi_sc7_variance_std , -0.6043795495406716 , 3.3317594027685493e-73
# guf_mean , ndvi_sc7_variance_sum , -0.205641222171375 , 2.4108817431231848e-08
# guf_mean , ndvi_sc5_variance_mean , -0.7409480204752249 , 8.546878661183005e-127
# guf_mean , ndvi_sc5_variance_std , -0.35862697507222896 , 2.2921230026260596e-23
# guf_mean , ndvi_sc5_variance_sum , -0.20733968722862955 , 1.8369449890631157e-08
# guf_mean , ndvi_sc5_mean_mean , -0.7127649726969882 , 3.646912316591486e-113
# guf_mean , ndvi_sc5_mean_std , -0.25555171935545506 , 3.04339280910785e-12
# guf_mean , ndvi_sc5_mean_sum , -0.18908284975495313 , 3.028622667513232e-07
# guf_mean , orb_sc71_skew_mean , -0.40198595540401244 , 1.8667776025367173e-29
# guf_mean , orb_sc71_skew_std , -0.6753646046148147 , 1.9597325931728442e-97
# guf_mean , orb_sc71_skew_sum , -0.1391547222097267 , 0.0001743921249140702
# guf_mean , orb_sc71_mean_mean , 0.6301330924525799 , 2.8793261342869563e-81
# guf_mean , orb_sc71_mean_std , 0.28600476893855387 , 4.45715891237077e-15
# guf_mean , orb_sc71_mean_sum , -0.16592847183217524 , 7.291390524761595e-06
# guf_mean , orb_sc31_max_mean , 0.5981093055319926 , 2.3769592671506554e-71
# guf_mean , orb_sc31_max_std , 0.4036805978584588 , 1.0330712196313847e-29
# guf_mean , orb_sc31_max_sum , -0.1715811104533772 , 3.483146918578827e-06
# guf_mean , orb_sc71_variance_mean , 0.4915506216824421 , 3.007388810584711e-45
# guf_mean , orb_sc71_variance_std , 0.36419252470719177 , 4.2580858136724796e-24
# guf_mean , orb_sc71_variance_sum , -0.15278545614312758 , 3.702013989718166e-05
# guf_mean , orb_sc51_skew_mean , -0.08965640254012472 , 0.015890228366010607
# guf_mean , orb_sc51_skew_std , -0.47592256061233656 , 3.8259584128253055e-42
# guf_mean , orb_sc51_skew_sum , -0.14172174741669005 , 0.00013160874494947967
# guf_mean , orb_sc31_variance_mean , 0.43004816018429015 , 6.611003506769561e-34
# guf_mean , orb_sc31_variance_std , 0.34187777973650885 , 2.9823613885750614e-21
# guf_mean , orb_sc31_variance_sum , -0.16498801582170813 , 8.22566474287214e-06
# guf_mean , orb_sc31_mean_mean , 0.5347869564571006 , 1.0046106907601572e-54
# guf_mean , orb_sc31_mean_std , 0.4287906289719607 , 1.0686655783338382e-33
# guf_mean , orb_sc31_mean_sum , -0.16778000202567417 , 5.739539853361997e-06
# guf_mean , orb_sc31_kurtosis_mean , 0.37452503021130307 , 1.711775689582019e-25
# guf_mean , orb_sc31_kurtosis_std , 0.22273390669215004 , 1.4052684322007083e-09
# guf_mean , orb_sc31_kurtosis_sum , -0.15352245678808174 , 3.3911798369367206e-05
# guf_mean , orb_sc31_skew_mean , 0.42301156178809024 , 9.465370729700824e-33
# guf_mean , orb_sc31_skew_std , 0.24221015974328974 , 4.112761631020615e-11
# guf_mean , orb_sc31_skew_sum , -0.1520768902536333 , 4.0261593888623514e-05
# guf_mean , orb_sc51_max_mean , 0.6281500523912995 , 1.2801104379873846e-80
# guf_mean , orb_sc51_max_std , 0.3486583345907995 , 4.304552342302339e-22
# guf_mean , orb_sc51_max_sum , -0.16965847221730013 , 4.490346468161007e-06
# guf_mean , orb_sc51_mean_mean , 0.5888146605667565 , 1.1199116201518566e-68
# guf_mean , orb_sc51_mean_std , 0.3450484844187385 , 1.2134766337172613e-21
# guf_mean , orb_sc51_mean_sum , -0.16664590354765613 , 6.647705873856631e-06
# guf_mean , orb_sc51_kurtosis_mean , -0.14127878814420416 , 0.0001382061598173951
# guf_mean , orb_sc51_kurtosis_std , -0.4905583561602763 , 4.7875268524517844e-45
# guf_mean , orb_sc51_kurtosis_sum , -0.1417364764799163 , 0.0001313945432286124
# guf_mean , orb_sc51_variance_mean , 0.4590210433286618 , 5.8140975842212557e-39
# guf_mean , orb_sc51_variance_std , 0.3565431403486257 , 4.2682630510985397e-23
# guf_mean , orb_sc51_variance_sum , -0.15836719459235457 , 1.886322252921748e-05
# guf_mean , orb_sc71_kurtosis_mean , -0.42428286014589367 , 5.879239725363786e-33
# guf_mean , orb_sc71_kurtosis_std , -0.6759887115476079 , 1.11899975122027e-97
# guf_mean , orb_sc71_kurtosis_sum , -0.13941050586614767 , 0.00016960547486102078
# guf_mean , orb_sc71_max_mean , 0.6465867245724383 , 7.8720057373251e-87
# guf_mean , orb_sc71_max_std , 0.32740669560264535 , 1.587089350136251e-19
# guf_mean , orb_sc71_max_sum , -0.168620719951533 , 5.144137734950066e-06
# guf_mean , pantex_sc5_min_mean , 0.8027667208144179 , 4.725671380588525e-164
# guf_mean , pantex_sc5_min_std , 0.539198849657419 , 9.036624610983093e-56
# guf_mean , pantex_sc5_min_sum , -0.255641745836707 , 2.98883651896878e-12
# guf_mean , pantex_sc7_min_mean , 0.8000407450089876 , 3.8731915979798696e-162
# guf_mean , pantex_sc7_min_std , 0.46633748679963877 , 2.564277276649976e-40
# guf_mean , pantex_sc7_min_sum , -0.25540061369385225 , 3.137161485371024e-12
# guf_mean , pantex_sc3_min_mean , 0.7706653700456093 , 3.0765009667209524e-143
# guf_mean , pantex_sc3_min_std , 0.7067615981356427 , 1.7963061967904613e-110
# guf_mean , pantex_sc3_min_sum , -0.2672609333836533 , 2.7280310499291184e-13
# guf_mean , sfs_sc31_max_ratio_of_orthgonal_angles_mean , -0.8477793078879524 , 8.98320196939287e-201
# guf_mean , sfs_sc31_max_ratio_of_orthgonal_angles_std , -0.334740824773877 , 2.174125714690035e-20
# guf_mean , sfs_sc31_max_ratio_of_orthgonal_angles_sum , -0.15152799258314825 , 4.295548133286669e-05
# guf_mean , sfs_sc71_std_mean , -0.04500867898770963 , 0.22676213411998347
# guf_mean , sfs_sc71_std_std , nan , 1.0
# guf_mean , sfs_sc71_std_sum , -0.05552468085484786 , 0.1358167034059308
# guf_mean , sfs_sc51_min_line_length_mean , -0.2131817074288956 , 7.083835097071378e-09
# guf_mean , sfs_sc51_min_line_length_std , -0.2583349514368129 , 1.7341145120895885e-12
# guf_mean , sfs_sc51_min_line_length_sum , -0.1339809923379875 , 0.00030310015600049176
# guf_mean , sfs_sc51_max_line_length_mean , -0.5132645444246543 , 7.748956305188191e-50
# guf_mean , sfs_sc51_max_line_length_std , -0.8519452689659596 , 9.106808335610317e-205
# guf_mean , sfs_sc51_max_line_length_sum , -0.2718545090028315 , 1.0247120210052955e-13
# guf_mean , sfs_sc31_mean_mean , 0.7178179214223156 , 1.7432442253869594e-115
# guf_mean , sfs_sc31_mean_std , -0.42997655871141327 , 6.794645657040345e-34
# guf_mean , sfs_sc31_mean_sum , -0.18520410303876766 , 5.311113030872726e-07
# guf_mean , sfs_sc71_max_line_length_mean , -0.7453100188373579 , 4.5956530076442394e-129
# guf_mean , sfs_sc71_max_line_length_std , -0.8399599604353477 , 1.3682312504797564e-193
# guf_mean , sfs_sc71_max_line_length_sum , -0.27153785032014754 , 1.0969263364694231e-13
# guf_mean , sfs_sc71_mean_mean , -0.5642963826185933 , 5.0172727940080856e-62
# guf_mean , sfs_sc71_mean_std , -0.8557951694744546 , 1.437252765496549e-208
# guf_mean , sfs_sc71_mean_sum , -0.283132595068398 , 8.546372238318116e-15
# guf_mean , sfs_sc31_min_line_length_mean , -0.2691529195263158 , 1.8267707149355797e-13
# guf_mean , sfs_sc31_min_line_length_std , -0.3224484256748925 , 5.903205656937708e-19
# guf_mean , sfs_sc31_min_line_length_sum , -0.14392000175840008 , 0.00010302534047228284
# guf_mean , sfs_sc71_w_mean_mean , -0.7553312423751021 , 1.8545475905717076e-134
# guf_mean , sfs_sc71_w_mean_std , -0.77477553970961 , 1.0407886658029599e-145
# guf_mean , sfs_sc71_w_mean_sum , -0.2729512263996244 , 8.088528418248226e-14
# guf_mean , sfs_sc51_mean_mean , -0.06187896425806077 , 0.09640116078336951
# guf_mean , sfs_sc51_mean_std , -0.8478356207788699 , 7.947740916249645e-201
# guf_mean , sfs_sc51_mean_sum , -0.23911772879359247 , 7.359383157706075e-11
# guf_mean , sfs_sc31_w_mean_mean , -0.633689024957784 , 1.929837278185937e-82
# guf_mean , sfs_sc31_w_mean_std , -0.7992142235629606 , 1.4535256733753424e-161
# guf_mean , sfs_sc31_w_mean_sum , -0.2767933929429293 , 3.501715636077462e-14
# guf_mean , sfs_sc51_max_ratio_of_orthgonal_angles_mean , -0.6985276200677543 , 6.885280566749333e-107
# guf_mean , sfs_sc51_max_ratio_of_orthgonal_angles_std , -0.3779984281167795 , 5.659705208479583e-26
# guf_mean , sfs_sc51_max_ratio_of_orthgonal_angles_sum , -0.1513798517263715 , 4.3711257813163086e-05
# guf_mean , sfs_sc31_max_line_length_mean , 0.5174097553581988 , 9.440778353814216e-51
# guf_mean , sfs_sc31_max_line_length_std , -0.7277850755972727 , 3.244007801200874e-120
# guf_mean , sfs_sc31_max_line_length_sum , -0.2273669453815971 , 6.242329629884431e-10
# guf_mean , sfs_sc51_w_mean_mean , -0.7641438503483956 , 2.0139197585116757e-139
# guf_mean , sfs_sc51_w_mean_std , -0.7894984988233453 , 5.22702282483099e-155
# guf_mean , sfs_sc51_w_mean_sum , -0.2774586554022317 , 3.0251181502796786e-14
# guf_mean , sfs_sc51_std_mean , -0.2204301852597535 , 2.0899774318997677e-09
# guf_mean , sfs_sc51_std_std , -0.8555709932589594 , 2.409527842915358e-208
# guf_mean , sfs_sc51_std_sum , -0.24586458012573062 , 2.0462934521923676e-11
# guf_mean , sfs_sc71_max_ratio_of_orthgonal_angles_mean , -0.7014743705183489 , 3.7121719693858445e-108
# guf_mean , sfs_sc71_max_ratio_of_orthgonal_angles_std , -0.4903377961565976 , 5.307674139389784e-45
# guf_mean , sfs_sc71_max_ratio_of_orthgonal_angles_sum , -0.15110563997947918 , 4.5143544141024175e-05
# guf_mean , sfs_sc31_std_mean , 0.16331511158873105 , 1.0176436998778659e-05
# guf_mean , sfs_sc31_std_std , -0.7930269572450845 , 2.388623295104537e-157
# guf_mean , sfs_sc31_std_sum , -0.2366344369672528 , 1.1674511274474638e-10
# guf_mean , sfs_sc71_min_line_length_mean , -0.38970806255615115 , 1.2275982869876435e-27
# guf_mean , sfs_sc71_min_line_length_std , -0.5822232720032284 , 7.816262284813088e-67
# guf_mean , sfs_sc71_min_line_length_sum , -0.09892962866107005 , 0.007767438065339309

# %%
x_df.head(50)
# Out:
#                                            x_var    abs_r2
# 165                        hog_sc5_kurtosis_mean  0.882898
# 189                        hog_sc7_kurtosis_mean  0.873470
# 205                             hog_sc3_mean_std  0.857705
# 393                            sfs_sc71_mean_std  0.855795
# 416                             sfs_sc51_std_std  0.855571
# 207                             lac_sc3_lac_mean  0.855243
# 196                         hog_sc3_variance_std  0.855034
# 384                 sfs_sc51_max_line_length_std  0.851945
# 401                            sfs_sc51_mean_std  0.847836
# 377  sfs_sc31_max_ratio_of_orthgonal_angles_mean  0.847779
# 181                             hog_sc3_skew_std  0.842367
# 390                 sfs_sc71_max_line_length_std  0.839960
# 168                            hog_sc5_skew_mean  0.839771
# 198                        hog_sc3_kurtosis_mean  0.839180
# 187                         hog_sc5_variance_std  0.837229
# 193                              hog_sc3_max_std  0.834895
# 172                         hog_sc7_variance_std  0.822984
# 135                     gabor_sc7_filter_11_mean  0.820904
# 150                     gabor_sc7_filter_13_mean  0.820021
# 186                        hog_sc5_variance_mean  0.819971
# 114                      gabor_sc7_filter_9_mean  0.819720
# 96                      gabor_sc5_filter_11_mean  0.818967
# 81                       gabor_sc5_filter_9_mean  0.818867
# 90                      gabor_sc5_filter_13_mean  0.818670
# 102                      gabor_sc5_filter_7_mean  0.818373
# 141                      gabor_sc7_filter_7_mean  0.818229
# 108                      gabor_sc5_filter_5_mean  0.818043
# 296                           mean_sc7_mean_mean  0.818042
# 126                      gabor_sc7_filter_5_mean  0.817937
# 78                       gabor_sc5_filter_3_mean  0.817532
# 129                      gabor_sc7_filter_3_mean  0.817275
# 57                      gabor_sc3_filter_11_mean  0.817069
# 42                       gabor_sc3_filter_9_mean  0.817023
# 24                       gabor_sc3_filter_7_mean  0.816958
# 18                       gabor_sc3_filter_5_mean  0.816901
# 302                           mean_sc5_mean_mean  0.816886
# 45                      gabor_sc3_filter_13_mean  0.816814
# 105                      gabor_sc5_filter_1_mean  0.816739
# 36                       gabor_sc3_filter_3_mean  0.816660
# 30                       gabor_sc3_filter_1_mean  0.816430
# 72                           gabor_sc5_mean_mean  0.816226
# 33                           gabor_sc3_mean_mean  0.816156
# 287                           mean_sc3_mean_mean  0.815934
# 123                      gabor_sc7_filter_1_mean  0.815281
# 117                          gabor_sc7_mean_mean  0.813801
# 174                            hog_sc7_skew_mean  0.813321
# 208                              lac_sc3_lac_std  0.811072
# 180                            hog_sc3_skew_mean  0.810796
# 171                        hog_sc7_variance_mean  0.808993
# 184                              hog_sc5_max_std  0.806615

# %%
#check 

for key in y_dict.keys():
    print(key,len(y_dict[key]))
# Out:
# guf_mean 200

# %% [markdown]
# ### Correlation Significance

# %% [markdown]
# For each dependent variable y in the list of all dependent values, calibrate the model.
# Add new key to the output dictionary where y is the dependent variable curently being processed and the values are empty for now

# %%
#Initialize the output dictionary, Y_D, 
# with each key being a dependent variable and the values being the results of the analyses

Y_D = {}

Y_D[y_var]={}

#Dictionary Models is used to store each result object for later use if needed

Models ={}

#Get independent variables from the variable dictionary and store in list x_vars
x_vars = y_dict[y_var]


vars_df = pd.DataFrame()

vars_df[y_var] = spfeas_guf[y_var]


for x in x_vars:
    vars_df[x] = spfeas_guf[x]

# %%
vars_df.head()
# Out:
#           guf_mean  hog_sc5_kurtosis_mean  hog_sc7_kurtosis_mean  \
# OBJECTID
# 1            0.001               8572.192              16205.395
# 2            0.004              14905.479              36392.528
# 3            0.026              42670.318             111379.225
# 4            0.000              18403.911              46792.398
# 5            0.018              24319.113              52112.358
#
#           hog_sc3_mean_std  sfs_sc71_mean_std  sfs_sc51_std_std  \
# OBJECTID
# 1                    0.030              3.611             2.171
# 2                    0.034              3.900             2.543
# 3                    0.050              6.270             4.127
# 4                    0.037              4.205             2.718
# 5                    0.044              5.750             3.668
#
#           lac_sc3_lac_mean  hog_sc3_variance_std  \
# OBJECTID
# 1                    5.032                 0.020
# 2                    5.120                 0.021
# 3                    5.442                 0.031
# 4                    5.157                 0.023
# 5                    5.008                 0.028
#
#           sfs_sc51_max_line_length_std  sfs_sc51_mean_std  ...  \
# OBJECTID                                                   ...
# 1                                8.963              2.139  ...
# 2                               10.370              2.498  ...
# 3                               15.748              4.135  ...
# 4                               10.530              2.726  ...
# 5                               14.556              3.617  ...
#
#           lbpm_sc7_mean_mean  orb_sc71_kurtosis_mean  orb_sc31_skew_mean  \
# OBJECTID
# 1                      2.479               12832.994             139.765
# 2                      2.476               19176.402             236.600
# 3                      2.454               20623.241             369.236
# 4                      2.459               13397.685             147.771
# 5                      2.463               26168.934             315.683
#
#           mean_sc5_variance_std  lbpm_sc3_mean_mean  lsr_sc31_line_mean_mean  \
# OBJECTID
# 1                        41.083               0.456                    0.010
# 2                        61.521               0.457                    0.025
# 3                       102.843               0.456                    0.043
# 4                        60.128               0.454                    0.020
# 5                        69.789               0.455                    0.025
#
#           orb_sc31_max_std  orb_sc71_skew_mean  gabor_sc3_mean_std  \
# OBJECTID
# 1                    0.212             180.055               6.290
# 2                    0.410             268.037               7.223
# 3                    0.771             289.146              10.871
# 4                    0.233             187.422               7.259
# 5                    0.405             365.633               9.250
#
#           gabor_sc3_filter_7_std
# OBJECTID
# 1                          6.289
# 2                          7.224
# 3                         10.872
# 4                          7.258
# 5                          9.250
#
# [5 rows x 201 columns]

# %% [markdown]
# ### Scale/Normalize Data

# %%
#minmax_scaler = preprocessing.MinMaxScaler()
standard_scaler = preprocessing.StandardScaler()

names = vars_df.columns
scaled_df = standard_scaler.fit_transform(vars_df)
scaled_df = pd.DataFrame(scaled_df, columns=names)
scaled_df.head()
# Out:
#    guf_mean  hog_sc5_kurtosis_mean  hog_sc7_kurtosis_mean  hog_sc3_mean_std  \
# 0 -0.868299              -1.466496              -1.162112          0.228516
# 1 -0.868268              -1.431310              -1.140364          0.425437
# 2 -0.868036              -1.277054              -1.059579          1.213121
# 3 -0.868310              -1.411873              -1.129160          0.573127
# 4 -0.868120              -1.379010              -1.123429          0.917739
#
#    sfs_sc71_mean_std  sfs_sc51_std_std  lac_sc3_lac_mean  \
# 0          -0.442054         -1.010173         -0.769269
# 1          -0.303468         -0.697011         -0.757040
# 2           0.833038          0.636455         -0.712293
# 3          -0.157208         -0.549690         -0.751898
# 4           0.583678          0.250053         -0.772604
#
#    hog_sc3_variance_std  sfs_sc51_max_line_length_std  sfs_sc51_mean_std  ...  \
# 0             -1.098023                     -0.642303          -1.153309  ...
# 1             -0.977374                     -0.337376          -0.863187  ...
# 2              0.229116                      0.828153           0.459734  ...
# 3             -0.736076                     -0.302700          -0.678932  ...
# 4             -0.132831                      0.569821           0.041119  ...
#
#    lbpm_sc7_mean_mean  orb_sc71_kurtosis_mean  orb_sc31_skew_mean  \
# 0            9.684850               -0.265775           -0.833535
# 1            9.401002               -0.101278           -0.801510
# 2            7.319452               -0.063758           -0.757646
# 3            7.792531               -0.251131           -0.830887
# 4            8.170995                0.080052           -0.775356
#
#    mean_sc5_variance_std  lbpm_sc3_mean_mean  lsr_sc31_line_mean_mean  \
# 0              -0.306638            3.295182                -1.341674
# 1               0.149147            3.579990                -1.326100
# 2               1.070662            3.295182                -1.307411
# 3               0.118082            2.725567                -1.331291
# 4               0.333530            3.010374                -1.326100
#
#    orb_sc31_max_std  orb_sc71_skew_mean  gabor_sc3_mean_std  \
# 0         -1.052740           -0.314308            2.085719
# 1         -0.852036           -0.156482            2.656299
# 2         -0.486104           -0.118615            4.887247
# 3         -1.031454           -0.301092            2.678315
# 4         -0.857104            0.018591            3.895918
#
#    gabor_sc3_filter_7_std
# 0                2.092570
# 1                2.665430
# 2                4.900503
# 3                2.686262
# 4                3.906729
#
# [5 rows x 201 columns]

# %%
# #Create a new dataframe for scaled and centered values
# scaled_df = pd.DataFrame()

# #Scale and center the values
# scaled_df[y_var] = scale(pop_count, with_mean=True, with_std=True)


# for x in x_vars:
#     scaled_df[x] = scale(spfeas_world_pop_merged[x], with_mean=True, with_std=True)

# scaled_df = scaled_df.round(3)

# %%
# Y = preprocessing.minmax_scale(vars_df[y_var])
# name='pop_sum'
# Y = pd.DataFrame(Y)
# #X = pd.DataFrame()

# X = scaler.fit_transform(vars_df[x_vars])
# X = pd.DataFrame(X, columns=x_vars)
# Y.head()

# %%
#X.head()

# %% [markdown]
# ### Scale the variables

# %% [markdown]
# ### Set Elastic net's parameters

# %%
enet_result = ElasticNetCV(max_iter=1e8,
                    alphas = [0.0005, 0.001, 0.01, 0.03, 0.05, 0.1],
                    l1_ratio =[.1, .5, .7, .9, .95, .99, 1],
                    verbose= False,
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)

# %%
scaled_df.shape
# Out:
# (723, 201)

# %%
# Fit the mode

# %%
#Fit the model with the scaled data
enet_result.fit(scaled_df[x_vars],scaled_df[y_var])
#Append the model to the Models dictionary
Models[y_var] = enet_result

# %%
enet_result
# Out:
# ElasticNetCV(alphas=[0.0005, 0.001, 0.01, 0.03, 0.05, 0.1], copy_X=True, cv=5,
#        eps=0.001, fit_intercept=False,
#        l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=100000000.0,
#        n_alphas=100, n_jobs=-1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='random',
#        tol=0.0001, verbose=False)

# %%
opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_

#Print update to ensure that the script is progressing properly
print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[x_vars],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.90 Alpha: 0.01 l1_ratio: 0.1

# %% [markdown]
# Record the overall R squared score and optimal alpha
# and l1 ratio values and store them in the output dictionary

# %%
Y_D[y_var]['Total R2'] = enet_result.score(scaled_df[x_vars],scaled_df[y_var])
Y_D[y_var]['Alpha'] = opt_alpha
Y_D[y_var]['l1_ratio'] = opt_l1_ratio

# %% [markdown]
# ### Ten Fold Cross validated regression

# %%
#Create a list R2s to store out of sample R squared values

R2s = []

#Specify the number of trials to run

trials = 10

#Run the number of trials specified in trials, 
#for each trial 66% of the observations are randomly selected to train the model
#Testing is done on the remaining 33% of observations and the R squared values are recorded

for i in range(trials):    
    X_train, X_test, y_train, y_test = train_test_split(scaled_df[x_vars],scaled_df[y_var], test_size=0.34)
    enet_regr = ElasticNetCV(max_iter=1e8,
                    alphas = [opt_alpha],
                    l1_ratio =[opt_l1_ratio],
                    n_jobs = -1, 
                    cv=5, 
                    selection = 'random',
                    fit_intercept=False)
    enet_regr.fit(X_train,y_train)
    R2s.append(enet_regr.score(X_test,y_test))

#print("Mean R2: {:.2f} StDev: {:.4f}".format(mean(R2s),pstdev(R2s)))
#Record the out of sample R squared values
Y_D[y_var]['Sampling']={'trials':trials,'R2':mean(R2s),'StDev':pstdev(R2s),'R2s':R2s}
#coefs = [i for i in zip(list(scaled_df[x_vars].axes[1]),enet_result.coef_)]
#remaining = [i for i in coefs if abs(i[1])>0.0]
#Y_D[y_var]["Coefficients"]=remaining

# %%
Y_D[y_var]
# Out:
# {'Total R2': 0.9002250532222461,
#  'Alpha': 0.01,
#  'l1_ratio': 0.1,
#  'Sampling': {'trials': 10,
#   'R2': 0.8612523446563781,
#   'StDev': 0.023065739096964293,
#   'R2s': [0.8801373602764369,
#    0.8640005926204498,
#    0.8691959046162878,
#    0.8651283991546372,
#    0.8260838403089498,
#    0.8141135569186908,
#    0.8788506747647068,
#    0.8879644449102,
#    0.8496406743013571,
#    0.8774079986920645]}}

# %%
y_df = pd.DataFrame([i for i in zip(list(scaled_df[x_vars].axes[1]),enet_result.coef_)], 
                    columns=["features","Coeff"]).sort_values("Coeff", ascending=False)

y_df.head(25)
# Out:
#                                         features     Coeff
# 128                             lbpm_sc5_max_std  0.217399
# 69                        fourier_sc71_mean_mean  0.172057
# 159                        mean_sc3_variance_std  0.144940
# 88                              hog_sc5_mean_std  0.143438
# 55                              sfs_sc31_std_std  0.135279
# 56                      gabor_sc7_filter_14_mean  0.130393
# 98                        ndvi_sc3_variance_mean  0.099113
# 89                              hog_sc5_skew_std  0.090964
# 147                 sfs_sc71_min_line_length_std  0.090292
# 17                      gabor_sc7_filter_11_mean  0.089561
# 20                       gabor_sc7_filter_9_mean  0.077019
# 187                       orb_sc31_variance_mean  0.075994
# 171                       lsr_sc31_line_mean_std  0.075208
# 44                           gabor_sc7_mean_mean  0.072216
# 192                           orb_sc31_skew_mean  0.069145
# 0                          hog_sc5_kurtosis_mean  0.068860
# 5                               lac_sc3_lac_mean  0.066988
# 189                            orb_sc31_mean_std  0.060385
# 86                         lbpm_sc5_variance_std  0.058978
# 100                           sfs_sc31_mean_mean  0.056785
# 149                           sfs_sc71_mean_mean  0.056520
# 18                      gabor_sc7_filter_13_mean  0.054645
# 108  sfs_sc51_max_ratio_of_orthgonal_angles_mean  0.052114
# 105                           pantex_sc3_min_std  0.052020
# 59                           sfs_sc51_w_mean_std  0.050081

# %% [markdown]
# # Result
#
# At national Scale, with GUF we can explain, 86% varriation of built up surface/human settlement

# %% [markdown]
# HOG, NDIV, SFS and MEAN are significant

# %% [markdown]
# ## HOG

# %%
filter_var = [col for col in scaled_df if col.startswith('hog')]
X_train, X_test, y_train, y_test = train_test_split(scaled_df[filter_var],scaled_df[y_var], test_size=0.34)
enet_result.fit(X_train,y_train)

Models[y_var] = enet_result

opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_


print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[filter_var],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.83 Alpha: 0.001 l1_ratio: 0.1

# %% [markdown]
# ## GABOR

# %%
filter_var = [col for col in scaled_df if col.startswith('gabor')]
X_train, X_test, y_train, y_test = train_test_split(scaled_df[filter_var],scaled_df[y_var], test_size=0.34)
enet_result.fit(X_train,y_train)

Models[y_var] = enet_result

opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_


print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[filter_var],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.76 Alpha: 0.0005 l1_ratio: 0.1

# %%
filter_var = [col for col in scaled_df if col.startswith('lbpm')]
X_train, X_test, y_train, y_test = train_test_split(scaled_df[filter_var],scaled_df[y_var], test_size=0.34)
enet_result.fit(X_train,y_train)

Models[y_var] = enet_result

opt_alpha, opt_l1_ratio = enet_result.alpha_, enet_result.l1_ratio_


print("R2: {:.2f} Alpha: {} l1_ratio: {}"
      .format(enet_result.score(scaled_df[filter_var],scaled_df[y_var]),
              enet_result.alpha_, enet_result.l1_ratio_))
# Out:
# R2: 0.80 Alpha: 0.0005 l1_ratio: 1.0
